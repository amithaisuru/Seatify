# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (8.3.133)
# Requirement already satisfied: opencv-python in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: pillow>=7.1.2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import time

# %%
# Load the YOLOv8 model
model = YOLO('yolov8x.pt')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs

# %%
# Initialize video capture
cap = cv2.VideoCapture(r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4')

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    while cap.isOpened():
        print("Reading frame...")
        ret, frame = cap.read()

        # Perform detection on the current frame
        results = model(frame)  # Detect objects in the frame

        # Filter detections for 'person' and 'chair' classes
        # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

        # Process the results
        for result in results:

            boxes = result.boxes  # Get bounding boxes

            for box in boxes:
                class_id = box.cls[0].item()  # Get the class id of the detected object
                if class_id in person_and_chair:  # Check if it is a person or a chair
                    # Get the bounding box coordinates
                    x1, y1, x2, y2 = map(int, box.xyxy[0])

                    # Get the class ID and confidence score
                    class_id = box.cls[0].item()
                    confidence = box.conf[0].item()

                    # Get the class name
                    label = model.names[class_id]

                    # Print out the detected object details
                    print(
                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                    )
                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                    # Draw a bounding box around the object

                    # Define different colors for different objects
                    if label == "person":
                        color = (255, 0, 0)  # Blue color for human (person)
                    elif label == "chair":
                        color = (0, 0, 255)  # Red color for chair
                    else:
                        color = (0, 255, 0)  # Default green for other objects

                    # Draw a bounding box around the object with the selected color
                    cv2.rectangle(
                        frame, (x1, y1), (x2, y2), color, 2
                    )  # Bounding box with the chosen color

                    cv2.putText(
                        frame,
                        label,
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        (0, 255, 0),
                        2,
                    )

        if frame is not None and frame.size > 0:
            cv2.imshow("Video", frame)
        else:
            print("Warning: Empty frame encountered!")
            break

        # Press 'q' to quit the video window
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Video file opened successfully.
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 1 bowl, 7 chairs, 13 potted plants, 3 dining tables, 1 laptop, 1 book, 803.7ms
# Speed: 8.1ms preprocess, 803.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [394, 252, 514, 385]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 89, 666, 201]
#
# Detected chair (Class ID: 56.0) with confidence 0.85
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.67
# Bounding box coordinates: [735, 224, 767, 359]
#
# Detected person (Class ID: 0.0) with confidence 0.64
# Bounding box coordinates: [249, 142, 338, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [226, 187, 316, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.41
# Bounding box coordinates: [702, 140, 767, 242]
#
# Detected person (Class ID: 0.0) with confidence 0.40
# Bounding box coordinates: [249, 142, 392, 376]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 1 bowl, 7 chairs, 14 potted plants, 3 dining tables, 1 laptop, 779.1ms
# Speed: 5.4ms preprocess, 779.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 84, 509, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 251, 515, 385]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 89, 666, 200]
#
# Detected chair (Class ID: 56.0) with confidence 0.85
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.71
# Bounding box coordinates: [249, 142, 338, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.61
# Bounding box coordinates: [735, 224, 767, 359]
#
# Detected chair (Class ID: 56.0) with confidence 0.55
# Bounding box coordinates: [226, 187, 314, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.45
# Bounding box coordinates: [702, 141, 767, 243]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 1 bowl, 7 chairs, 13 potted plants, 3 dining tables, 1 laptop, 1 book, 670.7ms
# Speed: 2.4ms preprocess, 670.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 84, 509, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [394, 251, 515, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 89, 666, 200]
#
# Detected chair (Class ID: 56.0) with confidence 0.85
# Bounding box coordinates: [525, 219, 610, 320]
#
# Detected person (Class ID: 0.0) with confidence 0.74
# Bounding box coordinates: [249, 142, 338, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.64
# Bounding box coordinates: [735, 224, 767, 359]
#
# Detected chair (Class ID: 56.0) with confidence 0.59
# Bounding box coordinates: [225, 186, 313, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [703, 139, 767, 242]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 1 bowl, 7 chairs, 12 potted plants, 3 dining tables, 1 laptop, 662.3ms
# Speed: 1.9ms preprocess, 662.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 84, 510, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [394, 252, 515, 388]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 89, 666, 201]
#
# Detected chair (Class ID: 56.0) with confidence 0.87
# Bounding box coordinates: [525, 219, 611, 320]
#
# Detected person (Class ID: 0.0) with confidence 0.73
# Bounding box coordinates: [249, 142, 338, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.63
# Bounding box coordinates: [736, 225, 767, 359]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [226, 186, 314, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.44
# Bounding box coordinates: [703, 138, 767, 242]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 1 bowl, 8 chairs, 12 potted plants, 3 dining tables, 1 laptop, 648.0ms
# Speed: 2.2ms preprocess, 648.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [420, 84, 510, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [394, 252, 515, 385]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 89, 667, 201]
#
# Detected chair (Class ID: 56.0) with confidence 0.87
# Bounding box coordinates: [525, 220, 611, 320]
#
# Detected person (Class ID: 0.0) with confidence 0.70
# Bounding box coordinates: [249, 142, 338, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.58
# Bounding box coordinates: [226, 187, 314, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.55
# Bounding box coordinates: [736, 225, 767, 359]
#
# Detected chair (Class ID: 56.0) with confidence 0.38
# Bounding box coordinates: [704, 139, 767, 241]
#
# Detected person (Class ID: 0.0) with confidence 0.33
# Bounding box coordinates: [249, 143, 395, 375]
#
# Detected chair (Class ID: 56.0) with confidence 0.27
# Bounding box coordinates: [746, 224, 767, 282]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 1 bowl, 8 chairs, 12 potted plants, 3 dining tables, 1 laptop, 666.9ms
# Speed: 2.1ms preprocess, 666.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [394, 252, 515, 382]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [420, 85, 510, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 89, 667, 201]
#
# Detected chair (Class ID: 56.0) with confidence 0.87
# Bounding box coordinates: [525, 220, 611, 320]
#
# Detected person (Class ID: 0.0) with confidence 0.71
# Bounding box coordinates: [249, 142, 338, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.57
# Bounding box coordinates: [226, 186, 313, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.57
# Bounding box coordinates: [736, 225, 767, 359]
#
# Detected chair (Class ID: 56.0) with confidence 0.34
# Bounding box coordinates: [705, 138, 767, 241]
#
# Detected chair (Class ID: 56.0) with confidence 0.27
# Bounding box coordinates: [746, 224, 767, 283]
#
# Detected person (Class ID: 0.0) with confidence 0.27
# Bounding box coordinates: [249, 146, 395, 376]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 7 chairs, 12 potted plants, 3 dining tables, 1 laptop, 667.4ms
# Speed: 1.9ms preprocess, 667.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [394, 252, 515, 382]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 510, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 89, 667, 201]
#
# Detected chair (Class ID: 56.0) with confidence 0.87
# Bounding box coordinates: [525, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.73
# Bounding box coordinates: [249, 143, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.61
# Bounding box coordinates: [735, 225, 767, 359]
#
# Detected chair (Class ID: 56.0) with confidence 0.55
# Bounding box coordinates: [225, 186, 314, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [703, 139, 767, 241]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 1 bowl, 7 chairs, 11 potted plants, 3 dining tables, 1 laptop, 660.5ms
# Speed: 1.6ms preprocess, 660.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [394, 252, 515, 382]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [591, 89, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.87
# Bounding box coordinates: [525, 220, 611, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.73
# Bounding box coordinates: [249, 143, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.66
# Bounding box coordinates: [735, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [225, 186, 314, 337]
#
# Detected chair (Class ID: 56.0) with confidence 0.37
# Bounding box coordinates: [703, 140, 767, 242]
#
# Detected person (Class ID: 0.0) with confidence 0.26
# Bounding box coordinates: [248, 146, 394, 376]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 1 bowl, 7 chairs, 9 potted plants, 3 dining tables, 1 laptop, 645.7ms
# Speed: 1.9ms preprocess, 645.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [394, 253, 514, 382]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 89, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.86
# Bounding box coordinates: [525, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.77
# Bounding box coordinates: [249, 143, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.72
# Bounding box coordinates: [735, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.55
# Bounding box coordinates: [226, 186, 314, 338]
#
# Detected chair (Class ID: 56.0) with confidence 0.41
# Bounding box coordinates: [702, 141, 767, 243]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 1 bowl, 7 chairs, 10 potted plants, 3 dining tables, 1 laptop, 639.4ms
# Speed: 2.6ms preprocess, 639.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [393, 252, 514, 382]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 89, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.85
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.77
# Bounding box coordinates: [249, 143, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.69
# Bounding box coordinates: [735, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.52
# Bounding box coordinates: [225, 185, 313, 338]
#
# Detected chair (Class ID: 56.0) with confidence 0.46
# Bounding box coordinates: [702, 141, 767, 243]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 2 bowls, 7 chairs, 11 potted plants, 3 dining tables, 1 laptop, 629.0ms
# Speed: 1.6ms preprocess, 629.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 232]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 252, 514, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 666, 201]
#
# Detected chair (Class ID: 56.0) with confidence 0.85
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.72
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [735, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.54
# Bounding box coordinates: [225, 185, 313, 338]
#
# Detected chair (Class ID: 56.0) with confidence 0.38
# Bounding box coordinates: [703, 141, 767, 242]
#
# Detected person (Class ID: 0.0) with confidence 0.30
# Bounding box coordinates: [249, 145, 391, 376]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 7 chairs, 11 potted plants, 3 dining tables, 1 laptop, 631.7ms
# Speed: 2.1ms preprocess, 631.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 252, 514, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.86
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.76
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.52
# Bounding box coordinates: [226, 186, 313, 338]
#
# Detected chair (Class ID: 56.0) with confidence 0.40
# Bounding box coordinates: [738, 225, 767, 361]
#
# Detected chair (Class ID: 56.0) with confidence 0.38
# Bounding box coordinates: [702, 140, 767, 242]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 7 chairs, 11 potted plants, 3 dining tables, 1 laptop, 630.9ms
# Speed: 2.0ms preprocess, 630.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 253, 514, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.86
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.76
# Bounding box coordinates: [249, 143, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.51
# Bounding box coordinates: [226, 186, 313, 338]
#
# Detected chair (Class ID: 56.0) with confidence 0.47
# Bounding box coordinates: [737, 225, 767, 361]
#
# Detected chair (Class ID: 56.0) with confidence 0.38
# Bounding box coordinates: [702, 140, 767, 242]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 1 bowl, 8 chairs, 11 potted plants, 3 dining tables, 1 laptop, 625.2ms
# Speed: 2.7ms preprocess, 625.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 85, 509, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [591, 90, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [393, 252, 514, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.85
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.75
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.55
# Bounding box coordinates: [226, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.41
# Bounding box coordinates: [702, 141, 767, 243]
#
# Detected chair (Class ID: 56.0) with confidence 0.26
# Bounding box coordinates: [735, 225, 767, 417]
#
# Detected chair (Class ID: 56.0) with confidence 0.26
# Bounding box coordinates: [742, 225, 767, 359]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 2 bowls, 7 chairs, 11 potted plants, 3 dining tables, 1 laptop, 636.9ms
# Speed: 2.7ms preprocess, 636.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 252, 514, 382]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.78
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.73
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [226, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.44
# Bounding box coordinates: [702, 141, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [745, 224, 767, 285]
#
# Detected person (Class ID: 0.0) with confidence 0.31
# Bounding box coordinates: [248, 145, 386, 376]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 7 chairs, 12 potted plants, 3 dining tables, 1 laptop, 630.6ms
# Speed: 2.2ms preprocess, 630.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 382]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 666, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.80
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.78
# Bounding box coordinates: [248, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.60
# Bounding box coordinates: [225, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.46
# Bounding box coordinates: [701, 142, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.29
# Bounding box coordinates: [745, 224, 767, 285]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 7 chairs, 12 potted plants, 3 dining tables, 1 laptop, 625.7ms
# Speed: 2.0ms preprocess, 625.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 381]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 666, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.81
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.79
# Bounding box coordinates: [248, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.60
# Bounding box coordinates: [225, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.46
# Bounding box coordinates: [701, 142, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [745, 224, 767, 285]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 2 bowls, 7 chairs, 12 potted plants, 3 dining tables, 1 laptop, 625.8ms
# Speed: 2.3ms preprocess, 625.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 252, 514, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 666, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.79
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.74
# Bounding box coordinates: [248, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [225, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.45
# Bounding box coordinates: [703, 142, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [745, 225, 767, 285]
#
# Detected person (Class ID: 0.0) with confidence 0.30
# Bounding box coordinates: [247, 149, 385, 376]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 2 bowls, 7 chairs, 11 potted plants, 3 dining tables, 1 laptop, 632.0ms
# Speed: 1.7ms preprocess, 632.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 253, 514, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 666, 202]
#
# Detected person (Class ID: 0.0) with confidence 0.75
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.75
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [226, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.43
# Bounding box coordinates: [702, 141, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.42
# Bounding box coordinates: [745, 225, 767, 285]
#
# Detected person (Class ID: 0.0) with confidence 0.28
# Bounding box coordinates: [249, 143, 384, 376]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 7 chairs, 10 potted plants, 3 dining tables, 1 laptop, 633.5ms
# Speed: 1.8ms preprocess, 633.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 666, 202]
#
# Detected chair (Class ID: 56.0) with confidence 0.82
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.77
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.53
# Bounding box coordinates: [226, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.41
# Bounding box coordinates: [701, 141, 767, 245]
#
# Detected chair (Class ID: 56.0) with confidence 0.40
# Bounding box coordinates: [745, 225, 767, 284]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 8 chairs, 13 potted plants, 3 dining tables, 1 laptop, 637.7ms
# Speed: 1.6ms preprocess, 637.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 86, 509, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 90, 666, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.82
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.77
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.54
# Bounding box coordinates: [226, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.50
# Bounding box coordinates: [745, 224, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.41
# Bounding box coordinates: [702, 140, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.29
# Bounding box coordinates: [726, 346, 767, 428]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 7 chairs, 13 potted plants, 3 dining tables, 1 laptop, 705.9ms
# Speed: 2.1ms preprocess, 705.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 86, 509, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 385]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [591, 90, 666, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.83
# Bounding box coordinates: [524, 219, 611, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.76
# Bounding box coordinates: [249, 143, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.54
# Bounding box coordinates: [226, 186, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.48
# Bounding box coordinates: [745, 224, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [701, 139, 767, 245]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 7 chairs, 14 potted plants, 3 dining tables, 1 laptop, 668.8ms
# Speed: 2.2ms preprocess, 668.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 86, 509, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [394, 253, 514, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [591, 90, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.82
# Bounding box coordinates: [249, 143, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.81
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.54
# Bounding box coordinates: [229, 188, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.48
# Bounding box coordinates: [745, 224, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.37
# Bounding box coordinates: [701, 140, 767, 246]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 8 chairs, 13 potted plants, 3 dining tables, 1 laptop, 738.7ms
# Speed: 3.9ms preprocess, 738.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 86, 509, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [591, 90, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.84
# Bounding box coordinates: [249, 143, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.81
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.55
# Bounding box coordinates: [230, 188, 313, 338]
#
# Detected chair (Class ID: 56.0) with confidence 0.48
# Bounding box coordinates: [745, 224, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.37
# Bounding box coordinates: [701, 139, 767, 245]
#
# Detected chair (Class ID: 56.0) with confidence 0.25
# Bounding box coordinates: [707, 341, 767, 422]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 1 bowl, 8 chairs, 12 potted plants, 3 dining tables, 1 laptop, 719.4ms
# Speed: 5.8ms preprocess, 719.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [419, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 90, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.81
# Bounding box coordinates: [248, 144, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.77
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.54
# Bounding box coordinates: [228, 188, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.51
# Bounding box coordinates: [703, 336, 767, 417]
#
# Detected chair (Class ID: 56.0) with confidence 0.47
# Bounding box coordinates: [745, 224, 767, 285]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [701, 140, 767, 246]
# Reading frame...
#
# 0: 384x640 1 person, 1 backpack, 2 bowls, 8 chairs, 13 potted plants, 3 dining tables, 2 laptops, 710.0ms
# Speed: 5.2ms preprocess, 710.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 253, 514, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [591, 90, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.82
# Bounding box coordinates: [248, 144, 338, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.72
# Bounding box coordinates: [524, 220, 611, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.63
# Bounding box coordinates: [225, 187, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.42
# Bounding box coordinates: [745, 224, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [700, 141, 767, 246]
#
# Detected chair (Class ID: 56.0) with confidence 0.25
# Bounding box coordinates: [701, 333, 767, 412]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 2 bowls, 7 chairs, 11 potted plants, 3 dining tables, 2 laptops, 799.1ms
# Speed: 1.9ms preprocess, 799.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 253, 514, 385]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.83
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.73
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.61
# Bounding box coordinates: [226, 186, 313, 339]
#
# Detected person (Class ID: 0.0) with confidence 0.55
# Bounding box coordinates: [714, 353, 767, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [745, 225, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.36
# Bounding box coordinates: [700, 141, 767, 244]
# Reading frame...
#
# 0: 384x640 3 persons, 1 backpack, 2 bowls, 7 chairs, 11 potted plants, 3 dining tables, 2 laptops, 691.3ms
# Speed: 2.0ms preprocess, 691.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 253, 514, 388]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.83
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.71
# Bounding box coordinates: [523, 219, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.61
# Bounding box coordinates: [226, 187, 314, 339]
#
# Detected person (Class ID: 0.0) with confidence 0.53
# Bounding box coordinates: [711, 344, 767, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.37
# Bounding box coordinates: [745, 225, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.35
# Bounding box coordinates: [701, 140, 767, 244]
#
# Detected person (Class ID: 0.0) with confidence 0.26
# Bounding box coordinates: [711, 225, 767, 429]
# Reading frame...
#
# 0: 384x640 3 persons, 1 backpack, 1 bowl, 7 chairs, 11 potted plants, 3 dining tables, 2 laptops, 638.1ms
# Speed: 1.8ms preprocess, 638.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 233]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.82
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.73
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.62
# Bounding box coordinates: [225, 187, 313, 339]
#
# Detected person (Class ID: 0.0) with confidence 0.53
# Bounding box coordinates: [709, 326, 767, 429]
#
# Detected chair (Class ID: 56.0) with confidence 0.38
# Bounding box coordinates: [700, 142, 767, 247]
#
# Detected chair (Class ID: 56.0) with confidence 0.31
# Bounding box coordinates: [745, 225, 767, 283]
#
# Detected person (Class ID: 0.0) with confidence 0.30
# Bounding box coordinates: [708, 224, 767, 428]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 10 potted plants, 3 dining tables, 2 laptops, 640.3ms
# Speed: 2.1ms preprocess, 640.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 666, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.80
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.80
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.59
# Bounding box coordinates: [224, 187, 314, 339]
#
# Detected person (Class ID: 0.0) with confidence 0.58
# Bounding box coordinates: [702, 315, 767, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.46
# Bounding box coordinates: [745, 225, 767, 284]
#
# Detected chair (Class ID: 56.0) with confidence 0.36
# Bounding box coordinates: [700, 143, 767, 245]
# Reading frame...
#
# 0: 384x640 3 persons, 1 backpack, 1 bowl, 7 chairs, 11 potted plants, 3 dining tables, 2 laptops, 638.5ms
# Speed: 1.9ms preprocess, 638.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.83
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.78
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.57
# Bounding box coordinates: [224, 187, 314, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.50
# Bounding box coordinates: [745, 225, 767, 295]
#
# Detected person (Class ID: 0.0) with confidence 0.37
# Bounding box coordinates: [693, 226, 767, 429]
#
# Detected chair (Class ID: 56.0) with confidence 0.36
# Bounding box coordinates: [698, 143, 767, 252]
#
# Detected person (Class ID: 0.0) with confidence 0.33
# Bounding box coordinates: [692, 305, 767, 429]
# Reading frame...
#
# 0: 384x640 2 persons, 1 bowl, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 640.9ms
# Speed: 2.0ms preprocess, 640.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [393, 253, 513, 393]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.83
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.81
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.81
# Bounding box coordinates: [681, 226, 767, 428]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [224, 187, 315, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.36
# Bounding box coordinates: [699, 143, 767, 247]
# Reading frame...
#
# 0: 384x640 2 persons, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 650.9ms
# Speed: 2.1ms preprocess, 650.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.92
# Bounding box coordinates: [672, 225, 767, 428]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 91, 666, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.82
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.82
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.59
# Bounding box coordinates: [224, 188, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.31
# Bounding box coordinates: [699, 143, 767, 245]
# Reading frame...
#
# 0: 384x640 2 persons, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 651.1ms
# Speed: 2.1ms preprocess, 651.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.91
# Bounding box coordinates: [663, 225, 767, 429]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.82
# Bounding box coordinates: [247, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.81
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected chair (Class ID: 56.0) with confidence 0.58
# Bounding box coordinates: [224, 188, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [699, 143, 767, 247]
# Reading frame...
#
# 0: 384x640 2 persons, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 644.6ms
# Speed: 2.8ms preprocess, 644.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [658, 225, 767, 428]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 253, 513, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 91, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.81
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.78
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.53
# Bounding box coordinates: [224, 188, 313, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.40
# Bounding box coordinates: [699, 144, 767, 250]
# Reading frame...
#
# 0: 384x640 2 persons, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 570.4ms
# Speed: 2.0ms preprocess, 570.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [653, 226, 767, 429]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.82
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.81
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.57
# Bounding box coordinates: [224, 188, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.37
# Bounding box coordinates: [699, 143, 767, 245]
# Reading frame...
#
# 0: 384x640 2 persons, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 582.4ms
# Speed: 2.0ms preprocess, 582.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [640, 224, 767, 429]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [393, 252, 514, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [589, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.83
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.79
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.57
# Bounding box coordinates: [224, 188, 313, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.30
# Bounding box coordinates: [700, 143, 767, 242]
# Reading frame...
#
# 0: 384x640 2 persons, 1 bowl, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 574.2ms
# Speed: 2.0ms preprocess, 574.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.92
# Bounding box coordinates: [590, 223, 767, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [589, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.82
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.79
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.57
# Bounding box coordinates: [224, 188, 312, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.35
# Bounding box coordinates: [700, 144, 767, 242]
# Reading frame...
#
# 0: 384x640 2 persons, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 575.1ms
# Speed: 1.6ms preprocess, 575.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [583, 222, 767, 431]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 252, 514, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.80
# Bounding box coordinates: [524, 219, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.79
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [224, 188, 313, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.43
# Bounding box coordinates: [701, 144, 767, 242]
# Reading frame...
#
# 0: 384x640 2 persons, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 569.6ms
# Speed: 1.9ms preprocess, 569.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.94
# Bounding box coordinates: [582, 218, 767, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [589, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.83
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.78
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.54
# Bounding box coordinates: [224, 188, 313, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.34
# Bounding box coordinates: [702, 143, 767, 246]
# Reading frame...
#
# 0: 384x640 2 persons, 1 bowl, 5 chairs, 12 potted plants, 3 dining tables, 2 laptops, 574.0ms
# Speed: 1.8ms preprocess, 574.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [582, 217, 766, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [393, 253, 514, 385]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 91, 666, 204]
#
# Detected chair (Class ID: 56.0) with confidence 0.83
# Bounding box coordinates: [524, 220, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.79
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [224, 188, 314, 339]
# Reading frame...
#
# 0: 384x640 2 persons, 1 bowl, 6 chairs, 11 potted plants, 3 dining tables, 2 laptops, 574.0ms
# Speed: 2.1ms preprocess, 574.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [583, 213, 756, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [393, 253, 514, 385]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.84
# Bounding box coordinates: [524, 221, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.77
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.47
# Bounding box coordinates: [226, 188, 315, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.42
# Bounding box coordinates: [708, 143, 767, 230]
# Reading frame...
#
# 0: 384x640 2 persons, 1 bowl, 7 chairs, 11 potted plants, 3 dining tables, 2 laptops, 607.9ms
# Speed: 2.2ms preprocess, 607.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.94
# Bounding box coordinates: [583, 209, 748, 430]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.87
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.85
# Bounding box coordinates: [524, 221, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.79
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.48
# Bounding box coordinates: [226, 188, 315, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.38
# Bounding box coordinates: [710, 143, 767, 235]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [745, 224, 767, 286]
# Reading frame...
#
# 0: 384x640 2 persons, 1 bowl, 7 chairs, 11 potted plants, 3 dining tables, 2 laptops, 592.4ms
# Speed: 2.3ms preprocess, 592.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.94
# Bounding box coordinates: [583, 208, 742, 429]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 387]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 665, 203]
#
# Detected chair (Class ID: 56.0) with confidence 0.84
# Bounding box coordinates: [524, 221, 610, 321]
#
# Detected person (Class ID: 0.0) with confidence 0.80
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.51
# Bounding box coordinates: [226, 188, 315, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.32
# Bounding box coordinates: [745, 224, 767, 287]
#
# Detected chair (Class ID: 56.0) with confidence 0.26
# Bounding box coordinates: [711, 143, 767, 238]
# Reading frame...
#
# 0: 384x640 2 persons, 1 bowl, 7 chairs, 11 potted plants, 3 dining tables, 2 laptops, 586.3ms
# Speed: 1.7ms preprocess, 586.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.94
# Bounding box coordinates: [583, 207, 736, 429]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 86, 508, 234]
#
# ...
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 87, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 664, 169]
#
# Detected person (Class ID: 0.0) with confidence 0.80
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.51
# Bounding box coordinates: [225, 188, 315, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.45
# Bounding box coordinates: [734, 225, 767, 361]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [702, 143, 767, 241]
#
# Detected chair (Class ID: 56.0) with confidence 0.34
# Bounding box coordinates: [745, 224, 767, 286]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 8 chairs, 10 potted plants, 3 dining tables, 2 laptops, 600.9ms
# Speed: 2.0ms preprocess, 600.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [534, 163, 672, 428]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 87, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [590, 90, 664, 167]
#
# Detected person (Class ID: 0.0) with confidence 0.78
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.49
# Bounding box coordinates: [734, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.49
# Bounding box coordinates: [226, 188, 314, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.37
# Bounding box coordinates: [703, 143, 767, 242]
#
# Detected chair (Class ID: 56.0) with confidence 0.37
# Bounding box coordinates: [523, 200, 602, 318]
#
# Detected chair (Class ID: 56.0) with confidence 0.34
# Bounding box coordinates: [745, 224, 767, 286]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 8 chairs, 10 potted plants, 3 dining tables, 1 laptop, 591.1ms
# Speed: 1.8ms preprocess, 591.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [533, 159, 668, 428]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 87, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 514, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.89
# Bounding box coordinates: [590, 90, 664, 164]
#
# Detected person (Class ID: 0.0) with confidence 0.80
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.59
# Bounding box coordinates: [734, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.47
# Bounding box coordinates: [224, 187, 313, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.40
# Bounding box coordinates: [702, 143, 767, 243]
#
# Detected chair (Class ID: 56.0) with confidence 0.28
# Bounding box coordinates: [524, 198, 598, 317]
#
# Detected chair (Class ID: 56.0) with confidence 0.27
# Bounding box coordinates: [745, 224, 767, 287]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 11 potted plants, 3 dining tables, 1 laptop, 607.2ms
# Speed: 2.0ms preprocess, 607.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [531, 152, 664, 427]
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [418, 87, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.88
# Bounding box coordinates: [590, 90, 664, 165]
#
# Detected person (Class ID: 0.0) with confidence 0.78
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.59
# Bounding box coordinates: [734, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.48
# Bounding box coordinates: [226, 188, 314, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.32
# Bounding box coordinates: [701, 142, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.25
# Bounding box coordinates: [745, 224, 767, 287]
# Reading frame...
#
# 0: 384x640 3 persons, 1 backpack, 7 chairs, 12 potted plants, 3 dining tables, 1 laptop, 592.3ms
# Speed: 2.1ms preprocess, 592.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [530, 146, 657, 426]
#
# Detected chair (Class ID: 56.0) with confidence 0.92
# Bounding box coordinates: [418, 87, 508, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.84
# Bounding box coordinates: [591, 90, 664, 168]
#
# Detected person (Class ID: 0.0) with confidence 0.74
# Bounding box coordinates: [248, 144, 337, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.55
# Bounding box coordinates: [734, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.49
# Bounding box coordinates: [225, 188, 313, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.36
# Bounding box coordinates: [700, 143, 767, 244]
#
# Detected chair (Class ID: 56.0) with confidence 0.32
# Bounding box coordinates: [744, 224, 767, 286]
#
# Detected person (Class ID: 0.0) with confidence 0.28
# Bounding box coordinates: [242, 159, 384, 376]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 10 potted plants, 3 dining tables, 1 laptop, 600.4ms
# Speed: 2.2ms preprocess, 600.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [418, 87, 508, 234]
#
# Detected person (Class ID: 0.0) with confidence 0.91
# Bounding box coordinates: [528, 142, 652, 421]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [393, 253, 513, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.86
# Bounding box coordinates: [591, 91, 664, 195]
#
# Detected person (Class ID: 0.0) with confidence 0.78
# Bounding box coordinates: [248, 144, 337, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.50
# Bounding box coordinates: [224, 188, 312, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.49
# Bounding box coordinates: [734, 226, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.36
# Bounding box coordinates: [700, 143, 767, 242]
#
# Detected chair (Class ID: 56.0) with confidence 0.35
# Bounding box coordinates: [744, 225, 767, 286]
# Reading frame...
#
# 0: 384x640 3 persons, 1 backpack, 7 chairs, 9 potted plants, 3 dining tables, 1 laptop, 604.1ms
# Speed: 1.7ms preprocess, 604.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [417, 87, 507, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [392, 253, 513, 383]
#
# Detected person (Class ID: 0.0) with confidence 0.91
# Bounding box coordinates: [524, 136, 647, 413]
#
# Detected chair (Class ID: 56.0) with confidence 0.86
# Bounding box coordinates: [592, 91, 664, 197]
#
# Detected person (Class ID: 0.0) with confidence 0.75
# Bounding box coordinates: [248, 144, 336, 281]
#
# Detected chair (Class ID: 56.0) with confidence 0.53
# Bounding box coordinates: [224, 188, 312, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.50
# Bounding box coordinates: [734, 226, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.38
# Bounding box coordinates: [700, 143, 767, 242]
#
# Detected chair (Class ID: 56.0) with confidence 0.31
# Bounding box coordinates: [744, 225, 767, 287]
#
# Detected person (Class ID: 0.0) with confidence 0.25
# Bounding box coordinates: [245, 148, 383, 375]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 10 potted plants, 3 dining tables, 1 laptop, 593.1ms
# Speed: 2.1ms preprocess, 593.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [417, 87, 507, 234]
#
# Detected person (Class ID: 0.0) with confidence 0.91
# Bounding box coordinates: [521, 133, 643, 406]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [392, 253, 513, 383]
#
# Detected chair (Class ID: 56.0) with confidence 0.87
# Bounding box coordinates: [592, 90, 664, 202]
#
# Detected person (Class ID: 0.0) with confidence 0.78
# Bounding box coordinates: [247, 144, 336, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.53
# Bounding box coordinates: [224, 188, 312, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.48
# Bounding box coordinates: [734, 226, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.32
# Bounding box coordinates: [699, 143, 767, 243]
#
# Detected chair (Class ID: 56.0) with confidence 0.30
# Bounding box coordinates: [744, 225, 767, 287]
# Reading frame...
#
# 0: 384x640 3 persons, 1 backpack, 7 chairs, 10 potted plants, 3 dining tables, 1 laptop, 597.0ms
# Speed: 2.0ms preprocess, 597.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.91
# Bounding box coordinates: [513, 128, 638, 402]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [417, 87, 506, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [392, 253, 513, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.83
# Bounding box coordinates: [593, 91, 664, 202]
#
# Detected person (Class ID: 0.0) with confidence 0.73
# Bounding box coordinates: [248, 144, 336, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.58
# Bounding box coordinates: [224, 188, 312, 339]
#
# Detected chair (Class ID: 56.0) with confidence 0.47
# Bounding box coordinates: [734, 226, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.35
# Bounding box coordinates: [699, 143, 767, 242]
#
# Detected chair (Class ID: 56.0) with confidence 0.32
# Bounding box coordinates: [744, 225, 767, 287]
#
# Detected person (Class ID: 0.0) with confidence 0.31
# Bounding box coordinates: [246, 145, 384, 375]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 12 potted plants, 3 dining tables, 1 laptop, 605.2ms
# Speed: 1.9ms preprocess, 605.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.92
# Bounding box coordinates: [509, 125, 632, 395]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [417, 87, 504, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [392, 253, 513, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.78
# Bounding box coordinates: [594, 91, 664, 203]
#
# Detected person (Class ID: 0.0) with confidence 0.76
# Bounding box coordinates: [248, 144, 336, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.52
# Bounding box coordinates: [224, 188, 312, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.44
# Bounding box coordinates: [734, 225, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [744, 225, 767, 287]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [698, 143, 767, 243]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 10 potted plants, 3 dining tables, 1 laptop, 976.5ms
# Speed: 4.1ms preprocess, 976.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.92
# Bounding box coordinates: [507, 122, 628, 389]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [392, 254, 513, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [417, 87, 503, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.84
# Bounding box coordinates: [595, 91, 664, 204]
#
# Detected person (Class ID: 0.0) with confidence 0.77
# Bounding box coordinates: [247, 144, 336, 279]
#
# Detected chair (Class ID: 56.0) with confidence 0.56
# Bounding box coordinates: [223, 188, 312, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.41
# Bounding box coordinates: [733, 225, 767, 361]
#
# Detected chair (Class ID: 56.0) with confidence 0.34
# Bounding box coordinates: [697, 144, 767, 242]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [743, 225, 767, 288]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 11 potted plants, 2 dining tables, 1 laptop, 897.8ms
# Speed: 4.0ms preprocess, 897.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.91
# Bounding box coordinates: [503, 120, 624, 388]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [392, 254, 513, 386]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [417, 87, 502, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.81
# Bounding box coordinates: [596, 91, 664, 204]
#
# Detected person (Class ID: 0.0) with confidence 0.77
# Bounding box coordinates: [247, 144, 336, 279]
#
# Detected chair (Class ID: 56.0) with confidence 0.59
# Bounding box coordinates: [224, 188, 312, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.43
# Bounding box coordinates: [733, 225, 767, 362]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [743, 225, 767, 288]
#
# Detected chair (Class ID: 56.0) with confidence 0.32
# Bounding box coordinates: [698, 143, 767, 242]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 8 chairs, 10 potted plants, 2 dining tables, 1 laptop, 728.8ms
# Speed: 2.7ms preprocess, 728.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.92
# Bounding box coordinates: [501, 118, 620, 376]
#
# Detected chair (Class ID: 56.0) with confidence 0.91
# Bounding box coordinates: [392, 254, 513, 384]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [417, 88, 502, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.78
# Bounding box coordinates: [594, 91, 664, 204]
#
# Detected person (Class ID: 0.0) with confidence 0.75
# Bounding box coordinates: [247, 145, 335, 279]
#
# Detected chair (Class ID: 56.0) with confidence 0.61
# Bounding box coordinates: [224, 189, 313, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.40
# Bounding box coordinates: [733, 226, 767, 360]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [743, 225, 767, 288]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [699, 143, 767, 241]
#
# Detected chair (Class ID: 56.0) with confidence 0.27
# Bounding box coordinates: [499, 90, 664, 205]
# Reading frame...
#
# 0: 384x640 2 persons, 1 backpack, 7 chairs, 10 potted plants, 2 dining tables, 1 laptop, 705.9ms
# Speed: 2.2ms preprocess, 705.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Detected person (Class ID: 0.0) with confidence 0.93
# Bounding box coordinates: [492, 117, 614, 375]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [392, 255, 513, 388]
#
# Detected chair (Class ID: 56.0) with confidence 0.90
# Bounding box coordinates: [417, 87, 502, 234]
#
# Detected chair (Class ID: 56.0) with confidence 0.84
# Bounding box coordinates: [592, 91, 664, 204]
#
# Detected person (Class ID: 0.0) with confidence 0.80
# Bounding box coordinates: [247, 145, 336, 280]
#
# Detected chair (Class ID: 56.0) with confidence 0.63
# Bounding box coordinates: [224, 189, 313, 340]
#
# Detected chair (Class ID: 56.0) with confidence 0.39
# Bounding box coordinates: [733, 226, 767, 361]
#
# Detected chair (Class ID: 56.0) with confidence 0.35
# Bounding box coordinates: [743, 225, 767, 288]
#
# Detected chair (Class ID: 56.0) with confidence 0.33
# Bounding box coordinates: [699, 143, 767, 242]

# %% [markdown]
# Tried to skip frames and process frames after every 10 seconds. Did not worked
#
# # Initialize video capture
# cap = cv2.VideoCapture(
#     r"D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4"
# )
#
# # Check if video opened successfully
# if not cap.isOpened():
#     print("Error: Couldn't open the video file.")
# else:
#     print("Video file opened successfully.")
#
#     # Get the frame rate (fps) of the video
#     fps = cap.get(cv2.CAP_PROP_FPS)
#     print(f"Video Frame Rate (FPS): {fps}")
#
#     # Time between frames we want to process (10 seconds)
#     interval = 2  # Process every 10 seconds
#
#     # Calculate the frame number corresponding to the desired times
#     frame_number = 0
#     prev_time = 0  # Start at time 0
#
#     while cap.isOpened():
#         # Calculate the time for the current frame (in seconds)
#         current_time = frame_number / fps
#
#         # If the current frame time is at the desired interval (0s, 10s, 20s, ...)
#         if current_time >= prev_time:
#
#             print("Reading frame...")
#             # Read a frame from the video
#             ret, frame = cap.read()
#
#             # Check if the frame was read properly
#             if not ret:
#                 print("Error: Couldn't read the frame.")
#                 break
#
#             # Perform detection on the current frame
#             results = model(frame)  # Detect objects in the frame
#
#             # Filter detections for 'person' and 'chair' classes
#             # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
#             person_and_chair = [0, 56]  # person (0) and chair (56) class IDs
#
#             # Process the results
#             for result in results:
#                 # Extract bounding boxes, confidence, and class IDs
#                 boxes = result.boxes  # Get bounding boxes
#
#                 for box in boxes:
#                     class_id = box.cls[0].item()  # Get the class id of the detected object
#
#                     if (class_id in person_and_chair):  # Check if it is a person or a chair
#                         # Get the bounding box coordinates
#                         x1, y1, x2, y2 = map(int, box.xyxy[0])
#
#                         # Get the class ID and confidence score
#                         class_id = box.cls[0].item()
#                         confidence = box.conf[0].item()
#
#                         # Get the class name
#                         label = model.names[class_id]
#
#                         # Print out the detected object details
#                         print(
#                             f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
#                         )
#                         print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")
#
#                         # Draw a bounding box around the object
#
#                         # Define different colors for different objects
#                         if label == "person":
#                             color = (255, 0, 0)  # Blue color for human (person)
#                         elif label == "chair":
#                             color = (0, 0, 255)  # Red color for chair
#                         else:
#                             color = (0, 255, 0)  # Default green for other objects
#
#                         # Draw a bounding box around the object with the selected color
#                         cv2.rectangle(
#                             frame, (x1, y1), (x2, y2), color, 2
#                         )  # Bounding box with the chosen color
#
#                         cv2.putText(
#                             frame,
#                             label,
#                             (x1, y1 - 10),
#                             cv2.FONT_HERSHEY_SIMPLEX,
#                             0.9,
#                             (0, 255, 0),
#                             2,
#                         )
#
#                 if frame is not None and frame.size > 0:
#                     cv2.imshow("Video", frame)
#                 else:
#                     print("Warning: Empty frame encountered!")
#                     break
#
#                 # Press 'q' to quit the video window
#                 if cv2.waitKey(1) & 0xFF == ord("q"):
#                     break
#
#                 # Update prev_time to the next desired frame time (e.g., t = 10s, 20s)
#                 prev_time += interval  # Move to the next interval (10 seconds)
#
#             # Skip frames until we reach the desired frame time
#             frame_number += 1
#
#
#     # Release the video capture object and close all windows
#     cap.release()
#     cv2.destroyAllWindows()
