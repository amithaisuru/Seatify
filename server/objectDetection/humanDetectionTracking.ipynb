# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (8.3.133)
# Requirement already satisfied: opencv-python in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: pillow>=7.1.2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.7.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.22.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import time

# %%
# Load the YOLOv8 model
model = YOLO('yolov8x.pt').to('cuda:0')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs

# %%
# --------Human & Object detection in video - correctly working--------

'''

# Initialize video capture
cap = cv2.VideoCapture(r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4')

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    while cap.isOpened():
        print("Reading frame...")
        ret, frame = cap.read()

        # Perform detection on the current frame
        results = model(frame)  # Detect objects in the frame

        # Filter detections for 'person' and 'chair' classes
        # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

        # Process the results
        for result in results:

            boxes = result.boxes  # Get bounding boxes

            for box in boxes:
                class_id = box.cls[0].item()  # Get the class id of the detected object
                if class_id in person_and_chair:  # Check if it is a person or a chair
                    # Get the bounding box coordinates
                    x1, y1, x2, y2 = map(int, box.xyxy[0])

                    # Get the class ID and confidence score
                    class_id = box.cls[0].item()
                    confidence = box.conf[0].item()

                    # Get the class name
                    label = model.names[class_id]

                    # Print out the detected object details
                    print(
                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                    )
                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                    # Draw a bounding box around the object

                    # Define different colors for different objects
                    if label == "person":
                        color = (255, 0, 0)  # Blue color for human (person)
                    elif label == "chair":
                        color = (0, 0, 255)  # Red color for chair
                    else:
                        color = (0, 255, 0)  # Default green for other objects

                    # Draw a bounding box around the object with the selected color
                    cv2.rectangle(
                        frame, (x1, y1), (x2, y2), color, 2
                    )  # Bounding box with the chosen color

                    cv2.putText(
                        frame,
                        label,
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        (0, 255, 0),
                        2,
                    )

        if frame is not None and frame.size > 0:
            cv2.imshow("Video", frame)
        else:
            print("Warning: Empty frame encountered!")
            break

        # Press 'q' to quit the video window
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_21800\1471836195.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo6.mp4\')\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    while cap.isOpened():\n        print("Reading frame...")\n        ret, frame = cap.read()\n\n        # Perform detection on the current frame\n        results = model(frame)  # Detect objects in the frame\n\n        # Filter detections for \'person\' and \'chair\' classes\n        # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n        # Process the results\n        for result in results:\n\n            boxes = result.boxes  # Get bounding boxes\n\n            for box in boxes:\n                class_id = box.cls[0].item()  # Get the class id of the detected object\n                if class_id in person_and_chair:  # Check if it is a person or a chair\n                    # Get the bounding box coordinates\n                    x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                    # Get the class ID and confidence score\n                    class_id = box.cls[0].item()\n                    confidence = box.conf[0].item()\n\n                    # Get the class name\n                    label = model.names[class_id]\n\n                    # Print out the detected object details\n                    print(\n                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                    )\n                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                    # Draw a bounding box around the object\n\n                    # Define different colors for different objects\n                    if label == "person":\n                        color = (255, 0, 0)  # Blue color for human (person)\n                    elif label == "chair":\n                        color = (0, 0, 255)  # Red color for chair\n                    else:\n                        color = (0, 255, 0)  # Default green for other objects\n\n                    # Draw a bounding box around the object with the selected color\n                    cv2.rectangle(\n                        frame, (x1, y1), (x2, y2), color, 2\n                    )  # Bounding box with the chosen color\n\n                    cv2.putText(\n                        frame,\n                        label,\n                        (x1, y1 - 10),\n                        cv2.FONT_HERSHEY_SIMPLEX,\n                        0.9,\n                        (0, 255, 0),\n                        2,\n                    )\n\n        if frame is not None and frame.size > 0:\n            cv2.imshow("Video", frame)\n        else:\n            print("Warning: Empty frame encountered!")\n            break\n\n        # Press \'q\' to quit the video window\n        if cv2.waitKey(1) & 0xFF == ord("q"):\n            break\n\n    # Release the video capture object and close all windows\n    cap.release()\n    cv2.destroyAllWindows()\n\n'

# %%
# -----Tried to skip frames and process frames after every 10 seconds. Did not worked-----


'''

# Initialize video capture
cap = cv2.VideoCapture(
    r"D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4"
)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    # Get the frame rate (fps) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video Frame Rate (FPS): {fps}")

    # Time between frames we want to process (10 seconds)
    interval = 2  # Process every 10 seconds

    # Calculate the frame number corresponding to the desired times
    frame_number = 0
    prev_time = 0  # Start at time 0

    while cap.isOpened():
        # Calculate the time for the current frame (in seconds)
        current_time = frame_number / fps

        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)
        if current_time >= prev_time:

            print("Reading frame...")
            # Read a frame from the video
            ret, frame = cap.read()

            # Check if the frame was read properly
            if not ret:
                print("Error: Couldn't read the frame.")
                break

            # Perform detection on the current frame
            results = model(frame)  # Detect objects in the frame

            # Filter detections for 'person' and 'chair' classes
            # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

            # Process the results
            for result in results:
                # Extract bounding boxes, confidence, and class IDs
                boxes = result.boxes  # Get bounding boxes

                for box in boxes:
                    class_id = box.cls[0].item()  # Get the class id of the detected object

                    if (class_id in person_and_chair):  # Check if it is a person or a chair
                        # Get the bounding box coordinates
                        x1, y1, x2, y2 = map(int, box.xyxy[0])

                        # Get the class ID and confidence score
                        class_id = box.cls[0].item()
                        confidence = box.conf[0].item()

                        # Get the class name
                        label = model.names[class_id]

                        # Print out the detected object details
                        print(
                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                        )
                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                        # Draw a bounding box around the object

                        # Define different colors for different objects
                        if label == "person":
                            color = (255, 0, 0)  # Blue color for human (person)
                        elif label == "chair":
                            color = (0, 0, 255)  # Red color for chair
                        else:
                            color = (0, 255, 0)  # Default green for other objects

                        # Draw a bounding box around the object with the selected color
                        cv2.rectangle(
                            frame, (x1, y1), (x2, y2), color, 2
                        )  # Bounding box with the chosen color

                        cv2.putText(
                            frame,
                            label,
                            (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.9,
                            (0, 255, 0),
                            2,
                        )

                if frame is not None and frame.size > 0:
                    cv2.imshow("Video", frame)
                else:
                    print("Warning: Empty frame encountered!")
                    break

                # Press 'q' to quit the video window
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break

                # Update prev_time to the next desired frame time (e.g., t = 10s, 20s)
                prev_time += interval  # Move to the next interval (10 seconds)

            # Skip frames until we reach the desired frame time
            frame_number += 1
        
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_21800\3711239310.py:4: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(\n    r"D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4"\n)\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    # Get the frame rate (fps) of the video\n    fps = cap.get(cv2.CAP_PROP_FPS)\n    print(f"Video Frame Rate (FPS): {fps}")\n\n    # Time between frames we want to process (10 seconds)\n    interval = 2  # Process every 10 seconds\n\n    # Calculate the frame number corresponding to the desired times\n    frame_number = 0\n    prev_time = 0  # Start at time 0\n\n    while cap.isOpened():\n        # Calculate the time for the current frame (in seconds)\n        current_time = frame_number / fps\n\n        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)\n        if current_time >= prev_time:\n\n            print("Reading frame...")\n            # Read a frame from the video\n            ret, frame = cap.read()\n\n            # Check if the frame was read properly\n            if not ret:\n                print("Error: Couldn\'t read the frame.")\n                break\n\n            # Perform detection on the current frame\n            results = model(frame)  # Detect objects in the frame\n\n            # Filter detections for \'person\' and \'chair\' classes\n            # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n            # Process the results\n            for result in results:\n                # Extract bounding boxes, confidence, and class IDs\n                boxes = result.boxes  # Get bounding boxes\n\n                for box in boxes:\n                    class_id = box.cls[0].item()  # Get the class id of the detected object\n\n                    if (class_id in person_and_chair):  # Check if it is a person or a chair\n                        # Get the bounding box coordinates\n                        x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                        # Get the class ID and confidence score\n                        class_id = box.cls[0].item()\n                        confidence = box.conf[0].item()\n\n                        # Get the class name\n                        label = model.names[class_id]\n\n                        # Print out the detected object details\n                        print(\n                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                        )\n                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                        # Draw a bounding box around the object\n\n                        # Define different colors for different objects\n                        if label == "person":\n                            color = (255, 0, 0)  # Blue color for human (person)\n                        elif label == "chair":\n                            color = (0, 0, 255)  # Red color for chair\n                        else:\n                            color = (0, 255, 0)  # Default green for other objects\n\n                        # Draw a bounding box around the object with the selected color\n                        cv2.rectangle(\n                            frame, (x1, y1), (x2, y2), color, 2\n                        )  # Bounding box with the chosen color\n\n                        cv2.putText(\n                            frame,\n                            label,\n                            (x1, y1 - 10),\n                            cv2.FONT_HERSHEY_SIMPLEX,\n                            0.9,\n                            (0, 255, 0),\n                            2,\n                        )\n\n                if frame is not None and frame.size > 0:\n                    cv2.imshow("Video", frame)\n                else:\n          ...

# %%
import torch
print("CUDA available? ", torch.cuda.is_available())
print("GPU count:    ", torch.cuda.device_count())
print("Current dev:  ", torch.cuda.current_device())
print("Dev name:     ", torch.cuda.get_device_name(0))
# Out:
# CUDA available?  True
# GPU count:     1
# Current dev:   0
# Dev name:      NVIDIA GeForce GTX 1660 Ti

# %%
# ----- Human & Chair detection and tracking - correctly working -----

'''
# 3. Run detection + ByteTrack on your video
#    – source: your file path
#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)
#    – classes: [0,56] → only person (0) & chair (56)
#    – persist: keep track IDs alive across frames
#    – show: pop up each frame (set False if headless)
#    – save: write out an annotated video to runs/track/exp*
stream = model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4',
    tracker='bytetrack.yaml',
    classes=[0, 56],
    persist=True,
    show=False,    # we’ll show manually
    save=True,    # disable automatic save
    save_dir='my_outputs/',
    stream=True,   # <— Enable streaming!
    device='cuda:0'
)

for frame_idx, res in enumerate(stream):
    print(f"Frame {frame_idx}:")
    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id
    for xyxy, conf, cls_id, track_id in zip(
        res.boxes.xyxy, 
        res.boxes.conf, 
        res.boxes.cls, 
        res.boxes.id
    ):
        x1, y1, x2, y2 = map(int, xyxy.tolist())
        conf = float(conf)
        cls_id = int(cls_id)
        track_id = int(track_id)
        label = res.names[cls_id]  # e.g. "person" or "chair"
        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")

    # Optional: display the annotated frame and quit on 'q'
    frame = res.plot()
    cv2.imshow("Track (press q to quit)", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_21800\1808955419.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n# 3. Run detection + ByteTrack on your video\n#    – source: your file path\n#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)\n#    – classes: [0,56] → only person (0) & chair (56)\n#    – persist: keep track IDs alive across frames\n#    – show: pop up each frame (set False if headless)\n#    – save: write out an annotated video to runs/track/exp*\nstream = model.track(\n    source=r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4\',\n    tracker=\'bytetrack.yaml\',\n    classes=[0, 56],\n    persist=True,\n    show=False,    # we’ll show manually\n    save=True,    # disable automatic save\n    save_dir=\'my_outputs/\',\n    stream=True,   # <— Enable streaming!\n    device=\'cuda:0\'\n)\n\nfor frame_idx, res in enumerate(stream):\n    print(f"Frame {frame_idx}:")\n    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id\n    for xyxy, conf, cls_id, track_id in zip(\n        res.boxes.xyxy, \n        res.boxes.conf, \n        res.boxes.cls, \n        res.boxes.id\n    ):\n        x1, y1, x2, y2 = map(int, xyxy.tolist())\n        conf = float(conf)\n        cls_id = int(cls_id)\n        track_id = int(track_id)\n        label = res.names[cls_id]  # e.g. "person" or "chair"\n        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")\n\n    # Optional: display the annotated frame and quit on \'q\'\n    frame = res.plot()\n    cv2.imshow("Track (press q to quit)", frame)\n    if cv2.waitKey(1) & 0xFF == ord(\'q\'):\n        break\n\ncv2.destroyAllWindows()\n\n'

# %%
import cv2
import numpy as np
from ultralytics import YOLO

def calculate_angle(a, b, c):
    #Builds vectors ba and bc around joint b.
    ba = a - b
    bc = c - b

    #Uses the dot-product formula to get the cosine of angle abc
    cosang = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-6)

    #clip to valid range and convert from radians to degrees
    return np.degrees(np.arccos(np.clip(cosang, -1.0, 1.0)))

# Load models
det_model  = YOLO('yolov8x.pt').to('cuda:0')
pose_model = YOLO('yolov8x-pose.pt').to('cuda:0')

# Start the detection+track stream
stream = det_model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4',
    tracker='bytetrack.yaml',
    classes=[0],
    persist=True,
    show=False,
    save=True,
    save_dir='my_outputs/',
    stream=True,
    device='cuda:0'
)

#process frames
for frame_idx, res in enumerate(stream): #enumerate(stream) gives (frame_idx, res) as soon as each frame is done
    frame = res.orig_img.copy() # copy of raw frame we annotate
    print(f"Frame {frame_idx}:")

    # Pull detections
    # Unpack the tracked detections in parallel arrays
    xyxys     = res.boxes.xyxy.cpu().numpy() # bounding boxes (n×4)
    confs     = res.boxes.conf.cpu().numpy() # confidence scores (n) 
    cls_ids   = res.boxes.cls.cpu().numpy().astype(int) # class IDs (n)
    track_ids = res.boxes.id.cpu().numpy().astype(int) # track IDs (n)

    #Iterate through each detection in this frame
    for (x1, y1, x2, y2), conf, cls_id, track_id in zip(xyxys, confs, cls_ids, track_ids): #Zips the four arrays so you handle each detection in lockstep.
        
        #Converts the box coords to integers
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))

        #looks up the human-readable class name
        label = res.names[cls_id] # e.g. "person" or "chair"

        # Person branch
        if label == 'person':

            # Defaults the posture to “unknown” with a yellow box
            posture, color = 'unknown', (0,255,255)

            # Crops the detected person region and runs pose_model on that ROI
            roi = frame[y1:y2, x1:x2]
            p = pose_model(roi, device='cuda:0')[0]

            # If keypoints are found, extracts the raw (n,17,3) array from p.keypoints.data.
            # In the shape tuple (n, 17, 3), that leading n is simply the number of person instances (i.e. detections) 
            # that the pose model found in your cropped image
            # Since you’re cropping around a single detected box, in most cases n will be 1
            if p.keypoints is not None:
                # Extract the raw (n,17,3) tensor of keypoints
                kpts_np = p.keypoints.data.cpu().numpy()  # shape (n,17,3)

                # Ensure we have at least 17 keypoints
                if kpts_np.ndim == 3 and kpts_np.shape[1] >= 17:
                    kpts = kpts_np[0]  # first person
                    # shape (17,3): [x,y,conf] per joint

                    try:
                        # compute left & right knee angles
                        l_ang = calculate_angle(kpts[11,:2], kpts[13,:2], kpts[15,:2]) #computes left knee angles
                        r_ang = calculate_angle(kpts[12,:2], kpts[14,:2], kpts[16,:2]) #computes right knee angles
                        # compute average angle
                        avg_ang = (l_ang + r_ang) / 2

                        # Threshold to decide sitting vs standing
                        if avg_ang < 140:
                            posture, color = 'sitting',  (0,255,0)
                        else:
                            posture, color = 'standing', (0,0,255)
                    except:
                        pass

            text = f"{posture} {conf:.2f} ID:{track_id}"

        else:
            # chair
            color = (255,0,0)
            text  = f"chair {conf:.2f} ID:{track_id}"

        # Draw & print
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
        cv2.putText(frame, text, (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        print(f"  → {text}  box=[{x1},{y1},{x2},{y2}]")

    cv2.imshow("Pose+Track", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# video 1/1 (frame 1/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 51.1ms
# Frame 0:
#
# 0: 640x416 1 person, 58.9ms
# Speed: 2.5ms preprocess, 58.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.64 ID:1  box=[249,142,338,280]
#
# 0: 640x416 2 persons, 64.8ms
# Speed: 2.6ms preprocess, 64.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.40 ID:2  box=[249,142,392,376]
# video 1/1 (frame 2/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 46.4ms
# Frame 1:
#
# 0: 640x416 1 person, 53.2ms
# Speed: 3.3ms preprocess, 53.2ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.71 ID:1  box=[249,142,338,280]
#
# 0: 640x416 2 persons, 56.8ms
# Speed: 2.5ms preprocess, 56.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.25 ID:2  box=[250,143,392,375]
# video 1/1 (frame 3/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 51.2ms
# Frame 2:
#
# 0: 640x416 1 person, 56.3ms
# Speed: 4.4ms preprocess, 56.3ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.74 ID:1  box=[249,142,338,280]
#
# 0: 640x416 3 persons, 52.0ms
# Speed: 2.3ms preprocess, 52.0ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.19 ID:2  box=[251,142,393,375]
# video 1/1 (frame 4/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 45.9ms
# Frame 3:
#
# 0: 640x416 1 person, 53.7ms
# Speed: 2.5ms preprocess, 53.7ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.73 ID:1  box=[249,142,338,280]
#
# 0: 640x416 2 persons, 57.5ms
# Speed: 4.1ms preprocess, 57.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.24 ID:2  box=[251,142,394,375]
# video 1/1 (frame 5/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 45.6ms
# Frame 4:
#
# 0: 640x416 1 person, 56.9ms
# Speed: 7.1ms preprocess, 56.9ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.70 ID:1  box=[249,142,338,280]
#
# 0: 640x416 2 persons, 58.1ms
# Speed: 3.7ms preprocess, 58.1ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.33 ID:2  box=[251,143,394,375]
# video 1/1 (frame 6/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 45.9ms
# Frame 5:
#
# 0: 640x416 1 person, 58.1ms
# Speed: 4.5ms preprocess, 58.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.71 ID:1  box=[249,142,338,280]
#
# 0: 640x416 2 persons, 56.7ms
# Speed: 2.7ms preprocess, 56.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.27 ID:2  box=[251,145,393,375]
# video 1/1 (frame 7/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 45.5ms
# Frame 6:
#
# 0: 640x416 1 person, 55.5ms
# Speed: 2.2ms preprocess, 55.5ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.73 ID:1  box=[249,143,338,281]
#
# 0: 640x416 2 persons, 55.1ms
# Speed: 2.9ms preprocess, 55.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.25 ID:2  box=[251,146,392,376]
# video 1/1 (frame 8/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.5ms
# Frame 7:
#
# 0: 640x416 1 person, 57.6ms
# Speed: 3.3ms preprocess, 57.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.73 ID:1  box=[249,143,338,281]
#
# 0: 640x416 2 persons, 62.1ms
# Speed: 2.7ms preprocess, 62.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.26 ID:2  box=[251,146,392,376]
# video 1/1 (frame 9/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.0ms
# Frame 8:
#
# 0: 640x416 1 person, 52.0ms
# Speed: 2.4ms preprocess, 52.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.77 ID:1  box=[249,143,338,281]
#
# 0: 640x416 2 persons, 56.5ms
# Speed: 1.7ms preprocess, 56.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.17 ID:2  box=[251,149,391,376]
# video 1/1 (frame 10/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.0ms
# Frame 9:
#
# 0: 640x416 1 person, 55.7ms
# Speed: 1.4ms preprocess, 55.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.77 ID:1  box=[249,143,338,281]
#
# 0: 640x416 2 persons, 61.2ms
# Speed: 2.7ms preprocess, 61.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.19 ID:2  box=[250,150,390,376]
# video 1/1 (frame 11/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.4ms
# Frame 10:
#
# 0: 640x416 1 person, 55.8ms
# Speed: 1.5ms preprocess, 55.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.72 ID:1  box=[249,143,338,281]
#
# 0: 640x416 2 persons, 55.8ms
# Speed: 2.9ms preprocess, 55.8ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.30 ID:2  box=[249,147,391,376]
# video 1/1 (frame 12/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 45.5ms
# Frame 11:
#
# 0: 640x416 1 person, 61.7ms
# Speed: 2.2ms preprocess, 61.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.76 ID:1  box=[249,143,338,281]
#
# 0: 640x416 2 persons, 57.4ms
# Speed: 1.4ms preprocess, 57.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.21 ID:2  box=[249,148,390,376]
# video 1/1 (frame 13/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 51.9ms
# Frame 12:
#
# 0: 640x416 1 person, 57.0ms
# Speed: 1.4ms preprocess, 57.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.76 ID:1  box=[249,143,337,281]
#
# 0: 640x416 2 persons, 56.8ms
# Speed: 2.5ms preprocess, 56.8ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.23 ID:2  box=[248,148,389,376]
# video 1/1 (frame 14/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.0ms
# Frame 13:
#
# 0: 640x416 1 person, 57.7ms
# Speed: 4.2ms preprocess, 57.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.75 ID:1  box=[249,143,337,281]
#
# 0: 640x416 2 persons, 57.1ms
# Speed: 1.4ms preprocess, 57.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.24 ID:2  box=[247,147,389,376]
# video 1/1 (frame 15/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.2ms
# Frame 14:
#
# 0: 640x416 1 person, 56.7ms
# Speed: 1.2ms preprocess, 56.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.73 ID:1  box=[249,143,337,281]
#
# 0: 640x416 2 persons, 55.0ms
# Speed: 3.9ms preprocess, 55.0ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.31 ID:2  box=[246,146,388,376]
# video 1/1 (frame 16/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 47.3ms
# Frame 15:
#
# 0: 640x416 1 person, 57.4ms
# Speed: 3.4ms preprocess, 57.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.78 ID:1  box=[248,143,337,281]
#
# 0: 640x416 2 persons, 57.4ms
# Speed: 2.4ms preprocess, 57.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.22 ID:2  box=[245,144,388,376]
# video 1/1 (frame 17/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 53.7ms
# Frame 16:
#
# 0: 640x416 1 person, 61.0ms
# Speed: 2.4ms preprocess, 61.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.79 ID:1  box=[248,143,337,281]
#
# 0: 640x416 2 persons, 57.4ms
# Speed: 1.4ms preprocess, 57.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.21 ID:2  box=[245,143,387,376]
# video 1/1 (frame 18/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.0ms
# Frame 17:
#
# 0: 640x416 1 person, 58.0ms
# Speed: 2.2ms preprocess, 58.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.74 ID:1  box=[248,143,337,281]
#
# 0: 640x416 2 persons, 63.1ms
# Speed: 3.9ms preprocess, 63.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.30 ID:2  box=[246,147,386,376]
# video 1/1 (frame 19/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.6ms
# Frame 18:
#
# 0: 640x416 1 person, 52.4ms
# Speed: 3.6ms preprocess, 52.4ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.75 ID:1  box=[248,143,337,281]
#
# 0: 640x416 2 persons, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.28 ID:2  box=[246,144,387,376]
# video 1/1 (frame 20/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 51.0ms
# Frame 19:
#
# 0: 640x416 1 person, 57.9ms
# Speed: 1.7ms preprocess, 57.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.77 ID:1  box=[249,143,337,281]
#
# 0: 640x416 2 persons, 57.0ms
# Speed: 1.2ms preprocess, 57.0ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.22 ID:2  box=[246,144,387,376]
# video 1/1 (frame 21/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 46.5ms
# Frame 20:
#
# 0: 640x416 1 person, 57.2ms
# Speed: 1.5ms preprocess, 57.2ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.77 ID:1  box=[249,143,337,281]
#
# 0: 640x416 2 persons, 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.23 ID:2  box=[247,143,387,376]
# video 1/1 (frame 22/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.8ms
# Frame 21:
#
# 0: 640x416 1 person, 59.0ms
# Speed: 2.7ms preprocess, 59.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.76 ID:1  box=[249,143,337,281]
#
# 0: 640x416 2 persons, 57.1ms
# Speed: 1.2ms preprocess, 57.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.22 ID:2  box=[250,151,386,376]
# video 1/1 (frame 23/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.5ms
# Frame 22:
#
# 0: 640x416 1 person, 56.6ms
# Speed: 1.3ms preprocess, 56.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.82 ID:1  box=[249,143,337,281]
#
# 0: 640x416 3 persons, 56.3ms
# Speed: 2.1ms preprocess, 56.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.10 ID:2  box=[251,146,391,376]
# video 1/1 (frame 24/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 1 person, 44.6ms
# Frame 23:
#
# 0: 640x416 1 person, 59.0ms
# Speed: 1.7ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.84 ID:1  box=[249,143,337,281]
# video 1/1 (frame 25/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 1 person, 50.2ms
# Frame 24:
#
# 0: 640x416 1 person, 58.3ms
# Speed: 3.2ms preprocess, 58.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.81 ID:1  box=[249,144,337,281]
# video 1/1 (frame 26/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 1 person, 46.1ms
# Frame 25:
#
# 0: 640x416 1 person, 58.4ms
# Speed: 2.1ms preprocess, 58.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.82 ID:1  box=[249,144,337,281]
# video 1/1 (frame 27/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 1 person, 49.6ms
# Frame 26:
#
# 0: 640x416 1 person, 57.0ms
# Speed: 1.3ms preprocess, 57.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.83 ID:1  box=[248,144,337,281]
# video 1/1 (frame 28/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.9ms
# Frame 27:
#
# 0: 640x416 1 person, 56.3ms
# Speed: 1.2ms preprocess, 56.3ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.83 ID:1  box=[248,144,337,281]
#
# 0: 640x448 (no detections), 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.53 ID:3  box=[710,346,768,430]
# video 1/1 (frame 29/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.0ms
# Frame 28:
#
# 0: 640x416 1 person, 58.0ms
# Speed: 1.3ms preprocess, 58.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.82 ID:1  box=[248,144,337,281]
#
# 0: 640x416 2 persons, 60.4ms
# Speed: 3.0ms preprocess, 60.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.53 ID:3  box=[704,331,768,430]
# video 1/1 (frame 30/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.5ms
# Frame 29:
#
# 0: 640x416 1 person, 57.8ms
# Speed: 1.2ms preprocess, 57.8ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.80 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 53.2ms
# Speed: 2.3ms preprocess, 53.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.58 ID:3  box=[697,318,768,429]
# video 1/1 (frame 31/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 46.6ms
# Frame 30:
#
# 0: 640x416 1 person, 56.9ms
# Speed: 1.6ms preprocess, 56.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.83 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 56.8ms
# Speed: 1.6ms preprocess, 56.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.33 ID:3  box=[689,307,768,429]
# video 1/1 (frame 32/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.7ms
# Frame 31:
#
# 0: 640x448 1 person, 60.0ms
# Speed: 1.3ms preprocess, 60.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.83 ID:1  box=[248,144,337,280]
#
# 0: 640x384 1 person, 54.9ms
# Speed: 1.6ms preprocess, 54.9ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.81 ID:3  box=[666,251,768,428]
# video 1/1 (frame 33/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 47.6ms
# Frame 32:
#
# 0: 640x448 1 person, 60.6ms
# Speed: 1.3ms preprocess, 60.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.82 ID:1  box=[248,144,337,280]
#
# 0: 640x384 1 person, 49.3ms
# Speed: 1.9ms preprocess, 49.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.92 ID:3  box=[655,228,768,428]
# video 1/1 (frame 34/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.7ms
# Frame 33:
#
# 0: 640x448 1 person, 60.1ms
# Speed: 1.4ms preprocess, 60.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.82 ID:1  box=[248,144,337,280]
#
# 0: 640x384 1 person, 50.9ms
# Speed: 2.8ms preprocess, 50.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.91 ID:3  box=[648,219,768,428]
# video 1/1 (frame 35/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.2ms
# Frame 34:
#
# 0: 640x448 1 person, 59.7ms
# Speed: 2.2ms preprocess, 59.7ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.78 ID:1  box=[248,144,337,280]
#
# 0: 640x384 1 person, 52.5ms
# Speed: 1.3ms preprocess, 52.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.93 ID:3  box=[645,216,768,428]
# video 1/1 (frame 36/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.0ms
# Frame 35:
#
# 0: 640x448 1 person, 64.9ms
# Speed: 2.7ms preprocess, 64.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.81 ID:1  box=[248,144,337,280]
#
# 0: 640x384 1 person, 54.3ms
# Speed: 1.2ms preprocess, 54.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.93 ID:3  box=[642,216,768,428]
# video 1/1 (frame 37/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.8ms
# Frame 36:
#
# 0: 640x448 1 person, 58.6ms
# Speed: 1.3ms preprocess, 58.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[248,144,337,280]
#
# 0: 640x416 1 person, 59.1ms
# Speed: 1.2ms preprocess, 59.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.93 ID:3  box=[637,215,768,428]
# video 1/1 (frame 38/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.0ms
# Frame 37:
#
# 0: 640x448 1 person, 59.5ms
# Speed: 1.7ms preprocess, 59.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[248,144,337,280]
#
# 0: 640x448 1 person, 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.92 ID:3  box=[617,215,757,429]
# video 1/1 (frame 39/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 45.7ms
# Frame 38:
#
# 0: 640x448 1 person, 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[248,144,337,280]
#
# 0: 640x448 1 person, 57.3ms
# Speed: 1.7ms preprocess, 57.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.93 ID:3  box=[605,214,751,430]
# video 1/1 (frame 40/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 51.8ms
# Frame 39:
#
# 0: 640x448 1 person, 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.78 ID:1  box=[248,144,337,280]
#
# 0: 640x448 1 person, 52.9ms
# Speed: 2.5ms preprocess, 52.9ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.94 ID:3  box=[599,213,749,430]
# video 1/1 (frame 41/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.9ms
# Frame 40:
#
# 0: 640x448 1 person, 61.9ms
# Speed: 2.4ms preprocess, 61.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[248,144,337,280]
#
# 0: 640x480 1 person, 62.3ms
# Speed: 1.7ms preprocess, 62.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.93 ID:3  box=[595,211,749,430]
# video 1/1 (frame 42/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.5ms
# Frame 41:
#
# 0: 640x448 1 person, 62.1ms
# Speed: 1.4ms preprocess, 62.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.77 ID:1  box=[248,144,337,280]
#
# 0: 640x480 1 person, 66.6ms
# Speed: 2.7ms preprocess, 66.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.93 ID:3  box=[590,209,747,430]
# video 1/1 (frame 43/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.6ms
# Frame 42:
#
# 0: 640x448 1 person, 60.1ms
# Speed: 1.7ms preprocess, 60.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[248,144,337,280]
#
# 0: 640x480 1 person, 64.1ms
# Speed: 2.4ms preprocess, 64.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.94 ID:3  box=[585,206,745,430]
# video 1/1 (frame 44/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.4ms
# Frame 43:
#
# 0: 640x416 2 persons, 62.4ms
# Speed: 2.6ms preprocess, 62.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.80 ID:1  box=[248,144,337,281]
#
# 0: 640x480 1 person, 66.6ms
# Speed: 2.5ms preprocess, 66.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.94 ID:3  box=[581,204,743,430]
# video 1/1 (frame 45/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.6ms
# Frame 44:
#
# 0: 640x416 2 persons, 63.9ms
# Speed: 2.3ms preprocess, 63.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.81 ID:1  box=[248,144,337,281]
#
# 0: 640x480 1 person, 62.4ms
# Speed: 1.4ms preprocess, 62.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.94 ID:3  box=[578,203,740,429]
# video 1/1 (frame 46/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.1ms
# Frame 45:
#
# 0: 640x416 2 persons, 59.3ms
# Speed: 1.2ms preprocess, 59.3ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.81 ID:1  box=[248,144,337,281]
#
# 0: 640x480 1 person, 60.8ms
# Speed: 2.4ms preprocess, 60.8ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.93 ID:3  box=[575,200,737,429]
# video 1/1 (frame 47/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.4ms
# Frame 46:
#
# 0: 640x416 2 persons, 60.3ms
# Speed: 1.6ms preprocess, 60.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.80 ID:1  box=[248,144,337,281]
#
# 0: 640x448 1 person, 60.2ms
# Speed: 1.5ms preprocess, 60.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.93 ID:3  box=[571,196,733,429]
# video 1/1 (frame 48/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.1ms
# Frame 47:
#
# 0: 640x416 2 persons, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.83 ID:1  box=[248,144,337,281]
#
# 0: 640x448 1 person, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.94 ID:3  box=[569,193,731,429]
# video 1/1 (frame 49/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.8ms
# Frame 48:
#
# 0: 640x416 1 person, 59.6ms
# Speed: 2.8ms preprocess, 59.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.83 ID:1  box=[248,144,337,281]
#
# 0: 640x448 1 person, 59.6ms
# Speed: 2.4ms preprocess, 59.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.93 ID:3  box=[565,190,727,429]
# video 1/1 (frame 50/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.7ms
# Frame 49:
#
# 0: 640x416 2 persons, 58.0ms
# Speed: 1.4ms preprocess, 58.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.84 ID:1  box=[248,144,337,281]
#
# 0: 640x448 1 person, 59.4ms
# Speed: 1.7ms preprocess, 59.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.93 ID:3  box=[561,186,723,429]
# video 1/1 (frame 51/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.5ms
# Frame 50:
#
# 0: 640x416 2 persons, 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.83 ID:1  box=[248,144,337,281]
#
# 0: 640x448 1 person, 60.2ms
# Speed: 2.3ms preprocess, 60.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.93 ID:3  box=[556,182,718,428]
# video 1/1 (frame 52/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 46.3ms
# Frame 51:
#
# 0: 640x416 2 persons, 58.5ms
# Speed: 1.3ms preprocess, 58.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.82 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.93 ID:3  box=[552,179,714,428]
# video 1/1 (frame 53/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.3ms
# Frame 52:
#
# 0: 640x416 2 persons, 54.4ms
# Speed: 1.9ms preprocess, 54.4ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.82 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 56.9ms
# Speed: 1.5ms preprocess, 56.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.93 ID:3  box=[548,176,708,428]
# video 1/1 (frame 54/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.4ms
# Frame 53:
#
# 0: 640x416 1 person, 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.82 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.93 ID:3  box=[542,174,702,428]
# video 1/1 (frame 55/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.8ms
# Frame 54:
#
# 0: 640x416 1 person, 55.1ms
# Speed: 2.3ms preprocess, 55.1ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.81 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 57.8ms
# Speed: 1.6ms preprocess, 57.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.93 ID:3  box=[535,172,695,428]
# video 1/1 (frame 56/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.6ms
# Frame 55:
#
# 0: 640x416 2 persons, 60.5ms
# Speed: 2.1ms preprocess, 60.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.80 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 61.3ms
# Speed: 3.1ms preprocess, 61.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.93 ID:3  box=[529,167,689,428]
# video 1/1 (frame 57/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.5ms
# Frame 56:
#
# 0: 640x416 2 persons, 61.3ms
# Speed: 1.5ms preprocess, 61.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.78 ID:1  box=[248,144,337,281]
#
# 0: 640x416 1 person, 57.2ms
# Speed: 2.9ms preprocess, 57.2ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 416)
#   → standing 0.93 ID:3  box=[523,163,684,428]
# video 1/1 (frame 58/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.2ms
# Frame 57:
#
# 0: 640x416 2 persons, 59.6ms
# Speed: 2.3ms preprocess, 59.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.80 ID:1  box=[248,144,337,281]
#
# 0: 640x384 1 person, 57.7ms
# Speed: 2.4ms preprocess, 57.7ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.93 ID:3  box=[519,158,680,428]
# video 1/1 (frame 59/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.0ms
# Frame 58:
#
# 0: 640x416 2 persons, 60.9ms
# Speed: 2.1ms preprocess, 60.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.78 ID:1  box=[248,144,337,281]
#
# 0: 640x384 1 person, 54.2ms
# Speed: 1.2ms preprocess, 54.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.93 ID:3  box=[516,153,677,428]
# video 1/1 (frame 60/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.4ms
# Frame 59:
#
# 0: 640x416 2 persons, 55.4ms
# Speed: 1.7ms preprocess, 55.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.74 ID:1  box=[248,144,337,281]
#
# 0: 640x384 1 person, 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.93 ID:3  box=[513,147,673,426]
# video 1/1 (frame 61/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.8ms
# Frame 60:
#
# 0: 640x416 1 person, 59.2ms
# Speed: 1.3ms preprocess, 59.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.78 ID:1  box=[248,144,337,281]
#
# 0: 640x384 1 person, 54.7ms
# Speed: 1.5ms preprocess, 54.7ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.91 ID:3  box=[511,142,668,423]
# video 1/1 (frame 62/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.1ms
# Frame 61:
#
# 0: 640x416 1 person, 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.75 ID:1  box=[248,144,337,281]
#
# 0: 640x352 1 person, 53.0ms
# Speed: 2.3ms preprocess, 53.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.91 ID:3  box=[509,137,662,416]
# video 1/1 (frame 63/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.2ms
# Frame 62:
#
# 0: 640x448 1 person, 59.0ms
# Speed: 1.5ms preprocess, 59.0ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.78 ID:1  box=[247,144,336,280]
#
# 0: 640x352 1 person, 52.9ms
# Speed: 2.7ms preprocess, 52.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.91 ID:3  box=[507,133,656,409]
# video 1/1 (frame 64/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.7ms
# Frame 63:
#
# 0: 640x416 1 person, 61.7ms
# Speed: 2.1ms preprocess, 61.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.73 ID:1  box=[248,144,336,280]
#
# 0: 640x352 1 person, 52.7ms
# Speed: 1.2ms preprocess, 52.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.91 ID:3  box=[503,128,650,404]
# video 1/1 (frame 65/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 54.5ms
# Frame 64:
#
# 0: 640x448 1 person, 59.8ms
# Speed: 1.4ms preprocess, 59.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.76 ID:1  box=[247,144,336,280]
#
# 0: 640x352 1 person, 52.6ms
# Speed: 1.9ms preprocess, 52.6ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.92 ID:3  box=[500,124,643,397]
# video 1/1 (frame 66/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.8ms
# Frame 65:
#
# 0: 640x448 1 person, 60.2ms
# Speed: 1.5ms preprocess, 60.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.77 ID:1  box=[247,144,336,280]
#
# 0: 640x352 1 person, 52.0ms
# Speed: 1.5ms preprocess, 52.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.92 ID:3  box=[497,121,637,391]
# video 1/1 (frame 67/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.0ms
# Frame 66:
#
# 0: 640x448 1 person, 60.4ms
# Speed: 1.9ms preprocess, 60.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.77 ID:1  box=[247,144,335,279]
#
# 0: 640x352 1 person, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.91 ID:3  box=[495,119,632,388]
# video 1/1 (frame 68/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.6ms
# Frame 67:
#
# 0: 640x448 1 person, 61.5ms
# Speed: 1.3ms preprocess, 61.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.75 ID:1  box=[247,145,335,279]
#
# 0: 640x352 1 person, 56.5ms
# Speed: 2.4ms preprocess, 56.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.92 ID:3  box=[494,117,627,379]
# video 1/1 (frame 69/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.1ms
# Frame 68:
#
# 0: 640x448 1 person, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.80 ID:1  box=[247,145,335,280]
#
# 0: 640x320 1 person, 54.4ms
# Speed: 1.1ms preprocess, 54.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.93 ID:3  box=[489,115,619,375]
# video 1/1 (frame 70/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.6ms
# Frame 69:
#
# 0: 640x416 1 person, 64.0ms
# Speed: 2.3ms preprocess, 64.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.79 ID:1  box=[248,146,335,280]
#
# 0: 640x320 1 person, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.93 ID:3  box=[483,114,613,374]
# video 1/1 (frame 71/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.2ms
# Frame 70:
#
# 0: 640x448 1 person, 59.5ms
# Speed: 1.5ms preprocess, 59.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.78 ID:1  box=[248,147,335,280]
#
# 0: 640x320 1 person, 56.2ms
# Speed: 1.2ms preprocess, 56.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.93 ID:3  box=[481,114,610,373]
# video 1/1 (frame 72/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.0ms
# Frame 71:
#
# 0: 640x448 1 person, 61.8ms
# Speed: 1.4ms preprocess, 61.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[248,148,334,279]
#
# 0: 640x320 1 person, 54.2ms
# Speed: 2.2ms preprocess, 54.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.92 ID:3  box=[479,115,606,373]
# video 1/1 (frame 73/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.3ms
# Frame 72:
#
# 0: 640x448 1 person, 61.4ms
# Speed: 2.8ms preprocess, 61.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[248,149,334,279]
#
# 0: 640x320 1 person, 52.8ms
# Speed: 1.1ms preprocess, 52.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.91 ID:3  box=[476,115,603,373]
# video 1/1 (frame 74/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.7ms
# Frame 73:
#
# 0: 640x448 1 person, 61.3ms
# Speed: 2.3ms preprocess, 61.3ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.78 ID:1  box=[249,151,334,280]
#
# 0: 640x320 1 person, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.92 ID:3  box=[473,116,598,372]
# video 1/1 (frame 75/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 48.4ms
# Frame 74:
#
# 0: 640x448 1 person, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.79 ID:1  box=[249,153,334,280]
#
# 0: 640x320 1 person, 48.1ms
# Speed: 1.3ms preprocess, 48.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.93 ID:3  box=[471,117,595,372]
# video 1/1 (frame 76/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.6ms
# Frame 75:
#
# 0: 640x448 1 person, 64.8ms
# Speed: 1.3ms preprocess, 64.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.80 ID:1  box=[249,154,333,280]
#
# 0: 640x320 1 person, 47.7ms
# Speed: 1.5ms preprocess, 47.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.93 ID:3  box=[469,118,591,372]
# video 1/1 (frame 77/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.7ms
# Frame 76:
#
# 0: 640x448 1 person, 65.0ms
# Speed: 2.9ms preprocess, 65.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.78 ID:1  box=[249,155,333,279]
#
# 0: 640x320 1 person, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.90 ID:3  box=[467,119,586,368]
# video 1/1 (frame 78/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.7ms
# Frame 77:
#
# 0: 640x448 1 person, 62.3ms
# Speed: 2.6ms preprocess, 62.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.74 ID:1  box=[250,156,333,279]
#
# 0: 640x320 1 person, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.89 ID:3  box=[466,120,582,363]
# video 1/1 (frame 79/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 44.7ms
# Frame 78:
#
# 0: 640x448 1 person, 60.4ms
# Speed: 1.3ms preprocess, 60.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.70 ID:1  box=[250,157,332,277]
#
# 0: 640x320 1 person, 55.1ms
# Speed: 2.3ms preprocess, 55.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.89 ID:3  box=[465,121,577,356]
# video 1/1 (frame 80/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 48.9ms
# Frame 79:
#
# 0: 640x448 1 person, 64.7ms
# Speed: 1.6ms preprocess, 64.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.63 ID:1  box=[251,159,332,275]
#
# 0: 640x320 1 person, 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.89 ID:3  box=[463,122,573,353]
#
# 0: 640x448 2 persons, 60.1ms
# Speed: 1.3ms preprocess, 60.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.39 ID:10  box=[246,161,391,378]
# video 1/1 (frame 81/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 47.2ms
# Frame 80:
#
# 0: 640x480 1 person, 62.3ms
# Speed: 1.6ms preprocess, 62.3ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.57 ID:1  box=[250,159,332,275]
#
# 0: 640x320 1 person, 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.91 ID:3  box=[460,122,569,350]
#
# 0: 640x448 1 person, 59.4ms
# Speed: 1.7ms preprocess, 59.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.48 ID:10  box=[245,160,391,378]
# video 1/1 (frame 82/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 44.8ms
# Frame 81:
#
# 0: 640x480 1 person, 67.7ms
# Speed: 2.7ms preprocess, 67.7ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.50 ID:1  box=[249,160,332,277]
#
# 0: 640x320 1 person, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.91 ID:3  box=[458,121,566,349]
#
# 0: 640x448 2 persons, 60.6ms
# Speed: 1.7ms preprocess, 60.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.55 ID:10  box=[244,161,390,378]
# video 1/1 (frame 83/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.8ms
# Frame 82:
#
# 0: 640x480 1 person, 60.0ms
# Speed: 2.9ms preprocess, 60.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.46 ID:1  box=[249,161,333,278]
#
# 0: 640x320 1 person, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.92 ID:3  box=[454,121,563,350]
#
# 0: 640x448 2 persons, 65.4ms
# Speed: 1.3ms preprocess, 65.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.55 ID:10  box=[244,162,389,379]
# video 1/1 (frame 84/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 50.0ms
# Frame 83:
#
# 0: 640x480 1 person, 67.5ms
# Speed: 1.4ms preprocess, 67.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.34 ID:1  box=[249,163,333,279]
#
# 0: 640x320 1 person, 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.92 ID:3  box=[452,120,560,349]
#
# 0: 640x448 2 persons, 61.4ms
# Speed: 2.5ms preprocess, 61.4ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.66 ID:10  box=[244,164,388,379]
# video 1/1 (frame 85/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.0ms
# Frame 84:
#
# 0: 640x480 1 person, 67.7ms
# Speed: 1.5ms preprocess, 67.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.24 ID:1  box=[249,164,333,279]
#
# 0: 640x320 1 person, 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.91 ID:3  box=[449,120,557,350]
#
# 0: 640x448 2 persons, 59.0ms
# Speed: 2.5ms preprocess, 59.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.73 ID:10  box=[244,165,388,380]
# video 1/1 (frame 86/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.2ms
# Frame 85:
#
# 0: 640x480 1 person, 61.3ms
# Speed: 1.5ms preprocess, 61.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.17 ID:1  box=[248,165,334,282]
#
# 0: 640x320 1 person, 48.3ms
# Speed: 2.5ms preprocess, 48.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.92 ID:3  box=[447,118,554,351]
#
# 0: 640x448 2 persons, 66.6ms
# Speed: 2.2ms preprocess, 66.6ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.80 ID:10  box=[244,166,388,380]
# video 1/1 (frame 87/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 48.4ms
# Frame 86:
#
# 0: 640x480 1 person, 63.8ms
# Speed: 1.9ms preprocess, 63.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.18 ID:1  box=[248,167,334,282]
#
# 0: 640x320 1 person, 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 320)
#   → standing 0.92 ID:3  box=[446,117,552,350]
#
# 0: 640x448 1 person, 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.80 ID:10  box=[245,167,388,380]
# video 1/1 (frame 88/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.6ms
# Frame 87:
#
# 0: 640x512 1 person, 63.6ms
# Speed: 3.1ms preprocess, 63.6ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 512)
#   → sitting 0.12 ID:1  box=[248,167,333,279]
#
# 0: 640x288 1 person, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 288)
#   → standing 0.92 ID:3  box=[444,116,549,351]
#
# 0: 640x448 2 persons, 62.6ms
# Speed: 2.9ms preprocess, 62.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.86 ID:10  box=[245,168,387,381]
# video 1/1 (frame 89/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 50.2ms
# Frame 88:
#
# 0: 640x512 1 person, 62.3ms
# Speed: 1.4ms preprocess, 62.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)
#   → sitting 0.17 ID:1  box=[249,169,331,276]
#
# 0: 640x288 1 person, 49.7ms
# Speed: 1.4ms preprocess, 49.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → standing 0.92 ID:3  box=[442,113,547,351]
#
# 0: 640x448 2 persons, 62.3ms
# Speed: 1.4ms preprocess, 62.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.82 ID:10  box=[245,169,387,381]
# video 1/1 (frame 90/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.8ms
# Frame 89:
#
# 0: 640x512 1 person, 67.9ms
# Speed: 2.9ms preprocess, 67.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#   → sitting 0.18 ID:1  box=[249,170,331,275]
#
# 0: 640x288 1 person, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 288)
#   → standing 0.91 ID:3  box=[440,111,544,351]
#
# 0: 640x448 2 persons, 63.6ms
# Speed: 1.4ms preprocess, 63.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.81 ID:10  box=[245,170,386,381]
# video 1/1 (frame 91/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.5ms
# Frame 90:
#
# 0: 640x512 1 person, 68.1ms
# Speed: 1.8ms preprocess, 68.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 512)
#   → sitting 0.21 ID:1  box=[248,171,333,279]
#
# 0: 640x288 1 person, 50.2ms
# Speed: 2.1ms preprocess, 50.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → standing 0.91 ID:3  box=[438,109,540,351]
#
# 0: 640x448 2 persons, 66.9ms
# Speed: 1.4ms preprocess, 66.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.77 ID:10  box=[245,171,386,381]
# video 1/1 (frame 92/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.9ms
# Frame 91:
#
# 0: 640x512 1 person, 68.9ms
# Speed: 2.7ms preprocess, 68.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 512)
#   → sitting 0.19 ID:1  box=[248,172,333,280]
#
# 0: 640x288 1 person, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 288)
#   → standing 0.91 ID:3  box=[435,105,537,351]
#
# 0: 640x448 3 persons, 57.1ms
# Speed: 2.1ms preprocess, 57.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.79 ID:10  box=[245,172,385,381]
# video 1/1 (frame 93/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.4ms
# Frame 92:
#
# 0: 640x544 1 person, 78.3ms
# Speed: 4.9ms preprocess, 78.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 544)
#   → sitting 0.21 ID:1  box=[248,174,334,280]
#
# 0: 640x288 1 person, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 288)
#   → standing 0.90 ID:3  box=[433,103,534,352]
#
# 0: 640x448 2 persons, 64.6ms
# Speed: 2.8ms preprocess, 64.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.78 ID:10  box=[246,174,385,381]
# video 1/1 (frame 94/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.4ms
# Frame 93:
#
# 0: 640x544 1 person, 75.9ms
# Speed: 2.1ms preprocess, 75.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 544)
#   → sitting 0.21 ID:1  box=[248,174,334,281]
#
# 0: 640x256 1 person, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 256)
#   → standing 0.90 ID:3  box=[430,98,531,351]
#
# 0: 640x448 3 persons, 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.79 ID:10  box=[246,174,385,381]
# video 1/1 (frame 95/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.3ms
# Frame 94:
#
# 0: 640x544 1 person, 72.0ms
# Speed: 2.1ms preprocess, 72.0ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 544)
#   → sitting 0.21 ID:1  box=[246,175,336,285]
#
# 0: 640x256 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 256)
#   → standing 0.91 ID:3  box=[429,94,529,351]
#
# 0: 640x448 2 persons, 61.5ms
# Speed: 3.1ms preprocess, 61.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.83 ID:10  box=[247,176,385,381]
# video 1/1 (frame 96/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 51.6ms
# Frame 95:
#
# 0: 640x544 1 person, 75.7ms
# Speed: 3.6ms preprocess, 75.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 544)
#   → sitting 0.16 ID:1  box=[246,176,335,286]
#
# 0: 640x256 1 person, 41.6ms
# Speed: 1.7ms preprocess, 41.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.90 ID:3  box=[427,91,526,349]
#
# 0: 640x448 2 persons, 64.2ms
# Speed: 1.4ms preprocess, 64.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → standing 0.84 ID:10  box=[247,177,385,381]
# ...
# Frame 247:
#
# 0: 640x448 1 person, 61.6ms
# Speed: 1.4ms preprocess, 61.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.78 ID:1  box=[256,166,343,291]
#
# 0: 640x576 1 person, 83.5ms
# Speed: 5.6ms preprocess, 83.5ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.74 ID:3  box=[343,207,472,354]
#
# 0: 640x384 3 persons, 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.12 ID:21  box=[257,166,373,371]
# video 1/1 (frame 249/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.1ms
# Frame 248:
#
# 0: 640x480 1 person, 67.6ms
# Speed: 3.4ms preprocess, 67.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.72 ID:1  box=[256,166,343,290]
#
# 0: 640x576 1 person, 78.8ms
# Speed: 3.7ms preprocess, 78.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.79 ID:3  box=[343,206,472,353]
#
# 0: 640x384 3 persons, 52.2ms
# Speed: 3.2ms preprocess, 52.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.26 ID:21  box=[258,167,374,372]
# video 1/1 (frame 250/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 44.7ms
# Frame 249:
#
# 0: 640x448 1 person, 59.3ms
# Speed: 2.2ms preprocess, 59.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.72 ID:1  box=[257,166,343,290]
#
# 0: 640x576 1 person, 73.6ms
# Speed: 4.0ms preprocess, 73.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.82 ID:3  box=[341,203,473,353]
#
# 0: 640x384 4 persons, 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.24 ID:21  box=[258,167,375,372]
# video 1/1 (frame 251/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.8ms
# Frame 250:
#
# 0: 640x448 2 persons, 59.7ms
# Speed: 2.5ms preprocess, 59.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.56 ID:1  box=[258,165,344,288]
#
# 0: 640x576 1 person, 78.0ms
# Speed: 2.6ms preprocess, 78.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.88 ID:3  box=[340,202,472,352]
#
# 0: 640x384 4 persons, 54.5ms
# Speed: 1.4ms preprocess, 54.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.40 ID:21  box=[259,166,376,372]
# video 1/1 (frame 252/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 50.6ms
# Frame 251:
#
# 0: 640x448 2 persons, 65.2ms
# Speed: 2.1ms preprocess, 65.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.62 ID:1  box=[258,165,343,287]
#
# 0: 640x576 1 person, 78.1ms
# Speed: 2.8ms preprocess, 78.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.88 ID:3  box=[340,202,472,352]
#
# 0: 640x384 3 persons, 55.4ms
# Speed: 1.2ms preprocess, 55.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.38 ID:21  box=[260,167,377,372]
# video 1/1 (frame 253/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.4ms
# Frame 252:
#
# 0: 640x448 2 persons, 60.4ms
# Speed: 1.9ms preprocess, 60.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.63 ID:1  box=[258,165,344,288]
#
# 0: 640x576 1 person, 78.1ms
# Speed: 2.4ms preprocess, 78.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.87 ID:3  box=[338,201,473,354]
#
# 0: 640x384 4 persons, 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.29 ID:21  box=[258,167,375,372]
# video 1/1 (frame 254/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.4ms
# Frame 253:
#
# 0: 640x448 1 person, 61.2ms
# Speed: 1.4ms preprocess, 61.2ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.63 ID:1  box=[258,165,344,288]
#
# 0: 640x576 2 persons, 82.4ms
# Speed: 4.0ms preprocess, 82.4ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.85 ID:3  box=[335,199,474,357]
#
# 0: 640x384 3 persons, 54.6ms
# Speed: 4.4ms preprocess, 54.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.25 ID:21  box=[258,167,373,372]
# video 1/1 (frame 255/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 47.6ms
# Frame 254:
#
# 0: 640x448 1 person, 58.5ms
# Speed: 3.3ms preprocess, 58.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.71 ID:1  box=[259,165,344,288]
#
# 0: 640x576 3 persons, 77.4ms
# Speed: 2.6ms preprocess, 77.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.85 ID:3  box=[333,199,474,360]
#
# 0: 640x384 3 persons, 55.3ms
# Speed: 1.2ms preprocess, 55.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.15 ID:21  box=[256,166,370,371]
# video 1/1 (frame 256/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 51.4ms
# Frame 255:
#
# 0: 640x480 1 person, 63.0ms
# Speed: 1.5ms preprocess, 63.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.66 ID:1  box=[259,166,344,287]
#
# 0: 640x576 3 persons, 81.2ms
# Speed: 4.2ms preprocess, 81.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.87 ID:3  box=[332,198,475,362]
#
# 0: 640x384 2 persons, 54.1ms
# Speed: 1.6ms preprocess, 54.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.19 ID:21  box=[254,166,367,370]
# video 1/1 (frame 257/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.1ms
# Frame 256:
#
# 0: 640x480 1 person, 62.4ms
# Speed: 1.9ms preprocess, 62.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.69 ID:1  box=[259,166,344,287]
#
# 0: 640x576 2 persons, 78.6ms
# Speed: 3.2ms preprocess, 78.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.89 ID:3  box=[332,198,475,362]
#
# 0: 640x352 3 persons, 51.8ms
# Speed: 2.6ms preprocess, 51.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.19 ID:21  box=[251,166,363,370]
# video 1/1 (frame 258/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.7ms
# Frame 257:
#
# 0: 640x480 1 person, 61.8ms
# Speed: 1.6ms preprocess, 61.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.72 ID:1  box=[259,166,344,287]
#
# 0: 640x576 2 persons, 74.8ms
# Speed: 2.9ms preprocess, 74.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.88 ID:3  box=[331,195,477,362]
#
# 0: 640x352 3 persons, 54.0ms
# Speed: 1.3ms preprocess, 54.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.16 ID:21  box=[253,166,364,370]
# video 1/1 (frame 259/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 50.1ms
# Frame 258:
#
# 0: 640x480 1 person, 61.7ms
# Speed: 2.4ms preprocess, 61.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.70 ID:1  box=[260,166,344,285]
#
# 0: 640x576 2 persons, 83.7ms
# Speed: 3.9ms preprocess, 83.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.89 ID:3  box=[331,193,477,362]
#
# 0: 640x352 1 person, 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.18 ID:21  box=[252,166,362,370]
# video 1/1 (frame 260/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 50.5ms
# Frame 259:
#
# 0: 640x480 1 person, 62.8ms
# Speed: 1.6ms preprocess, 62.8ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.69 ID:1  box=[259,166,345,287]
#
# 0: 640x576 2 persons, 71.9ms
# Speed: 2.7ms preprocess, 71.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.88 ID:3  box=[331,192,477,362]
#
# 0: 640x352 2 persons, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.23 ID:21  box=[258,167,367,370]
# video 1/1 (frame 261/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 50.7ms
# Frame 260:
#
# 0: 640x480 1 person, 64.3ms
# Speed: 2.7ms preprocess, 64.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.66 ID:1  box=[259,166,345,287]
#
# 0: 640x576 1 person, 80.8ms
# Speed: 3.0ms preprocess, 80.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.87 ID:3  box=[331,192,476,361]
#
# 0: 640x352 1 person, 48.9ms
# Speed: 2.8ms preprocess, 48.9ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.31 ID:21  box=[261,168,371,371]
# video 1/1 (frame 262/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.2ms
# Frame 261:
#
# 0: 640x480 1 person, 56.8ms
# Speed: 2.2ms preprocess, 56.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.72 ID:1  box=[259,166,345,287]
#
# 0: 640x576 2 persons, 73.0ms
# Speed: 2.9ms preprocess, 73.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.86 ID:3  box=[332,192,476,361]
#
# 0: 640x352 2 persons, 52.9ms
# Speed: 1.9ms preprocess, 52.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.21 ID:21  box=[261,168,370,371]
# video 1/1 (frame 263/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.9ms
# Frame 262:
#
# 0: 640x480 1 person, 60.5ms
# Speed: 1.6ms preprocess, 60.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.70 ID:1  box=[260,167,345,286]
#
# 0: 640x576 1 person, 76.7ms
# Speed: 2.4ms preprocess, 76.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.86 ID:3  box=[334,192,474,356]
#
# 0: 640x352 3 persons, 53.6ms
# Speed: 1.8ms preprocess, 53.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.21 ID:21  box=[263,169,373,371]
# video 1/1 (frame 264/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.1ms
# Frame 263:
#
# 0: 640x480 1 person, 62.0ms
# Speed: 1.6ms preprocess, 62.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.73 ID:1  box=[259,167,345,287]
#
# 0: 640x576 1 person, 77.0ms
# Speed: 3.6ms preprocess, 77.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.84 ID:3  box=[332,192,475,359]
#
# 0: 640x352 2 persons, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.14 ID:21  box=[261,168,372,370]
# video 1/1 (frame 265/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.4ms
# Frame 264:
#
# 0: 640x480 1 person, 61.7ms
# Speed: 1.8ms preprocess, 61.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.72 ID:1  box=[260,167,345,285]
#
# 0: 640x576 1 person, 79.7ms
# Speed: 3.8ms preprocess, 79.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.86 ID:3  box=[333,192,475,358]
#
# 0: 640x352 2 persons, 53.5ms
# Speed: 1.9ms preprocess, 53.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#   → standing 0.15 ID:21  box=[261,167,372,370]
# video 1/1 (frame 266/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 45.1ms
# Frame 265:
#
# 0: 640x480 1 person, 63.4ms
# Speed: 1.5ms preprocess, 63.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.75 ID:1  box=[260,167,345,285]
#
# 0: 640x576 1 person, 74.0ms
# Speed: 4.6ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.85 ID:3  box=[333,192,475,358]
#
# 0: 640x384 2 persons, 55.0ms
# Speed: 1.7ms preprocess, 55.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.13 ID:21  box=[260,167,372,370]
# video 1/1 (frame 267/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 3 persons, 49.9ms
# Frame 266:
#
# 0: 640x480 1 person, 67.5ms
# Speed: 1.9ms preprocess, 67.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.77 ID:1  box=[260,166,345,285]
#
# 0: 640x576 1 person, 74.8ms
# Speed: 3.8ms preprocess, 74.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.85 ID:3  box=[334,192,474,356]
#
# 0: 640x384 2 persons, 55.2ms
# Speed: 1.3ms preprocess, 55.2ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 384)
#   → standing 0.11 ID:21  box=[259,167,371,369]
# video 1/1 (frame 268/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.0ms
# Frame 267:
#
# 0: 640x480 1 person, 61.4ms
# Speed: 1.7ms preprocess, 61.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.77 ID:1  box=[259,167,346,285]
#
# 0: 640x576 1 person, 79.9ms
# Speed: 4.6ms preprocess, 79.9ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.85 ID:3  box=[334,193,474,355]
# video 1/1 (frame 269/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 51.0ms
# Frame 268:
#
# 0: 640x480 1 person, 62.6ms
# Speed: 3.3ms preprocess, 62.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.76 ID:1  box=[259,167,346,285]
#
# 0: 640x576 1 person, 78.3ms
# Speed: 4.9ms preprocess, 78.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.85 ID:3  box=[334,192,474,355]
# video 1/1 (frame 270/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 47.1ms
# Frame 269:
#
# 0: 640x480 1 person, 64.9ms
# Speed: 3.0ms preprocess, 64.9ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.71 ID:1  box=[259,167,346,285]
#
# 0: 640x576 1 person, 78.1ms
# Speed: 3.0ms preprocess, 78.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.85 ID:3  box=[334,193,475,357]
# video 1/1 (frame 271/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 45.4ms
# Frame 270:
#
# 0: 640x480 1 person, 62.4ms
# Speed: 1.8ms preprocess, 62.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.74 ID:1  box=[259,167,346,285]
#
# 0: 640x576 1 person, 73.8ms
# Speed: 2.6ms preprocess, 73.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.87 ID:3  box=[334,193,474,356]
# video 1/1 (frame 272/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 50.3ms
# Frame 271:
#
# 0: 640x480 1 person, 62.9ms
# Speed: 1.6ms preprocess, 62.9ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.78 ID:1  box=[259,167,346,285]
#
# 0: 640x576 1 person, 73.9ms
# Speed: 2.5ms preprocess, 73.9ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.88 ID:3  box=[333,193,475,359]
# video 1/1 (frame 273/273) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4: 384x640 2 persons, 49.8ms
# Frame 272:
#
# 0: 640x480 1 person, 63.3ms
# Speed: 3.4ms preprocess, 63.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.77 ID:1  box=[259,167,346,284]
#
# 0: 640x576 1 person, 77.9ms
# Speed: 3.5ms preprocess, 77.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.88 ID:3  box=[333,193,475,359]
# Speed: 2.6ms preprocess, 49.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to d:\self study\0 - FYP\Tracking-and-counting-Using-YOLOv8-and-DeepSORT\runs\detect\track25
