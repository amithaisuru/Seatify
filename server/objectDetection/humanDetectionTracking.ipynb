# %%
# !pip install ultralytics opencv-python

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import time

# %%
# Load the YOLOv8 model
model = YOLO('yolov8x.pt').to('cuda:0')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs

# %%
# --------Human & Object detection in video - correctly working--------

'''

# Initialize video capture
cap = cv2.VideoCapture(r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4')

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    while cap.isOpened():
        print("Reading frame...")
        ret, frame = cap.read()

        # Perform detection on the current frame
        results = model(frame)  # Detect objects in the frame

        # Filter detections for 'person' and 'chair' classes
        # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

        # Process the results
        for result in results:

            boxes = result.boxes  # Get bounding boxes

            for box in boxes:
                class_id = box.cls[0].item()  # Get the class id of the detected object
                if class_id in person_and_chair:  # Check if it is a person or a chair
                    # Get the bounding box coordinates
                    x1, y1, x2, y2 = map(int, box.xyxy[0])

                    # Get the class ID and confidence score
                    class_id = box.cls[0].item()
                    confidence = box.conf[0].item()

                    # Get the class name
                    label = model.names[class_id]

                    # Print out the detected object details
                    print(
                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                    )
                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                    # Draw a bounding box around the object

                    # Define different colors for different objects
                    if label == "person":
                        color = (255, 0, 0)  # Blue color for human (person)
                    elif label == "chair":
                        color = (0, 0, 255)  # Red color for chair
                    else:
                        color = (0, 255, 0)  # Default green for other objects

                    # Draw a bounding box around the object with the selected color
                    cv2.rectangle(
                        frame, (x1, y1), (x2, y2), color, 2
                    )  # Bounding box with the chosen color

                    cv2.putText(
                        frame,
                        label,
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        (0, 255, 0),
                        2,
                    )

        if frame is not None and frame.size > 0:
            cv2.imshow("Video", frame)
        else:
            print("Warning: Empty frame encountered!")
            break

        # Press 'q' to quit the video window
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''

# %%
# -----Tried to skip frames and process frames after every 10 seconds. Did not worked-----


'''

# Initialize video capture
cap = cv2.VideoCapture(
    r"D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4"
)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    # Get the frame rate (fps) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video Frame Rate (FPS): {fps}")

    # Time between frames we want to process (10 seconds)
    interval = 2  # Process every 10 seconds

    # Calculate the frame number corresponding to the desired times
    frame_number = 0
    prev_time = 0  # Start at time 0

    while cap.isOpened():
        # Calculate the time for the current frame (in seconds)
        current_time = frame_number / fps

        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)
        if current_time >= prev_time:

            print("Reading frame...")
            # Read a frame from the video
            ret, frame = cap.read()

            # Check if the frame was read properly
            if not ret:
                print("Error: Couldn't read the frame.")
                break

            # Perform detection on the current frame
            results = model(frame)  # Detect objects in the frame

            # Filter detections for 'person' and 'chair' classes
            # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

            # Process the results
            for result in results:
                # Extract bounding boxes, confidence, and class IDs
                boxes = result.boxes  # Get bounding boxes

                for box in boxes:
                    class_id = box.cls[0].item()  # Get the class id of the detected object

                    if (class_id in person_and_chair):  # Check if it is a person or a chair
                        # Get the bounding box coordinates
                        x1, y1, x2, y2 = map(int, box.xyxy[0])

                        # Get the class ID and confidence score
                        class_id = box.cls[0].item()
                        confidence = box.conf[0].item()

                        # Get the class name
                        label = model.names[class_id]

                        # Print out the detected object details
                        print(
                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                        )
                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                        # Draw a bounding box around the object

                        # Define different colors for different objects
                        if label == "person":
                            color = (255, 0, 0)  # Blue color for human (person)
                        elif label == "chair":
                            color = (0, 0, 255)  # Red color for chair
                        else:
                            color = (0, 255, 0)  # Default green for other objects

                        # Draw a bounding box around the object with the selected color
                        cv2.rectangle(
                            frame, (x1, y1), (x2, y2), color, 2
                        )  # Bounding box with the chosen color

                        cv2.putText(
                            frame,
                            label,
                            (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.9,
                            (0, 255, 0),
                            2,
                        )

                if frame is not None and frame.size > 0:
                    cv2.imshow("Video", frame)
                else:
                    print("Warning: Empty frame encountered!")
                    break

                # Press 'q' to quit the video window
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break

                # Update prev_time to the next desired frame time (e.g., t = 10s, 20s)
                prev_time += interval  # Move to the next interval (10 seconds)

            # Skip frames until we reach the desired frame time
            frame_number += 1
        
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''

# %%
import torch
print("CUDA available? ", torch.cuda.is_available())
print("GPU count:    ", torch.cuda.device_count())
print("Current dev:  ", torch.cuda.current_device())
print("Dev name:     ", torch.cuda.get_device_name(0))
# Out:
# CUDA available?  True
# GPU count:     1
# Current dev:   0
# Dev name:      NVIDIA GeForce GTX 1660 Ti

# %%
# ----- Human & Chair detection and tracking - correctly working -----

'''
# 3. Run detection + ByteTrack on your video
#    – source: your file path
#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)
#    – classes: [0,56] → only person (0) & chair (56)
#    – persist: keep track IDs alive across frames
#    – show: pop up each frame (set False if headless)
#    – save: write out an annotated video to runs/track/exp*
stream = model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4',
    tracker='bytetrack.yaml',
    classes=[0, 56],
    persist=True,
    show=False,    # we’ll show manually
    save=True,    # disable automatic save
    save_dir='my_outputs/',
    stream=True,   # <— Enable streaming!
    device='cuda:0'
)

for frame_idx, res in enumerate(stream):
    print(f"Frame {frame_idx}:")
    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id
    for xyxy, conf, cls_id, track_id in zip(
        res.boxes.xyxy, 
        res.boxes.conf, 
        res.boxes.cls, 
        res.boxes.id
    ):
        x1, y1, x2, y2 = map(int, xyxy.tolist())
        conf = float(conf)
        cls_id = int(cls_id)
        track_id = int(track_id)
        label = res.names[cls_id]  # e.g. "person" or "chair"
        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")

    # Optional: display the annotated frame and quit on 'q'
    frame = res.plot()
    cv2.imshow("Track (press q to quit)", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

'''

# %%
import cv2
import numpy as np
import os

# Create an output folder for annotated frames
output_dir = 'annotated_frames/HOTWOK-1-A'
os.makedirs(output_dir, exist_ok=True)

from ultralytics import YOLO

# Load models onto GPU
det_model  = YOLO('yolov8x.pt').to('cuda:0')
pose_model = YOLO('yolov8x-pose.pt').to('cuda:0')

def calculate_angle(a, b, c):
    #Builds vectors ba and bc around joint b.
    ba = a - b
    bc = c - b
    
    #Uses the dot-product formula to get the cosine of angle abc
    cosang = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-6)

    #clip to valid range and convert from radians to degrees
    return np.degrees(np.arccos(np.clip(cosang, -1.0, 1.0)))

# compute knee angle
def kneeAngleCondition(kpts):
    try:
        # compute left & right knee angles
        l_ang = calculate_angle(kpts[11,:2], kpts[13,:2], kpts[15,:2]) #computes left knee angles
        r_ang = calculate_angle(kpts[12,:2], kpts[14,:2], kpts[16,:2]) #computes right knee angles
        # compute average angle
        knee_angle = (l_ang + r_ang) / 2

        # Threshold to decide sitting vs standing
        if knee_angle < 110:
            return True
        else:
            return False
    except:
        pass  

#Compute torso lean: angle at the hip by shoulder→hip→knee
def torsoAngleCondition(kpts):
    try:
        left_torso  = calculate_angle(kpts[5,:2],  kpts[11,:2], kpts[13,:2])  # L-shoulder, L-hip, L-knee
        right_torso = calculate_angle(kpts[6,:2],  kpts[12,:2], kpts[14,:2])  # R-shoulder, R-hip, R-knee
        torso_angle = (left_torso + right_torso) / 2

        # Threshold to decide sitting vs standing
        if torso_angle < 110:
            return True
        else:
            return False

    except:
        pass  

#Hip‐knee level test: True if avg vertical distance between hip & knee is < 15% of crop height
def hipKneeLevelCondition(kpts, crop_height):
    try:
        dy_left  = abs(kpts[11,1] - kpts[13,1])
        dy_right = abs(kpts[12,1] - kpts[14,1])
        avg_dy   = (dy_left + dy_right) / 2

        return (avg_dy / crop_height) < 0.15
    except:
        return False

# IoU helper
def bbox_iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1b, y1b, x2b, y2b = box2
    xi1, yi1 = max(x1, x1b), max(y1, y1b)
    xi2, yi2 = min(x2, x2b), min(y2, y2b)
    inter_w = max(0, xi2 - xi1)
    inter_h = max(0, yi2 - yi1)
    inter = inter_w * inter_h
    area1 = (x2 - x1) * (y2 - y1)
    area2 = (x2b - x1b) * (y2b - y1b)
    union = area1 + area2 - inter
    return inter / union if union > 0 else 0

IOU_THRESHOLD = 0.2

## ------------------Save Annotated Video------------------

# 5) Prepare VideoWriter
'''
input_path = r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam1 - 1.mp4'
cap = cv2.VideoCapture(input_path)
fps    = cap.get(cv2.CAP_PROP_FPS)
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
output_path = 'outputs/annotated_HOTWOK_Cam1_OR.mp4'
os.makedirs(os.path.dirname(output_path), exist_ok=True)
writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

'''
# ---end of save annotated video code---

# Start the detection + track stream
stream = det_model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4',
    tracker='bytetrack.yaml',
    classes=[0,56],
    persist=True,
    show=False,
    save=True,
    save_dir='outputs/',
    stream=True,
    device='cuda:0'
)

#process frames
for frameIndex, singleFrame in enumerate(stream): #enumerate(stream) gives (frame_idx, res) as soon as each frame is done
    frame = singleFrame.orig_img.copy() # copy of raw frame we annotate
    print(f"Frame {frameIndex}:")

    # Pull detections
    # Unpack the tracked detections in parallel arrays
    boxesXYXYs = singleFrame.boxes.xyxy.cpu().numpy() # bounding boxes (n×4)
    confs     = singleFrame.boxes.conf.cpu().numpy() # confidence scores (n) 
    cls_ids   = singleFrame.boxes.cls.cpu().numpy().astype(int) # class IDs (n)
    track_ids = singleFrame.boxes.id.cpu().numpy().astype(int) # track IDs (n)

    # Build a list of chairs this frame
    chair_boxes = []
    for (x1,y1,x2,y2), cls_id in zip(boxesXYXYs, cls_ids):
        if singleFrame.names[cls_id] == 'chair':
            chairBoundingBox = list(map(int, (x1,y1,x2,y2)))
            chair_boxes.append(chairBoundingBox)
        
    # print(f"  → Found {len(chair_boxes)} chairs in this frame")
    # print(f"  → Found {len(boxesXYXYs)} total detections in this frame")

    #Iterate through each detection in this frame
    for (x1, y1, x2, y2), conf, cls_id, track_id in zip(boxesXYXYs, confs, cls_ids, track_ids): #Zips the four arrays so you handle each detection in lockstep.
        
        #Converts the box coords to integers
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))

        #looks up the human-readable class name
        label = singleFrame.names[cls_id] # e.g. "person" or "chair"

        # Person branch
        if label == 'person':

            # Defaults the posture to “unknown” with a yellow box
            posture, color = 'unknown', (0,255,255)

            # Crops the detected person region and runs pose_model on that ROI
            roi = frame[y1:y2, x1:x2]
            p = pose_model(roi, device='cuda:0')[0]


            # If keypoints were found, extracts the raw (n,17,3) array from p.keypoints.data.
            # In the shape tuple (n, 17, 3), that leading n is simply the number of person instances (i.e. detections) 
            # that the pose model found in your cropped image
            # Since you’re cropping around a single detected box, in most cases n will be 1
            if p.keypoints is not None:
                # Extract the raw (n,17,3) tensor of keypoints
                kpts_np = p.keypoints.data.cpu().numpy()  # shape (n,17,3)

                # Ensure we have at least 17 keypoints
                if kpts_np.ndim == 3 and kpts_np.shape[1] >= 17:
                    kpts = kpts_np[0]  # first person
                    # shape (17,3): [x,y,conf] per joint

                    # Compute the knee angle
                    kneeAngleResult = kneeAngleCondition(kpts)

                    # Compute the torso angle
                    torsoAngleResult = torsoAngleCondition(kpts)

                    # Compute the hip-knee level condition
                    hipKneeLevelResult = hipKneeLevelCondition(kpts, crop_height=(y2-y1))
                    
                    # 4th test: does this person overlap any chair?
                    iouSittingResult = any(
                        bbox_iou([x1,y1,x2,y2], cb) > IOU_THRESHOLD
                        for cb in chair_boxes
                    )
                    
                    if kneeAngleResult or torsoAngleResult:
                        posture, color = 'sitting',  (0,255,0)
                    else:
                        posture, color = 'standing', (0,0,255)
                    
            text = f"{posture} {conf:.2f} ID:{track_id}"

        else:
            # chair
            color = (255,0,0)
            text  = f"chair {conf:.2f} ID:{track_id}"

        # Draw & print
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
        cv2.putText(frame, text, (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        print(f"  → {text}  box=[{x1},{y1},{x2},{y2}]")

    # write and optionally display
    #writer.write(frame)

    out_path = os.path.join(output_dir, f"frame_{frameIndex:06d}.jpg")
    cv2.imwrite(out_path, frame)

    cv2.imshow("Pose+Track", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# <>:89: SyntaxWarning: invalid escape sequence '\s'
# <>:89: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_4904\2187437397.py:89: SyntaxWarning: invalid escape sequence '\s'
#   '''
# video 1/1 (frame 1/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 56.5ms
# Frame 0:
#   → chair 0.66 ID:1  box=[393,321,498,492]
#
# 0: 640x224 1 person, 34.3ms
# Speed: 0.9ms preprocess, 34.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:2  box=[422,143,500,389]
#
# 0: 640x224 (no detections), 37.9ms
# Speed: 2.3ms preprocess, 37.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.54 ID:3  box=[195,343,291,633]
#   → chair 0.40 ID:4  box=[967,217,1011,378]
#   → chair 0.28 ID:5  box=[944,222,1012,378]
# video 1/1 (frame 2/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 55.0ms
# Frame 1:
#   → chair 0.65 ID:1  box=[393,321,498,493]
#
# 0: 640x224 1 person, 265.8ms
# Speed: 6.9ms preprocess, 265.8ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:2  box=[423,143,501,389]
#
# 0: 640x224 (no detections), 230.9ms
# Speed: 6.3ms preprocess, 230.9ms inference, 55.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.59 ID:3  box=[194,343,292,638]
#   → chair 0.44 ID:4  box=[967,217,1011,376]
#   → chair 0.27 ID:5  box=[946,221,1014,378]
# video 1/1 (frame 3/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 178.7ms
# Frame 2:
#   → chair 0.61 ID:1  box=[392,321,498,494]
#
# 0: 640x224 1 person, 106.0ms
# Speed: 2.6ms preprocess, 106.0ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:2  box=[423,143,501,389]
#
# 0: 640x224 (no detections), 110.7ms
# Speed: 3.7ms preprocess, 110.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.57 ID:3  box=[193,343,293,645]
#   → chair 0.39 ID:4  box=[967,216,1011,375]
#   → chair 0.22 ID:5  box=[946,221,1013,378]
# video 1/1 (frame 4/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 179.7ms
# Frame 3:
#   → chair 0.62 ID:1  box=[392,321,498,494]
#
# 0: 640x224 1 person, 108.4ms
# Speed: 2.7ms preprocess, 108.4ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[423,143,501,389]
#
# 0: 640x224 (no detections), 107.2ms
# Speed: 3.3ms preprocess, 107.2ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.54 ID:3  box=[191,343,292,648]
#   → chair 0.37 ID:4  box=[967,217,1011,376]
#   → chair 0.17 ID:5  box=[946,223,1013,377]
# video 1/1 (frame 5/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 183.1ms
# Frame 4:
#   → chair 0.61 ID:1  box=[392,321,498,495]
#
# 0: 640x224 1 person, 105.7ms
# Speed: 2.6ms preprocess, 105.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:2  box=[422,143,500,389]
#
# 0: 640x224 1 person, 103.9ms
# Speed: 1.6ms preprocess, 103.9ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.50 ID:3  box=[191,342,292,649]
#   → chair 0.36 ID:4  box=[967,217,1011,376]
#   → chair 0.15 ID:5  box=[946,223,1012,377]
# video 1/1 (frame 6/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 177.2ms
# Frame 5:
#   → chair 0.65 ID:1  box=[392,321,498,494]
#
# 0: 640x224 1 person, 105.1ms
# Speed: 2.2ms preprocess, 105.1ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[422,143,500,390]
#
# 0: 640x224 1 person, 103.4ms
# Speed: 2.4ms preprocess, 103.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:3  box=[190,342,292,653]
#   → chair 0.34 ID:4  box=[967,217,1011,375]
#   → chair 0.14 ID:5  box=[946,224,1012,377]
# video 1/1 (frame 7/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 177.6ms
# Frame 6:
#   → chair 0.64 ID:1  box=[392,321,499,495]
#
# 0: 640x224 1 person, 104.8ms
# Speed: 1.8ms preprocess, 104.8ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[422,143,500,390]
#
# 0: 640x224 1 person, 106.1ms
# Speed: 2.1ms preprocess, 106.1ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[191,342,292,654]
#   → chair 0.29 ID:4  box=[967,217,1011,375]
#   → chair 0.12 ID:5  box=[944,224,1010,375]
#   → chair 0.33 ID:7  box=[511,261,662,543]
# video 1/1 (frame 8/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 178.0ms
# Frame 7:
#   → chair 0.66 ID:1  box=[392,321,499,496]
#
# 0: 640x224 1 person, 104.5ms
# Speed: 1.9ms preprocess, 104.5ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:2  box=[422,142,500,390]
#
# 0: 640x224 (no detections), 103.3ms
# Speed: 2.0ms preprocess, 103.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.61 ID:3  box=[191,342,293,656]
#   → chair 0.31 ID:4  box=[967,217,1011,375]
#   → chair 0.11 ID:5  box=[944,224,1009,374]
#   → chair 0.46 ID:7  box=[510,256,664,545]
# video 1/1 (frame 9/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 178.7ms
# Frame 8:
#   → chair 0.67 ID:1  box=[392,321,499,495]
#
# 0: 640x224 1 person, 103.2ms
# Speed: 1.6ms preprocess, 103.2ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,142,500,389]
#
# 0: 640x224 (no detections), 103.3ms
# Speed: 1.9ms preprocess, 103.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.58 ID:3  box=[192,342,293,655]
#   → chair 0.30 ID:4  box=[967,217,1011,375]
#   → chair 0.10 ID:5  box=[944,224,1009,373]
#   → chair 0.55 ID:7  box=[512,255,667,545]
# video 1/1 (frame 10/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 177.6ms
# Frame 9:
#   → chair 0.67 ID:1  box=[392,321,498,495]
#
# 0: 640x224 1 person, 103.2ms
# Speed: 1.6ms preprocess, 103.2ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:2  box=[422,142,500,389]
#
# 0: 640x224 (no detections), 103.2ms
# Speed: 1.9ms preprocess, 103.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.59 ID:3  box=[192,342,293,655]
#   → chair 0.32 ID:4  box=[967,217,1011,375]
#   → chair 0.12 ID:5  box=[945,223,1011,375]
#   → chair 0.58 ID:7  box=[513,256,667,545]
# video 1/1 (frame 11/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 178.0ms
# Frame 10:
#   → chair 0.68 ID:1  box=[392,321,499,495]
#
# 0: 640x224 1 person, 104.1ms
# Speed: 1.7ms preprocess, 104.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,142,500,390]
#
# 0: 640x224 1 person, 103.0ms
# Speed: 1.6ms preprocess, 103.0ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.53 ID:3  box=[194,342,292,650]
#   → chair 0.30 ID:4  box=[966,217,1011,374]
#   → chair 0.55 ID:7  box=[513,256,667,544]
#
# 0: 640x480 1 person, 193.8ms
# Speed: 2.6ms preprocess, 193.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.42 ID:9  box=[537,174,641,319]
#   → chair 0.45 ID:10  box=[822,342,977,723]
# video 1/1 (frame 12/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 177.4ms
# Frame 11:
#   → chair 0.67 ID:1  box=[392,321,499,496]
#
# 0: 640x224 1 person, 105.0ms
# Speed: 1.7ms preprocess, 105.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:2  box=[422,142,500,390]
#
# 0: 640x224 1 person, 102.9ms
# Speed: 1.8ms preprocess, 102.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.53 ID:3  box=[194,342,292,649]
#   → chair 0.36 ID:4  box=[966,217,1011,375]
#   → chair 0.60 ID:7  box=[514,256,668,544]
#
# 0: 640x480 1 person, 194.0ms
# Speed: 2.4ms preprocess, 194.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.38 ID:9  box=[539,179,638,319]
#   → chair 0.47 ID:10  box=[822,342,977,723]
# video 1/1 (frame 13/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 178.5ms
# Frame 12:
#   → chair 0.68 ID:1  box=[392,321,499,497]
#
# 0: 640x224 1 person, 104.9ms
# Speed: 1.7ms preprocess, 104.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,142,500,390]
#
# 0: 640x224 1 person, 103.1ms
# Speed: 1.9ms preprocess, 103.1ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[195,343,292,648]
#   → chair 0.35 ID:4  box=[966,217,1011,375]
#   → chair 0.58 ID:7  box=[513,255,669,543]
#
# 0: 640x480 1 person, 193.5ms
# Speed: 2.6ms preprocess, 193.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.35 ID:9  box=[541,189,635,319]
#   → chair 0.48 ID:10  box=[823,342,978,723]
# video 1/1 (frame 14/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 177.7ms
# Frame 13:
#   → chair 0.65 ID:1  box=[392,321,499,497]
#
# 0: 640x224 1 person, 104.9ms
# Speed: 1.7ms preprocess, 104.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[423,142,501,389]
#
# 0: 640x224 1 person, 102.9ms
# Speed: 1.5ms preprocess, 102.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.49 ID:3  box=[195,342,292,648]
#   → chair 0.28 ID:4  box=[966,217,1011,375]
#   → chair 0.53 ID:7  box=[514,255,670,543]
#
# 0: 640x480 1 person, 193.5ms
# Speed: 2.5ms preprocess, 193.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.25 ID:9  box=[539,181,639,320]
#   → chair 0.44 ID:10  box=[822,342,978,723]
# video 1/1 (frame 15/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 177.6ms
# Frame 14:
#   → chair 0.70 ID:1  box=[393,321,497,493]
#
# 0: 640x224 2 persons, 106.1ms
# Speed: 1.7ms preprocess, 106.1ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[423,142,501,389]
#
# 0: 640x224 1 person, 102.9ms
# Speed: 1.8ms preprocess, 102.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:3  box=[196,342,291,642]
#   → chair 0.39 ID:4  box=[965,218,1010,375]
#   → chair 0.42 ID:7  box=[513,257,670,543]
#
# 0: 640x480 1 person, 193.4ms
# Speed: 2.6ms preprocess, 193.4ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.28 ID:9  box=[537,181,638,321]
#   → chair 0.28 ID:10  box=[823,342,977,722]
# video 1/1 (frame 16/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 177.2ms
# Frame 15:
#   → chair 0.70 ID:1  box=[393,321,497,491]
#
# 0: 640x224 2 persons, 105.4ms
# Speed: 1.4ms preprocess, 105.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[423,142,501,389]
#
# 0: 640x224 1 person, 102.9ms
# Speed: 1.4ms preprocess, 102.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.51 ID:3  box=[195,342,290,642]
#   → chair 0.39 ID:4  box=[965,219,1010,375]
#   → chair 0.43 ID:7  box=[513,258,670,543]
#
# 0: 640x480 (no detections), 193.1ms
# Speed: 2.2ms preprocess, 193.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#   → unknown 0.25 ID:9  box=[536,177,639,321]
#   → chair 0.26 ID:10  box=[822,342,977,722]
# video 1/1 (frame 17/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 4 chairs, 178.5ms
# Frame 16:
#   → chair 0.70 ID:1  box=[393,321,496,490]
#
# 0: 640x224 1 person, 106.3ms
# Speed: 1.8ms preprocess, 106.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[423,142,500,388]
#
# 0: 640x224 1 person, 103.3ms
# Speed: 1.9ms preprocess, 103.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[194,343,289,644]
#   → chair 0.40 ID:4  box=[965,219,1010,376]
#   → chair 0.43 ID:7  box=[514,260,671,543]
#
# 0: 640x480 1 person, 194.0ms
# Speed: 2.7ms preprocess, 194.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.35 ID:9  box=[531,163,644,322]
#   → chair 0.16 ID:10  box=[833,343,987,719]
#
# 0: 640x288 (no detections), 141.9ms
# Speed: 2.0ms preprocess, 141.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.35 ID:16  box=[99,503,201,743]
# video 1/1 (frame 18/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 4 chairs, 177.3ms
# Frame 17:
#   → chair 0.70 ID:1  box=[393,321,497,492]
#
# 0: 640x224 1 person, 106.8ms
# Speed: 1.5ms preprocess, 106.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,141,500,388]
#
# 0: 640x224 (no detections), 103.0ms
# Speed: 1.4ms preprocess, 103.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.58 ID:3  box=[194,343,289,646]
#   → chair 0.39 ID:4  box=[965,219,1010,376]
#   → chair 0.42 ID:7  box=[513,259,672,543]
#
# 0: 640x480 (no detections), 198.9ms
# Speed: 2.3ms preprocess, 198.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#   → unknown 0.23 ID:9  box=[532,164,644,321]
#   → chair 0.17 ID:10  box=[837,343,992,719]
#
# 0: 640x288 (no detections), 141.6ms
# Speed: 1.7ms preprocess, 141.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.34 ID:16  box=[99,502,201,743]
# video 1/1 (frame 19/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 5 chairs, 178.7ms
# Frame 18:
#   → chair 0.68 ID:1  box=[393,321,497,492]
#
# 0: 640x224 1 person, 105.0ms
# Speed: 1.4ms preprocess, 105.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,141,500,389]
#
# 0: 640x224 (no detections), 102.9ms
# Speed: 1.4ms preprocess, 102.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.55 ID:3  box=[194,343,289,647]
#   → chair 0.40 ID:4  box=[964,219,1010,376]
#   → chair 0.34 ID:7  box=[512,256,673,542]
#   → chair 0.31 ID:10  box=[828,343,984,721]
#
# 0: 640x288 (no detections), 141.7ms
# Speed: 2.0ms preprocess, 141.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.31 ID:16  box=[100,502,202,743]
#   → chair 0.31 ID:5  box=[943,219,1012,377]
# video 1/1 (frame 20/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 5 chairs, 178.7ms
# Frame 19:
#   → chair 0.69 ID:1  box=[392,321,497,493]
#
# 0: 640x224 (no detections), 105.0ms
# Speed: 1.7ms preprocess, 105.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.67 ID:2  box=[422,141,500,390]
#
# 0: 640x224 1 person, 102.9ms
# Speed: 2.0ms preprocess, 102.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:3  box=[195,343,289,647]
#   → chair 0.38 ID:4  box=[964,220,1009,376]
#   → chair 0.36 ID:7  box=[512,256,673,542]
#   → chair 0.54 ID:10  box=[824,342,979,722]
#
# 0: 640x288 (no detections), 141.7ms
# Speed: 2.0ms preprocess, 141.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[100,502,202,742]
#   → chair 0.34 ID:5  box=[942,219,1011,377]
# video 1/1 (frame 21/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 5 chairs, 178.8ms
# Frame 20:
#   → chair 0.68 ID:1  box=[392,321,496,491]
#
# 0: 640x224 1 person, 104.9ms
# Speed: 1.7ms preprocess, 104.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,141,500,389]
#
# 0: 640x224 (no detections), 102.9ms
# Speed: 2.0ms preprocess, 102.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.50 ID:3  box=[195,343,289,647]
#   → chair 0.38 ID:4  box=[964,220,1010,376]
#   → chair 0.43 ID:7  box=[512,255,674,542]
#   → chair 0.34 ID:10  box=[823,343,978,722]
#
# 0: 640x288 (no detections), 141.8ms
# Speed: 2.0ms preprocess, 141.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.32 ID:16  box=[100,502,202,742]
#   → chair 0.31 ID:5  box=[943,219,1011,377]
# video 1/1 (frame 22/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 5 chairs, 177.5ms
# Frame 21:
#   → chair 0.67 ID:1  box=[392,320,496,490]
#
# 0: 640x224 (no detections), 104.7ms
# Speed: 1.7ms preprocess, 104.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.68 ID:2  box=[422,141,500,389]
#
# 0: 640x224 1 person, 102.8ms
# Speed: 1.8ms preprocess, 102.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[194,343,289,649]
#   → chair 0.41 ID:4  box=[964,221,1010,376]
#   → chair 0.36 ID:7  box=[511,256,673,541]
#   → chair 0.33 ID:10  box=[822,343,978,722]
#
# 0: 640x288 (no detections), 141.6ms
# Speed: 1.7ms preprocess, 141.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[100,503,202,742]
#   → chair 0.30 ID:5  box=[943,221,1011,376]
# video 1/1 (frame 23/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 178.1ms
# Frame 22:
#   → chair 0.64 ID:1  box=[392,320,496,490]
#
# 0: 640x224 (no detections), 105.7ms
# Speed: 1.4ms preprocess, 105.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.69 ID:2  box=[422,141,500,389]
#
# 0: 640x224 1 person, 102.6ms
# Speed: 1.5ms preprocess, 102.6ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:3  box=[194,343,289,650]
#   → chair 0.45 ID:4  box=[964,221,1009,377]
#   → chair 0.39 ID:7  box=[511,254,674,542]
#   → chair 0.30 ID:10  box=[823,343,978,723]
#
# 0: 640x288 (no detections), 141.8ms
# Speed: 2.0ms preprocess, 141.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.29 ID:16  box=[100,504,202,743]
#   → chair 0.27 ID:5  box=[942,220,1011,377]
#
# 0: 640x320 (no detections), 148.0ms
# Speed: 2.0ms preprocess, 148.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 320)
#   → unknown 0.32 ID:20  box=[532,97,600,233]
# video 1/1 (frame 24/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 177.1ms
# Frame 23:
#   → chair 0.63 ID:1  box=[392,320,496,490]
#
# 0: 640x224 (no detections), 107.4ms
# Speed: 1.3ms preprocess, 107.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.68 ID:2  box=[422,141,500,389]
#
# 0: 640x224 1 person, 103.1ms
# Speed: 1.9ms preprocess, 103.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[195,343,289,649]
#   → chair 0.46 ID:4  box=[964,221,1009,377]
#   → chair 0.37 ID:7  box=[510,254,674,542]
#   → chair 0.18 ID:10  box=[821,342,977,722]
#
# 0: 640x288 (no detections), 141.6ms
# Speed: 1.6ms preprocess, 141.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.27 ID:16  box=[100,503,202,743]
#   → chair 0.25 ID:5  box=[942,219,1011,377]
#
# 0: 640x352 1 person, 162.5ms
# Speed: 1.8ms preprocess, 162.5ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.30 ID:20  box=[531,96,600,233]
# video 1/1 (frame 25/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 177.9ms
# Frame 24:
#   → chair 0.65 ID:1  box=[392,320,496,490]
#
# 0: 640x224 1 person, 105.6ms
# Speed: 1.6ms preprocess, 105.6ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:2  box=[422,141,500,389]
#
# 0: 640x224 1 person, 103.6ms
# Speed: 1.9ms preprocess, 103.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:3  box=[195,343,289,649]
#   → chair 0.46 ID:4  box=[963,222,1009,377]
#   → chair 0.40 ID:7  box=[510,254,674,543]
#   → chair 0.19 ID:10  box=[822,342,977,722]
#
# 0: 640x288 (no detections), 141.8ms
# Speed: 2.1ms preprocess, 141.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.30 ID:16  box=[101,505,202,743]
#   → chair 0.26 ID:5  box=[942,219,1011,377]
#
# 0: 640x352 1 person, 161.5ms
# Speed: 2.3ms preprocess, 161.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.23 ID:20  box=[531,97,600,232]
# video 1/1 (frame 26/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 177.2ms
# Frame 25:
#   → chair 0.64 ID:1  box=[392,320,497,492]
#
# 0: 640x224 1 person, 105.6ms
# Speed: 1.4ms preprocess, 105.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,141,500,390]
#
# 0: 640x224 2 persons, 102.9ms
# Speed: 1.5ms preprocess, 102.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:3  box=[194,344,289,651]
#   → chair 0.42 ID:4  box=[964,223,1010,377]
#   → chair 0.41 ID:7  box=[509,256,674,543]
#   → chair 0.51 ID:10  box=[821,343,977,722]
#
# 0: 640x288 (no detections), 141.8ms
# Speed: 1.6ms preprocess, 141.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[101,505,203,743]
#   → chair 0.24 ID:5  box=[943,222,1010,378]
#
# 0: 640x352 (no detections), 161.5ms
# Speed: 2.3ms preprocess, 161.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.24 ID:20  box=[531,97,600,232]
# video 1/1 (frame 27/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 177.5ms
# Frame 26:
#   → chair 0.65 ID:1  box=[393,320,497,491]
#
# 0: 640x224 (no detections), 104.9ms
# Speed: 1.7ms preprocess, 104.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.66 ID:2  box=[422,141,500,389]
#
# 0: 640x224 1 person, 103.0ms
# Speed: 1.8ms preprocess, 103.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:3  box=[194,344,288,650]
#   → chair 0.41 ID:4  box=[964,224,1010,377]
#   → chair 0.37 ID:7  box=[509,255,674,543]
#   → chair 0.47 ID:10  box=[822,343,978,722]
#
# 0: 640x288 (no detections), 141.9ms
# Speed: 1.9ms preprocess, 141.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.36 ID:16  box=[101,504,202,743]
#   → chair 0.28 ID:5  box=[944,224,1011,377]
#
# 0: 640x352 (no detections), 161.9ms
# Speed: 2.2ms preprocess, 161.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.30 ID:20  box=[532,97,600,232]
# video 1/1 (frame 28/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 97.8ms
# Frame 27:
#   → chair 0.66 ID:1  box=[392,321,496,491]
#
# 0: 640x224 (no detections), 30.6ms
# Speed: 1.1ms preprocess, 30.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.68 ID:2  box=[422,141,500,389]
#
# 0: 640x224 1 person, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:3  box=[195,345,288,649]
#   → chair 0.40 ID:4  box=[964,225,1010,377]
#   → chair 0.38 ID:7  box=[509,255,675,543]
#   → chair 0.44 ID:10  box=[823,342,979,722]
#
# 0: 640x288 (no detections), 47.8ms
# Speed: 1.4ms preprocess, 47.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.39 ID:16  box=[101,504,202,742]
#   → chair 0.26 ID:5  box=[943,224,1010,377]
#
# 0: 640x352 (no detections), 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.30 ID:20  box=[532,97,600,231]
# video 1/1 (frame 29/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 44.9ms
# Frame 28:
#   → chair 0.64 ID:1  box=[393,320,496,490]
#
# 0: 640x224 1 person, 29.9ms
# Speed: 1.1ms preprocess, 29.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:2  box=[422,141,499,388]
#
# 0: 640x224 1 person, 27.8ms
# Speed: 2.6ms preprocess, 27.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[194,345,288,650]
#   → chair 0.44 ID:4  box=[964,224,1010,378]
#   → chair 0.34 ID:7  box=[509,254,676,543]
#   → chair 0.50 ID:10  box=[822,342,979,722]
#
# 0: 640x288 (no detections), 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.36 ID:16  box=[101,503,202,742]
#   → chair 0.22 ID:5  box=[943,223,1011,378]
#
# 0: 640x352 (no detections), 40.9ms
# Speed: 2.6ms preprocess, 40.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.32 ID:20  box=[532,97,600,232]
# video 1/1 (frame 30/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 4 chairs, 45.2ms
# Frame 29:
#   → chair 0.68 ID:1  box=[391,321,497,497]
#
# 0: 640x224 1 person, 28.6ms
# Speed: 2.5ms preprocess, 28.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.70 ID:2  box=[422,141,499,388]
#
# 0: 640x224 1 person, 27.8ms
# Speed: 1.2ms preprocess, 27.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[195,345,288,646]
#   → chair 0.53 ID:4  box=[964,221,1011,378]
#   → chair 0.66 ID:7  box=[510,253,677,543]
#   → chair 0.70 ID:10  box=[821,341,978,722]
#
# 0: 640x288 1 person, 38.7ms
# Speed: 1.3ms preprocess, 38.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.34 ID:16  box=[100,502,202,742]
#
# 0: 640x352 (no detections), 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.35 ID:20  box=[532,96,600,231]
# video 1/1 (frame 31/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 44.3ms
# Frame 30:
#   → chair 0.68 ID:1  box=[390,321,498,499]
#
# 0: 640x224 1 person, 29.5ms
# Speed: 1.5ms preprocess, 29.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:2  box=[423,141,500,387]
#
# 0: 640x224 1 person, 27.4ms
# Speed: 1.1ms preprocess, 27.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[196,346,288,645]
#   → chair 0.52 ID:4  box=[964,220,1011,378]
#   → chair 0.71 ID:7  box=[511,253,678,544]
#   → chair 0.70 ID:10  box=[821,341,977,722]
#
# 0: 640x288 (no detections), 38.5ms
# Speed: 1.3ms preprocess, 38.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[100,502,202,742]
#
# 0: 640x352 (no detections), 40.5ms
# Speed: 2.1ms preprocess, 40.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.35 ID:20  box=[531,96,600,231]
#   → chair 0.31 ID:21  box=[739,239,814,642]
# video 1/1 (frame 32/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 44.7ms
# Frame 31:
#   → chair 0.68 ID:1  box=[390,321,498,500]
#
# 0: 640x224 1 person, 29.6ms
# Speed: 1.8ms preprocess, 29.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:2  box=[422,141,500,388]
#
# 0: 640x224 1 person, 27.2ms
# Speed: 1.2ms preprocess, 27.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.48 ID:3  box=[196,346,288,642]
#   → chair 0.48 ID:4  box=[964,220,1011,378]
#   → chair 0.73 ID:7  box=[512,254,679,543]
#   → chair 0.63 ID:10  box=[820,341,977,722]
#
# 0: 640x288 (no detections), 38.9ms
# Speed: 1.9ms preprocess, 38.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[100,502,202,742]
#
# 0: 640x352 1 person, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.47 ID:20  box=[532,95,600,230]
#   → chair 0.24 ID:21  box=[740,238,815,642]
# video 1/1 (frame 33/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 44.2ms
# Frame 32:
#   → chair 0.67 ID:1  box=[390,321,498,500]
#
# 0: 640x224 1 person, 29.2ms
# Speed: 1.1ms preprocess, 29.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,141,499,388]
#
# 0: 640x224 1 person, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.49 ID:3  box=[196,346,288,642]
#   → chair 0.49 ID:4  box=[964,220,1011,377]
#   → chair 0.76 ID:7  box=[512,254,678,543]
#   → chair 0.69 ID:10  box=[820,341,977,722]
#
# 0: 640x288 1 person, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.35 ID:16  box=[100,502,202,741]
#
# 0: 640x352 1 person, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.36 ID:20  box=[531,95,600,229]
#   → chair 0.26 ID:21  box=[741,238,815,643]
# video 1/1 (frame 34/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 44.3ms
# Frame 33:
#   → chair 0.66 ID:1  box=[390,321,498,500]
#
# 0: 640x224 1 person, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,141,499,388]
#
# 0: 640x224 1 person, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.53 ID:3  box=[196,346,288,644]
#   → chair 0.46 ID:4  box=[965,219,1011,377]
#   → chair 0.70 ID:7  box=[511,254,678,543]
#   → chair 0.60 ID:10  box=[820,341,977,722]
#
# 0: 640x288 1 person, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.32 ID:16  box=[100,502,202,742]
#
# 0: 640x352 1 person, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.26 ID:20  box=[530,95,599,229]
#   → chair 0.28 ID:21  box=[741,238,815,642]
# video 1/1 (frame 35/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 49.2ms
# Frame 34:
#   → chair 0.66 ID:1  box=[390,321,497,500]
#
# 0: 640x224 2 persons, 204.1ms
# Speed: 1.1ms preprocess, 204.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[422,141,499,388]
#
# 0: 640x224 1 person, 26.9ms
# Speed: 1.3ms preprocess, 26.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.53 ID:3  box=[195,346,288,645]
#   → chair 0.45 ID:4  box=[965,219,1011,377]
#   → chair 0.63 ID:7  box=[511,254,678,543]
#   → chair 0.57 ID:10  box=[821,342,977,722]
#
# 0: 640x288 1 person, 37.2ms
# Speed: 1.3ms preprocess, 37.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.30 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.27 ID:20  box=[530,95,599,231]
#   → chair 0.20 ID:21  box=[741,239,815,642]
# video 1/1 (frame 36/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 45.5ms
# Frame 35:
#   → chair 0.64 ID:1  box=[390,321,498,501]
#
# 0: 640x224 1 person, 34.8ms
# Speed: 3.6ms preprocess, 34.8ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:2  box=[422,141,499,389]
#
# 0: 640x224 2 persons, 29.7ms
# Speed: 3.3ms preprocess, 29.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[195,346,288,645]
#   → chair 0.35 ID:4  box=[968,240,1009,377]
#   → chair 0.59 ID:7  box=[511,253,678,543]
#   → chair 0.55 ID:10  box=[821,342,977,722]
#
# 0: 640x288 (no detections), 39.6ms
# Speed: 1.8ms preprocess, 39.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.29 ID:16  box=[99,502,202,742]
#
# 0: 640x352 (no detections), 43.4ms
# Speed: 5.2ms preprocess, 43.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.30 ID:20  box=[530,95,599,230]
#   → chair 0.15 ID:21  box=[741,239,815,642]
# video 1/1 (frame 37/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 5 chairs, 44.1ms
# Frame 36:
#   → chair 0.63 ID:1  box=[390,321,498,502]
#
# 0: 640x224 1 person, 33.0ms
# Speed: 3.6ms preprocess, 33.0ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,141,499,389]
#
# 0: 640x224 1 person, 29.4ms
# Speed: 1.9ms preprocess, 29.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:3  box=[195,346,289,648]
#   → chair 0.36 ID:4  box=[969,248,1008,377]
#   → chair 0.59 ID:7  box=[512,254,678,543]
#   → chair 0.57 ID:10  box=[821,343,977,722]
#
# 0: 640x288 1 person, 37.4ms
# Speed: 1.8ms preprocess, 37.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.32 ID:16  box=[99,502,202,742]
#
# 0: 640x352 (no detections), 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.28 ID:20  box=[531,95,598,228]
#   → chair 0.10 ID:21  box=[743,261,813,643]
# video 1/1 (frame 38/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 5 chairs, 46.2ms
# Frame 37:
#   → chair 0.65 ID:1  box=[391,321,498,502]
#
# 0: 640x224 2 persons, 31.4ms
# Speed: 3.5ms preprocess, 31.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:2  box=[422,141,500,390]
#
# 0: 640x224 1 person, 27.7ms
# Speed: 1.7ms preprocess, 27.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:3  box=[195,346,289,649]
#   → chair 0.37 ID:4  box=[969,249,1008,377]
#   → chair 0.57 ID:7  box=[512,254,678,543]
#   → chair 0.44 ID:10  box=[820,342,977,722]
#
# 0: 640x288 1 person, 41.6ms
# Speed: 4.0ms preprocess, 41.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.35 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 42.7ms
# Speed: 1.9ms preprocess, 42.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.31 ID:20  box=[530,95,598,228]
#   → chair 0.14 ID:21  box=[744,268,812,643]
#
# 0: 640x480 (no detections), 53.6ms
# Speed: 2.9ms preprocess, 53.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#   → unknown 0.46 ID:9  box=[543,193,635,319]
# video 1/1 (frame 39/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 5 chairs, 44.4ms
# Frame 38:
#   → chair 0.65 ID:1  box=[391,321,498,502]
#
# 0: 640x224 1 person, 29.0ms
# Speed: 1.2ms preprocess, 29.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,141,500,390]
#
# 0: 640x224 1 person, 28.1ms
# Speed: 1.6ms preprocess, 28.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:3  box=[194,346,289,651]
#   → chair 0.35 ID:4  box=[968,249,1008,378]
#   → chair 0.52 ID:7  box=[512,254,678,542]
#   → chair 0.45 ID:10  box=[821,342,978,722]
#
# 0: 640x288 (no detections), 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.21 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 42.9ms
# Speed: 3.8ms preprocess, 42.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.31 ID:20  box=[530,95,598,227]
#   → chair 0.12 ID:21  box=[743,251,814,642]
#
# 0: 640x512 (no detections), 52.8ms
# Speed: 2.3ms preprocess, 52.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#   → unknown 0.41 ID:9  box=[543,193,638,319]
# video 1/1 (frame 40/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 4 chairs, 44.7ms
# Frame 39:
#   → chair 0.64 ID:1  box=[391,321,498,501]
#
# 0: 640x224 1 person, 28.8ms
# Speed: 1.3ms preprocess, 28.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:2  box=[422,141,500,390]
#
# 0: 640x224 1 person, 27.8ms
# Speed: 1.6ms preprocess, 27.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[194,346,289,652]
#   → chair 0.37 ID:4  box=[968,250,1008,378]
#   → chair 0.48 ID:7  box=[511,254,676,542]
#   → chair 0.34 ID:10  box=[821,342,978,722]
#
# 0: 640x288 (no detections), 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.22 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.31 ID:20  box=[531,95,598,226]
#
# 0: 640x512 (no detections), 55.5ms
# Speed: 5.1ms preprocess, 55.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#   → unknown 0.33 ID:9  box=[543,195,639,319]
# video 1/1 (frame 41/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 4 chairs, 52.8ms
# Frame 40:
#   → chair 0.65 ID:1  box=[391,321,498,501]
#
# 0: 640x224 1 person, 30.7ms
# Speed: 2.3ms preprocess, 30.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,141,500,390]
#
# 0: 640x224 1 person, 30.2ms
# Speed: 2.1ms preprocess, 30.2ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.57 ID:3  box=[194,346,288,650]
#   → chair 0.36 ID:4  box=[968,250,1009,378]
#   → chair 0.58 ID:7  box=[511,255,676,542]
#   → chair 0.34 ID:10  box=[822,342,979,722]
#
# 0: 640x288 1 person, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.25 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.30 ID:20  box=[530,96,597,227]
#
# 0: 640x512 (no detections), 56.2ms
# Speed: 2.6ms preprocess, 56.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#   → unknown 0.38 ID:9  box=[542,194,640,320]
# video 1/1 (frame 42/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 4 chairs, 48.7ms
# Frame 41:
#   → chair 0.65 ID:1  box=[391,321,498,501]
#
# 0: 640x224 1 person, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,141,500,390]
#
# 0: 640x224 1 person, 32.7ms
# Speed: 3.2ms preprocess, 32.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[194,346,288,649]
#   → chair 0.34 ID:4  box=[966,232,1011,377]
#   → chair 0.53 ID:7  box=[511,255,675,543]
#   → chair 0.41 ID:10  box=[821,342,979,722]
#
# 0: 640x288 1 person, 45.6ms
# Speed: 2.7ms preprocess, 45.6ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.20 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.32 ID:20  box=[530,95,598,227]
#
# 0: 640x512 (no detections), 65.8ms
# Speed: 3.5ms preprocess, 65.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#   → unknown 0.34 ID:9  box=[540,194,639,320]
# video 1/1 (frame 43/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 4 chairs, 54.0ms
# Frame 42:
#   → chair 0.64 ID:1  box=[391,321,498,502]
#
# 0: 640x224 1 person, 35.8ms
# Speed: 2.7ms preprocess, 35.8ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,141,499,390]
#
# 0: 640x224 1 person, 33.8ms
# Speed: 2.6ms preprocess, 33.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[194,346,288,649]
#   → chair 0.34 ID:4  box=[967,243,1010,377]
#   → chair 0.51 ID:7  box=[510,256,674,543]
#   → chair 0.43 ID:10  box=[820,341,979,722]
#
# 0: 640x288 (no detections), 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.19 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 50.1ms
# Speed: 3.3ms preprocess, 50.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.28 ID:20  box=[530,95,598,227]
#
# 0: 640x512 (no detections), 59.8ms
# Speed: 1.6ms preprocess, 59.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#   → unknown 0.34 ID:9  box=[541,196,640,320]
# video 1/1 (frame 44/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 4 chairs, 54.2ms
# Frame 43:
#   → chair 0.65 ID:1  box=[391,321,498,502]
#
# 0: 640x224 1 person, 33.1ms
# Speed: 0.9ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[423,141,499,389]
#
# 0: 640x224 1 person, 35.6ms
# Speed: 1.9ms preprocess, 35.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[194,346,288,648]
#   → chair 0.36 ID:4  box=[967,247,1009,378]
#   → chair 0.52 ID:7  box=[510,255,674,543]
#   → chair 0.46 ID:10  box=[821,341,979,722]
#
# 0: 640x288 (no detections), 47.2ms
# Speed: 2.0ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.18 ID:16  box=[100,502,203,742]
#
# 0: 640x352 (no detections), 50.4ms
# Speed: 1.2ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.26 ID:20  box=[530,96,597,226]
#
# 0: 640x544 (no detections), 71.9ms
# Speed: 2.7ms preprocess, 71.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 544)
#   → unknown 0.32 ID:9  box=[541,197,639,319]
# video 1/1 (frame 45/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 5 chairs, 53.7ms
# Frame 44:
#   → chair 0.64 ID:1  box=[391,322,499,504]
#
# 0: 640x224 (no detections), 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.68 ID:2  box=[423,141,499,390]
#
# 0: 640x224 2 persons, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.49 ID:3  box=[196,346,287,639]
#   → chair 0.40 ID:4  box=[967,243,1010,377]
#   → chair 0.38 ID:7  box=[509,255,673,545]
#   → chair 0.56 ID:10  box=[820,343,978,722]
#
# 0: 640x288 (no detections), 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.35 ID:16  box=[100,503,203,742]
#
# 0: 640x352 (no detections), 52.3ms
# Speed: 3.5ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.20 ID:20  box=[530,95,597,225]
#
# 0: 640x544 (no detections), 69.7ms
# Speed: 2.2ms preprocess, 69.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 544)
#   → unknown 0.41 ID:9  box=[539,193,641,319]
#   → chair 0.25 ID:5  box=[946,238,1008,377]
# video 1/1 (frame 46/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 5 chairs, 50.7ms
# Frame 45:
#   → chair 0.64 ID:1  box=[391,322,499,505]
#
# 0: 640x224 (no detections), 35.4ms
# Speed: 2.0ms preprocess, 35.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.67 ID:2  box=[423,141,500,390]
#
# 0: 640x224 2 persons, 32.6ms
# Speed: 1.1ms preprocess, 32.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.48 ID:3  box=[196,346,287,637]
#   → chair 0.39 ID:4  box=[966,242,1010,377]
#   → chair 0.34 ID:7  box=[508,255,672,546]
#   → chair 0.59 ID:10  box=[820,343,978,722]
#
# 0: 640x288 (no detections), 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[100,504,203,743]
#
# 0: 640x352 (no detections), 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.18 ID:20  box=[530,95,597,225]
#
# 0: 640x544 (no detections), 65.0ms
# Speed: 5.3ms preprocess, 65.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
#   → unknown 0.38 ID:9  box=[536,189,641,320]
#   → chair 0.34 ID:5  box=[948,236,1011,377]
# video 1/1 (frame 47/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 5 chairs, 56.5ms
# Frame 46:
#   → chair 0.63 ID:1  box=[391,322,499,505]
#
# 0: 640x224 (no detections), 32.8ms
# Speed: 1.7ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.68 ID:2  box=[423,141,499,390]
#
# 0: 640x224 2 persons, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.49 ID:3  box=[196,346,287,636]
#   → chair 0.43 ID:4  box=[965,236,1011,377]
#   → chair 0.31 ID:7  box=[507,254,670,547]
#   → chair 0.59 ID:10  box=[821,343,978,722]
#
# 0: 640x288 (no detections), 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.35 ID:16  box=[100,503,203,743]
#
# 0: 640x352 (no detections), 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.26 ID:20  box=[530,96,597,227]
#
# 0: 640x544 (no detections), 61.1ms
# Speed: 2.1ms preprocess, 61.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#   → unknown 0.43 ID:9  box=[537,191,641,319]
#   → chair 0.31 ID:5  box=[948,235,1011,376]
# video 1/1 (frame 48/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 4 chairs, 53.5ms
# Frame 47:
#   → chair 0.62 ID:1  box=[392,323,498,504]
#
# 0: 640x224 1 person, 30.0ms
# Speed: 2.8ms preprocess, 30.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[423,141,499,390]
#
# 0: 640x224 1 person, 31.8ms
# Speed: 1.1ms preprocess, 31.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.53 ID:3  box=[195,346,288,641]
#   → chair 0.46 ID:4  box=[964,231,1011,377]
#   → chair 0.34 ID:7  box=[508,255,670,546]
#   → chair 0.53 ID:10  box=[821,343,978,722]
#
# 0: 640x288 (no detections), 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[100,503,203,743]
#
# 0: 640x352 (no detections), 44.8ms
# Speed: 1.6ms preprocess, 44.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.16 ID:20  box=[531,95,598,228]
#
# 0: 640x544 (no detections), 64.2ms
# Speed: 2.4ms preprocess, 64.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 544)
#   → unknown 0.35 ID:9  box=[537,190,642,319]
# video 1/1 (frame 49/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 5 persons, 4 chairs, 54.1ms
# Frame 48:
#   → chair 0.63 ID:1  box=[392,323,498,502]
#
# 0: 640x224 1 person, 32.8ms
# Speed: 0.9ms preprocess, 32.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[423,141,499,390]
#
# 0: 640x224 1 person, 27.8ms
# Speed: 0.9ms preprocess, 27.8ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[195,346,288,643]
#   → chair 0.46 ID:4  box=[964,228,1011,377]
#   → chair 0.36 ID:7  box=[509,256,670,546]
#   → chair 0.43 ID:10  box=[821,343,978,722]
#
# 0: 640x288 (no detections), 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.33 ID:16  box=[100,503,203,743]
#
# 0: 640x352 (no detections), 40.8ms
# Speed: 1.3ms preprocess, 40.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.20 ID:20  box=[531,96,598,226]
#
# 0: 640x544 (no detections), 64.0ms
# Speed: 2.1ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#   → unknown 0.39 ID:9  box=[535,185,644,320]
# ...
#
# 0: 640x352 1 person, 50.1ms
# Speed: 5.4ms preprocess, 50.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.40 ID:896  box=[40,485,181,750]
#
# 0: 640x256 3 persons, 36.2ms
# Speed: 2.1ms preprocess, 36.2ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.25 ID:868  box=[185,356,292,658]
#   → chair 0.77 ID:710  box=[889,342,983,725]
# video 1/1 (frame 3030/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 2 chairs, 54.4ms
# Frame 3029:
#
# 0: 640x192 1 person, 36.9ms
# Speed: 1.2ms preprocess, 36.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.69 ID:869  box=[443,134,511,397]
#   → chair 0.46 ID:819  box=[392,321,495,510]
#
# 0: 640x160 1 person, 35.4ms
# Speed: 2.6ms preprocess, 35.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.89 ID:879  box=[913,289,1085,1132]
#
# 0: 640x352 1 person, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.40 ID:896  box=[41,485,182,750]
#
# 0: 640x256 2 persons, 38.6ms
# Speed: 2.4ms preprocess, 38.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.25 ID:868  box=[185,356,292,658]
#   → chair 0.78 ID:710  box=[890,342,983,725]
# video 1/1 (frame 3031/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 2 chairs, 55.1ms
# Frame 3030:
#
# 0: 640x192 1 person, 36.6ms
# Speed: 3.1ms preprocess, 36.6ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.67 ID:869  box=[443,134,510,395]
#   → chair 0.39 ID:819  box=[393,321,495,510]
#
# 0: 640x160 1 person, 33.9ms
# Speed: 2.4ms preprocess, 33.9ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.85 ID:879  box=[916,289,1082,1106]
#
# 0: 640x352 1 person, 49.2ms
# Speed: 2.7ms preprocess, 49.2ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.39 ID:896  box=[43,485,184,751]
#
# 0: 640x256 2 persons, 37.7ms
# Speed: 2.8ms preprocess, 37.7ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.37 ID:868  box=[187,355,294,656]
#   → chair 0.79 ID:710  box=[890,342,982,725]
# video 1/1 (frame 3032/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 2 chairs, 56.2ms
# Frame 3031:
#
# 0: 640x192 1 person, 34.4ms
# Speed: 2.0ms preprocess, 34.4ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.67 ID:869  box=[443,134,510,394]
#   → chair 0.38 ID:819  box=[393,321,496,510]
#
# 0: 640x160 1 person, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.83 ID:879  box=[917,290,1081,1097]
#
# 0: 640x352 1 person, 50.3ms
# Speed: 3.3ms preprocess, 50.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.40 ID:896  box=[43,485,184,751]
#
# 0: 640x256 2 persons, 36.1ms
# Speed: 1.2ms preprocess, 36.1ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.24 ID:868  box=[188,355,293,653]
#   → chair 0.78 ID:710  box=[890,342,982,724]
# video 1/1 (frame 3033/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 48.6ms
# Frame 3032:
#
# 0: 640x192 1 person, 38.3ms
# Speed: 2.3ms preprocess, 38.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.67 ID:869  box=[442,134,509,394]
#   → chair 0.35 ID:819  box=[394,321,496,510]
#
# 0: 640x160 1 person, 32.1ms
# Speed: 1.9ms preprocess, 32.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.83 ID:879  box=[916,290,1081,1095]
#
# 0: 640x352 1 person, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.38 ID:896  box=[43,485,184,751]
#
# 0: 640x256 2 persons, 34.7ms
# Speed: 2.3ms preprocess, 34.7ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.21 ID:868  box=[188,355,292,651]
#   → chair 0.77 ID:710  box=[890,342,982,724]
#   → chair 0.27 ID:895  box=[742,269,816,647]
# video 1/1 (frame 3034/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 53.7ms
# Frame 3033:
#
# 0: 640x192 1 person, 34.3ms
# Speed: 2.9ms preprocess, 34.3ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.69 ID:869  box=[442,134,509,394]
#   → chair 0.39 ID:819  box=[393,321,495,510]
#
# 0: 640x160 1 person, 33.6ms
# Speed: 2.5ms preprocess, 33.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.86 ID:879  box=[915,290,1082,1107]
#
# 0: 640x352 1 person, 46.9ms
# Speed: 2.7ms preprocess, 46.9ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.34 ID:896  box=[42,485,184,752]
#
# 0: 640x256 1 person, 35.7ms
# Speed: 2.0ms preprocess, 35.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.38 ID:868  box=[189,355,290,642]
#   → chair 0.79 ID:710  box=[890,342,981,724]
#   → chair 0.28 ID:895  box=[743,269,816,647]
# video 1/1 (frame 3035/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 51.1ms
# Frame 3034:
#
# 0: 640x192 1 person, 32.5ms
# Speed: 2.2ms preprocess, 32.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:869  box=[442,134,509,394]
#   → chair 0.40 ID:819  box=[394,322,496,510]
#
# 0: 640x160 1 person, 39.0ms
# Speed: 2.2ms preprocess, 39.0ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.89 ID:879  box=[915,289,1084,1120]
#
# 0: 640x352 1 person, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.29 ID:896  box=[43,486,184,752]
#
# 0: 640x256 1 person, 44.0ms
# Speed: 2.3ms preprocess, 44.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.35 ID:868  box=[189,356,291,646]
#   → chair 0.77 ID:710  box=[890,342,981,724]
#   → chair 0.29 ID:895  box=[742,268,816,647]
# video 1/1 (frame 3036/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 50.6ms
# Frame 3035:
#
# 0: 640x192 1 person, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:869  box=[442,134,509,394]
#   → chair 0.38 ID:819  box=[394,322,496,510]
#
# 0: 640x160 1 person, 31.2ms
# Speed: 1.8ms preprocess, 31.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.89 ID:879  box=[915,289,1084,1125]
#
# 0: 640x352 1 person, 50.1ms
# Speed: 2.6ms preprocess, 50.1ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.32 ID:896  box=[42,485,184,752]
#
# 0: 640x256 1 person, 37.0ms
# Speed: 1.5ms preprocess, 37.0ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.45 ID:868  box=[188,355,292,648]
#   → chair 0.77 ID:710  box=[890,342,981,725]
#   → chair 0.26 ID:895  box=[742,268,816,647]
# video 1/1 (frame 3037/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 53.9ms
# Frame 3036:
#
# 0: 640x192 1 person, 34.4ms
# Speed: 1.2ms preprocess, 34.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:869  box=[442,134,509,394]
#   → chair 0.39 ID:819  box=[394,321,496,511]
#
# 0: 640x160 1 person, 33.8ms
# Speed: 4.5ms preprocess, 33.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.88 ID:879  box=[915,289,1083,1122]
#
# 0: 640x352 1 person, 48.0ms
# Speed: 2.6ms preprocess, 48.0ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.33 ID:896  box=[42,486,184,753]
#
# 0: 640x256 2 persons, 37.6ms
# Speed: 2.3ms preprocess, 37.6ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.55 ID:868  box=[189,355,292,648]
#   → chair 0.78 ID:710  box=[890,342,981,725]
#   → chair 0.23 ID:895  box=[742,269,815,647]
# video 1/1 (frame 3038/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 51.5ms
# Frame 3037:
#
# 0: 640x192 1 person, 37.9ms
# Speed: 2.5ms preprocess, 37.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.69 ID:869  box=[443,134,509,394]
#   → chair 0.42 ID:819  box=[393,321,495,511]
#
# 0: 640x160 1 person, 38.1ms
# Speed: 1.6ms preprocess, 38.1ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.88 ID:879  box=[915,289,1083,1123]
#
# 0: 640x352 1 person, 50.9ms
# Speed: 4.0ms preprocess, 50.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.40 ID:896  box=[41,486,183,753]
#
# 0: 640x256 2 persons, 37.7ms
# Speed: 1.9ms preprocess, 37.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.50 ID:868  box=[188,356,292,647]
#   → chair 0.78 ID:710  box=[891,343,981,724]
#   → chair 0.20 ID:895  box=[742,269,815,646]
# video 1/1 (frame 3039/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 54.5ms
# Frame 3038:
#
# 0: 640x192 1 person, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.69 ID:869  box=[443,134,509,395]
#   → chair 0.42 ID:819  box=[393,322,495,511]
#
# 0: 640x128 1 person, 29.5ms
# Speed: 2.2ms preprocess, 29.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 128)
#   → standing 0.89 ID:879  box=[915,288,1083,1126]
#
# 0: 640x352 1 person, 53.0ms
# Speed: 2.7ms preprocess, 53.0ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.43 ID:896  box=[40,486,183,753]
#
# 0: 640x256 1 person, 43.0ms
# Speed: 3.7ms preprocess, 43.0ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.50 ID:868  box=[188,356,291,646]
#   → chair 0.78 ID:710  box=[891,343,981,724]
#   → chair 0.20 ID:895  box=[742,269,815,646]
# video 1/1 (frame 3040/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 55.5ms
# Frame 3039:
#
# 0: 640x192 1 person, 36.4ms
# Speed: 3.8ms preprocess, 36.4ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:869  box=[443,134,510,395]
#   → chair 0.42 ID:819  box=[393,321,495,511]
#
# 0: 640x160 1 person, 39.4ms
# Speed: 2.8ms preprocess, 39.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.85 ID:879  box=[916,289,1082,1112]
#
# 0: 640x352 1 person, 49.2ms
# Speed: 2.8ms preprocess, 49.2ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.47 ID:896  box=[39,485,182,753]
#
# 0: 640x256 3 persons, 41.0ms
# Speed: 2.9ms preprocess, 41.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.58 ID:868  box=[188,356,292,648]
#   → chair 0.78 ID:710  box=[890,342,981,724]
#   → chair 0.19 ID:895  box=[742,268,814,645]
# video 1/1 (frame 3041/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 53.4ms
# Frame 3040:
#
# 0: 640x192 1 person, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:869  box=[443,134,509,395]
#   → chair 0.44 ID:819  box=[394,322,496,511]
#
# 0: 640x160 1 person, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.86 ID:879  box=[915,288,1082,1116]
#
# 0: 640x352 1 person, 48.2ms
# Speed: 2.2ms preprocess, 48.2ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.47 ID:896  box=[39,485,182,751]
#
# 0: 640x256 2 persons, 37.1ms
# Speed: 1.9ms preprocess, 37.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.56 ID:868  box=[188,356,292,648]
#   → chair 0.80 ID:710  box=[890,342,980,724]
#   → chair 0.29 ID:895  box=[741,249,815,635]
# video 1/1 (frame 3042/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 53.8ms
# Frame 3041:
#
# 0: 640x192 1 person, 33.4ms
# Speed: 1.6ms preprocess, 33.4ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.67 ID:869  box=[442,134,509,396]
#   → chair 0.43 ID:819  box=[394,322,496,511]
#
# 0: 640x160 1 person, 31.0ms
# Speed: 3.0ms preprocess, 31.0ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.86 ID:879  box=[915,287,1082,1118]
#
# 0: 640x352 1 person, 49.2ms
# Speed: 1.9ms preprocess, 49.2ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.43 ID:896  box=[40,485,182,750]
#
# 0: 640x256 1 person, 40.1ms
# Speed: 1.9ms preprocess, 40.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.54 ID:868  box=[188,356,292,649]
#   → chair 0.81 ID:710  box=[889,342,980,724]
#   → chair 0.24 ID:895  box=[740,242,816,631]
# video 1/1 (frame 3043/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 50.0ms
# Frame 3042:
#
# 0: 640x192 1 person, 36.2ms
# Speed: 2.9ms preprocess, 36.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.67 ID:869  box=[443,134,509,396]
#   → chair 0.43 ID:819  box=[394,322,496,511]
#
# 0: 640x160 1 person, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.86 ID:879  box=[916,288,1082,1112]
#
# 0: 640x352 1 person, 48.1ms
# Speed: 1.9ms preprocess, 48.1ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.37 ID:896  box=[40,486,182,750]
#
# 0: 640x256 1 person, 38.8ms
# Speed: 3.5ms preprocess, 38.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.41 ID:868  box=[188,357,291,648]
#   → chair 0.78 ID:710  box=[889,342,980,724]
#   → chair 0.23 ID:895  box=[740,241,816,631]
# video 1/1 (frame 3044/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 49.8ms
# Frame 3043:
#
# 0: 640x192 1 person, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.69 ID:869  box=[443,133,510,395]
#   → chair 0.44 ID:819  box=[394,322,497,511]
#
# 0: 640x160 1 person, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.85 ID:879  box=[915,289,1081,1109]
#
# 0: 640x352 1 person, 51.5ms
# Speed: 1.8ms preprocess, 51.5ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.38 ID:896  box=[40,486,182,749]
#
# 0: 640x256 1 person, 42.9ms
# Speed: 2.0ms preprocess, 42.9ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.39 ID:868  box=[188,357,291,648]
#   → chair 0.78 ID:710  box=[890,342,980,724]
#   → chair 0.23 ID:895  box=[741,258,815,638]
# video 1/1 (frame 3045/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 4 persons, 3 chairs, 55.0ms
# Frame 3044:
#
# 0: 640x192 1 person, 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.70 ID:869  box=[443,133,510,395]
#   → chair 0.45 ID:819  box=[394,322,496,510]
#
# 0: 640x160 1 person, 31.5ms
# Speed: 1.4ms preprocess, 31.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 160)
#   → standing 0.84 ID:879  box=[915,289,1081,1109]
#
# 0: 640x352 1 person, 48.0ms
# Speed: 2.5ms preprocess, 48.0ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.39 ID:896  box=[40,487,182,749]
#
# 0: 640x256 1 person, 38.8ms
# Speed: 3.6ms preprocess, 38.8ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.38 ID:868  box=[188,360,290,649]
#   → chair 0.77 ID:710  box=[890,341,980,724]
#   → chair 0.24 ID:895  box=[741,265,814,641]
