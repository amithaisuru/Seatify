# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (8.3.133)
# Requirement already satisfied: opencv-python in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: pillow>=7.1.2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.7.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.22.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import time

# %%
# Load the YOLOv8 model
model = YOLO('yolov8x.pt').to('cuda:0')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs

# %%
# --------Human & Object detection in video - correctly working--------

'''

# Initialize video capture
cap = cv2.VideoCapture(r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4')

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    while cap.isOpened():
        print("Reading frame...")
        ret, frame = cap.read()

        # Perform detection on the current frame
        results = model(frame)  # Detect objects in the frame

        # Filter detections for 'person' and 'chair' classes
        # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

        # Process the results
        for result in results:

            boxes = result.boxes  # Get bounding boxes

            for box in boxes:
                class_id = box.cls[0].item()  # Get the class id of the detected object
                if class_id in person_and_chair:  # Check if it is a person or a chair
                    # Get the bounding box coordinates
                    x1, y1, x2, y2 = map(int, box.xyxy[0])

                    # Get the class ID and confidence score
                    class_id = box.cls[0].item()
                    confidence = box.conf[0].item()

                    # Get the class name
                    label = model.names[class_id]

                    # Print out the detected object details
                    print(
                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                    )
                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                    # Draw a bounding box around the object

                    # Define different colors for different objects
                    if label == "person":
                        color = (255, 0, 0)  # Blue color for human (person)
                    elif label == "chair":
                        color = (0, 0, 255)  # Red color for chair
                    else:
                        color = (0, 255, 0)  # Default green for other objects

                    # Draw a bounding box around the object with the selected color
                    cv2.rectangle(
                        frame, (x1, y1), (x2, y2), color, 2
                    )  # Bounding box with the chosen color

                    cv2.putText(
                        frame,
                        label,
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        (0, 255, 0),
                        2,
                    )

        if frame is not None and frame.size > 0:
            cv2.imshow("Video", frame)
        else:
            print("Warning: Empty frame encountered!")
            break

        # Press 'q' to quit the video window
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\1471836195.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo6.mp4\')\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    while cap.isOpened():\n        print("Reading frame...")\n        ret, frame = cap.read()\n\n        # Perform detection on the current frame\n        results = model(frame)  # Detect objects in the frame\n\n        # Filter detections for \'person\' and \'chair\' classes\n        # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n        # Process the results\n        for result in results:\n\n            boxes = result.boxes  # Get bounding boxes\n\n            for box in boxes:\n                class_id = box.cls[0].item()  # Get the class id of the detected object\n                if class_id in person_and_chair:  # Check if it is a person or a chair\n                    # Get the bounding box coordinates\n                    x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                    # Get the class ID and confidence score\n                    class_id = box.cls[0].item()\n                    confidence = box.conf[0].item()\n\n                    # Get the class name\n                    label = model.names[class_id]\n\n                    # Print out the detected object details\n                    print(\n                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                    )\n                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                    # Draw a bounding box around the object\n\n                    # Define different colors for different objects\n                    if label == "person":\n                        color = (255, 0, 0)  # Blue color for human (person)\n                    elif label == "chair":\n                        color = (0, 0, 255)  # Red color for chair\n                    else:\n                        color = (0, 255, 0)  # Default green for other objects\n\n                    # Draw a bounding box around the object with the selected color\n                    cv2.rectangle(\n                        frame, (x1, y1), (x2, y2), color, 2\n                    )  # Bounding box with the chosen color\n\n                    cv2.putText(\n                        frame,\n                        label,\n                        (x1, y1 - 10),\n                        cv2.FONT_HERSHEY_SIMPLEX,\n                        0.9,\n                        (0, 255, 0),\n                        2,\n                    )\n\n        if frame is not None and frame.size > 0:\n            cv2.imshow("Video", frame)\n        else:\n            print("Warning: Empty frame encountered!")\n            break\n\n        # Press \'q\' to quit the video window\n        if cv2.waitKey(1) & 0xFF == ord("q"):\n            break\n\n    # Release the video capture object and close all windows\n    cap.release()\n    cv2.destroyAllWindows()\n\n'

# %%
# -----Tried to skip frames and process frames after every 10 seconds. Did not worked-----


'''

# Initialize video capture
cap = cv2.VideoCapture(
    r"D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4"
)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    # Get the frame rate (fps) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video Frame Rate (FPS): {fps}")

    # Time between frames we want to process (10 seconds)
    interval = 2  # Process every 10 seconds

    # Calculate the frame number corresponding to the desired times
    frame_number = 0
    prev_time = 0  # Start at time 0

    while cap.isOpened():
        # Calculate the time for the current frame (in seconds)
        current_time = frame_number / fps

        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)
        if current_time >= prev_time:

            print("Reading frame...")
            # Read a frame from the video
            ret, frame = cap.read()

            # Check if the frame was read properly
            if not ret:
                print("Error: Couldn't read the frame.")
                break

            # Perform detection on the current frame
            results = model(frame)  # Detect objects in the frame

            # Filter detections for 'person' and 'chair' classes
            # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

            # Process the results
            for result in results:
                # Extract bounding boxes, confidence, and class IDs
                boxes = result.boxes  # Get bounding boxes

                for box in boxes:
                    class_id = box.cls[0].item()  # Get the class id of the detected object

                    if (class_id in person_and_chair):  # Check if it is a person or a chair
                        # Get the bounding box coordinates
                        x1, y1, x2, y2 = map(int, box.xyxy[0])

                        # Get the class ID and confidence score
                        class_id = box.cls[0].item()
                        confidence = box.conf[0].item()

                        # Get the class name
                        label = model.names[class_id]

                        # Print out the detected object details
                        print(
                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                        )
                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                        # Draw a bounding box around the object

                        # Define different colors for different objects
                        if label == "person":
                            color = (255, 0, 0)  # Blue color for human (person)
                        elif label == "chair":
                            color = (0, 0, 255)  # Red color for chair
                        else:
                            color = (0, 255, 0)  # Default green for other objects

                        # Draw a bounding box around the object with the selected color
                        cv2.rectangle(
                            frame, (x1, y1), (x2, y2), color, 2
                        )  # Bounding box with the chosen color

                        cv2.putText(
                            frame,
                            label,
                            (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.9,
                            (0, 255, 0),
                            2,
                        )

                if frame is not None and frame.size > 0:
                    cv2.imshow("Video", frame)
                else:
                    print("Warning: Empty frame encountered!")
                    break

                # Press 'q' to quit the video window
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break

                # Update prev_time to the next desired frame time (e.g., t = 10s, 20s)
                prev_time += interval  # Move to the next interval (10 seconds)

            # Skip frames until we reach the desired frame time
            frame_number += 1
        
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\3711239310.py:4: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(\n    r"D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4"\n)\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    # Get the frame rate (fps) of the video\n    fps = cap.get(cv2.CAP_PROP_FPS)\n    print(f"Video Frame Rate (FPS): {fps}")\n\n    # Time between frames we want to process (10 seconds)\n    interval = 2  # Process every 10 seconds\n\n    # Calculate the frame number corresponding to the desired times\n    frame_number = 0\n    prev_time = 0  # Start at time 0\n\n    while cap.isOpened():\n        # Calculate the time for the current frame (in seconds)\n        current_time = frame_number / fps\n\n        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)\n        if current_time >= prev_time:\n\n            print("Reading frame...")\n            # Read a frame from the video\n            ret, frame = cap.read()\n\n            # Check if the frame was read properly\n            if not ret:\n                print("Error: Couldn\'t read the frame.")\n                break\n\n            # Perform detection on the current frame\n            results = model(frame)  # Detect objects in the frame\n\n            # Filter detections for \'person\' and \'chair\' classes\n            # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n            # Process the results\n            for result in results:\n                # Extract bounding boxes, confidence, and class IDs\n                boxes = result.boxes  # Get bounding boxes\n\n                for box in boxes:\n                    class_id = box.cls[0].item()  # Get the class id of the detected object\n\n                    if (class_id in person_and_chair):  # Check if it is a person or a chair\n                        # Get the bounding box coordinates\n                        x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                        # Get the class ID and confidence score\n                        class_id = box.cls[0].item()\n                        confidence = box.conf[0].item()\n\n                        # Get the class name\n                        label = model.names[class_id]\n\n                        # Print out the detected object details\n                        print(\n                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                        )\n                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                        # Draw a bounding box around the object\n\n                        # Define different colors for different objects\n                        if label == "person":\n                            color = (255, 0, 0)  # Blue color for human (person)\n                        elif label == "chair":\n                            color = (0, 0, 255)  # Red color for chair\n                        else:\n                            color = (0, 255, 0)  # Default green for other objects\n\n                        # Draw a bounding box around the object with the selected color\n                        cv2.rectangle(\n                            frame, (x1, y1), (x2, y2), color, 2\n                        )  # Bounding box with the chosen color\n\n                        cv2.putText(\n                            frame,\n                            label,\n                            (x1, y1 - 10),\n                            cv2.FONT_HERSHEY_SIMPLEX,\n                            0.9,\n                            (0, 255, 0),\n                            2,\n                        )\n\n                if frame is not None and frame.size > 0:\n                    cv2.imshow("Video", frame)\n                else:\n          ...

# %%
import torch
print("CUDA available? ", torch.cuda.is_available())
print("GPU count:    ", torch.cuda.device_count())
print("Current dev:  ", torch.cuda.current_device())
print("Dev name:     ", torch.cuda.get_device_name(0))
# Out:
# CUDA available?  True
# GPU count:     1
# Current dev:   0
# Dev name:      NVIDIA GeForce GTX 1660 Ti

# %%
# ----- Human & Chair detection and tracking - correctly working -----

'''
# 3. Run detection + ByteTrack on your video
#    – source: your file path
#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)
#    – classes: [0,56] → only person (0) & chair (56)
#    – persist: keep track IDs alive across frames
#    – show: pop up each frame (set False if headless)
#    – save: write out an annotated video to runs/track/exp*
stream = model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4',
    tracker='bytetrack.yaml',
    classes=[0, 56],
    persist=True,
    show=False,    # we’ll show manually
    save=True,    # disable automatic save
    save_dir='my_outputs/',
    stream=True,   # <— Enable streaming!
    device='cuda:0'
)

for frame_idx, res in enumerate(stream):
    print(f"Frame {frame_idx}:")
    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id
    for xyxy, conf, cls_id, track_id in zip(
        res.boxes.xyxy, 
        res.boxes.conf, 
        res.boxes.cls, 
        res.boxes.id
    ):
        x1, y1, x2, y2 = map(int, xyxy.tolist())
        conf = float(conf)
        cls_id = int(cls_id)
        track_id = int(track_id)
        label = res.names[cls_id]  # e.g. "person" or "chair"
        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")

    # Optional: display the annotated frame and quit on 'q'
    frame = res.plot()
    cv2.imshow("Track (press q to quit)", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\1808955419.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n# 3. Run detection + ByteTrack on your video\n#    – source: your file path\n#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)\n#    – classes: [0,56] → only person (0) & chair (56)\n#    – persist: keep track IDs alive across frames\n#    – show: pop up each frame (set False if headless)\n#    – save: write out an annotated video to runs/track/exp*\nstream = model.track(\n    source=r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4\',\n    tracker=\'bytetrack.yaml\',\n    classes=[0, 56],\n    persist=True,\n    show=False,    # we’ll show manually\n    save=True,    # disable automatic save\n    save_dir=\'my_outputs/\',\n    stream=True,   # <— Enable streaming!\n    device=\'cuda:0\'\n)\n\nfor frame_idx, res in enumerate(stream):\n    print(f"Frame {frame_idx}:")\n    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id\n    for xyxy, conf, cls_id, track_id in zip(\n        res.boxes.xyxy, \n        res.boxes.conf, \n        res.boxes.cls, \n        res.boxes.id\n    ):\n        x1, y1, x2, y2 = map(int, xyxy.tolist())\n        conf = float(conf)\n        cls_id = int(cls_id)\n        track_id = int(track_id)\n        label = res.names[cls_id]  # e.g. "person" or "chair"\n        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")\n\n    # Optional: display the annotated frame and quit on \'q\'\n    frame = res.plot()\n    cv2.imshow("Track (press q to quit)", frame)\n    if cv2.waitKey(1) & 0xFF == ord(\'q\'):\n        break\n\ncv2.destroyAllWindows()\n\n'

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load models onto GPU
det_model  = YOLO('yolov8x.pt').to('cuda:0')
pose_model = YOLO('yolov8x-pose.pt').to('cuda:0')

def calculate_angle(a, b, c):
    #Builds vectors ba and bc around joint b.
    ba = a - b
    bc = c - b
    
    #Uses the dot-product formula to get the cosine of angle abc
    cosang = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-6)

    #clip to valid range and convert from radians to degrees
    return np.degrees(np.arccos(np.clip(cosang, -1.0, 1.0)))

# compute knee angle
def kneeAngleCondition(kpts):
    try:
        # compute left & right knee angles
        l_ang = calculate_angle(kpts[11,:2], kpts[13,:2], kpts[15,:2]) #computes left knee angles
        r_ang = calculate_angle(kpts[12,:2], kpts[14,:2], kpts[16,:2]) #computes right knee angles
        # compute average angle
        knee_angle = (l_ang + r_ang) / 2

        # Threshold to decide sitting vs standing
        if knee_angle < 110:
            return True
        else:
            return False
    except:
        pass  

#Compute torso lean: angle at the hip by shoulder→hip→knee
def torsoAngleCondition(kpts):
    try:
        left_torso  = calculate_angle(kpts[5,:2],  kpts[11,:2], kpts[13,:2])  # L-shoulder, L-hip, L-knee
        right_torso = calculate_angle(kpts[6,:2],  kpts[12,:2], kpts[14,:2])  # R-shoulder, R-hip, R-knee
        torso_angle = (left_torso + right_torso) / 2

        # Threshold to decide sitting vs standing
        if torso_angle < 110:
            return True
        else:
            return False

    except:
        pass  

#Hip‐knee level test: True if avg vertical distance between hip & knee is < 15% of crop height
def hipKneeLevelCondition(kpts, crop_height):
    try:
        dy_left  = abs(kpts[11,1] - kpts[13,1])
        dy_right = abs(kpts[12,1] - kpts[14,1])
        avg_dy   = (dy_left + dy_right) / 2

        return (avg_dy / crop_height) < 0.15
    except:
        return False

# IoU helper
def bbox_iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1b, y1b, x2b, y2b = box2
    xi1, yi1 = max(x1, x1b), max(y1, y1b)
    xi2, yi2 = min(x2, x2b), min(y2, y2b)
    inter_w = max(0, xi2 - xi1)
    inter_h = max(0, yi2 - yi1)
    inter = inter_w * inter_h
    area1 = (x2 - x1) * (y2 - y1)
    area2 = (x2b - x1b) * (y2b - y1b)
    union = area1 + area2 - inter
    return inter / union if union > 0 else 0

IOU_THRESHOLD = 0.2

# Start the detection + track stream
stream = det_model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4',
    tracker='bytetrack.yaml',
    classes=[0,56],
    persist=True,
    show=False,
    save=True,
    save_dir='my_outputs/',
    stream=True,
    device='cuda:0'
)

#process frames
for frameIndex, singleFrame in enumerate(stream): #enumerate(stream) gives (frame_idx, res) as soon as each frame is done
    frame = singleFrame.orig_img.copy() # copy of raw frame we annotate
    print(f"Frame {frameIndex}:")

    # Pull detections
    # Unpack the tracked detections in parallel arrays
    boxesXYXYs = singleFrame.boxes.xyxy.cpu().numpy() # bounding boxes (n×4)
    confs     = singleFrame.boxes.conf.cpu().numpy() # confidence scores (n) 
    cls_ids   = singleFrame.boxes.cls.cpu().numpy().astype(int) # class IDs (n)
    track_ids = singleFrame.boxes.id.cpu().numpy().astype(int) # track IDs (n)

    # Build a list of chairs this frame
    chair_boxes = []
    for (x1,y1,x2,y2), cls_id in zip(boxesXYXYs, cls_ids):
        if singleFrame.names[cls_id] == 'chair':
            chairBoundingBox = list(map(int, (x1,y1,x2,y2)))
            chair_boxes.append(chairBoundingBox)
        
    # print(f"  → Found {len(chair_boxes)} chairs in this frame")
    # print(f"  → Found {len(boxesXYXYs)} total detections in this frame")

    #Iterate through each detection in this frame
    for (x1, y1, x2, y2), conf, cls_id, track_id in zip(boxesXYXYs, confs, cls_ids, track_ids): #Zips the four arrays so you handle each detection in lockstep.
        
        #Converts the box coords to integers
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))

        #looks up the human-readable class name
        label = singleFrame.names[cls_id] # e.g. "person" or "chair"

        # Person branch
        if label == 'person':

            # Defaults the posture to “unknown” with a yellow box
            posture, color = 'unknown', (0,255,255)

            # Crops the detected person region and runs pose_model on that ROI
            roi = frame[y1:y2, x1:x2]
            p = pose_model(roi, device='cuda:0')[0]


            # If keypoints were found, extracts the raw (n,17,3) array from p.keypoints.data.
            # In the shape tuple (n, 17, 3), that leading n is simply the number of person instances (i.e. detections) 
            # that the pose model found in your cropped image
            # Since you’re cropping around a single detected box, in most cases n will be 1
            if p.keypoints is not None:
                # Extract the raw (n,17,3) tensor of keypoints
                kpts_np = p.keypoints.data.cpu().numpy()  # shape (n,17,3)

                # Ensure we have at least 17 keypoints
                if kpts_np.ndim == 3 and kpts_np.shape[1] >= 17:
                    kpts = kpts_np[0]  # first person
                    # shape (17,3): [x,y,conf] per joint

                    # Compute the knee angle
                    kneeAngleResult = kneeAngleCondition(kpts)

                    # Compute the torso angle
                    torsoAngleResult = torsoAngleCondition(kpts)

                    # Compute the hip-knee level condition
                    hipKneeLevelResult = hipKneeLevelCondition(kpts, crop_height=(y2-y1))
                    
                    # 4th test: does this person overlap any chair?
                    iouSittingResult = any(
                        bbox_iou([x1,y1,x2,y2], cb) > IOU_THRESHOLD
                        for cb in chair_boxes
                    )
                    
                    if kneeAngleResult:
                        posture, color = 'sitting',  (0,255,0)
                    else:
                        posture, color = 'standing', (0,0,255)
                    
            text = f"{posture} {conf:.2f} ID:{track_id}"

        else:
            # chair
            color = (255,0,0)
            text  = f"chair {conf:.2f} ID:{track_id}"

        # Draw & print
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
        cv2.putText(frame, text, (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        print(f"  → {text}  box=[{x1},{y1},{x2},{y2}]")

    cv2.imshow("Pose+Track", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# video 1/1 (frame 1/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 3 chairs, 88.4ms
# Frame 0:
#   → chair 0.63 ID:1  box=[822,337,974,719]
#   → chair 0.52 ID:2  box=[393,317,494,497]
#
# 0: 640x224 (no detections), 35.6ms
# Speed: 2.2ms preprocess, 35.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.47 ID:3  box=[192,339,290,632]
#   → chair 0.47 ID:4  box=[941,220,1010,370]
#
# 0: 640x224 (no detections), 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.38 ID:5  box=[425,142,501,385]
# video 1/1 (frame 2/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 3 chairs, 50.9ms
# Frame 1:
#   → chair 0.69 ID:1  box=[823,337,975,719]
#   → chair 0.55 ID:2  box=[393,317,494,498]
#
# 0: 640x224 (no detections), 30.4ms
# Speed: 5.2ms preprocess, 30.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.42 ID:3  box=[192,339,290,634]
#   → chair 0.46 ID:4  box=[941,219,1011,369]
# video 1/1 (frame 3/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 3 chairs, 53.9ms
# Frame 2:
#   → chair 0.57 ID:1  box=[824,338,976,719]
#   → chair 0.56 ID:2  box=[394,317,493,494]
#
# 0: 640x224 2 persons, 32.6ms
# Speed: 5.5ms preprocess, 32.6ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.32 ID:3  box=[193,339,289,629]
#   → chair 0.47 ID:4  box=[941,218,1011,370]
#
# 0: 640x224 1 person, 39.9ms
# Speed: 4.0ms preprocess, 39.9ms inference, 9.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.37 ID:5  box=[422,141,499,385]
# video 1/1 (frame 4/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 55.3ms
# Frame 3:
#   → chair 0.53 ID:1  box=[825,339,976,719]
#   → chair 0.61 ID:2  box=[396,317,493,490]
#
# 0: 640x224 1 person, 33.5ms
# Speed: 5.2ms preprocess, 33.5ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.35 ID:3  box=[193,339,290,631]
#   → chair 0.56 ID:4  box=[940,217,1011,371]
#   → chair 0.33 ID:7  box=[739,233,816,639]
#   → chair 0.34 ID:8  box=[511,252,663,535]
#
# 0: 640x224 1 person, 31.7ms
# Speed: 4.0ms preprocess, 31.7ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.32 ID:5  box=[422,140,499,386]
# video 1/1 (frame 5/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 59.2ms
# Frame 4:
#   → chair 0.43 ID:1  box=[825,336,977,719]
#   → chair 0.63 ID:2  box=[396,318,492,489]
#
# 0: 640x224 (no detections), 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.32 ID:3  box=[192,339,289,632]
#   → chair 0.58 ID:4  box=[940,217,1011,371]
#   → chair 0.28 ID:7  box=[739,232,815,640]
#   → chair 0.43 ID:8  box=[512,251,665,535]
#
# 0: 640x224 1 person, 34.9ms
# Speed: 7.9ms preprocess, 34.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.38 ID:5  box=[423,140,499,386]
# video 1/1 (frame 6/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 58.3ms
# Frame 5:
#   → chair 0.32 ID:1  box=[825,339,976,719]
#   → chair 0.66 ID:2  box=[396,318,492,488]
#
# 0: 640x224 2 persons, 38.2ms
# Speed: 2.6ms preprocess, 38.2ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.31 ID:3  box=[192,339,289,632]
#   → chair 0.51 ID:4  box=[940,218,1010,371]
#   → chair 0.26 ID:7  box=[738,232,815,640]
#   → chair 0.52 ID:8  box=[513,251,667,537]
#
# 0: 640x224 1 person, 37.3ms
# Speed: 4.2ms preprocess, 37.3ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.43 ID:5  box=[423,140,499,386]
# video 1/1 (frame 7/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 60.6ms
# Frame 6:
#   → chair 0.35 ID:1  box=[825,339,976,719]
#   → chair 0.66 ID:2  box=[395,317,493,490]
#
# 0: 640x224 (no detections), 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.49 ID:3  box=[191,339,288,633]
#   → chair 0.52 ID:4  box=[940,218,1010,372]
#   → chair 0.36 ID:7  box=[738,232,815,640]
#   → chair 0.47 ID:8  box=[514,252,668,536]
#
# 0: 640x224 1 person, 37.4ms
# Speed: 3.2ms preprocess, 37.4ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.46 ID:5  box=[424,140,499,386]
# video 1/1 (frame 8/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 61.3ms
# Frame 7:
#   → chair 0.31 ID:1  box=[827,339,977,719]
#   → chair 0.64 ID:2  box=[396,318,493,489]
#
# 0: 640x224 2 persons, 36.8ms
# Speed: 3.0ms preprocess, 36.8ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.33 ID:3  box=[192,339,288,631]
#   → chair 0.47 ID:4  box=[940,219,1010,371]
#   → chair 0.27 ID:7  box=[738,233,814,639]
#   → chair 0.49 ID:8  box=[513,251,668,538]
#
# 0: 640x224 1 person, 41.1ms
# Speed: 2.4ms preprocess, 41.1ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.51 ID:5  box=[424,140,500,386]
# video 1/1 (frame 9/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 235.8ms
# Frame 8:
#   → chair 0.50 ID:1  box=[825,336,977,719]
#   → chair 0.66 ID:2  box=[396,318,493,489]
#
# 0: 640x224 1 person, 35.4ms
# Speed: 3.4ms preprocess, 35.4ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.38 ID:3  box=[193,339,288,629]
#   → chair 0.46 ID:4  box=[940,219,1010,371]
#   → chair 0.31 ID:7  box=[738,233,814,639]
#   → chair 0.56 ID:8  box=[512,251,669,539]
#
# 0: 640x224 1 person, 37.0ms
# Speed: 2.9ms preprocess, 37.0ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:5  box=[424,140,499,385]
#
# 0: 640x448 (no detections), 63.2ms
# Speed: 6.6ms preprocess, 63.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.39 ID:9  box=[532,152,643,322]
# video 1/1 (frame 10/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 52.1ms
# Frame 9:
#   → chair 0.53 ID:1  box=[824,338,976,719]
#   → chair 0.67 ID:2  box=[396,318,493,487]
#
# 0: 640x224 1 person, 41.0ms
# Speed: 2.7ms preprocess, 41.0ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.41 ID:3  box=[193,339,289,631]
#   → chair 0.42 ID:4  box=[940,219,1010,371]
#   → chair 0.29 ID:7  box=[739,234,815,639]
#   → chair 0.71 ID:8  box=[513,251,670,539]
#
# 0: 640x224 1 person, 34.5ms
# Speed: 4.9ms preprocess, 34.5ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:5  box=[424,139,499,386]
#
# 0: 640x448 (no detections), 54.9ms
# Speed: 3.6ms preprocess, 54.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.30 ID:9  box=[533,156,642,321]
# video 1/1 (frame 11/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 57.7ms
# Frame 10:
#   → chair 0.64 ID:1  box=[823,338,975,718]
#   → chair 0.65 ID:2  box=[396,318,493,487]
#
# 0: 640x224 1 person, 41.1ms
# Speed: 2.8ms preprocess, 41.1ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.51 ID:3  box=[193,339,290,633]
#   → chair 0.35 ID:4  box=[940,218,1011,371]
#   → chair 0.28 ID:7  box=[739,234,815,639]
#   → chair 0.67 ID:8  box=[513,251,671,539]
#
# 0: 640x224 1 person, 36.5ms
# Speed: 5.1ms preprocess, 36.5ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:5  box=[424,140,499,385]
#
# 0: 640x448 1 person, 64.5ms
# Speed: 4.1ms preprocess, 64.5ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.26 ID:9  box=[538,167,639,320]
# video 1/1 (frame 12/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 59.9ms
# Frame 11:
#   → chair 0.57 ID:1  box=[825,339,976,718]
#   → chair 0.65 ID:2  box=[396,318,493,486]
#
# 0: 640x224 (no detections), 40.0ms
# Speed: 4.0ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.33 ID:3  box=[193,339,290,633]
#   → chair 0.32 ID:4  box=[941,218,1011,371]
#   → chair 0.23 ID:7  box=[739,233,815,639]
#   → chair 0.68 ID:8  box=[512,250,671,540]
#
# 0: 640x224 1 person, 42.5ms
# Speed: 3.8ms preprocess, 42.5ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.57 ID:5  box=[424,140,498,385]
#
# 0: 640x448 (no detections), 53.3ms
# Speed: 3.4ms preprocess, 53.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.19 ID:9  box=[541,174,636,317]
# video 1/1 (frame 13/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 50.8ms
# Frame 12:
#   → chair 0.50 ID:1  box=[827,339,978,718]
#   → chair 0.70 ID:2  box=[396,318,493,485]
#
# 0: 640x224 1 person, 30.2ms
# Speed: 1.5ms preprocess, 30.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.42 ID:3  box=[193,339,289,631]
#   → chair 0.29 ID:4  box=[941,217,1011,372]
#   → chair 0.21 ID:7  box=[741,234,817,639]
#   → chair 0.64 ID:8  box=[512,251,672,540]
#
# 0: 640x224 1 person, 27.7ms
# Speed: 3.0ms preprocess, 27.7ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:5  box=[424,140,498,385]
#
# 0: 640x448 (no detections), 50.9ms
# Speed: 3.3ms preprocess, 50.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.35 ID:9  box=[539,170,637,317]
# video 1/1 (frame 14/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 54.0ms
# Frame 13:
#   → chair 0.48 ID:1  box=[829,340,979,718]
#   → chair 0.70 ID:2  box=[395,318,493,487]
#
# 0: 640x224 1 person, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.44 ID:3  box=[194,339,289,628]
#   → chair 0.32 ID:4  box=[941,217,1011,373]
#   → chair 0.20 ID:7  box=[741,235,817,640]
#   → chair 0.52 ID:8  box=[510,251,670,541]
#
# 0: 640x224 1 person, 28.2ms
# Speed: 2.6ms preprocess, 28.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:5  box=[424,140,498,385]
#
# 0: 640x448 (no detections), 52.7ms
# Speed: 3.1ms preprocess, 52.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.36 ID:9  box=[539,168,638,317]
#   → chair 0.33 ID:13  box=[795,153,864,270]
# video 1/1 (frame 15/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 49.4ms
# Frame 14:
#   → chair 0.54 ID:1  box=[828,340,979,718]
#   → chair 0.69 ID:2  box=[395,318,493,488]
#
# 0: 640x224 1 person, 30.9ms
# Speed: 2.6ms preprocess, 30.9ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.42 ID:3  box=[192,339,289,634]
#   → chair 0.42 ID:4  box=[940,218,1011,373]
#   → chair 0.19 ID:7  box=[743,260,814,641]
#   → chair 0.57 ID:8  box=[510,251,671,541]
#
# 0: 640x224 1 person, 44.3ms
# Speed: 4.9ms preprocess, 44.3ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:5  box=[423,139,498,387]
#
# 0: 640x448 1 person, 55.9ms
# Speed: 6.8ms preprocess, 55.9ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.28 ID:9  box=[538,169,638,317]
#   → chair 0.36 ID:13  box=[795,153,864,269]
# video 1/1 (frame 16/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 6 chairs, 50.8ms
# Frame 15:
#   → chair 0.25 ID:1  box=[838,342,988,718]
#   → chair 0.69 ID:2  box=[396,317,494,484]
#
# 0: 640x224 1 person, 35.9ms
# Speed: 2.1ms preprocess, 35.9ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.47 ID:3  box=[192,339,291,640]
#   → chair 0.41 ID:4  box=[940,218,1011,373]
#   → chair 0.22 ID:7  box=[740,243,815,639]
#   → chair 0.23 ID:8  box=[510,251,671,542]
#
# 0: 640x224 1 person, 39.3ms
# Speed: 3.5ms preprocess, 39.3ms inference, 11.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:5  box=[423,139,498,387]
#   → chair 0.21 ID:13  box=[794,153,863,270]
# video 1/1 (frame 17/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 51.2ms
# Frame 16:
#   → chair 0.30 ID:1  box=[840,342,990,719]
#   → chair 0.69 ID:2  box=[397,317,494,483]
#
# 0: 640x224 1 person, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:3  box=[193,339,290,636]
#   → chair 0.45 ID:4  box=[940,218,1011,373]
#   → chair 0.25 ID:7  box=[740,236,816,638]
#   → chair 0.32 ID:8  box=[512,251,674,542]
#
# 0: 640x224 1 person, 30.6ms
# Speed: 2.9ms preprocess, 30.6ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:5  box=[424,139,499,387]
#   → chair 0.28 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 47.0ms
# Speed: 2.7ms preprocess, 47.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.38 ID:15  box=[529,96,599,227]
# video 1/1 (frame 18/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 54.5ms
# Frame 17:
#   → chair 0.22 ID:1  box=[840,342,991,719]
#   → chair 0.66 ID:2  box=[397,317,495,482]
#
# 0: 640x224 (no detections), 54.8ms
# Speed: 3.1ms preprocess, 54.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.64 ID:3  box=[193,339,289,633]
#   → chair 0.33 ID:4  box=[940,218,1010,373]
#   → chair 0.19 ID:7  box=[740,234,817,640]
#   → chair 0.37 ID:8  box=[514,252,675,540]
#
# 0: 640x192 (no detections), 70.2ms
# Speed: 3.9ms preprocess, 70.2ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.60 ID:5  box=[423,138,498,388]
#   → chair 0.19 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 58.4ms
# Speed: 6.3ms preprocess, 58.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.25 ID:15  box=[530,94,600,227]
# video 1/1 (frame 19/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 55.0ms
# Frame 18:
#   → chair 0.12 ID:1  box=[843,351,990,716]
#   → chair 0.70 ID:2  box=[397,316,496,482]
#
# 0: 640x224 1 person, 56.3ms
# Speed: 6.4ms preprocess, 56.3ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.61 ID:3  box=[193,339,288,632]
#   → chair 0.50 ID:4  box=[940,217,1011,374]
#   → chair 0.20 ID:7  box=[739,233,817,641]
#   → chair 0.49 ID:8  box=[514,251,676,540]
#
# 0: 640x224 (no detections), 57.9ms
# Speed: 6.2ms preprocess, 57.9ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.64 ID:5  box=[423,138,498,387]
#   → chair 0.28 ID:13  box=[794,154,863,270]
#
# 0: 640x352 1 person, 55.4ms
# Speed: 5.0ms preprocess, 55.4ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.40 ID:15  box=[531,93,601,226]
# video 1/1 (frame 20/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 58.3ms
# Frame 19:
#   → chair 0.27 ID:1  box=[833,343,983,717]
#   → chair 0.68 ID:2  box=[397,316,496,483]
#
# 0: 640x224 (no detections), 48.2ms
# Speed: 4.1ms preprocess, 48.2ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.56 ID:3  box=[193,339,288,631]
#   → chair 0.48 ID:4  box=[940,217,1011,374]
#   → chair 0.17 ID:7  box=[738,233,816,640]
#   → chair 0.61 ID:8  box=[513,250,677,541]
#
# 0: 640x192 (no detections), 37.0ms
# Speed: 5.9ms preprocess, 37.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.65 ID:5  box=[423,137,498,387]
#   → chair 0.30 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 45.2ms
# Speed: 5.0ms preprocess, 45.2ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.36 ID:15  box=[530,93,601,225]
#
# 0: 640x448 (no detections), 51.7ms
# Speed: 3.2ms preprocess, 51.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.39 ID:9  box=[533,157,640,318]
# video 1/1 (frame 21/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 53.4ms
# Frame 20:
#   → chair 0.30 ID:1  box=[830,340,981,718]
#   → chair 0.67 ID:2  box=[396,316,496,483]
#
# 0: 640x224 1 person, 42.4ms
# Speed: 2.5ms preprocess, 42.4ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:3  box=[194,339,288,631]
#   → chair 0.39 ID:4  box=[941,217,1011,374]
#   → chair 0.23 ID:7  box=[737,232,815,639]
#   → chair 0.56 ID:8  box=[513,250,677,541]
#
# 0: 640x192 (no detections), 38.4ms
# Speed: 3.5ms preprocess, 38.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.65 ID:5  box=[423,137,498,387]
#   → chair 0.27 ID:13  box=[794,154,863,270]
#
# 0: 640x352 1 person, 53.2ms
# Speed: 2.9ms preprocess, 53.2ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.27 ID:15  box=[530,93,601,227]
#
# 0: 640x288 1 person, 60.7ms
# Speed: 5.5ms preprocess, 60.7ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.32 ID:19  box=[94,496,203,739]
#
# 0: 640x448 (no detections), 51.7ms
# Speed: 4.6ms preprocess, 51.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.18 ID:9  box=[531,154,640,318]
# video 1/1 (frame 22/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 52.9ms
# Frame 21:
#   → chair 0.20 ID:1  box=[838,344,988,717]
#   → chair 0.67 ID:2  box=[396,316,496,483]
#
# 0: 640x224 1 person, 34.3ms
# Speed: 1.7ms preprocess, 34.3ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.52 ID:3  box=[193,340,288,631]
#   → chair 0.53 ID:4  box=[941,217,1011,375]
#   → chair 0.20 ID:7  box=[736,232,814,638]
#   → chair 0.52 ID:8  box=[513,249,678,541]
#
# 0: 640x192 2 persons, 35.0ms
# Speed: 1.4ms preprocess, 35.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.66 ID:5  box=[423,137,498,387]
#   → chair 0.27 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 46.0ms
# Speed: 4.1ms preprocess, 46.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.42 ID:15  box=[530,92,602,229]
#
# 0: 640x288 1 person, 42.9ms
# Speed: 2.6ms preprocess, 42.9ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.31 ID:19  box=[94,496,203,740]
# video 1/1 (frame 23/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 49.1ms
# Frame 22:
#   → chair 0.26 ID:1  box=[840,344,990,718]
#   → chair 0.64 ID:2  box=[395,317,496,483]
#
# 0: 640x224 2 persons, 41.9ms
# Speed: 1.7ms preprocess, 41.9ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[193,340,287,632]
#   → chair 0.55 ID:4  box=[941,218,1011,375]
#   → chair 0.31 ID:7  box=[736,232,814,639]
#   → chair 0.44 ID:8  box=[513,250,678,541]
#
# 0: 640x192 1 person, 42.2ms
# Speed: 3.6ms preprocess, 42.2ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.61 ID:5  box=[423,137,498,387]
#   → chair 0.26 ID:13  box=[794,154,864,270]
#
# 0: 640x352 (no detections), 69.1ms
# Speed: 3.8ms preprocess, 69.1ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.41 ID:15  box=[530,93,602,230]
#
# 0: 640x288 1 person, 44.1ms
# Speed: 9.9ms preprocess, 44.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.38 ID:19  box=[94,496,203,741]
# video 1/1 (frame 24/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 49.5ms
# Frame 23:
#   → chair 0.34 ID:1  box=[836,342,988,718]
#   → chair 0.64 ID:2  box=[395,317,497,484]
#
# 0: 640x224 1 person, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.45 ID:3  box=[194,340,287,629]
#   → chair 0.50 ID:4  box=[941,219,1010,375]
#   → chair 0.35 ID:7  box=[736,231,815,639]
#   → chair 0.48 ID:8  box=[513,251,678,541]
#
# 0: 640x192 1 person, 40.3ms
# Speed: 4.2ms preprocess, 40.3ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.64 ID:5  box=[423,137,498,388]
#   → chair 0.25 ID:13  box=[794,154,864,270]
#
# 0: 640x352 (no detections), 47.2ms
# Speed: 4.6ms preprocess, 47.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.26 ID:15  box=[530,93,602,229]
#
# 0: 640x288 1 person, 49.5ms
# Speed: 3.0ms preprocess, 49.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.35 ID:19  box=[94,496,204,741]
# video 1/1 (frame 25/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 51.1ms
# Frame 24:
#   → chair 0.27 ID:1  box=[838,343,990,718]
#   → chair 0.64 ID:2  box=[396,318,496,482]
#
# 0: 640x224 1 person, 42.8ms
# Speed: 3.9ms preprocess, 42.8ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:3  box=[193,340,288,631]
#   → chair 0.43 ID:4  box=[941,218,1011,374]
#   → chair 0.39 ID:7  box=[737,232,815,638]
#   → chair 0.44 ID:8  box=[512,251,678,541]
#
# 0: 640x192 1 person, 37.3ms
# Speed: 2.6ms preprocess, 37.3ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.60 ID:5  box=[423,137,498,387]
#   → chair 0.27 ID:13  box=[794,154,863,269]
#
# 0: 640x352 (no detections), 44.7ms
# Speed: 3.5ms preprocess, 44.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.32 ID:15  box=[530,93,602,230]
#
# 0: 640x288 1 person, 44.0ms
# Speed: 2.0ms preprocess, 44.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.42 ID:19  box=[94,496,204,742]
# video 1/1 (frame 26/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 48.2ms
# Frame 25:
#   → chair 0.35 ID:1  box=[830,340,983,718]
#   → chair 0.67 ID:2  box=[396,318,496,481]
#
# 0: 640x224 1 person, 33.6ms
# Speed: 3.3ms preprocess, 33.6ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[194,340,288,632]
#   → chair 0.40 ID:4  box=[942,219,1011,374]
#   → chair 0.49 ID:7  box=[736,232,815,638]
#   → chair 0.48 ID:8  box=[511,249,678,541]
#
# 0: 640x192 (no detections), 36.2ms
# Speed: 3.0ms preprocess, 36.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.62 ID:5  box=[423,137,498,388]
#   → chair 0.29 ID:13  box=[793,154,863,269]
#
# 0: 640x352 (no detections), 43.7ms
# Speed: 3.6ms preprocess, 43.7ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.32 ID:15  box=[530,93,602,229]
#
# 0: 640x288 1 person, 41.2ms
# Speed: 2.9ms preprocess, 41.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.42 ID:19  box=[94,496,204,742]
# video 1/1 (frame 27/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 49.0ms
# Frame 26:
#   → chair 0.40 ID:1  box=[827,339,980,718]
#   → chair 0.66 ID:2  box=[396,318,496,482]
#
# 0: 640x224 2 persons, 35.1ms
# Speed: 2.5ms preprocess, 35.1ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:3  box=[194,341,289,633]
#   → chair 0.44 ID:4  box=[942,218,1011,374]
#   → chair 0.44 ID:7  box=[736,232,814,637]
#   → chair 0.51 ID:8  box=[511,249,679,541]
#
# 0: 640x192 1 person, 30.6ms
# Speed: 1.6ms preprocess, 30.6ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.59 ID:5  box=[423,137,498,388]
#   → chair 0.36 ID:13  box=[793,154,863,270]
#
# 0: 640x352 (no detections), 43.7ms
# Speed: 4.4ms preprocess, 43.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.23 ID:15  box=[529,93,601,229]
#
# 0: 640x288 1 person, 42.3ms
# Speed: 3.1ms preprocess, 42.3ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.38 ID:19  box=[94,496,204,741]
# video 1/1 (frame 28/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 50.4ms
# Frame 27:
#   → chair 0.43 ID:1  box=[826,340,978,718]
#   → chair 0.65 ID:2  box=[395,318,497,482]
#
# 0: 640x224 1 person, 29.6ms
# Speed: 2.3ms preprocess, 29.6ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[194,341,288,630]
#   → chair 0.33 ID:4  box=[943,218,1012,373]
#   → chair 0.48 ID:7  box=[736,232,814,637]
#   → chair 0.52 ID:8  box=[511,250,679,542]
#
# 0: 640x192 1 person, 27.9ms
# Speed: 1.8ms preprocess, 27.9ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.60 ID:5  box=[423,137,498,389]
#   → chair 0.35 ID:13  box=[793,154,862,270]
#
# 0: 640x352 (no detections), 40.2ms
# Speed: 1.3ms preprocess, 40.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.14 ID:15  box=[530,93,598,221]
#
# 0: 640x288 1 person, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.42 ID:19  box=[95,496,204,741]
#
# 0: 640x416 (no detections), 49.5ms
# Speed: 2.1ms preprocess, 49.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.40 ID:9  box=[530,151,639,319]
# video 1/1 (frame 29/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 50.7ms
# Frame 28:
#   → chair 0.46 ID:1  box=[827,340,978,718]
#   → chair 0.59 ID:2  box=[394,318,499,488]
#
# 0: 640x224 2 persons, 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:3  box=[194,341,288,630]
#   → chair 0.35 ID:4  box=[943,219,1011,373]
#   → chair 0.45 ID:7  box=[736,232,815,638]
#   → chair 0.40 ID:8  box=[511,251,679,543]
#
# 0: 640x224 1 person, 29.1ms
# Speed: 3.6ms preprocess, 29.1ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:5  box=[423,137,499,388]
#   → chair 0.31 ID:13  box=[793,154,862,270]
#
# 0: 640x352 (no detections), 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.16 ID:15  box=[530,93,596,219]
#
# 0: 640x288 1 person, 44.3ms
# Speed: 3.7ms preprocess, 44.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.44 ID:19  box=[95,496,204,741]
#
# 0: 640x416 1 person, 49.3ms
# Speed: 2.5ms preprocess, 49.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.39 ID:9  box=[530,151,637,318]
# video 1/1 (frame 30/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 48.4ms
# Frame 29:
#   → chair 0.48 ID:1  box=[826,340,978,718]
#   → chair 0.61 ID:2  box=[393,317,499,489]
#
# 0: 640x224 1 person, 30.7ms
# Speed: 2.3ms preprocess, 30.7ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[194,341,288,629]
#   → chair 0.38 ID:4  box=[943,218,1011,373]
#   → chair 0.47 ID:7  box=[736,232,816,639]
#   → chair 0.52 ID:8  box=[511,250,679,543]
#
# 0: 640x192 1 person, 29.8ms
# Speed: 1.9ms preprocess, 29.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.65 ID:5  box=[423,137,498,388]
#   → chair 0.41 ID:13  box=[792,154,862,270]
#
# 0: 640x352 (no detections), 43.8ms
# Speed: 1.8ms preprocess, 43.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.36 ID:15  box=[531,94,601,225]
#
# 0: 640x288 1 person, 41.8ms
# Speed: 1.8ms preprocess, 41.8ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.34 ID:19  box=[95,496,204,741]
# video 1/1 (frame 31/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 5 chairs, 46.6ms
# Frame 30:
#   → chair 0.66 ID:2  box=[394,318,495,482]
#
# 0: 640x224 (no detections), 29.7ms
# Speed: 1.8ms preprocess, 29.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.40 ID:3  box=[194,341,287,628]
#   → chair 0.26 ID:4  box=[942,222,1010,374]
#   → chair 0.12 ID:7  box=[736,235,813,627]
#   → chair 0.30 ID:8  box=[507,250,674,542]
#
# 0: 640x192 1 person, 29.2ms
# Speed: 1.6ms preprocess, 29.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.66 ID:5  box=[423,137,498,387]
#   → chair 0.12 ID:13  box=[805,154,877,269]
#
# 0: 640x352 (no detections), 41.8ms
# Speed: 2.7ms preprocess, 41.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.51 ID:15  box=[531,98,600,226]
#
# 0: 640x288 1 person, 41.5ms
# Speed: 3.3ms preprocess, 41.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.13 ID:19  box=[95,496,204,741]
# video 1/1 (frame 32/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 5 chairs, 50.4ms
# Frame 31:
#   → chair 0.67 ID:2  box=[395,318,494,479]
#
# 0: 640x224 (no detections), 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.49 ID:3  box=[194,342,288,629]
#   → chair 0.31 ID:4  box=[942,222,1009,375]
#   → chair 0.22 ID:7  box=[736,234,814,633]
#   → chair 0.29 ID:8  box=[504,250,669,542]
#
# 0: 640x224 2 persons, 30.3ms
# Speed: 1.6ms preprocess, 30.3ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[423,137,498,386]
#   → chair 0.16 ID:13  box=[808,154,884,270]
#
# 0: 640x352 (no detections), 42.5ms
# Speed: 2.2ms preprocess, 42.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.57 ID:15  box=[531,99,599,225]
#
# 0: 640x288 (no detections), 41.5ms
# Speed: 2.0ms preprocess, 41.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.11 ID:19  box=[94,496,204,742]
# video 1/1 (frame 33/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 5 chairs, 51.8ms
# Frame 32:
#   → chair 0.66 ID:2  box=[395,318,494,478]
#
# 0: 640x224 1 person, 30.8ms
# Speed: 2.7ms preprocess, 30.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.46 ID:3  box=[193,342,288,630]
#   → chair 0.23 ID:4  box=[941,224,1008,375]
#   → chair 0.25 ID:7  box=[736,233,814,636]
#   → chair 0.33 ID:8  box=[503,250,667,541]
#
# 0: 640x224 2 persons, 28.3ms
# Speed: 2.8ms preprocess, 28.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:5  box=[423,138,498,387]
#   → chair 0.20 ID:13  box=[809,154,887,270]
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 3.3ms preprocess, 43.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.57 ID:15  box=[532,97,599,221]
#
# 0: 640x288 1 person, 40.3ms
# Speed: 2.3ms preprocess, 40.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.14 ID:19  box=[95,496,204,741]
# video 1/1 (frame 34/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 48.7ms
# Frame 33:
#   → chair 0.65 ID:2  box=[395,318,494,478]
#
# 0: 640x224 (no detections), 31.1ms
# Speed: 3.8ms preprocess, 31.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.46 ID:3  box=[194,342,288,632]
#   → chair 0.22 ID:4  box=[941,225,1008,375]
#   → chair 0.26 ID:7  box=[737,232,815,638]
#   → chair 0.37 ID:8  box=[504,250,667,541]
#
# 0: 640x224 1 person, 28.5ms
# Speed: 2.1ms preprocess, 28.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:5  box=[423,138,498,386]
#   → chair 0.11 ID:13  box=[808,154,889,271]
#
# 0: 640x352 (no detections), 43.7ms
# Speed: 1.9ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.57 ID:15  box=[531,96,599,220]
#
# 0: 640x320 (no detections), 43.9ms
# Speed: 2.9ms preprocess, 43.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 320)
#   → unknown 0.20 ID:19  box=[94,496,204,740]
#   → chair 0.31 ID:1  box=[825,337,977,718]
# video 1/1 (frame 35/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 49.1ms
# Frame 34:
#   → chair 0.61 ID:2  box=[393,317,496,484]
#
# 0: 640x224 1 person, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.30 ID:3  box=[193,342,288,635]
#   → chair 0.33 ID:4  box=[942,227,1008,375]
#   → chair 0.39 ID:7  box=[738,231,816,639]
#   → chair 0.41 ID:8  box=[505,250,668,542]
#
# 0: 640x224 1 person, 29.9ms
# Speed: 3.1ms preprocess, 29.9ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:5  box=[422,137,498,387]
#   → chair 0.18 ID:13  box=[807,154,890,270]
#
# 0: 640x352 (no detections), 46.2ms
# Speed: 2.9ms preprocess, 46.2ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.47 ID:15  box=[531,94,601,223]
#
# 0: 640x288 1 person, 43.8ms
# Speed: 5.0ms preprocess, 43.8ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.13 ID:19  box=[94,496,203,739]
#   → chair 0.39 ID:1  box=[827,337,979,718]
# video 1/1 (frame 36/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 51.7ms
# Frame 35:
#   → chair 0.63 ID:2  box=[391,317,497,490]
#
# 0: 640x224 1 person, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.32 ID:3  box=[192,342,289,639]
#   → chair 0.29 ID:4  box=[942,227,1008,374]
#   → chair 0.37 ID:7  box=[737,231,815,639]
#   → chair 0.49 ID:8  box=[507,250,669,541]
#
# 0: 640x192 1 person, 29.4ms
# Speed: 2.4ms preprocess, 29.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:5  box=[423,137,498,387]
#   → chair 0.13 ID:13  box=[805,154,891,271]
#
# 0: 640x384 (no detections), 45.0ms
# Speed: 2.9ms preprocess, 45.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.46 ID:15  box=[530,93,601,220]
#
# 0: 640x288 1 person, 44.5ms
# Speed: 1.9ms preprocess, 44.5ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.12 ID:19  box=[94,496,204,742]
#   → chair 0.33 ID:1  box=[828,337,979,718]
# video 1/1 (frame 37/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 52.3ms
# Frame 36:
#   → chair 0.66 ID:2  box=[390,316,498,494]
#
# 0: 640x224 (no detections), 43.3ms
# Speed: 2.3ms preprocess, 43.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.40 ID:3  box=[193,342,289,637]
#   → chair 0.30 ID:4  box=[944,220,1013,374]
#   → chair 0.41 ID:7  box=[737,231,815,639]
#   → chair 0.53 ID:8  box=[508,250,670,540]
#
# 0: 640x192 1 person, 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.67 ID:5  box=[423,137,498,387]
#   → chair 0.24 ID:13  box=[793,154,876,271]
#
# 0: 640x384 (no detections), 48.8ms
# Speed: 2.6ms preprocess, 48.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:15  box=[530,93,601,220]
#
# 0: 640x288 1 person, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.15 ID:19  box=[93,496,203,742]
#   → chair 0.32 ID:1  box=[830,337,980,719]
# video 1/1 (frame 38/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 52.4ms
# Frame 37:
#   → chair 0.67 ID:2  box=[391,316,498,494]
#
# 0: 640x224 1 person, 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.39 ID:3  box=[193,342,288,637]
#   → chair 0.32 ID:4  box=[945,217,1014,373]
#   → chair 0.36 ID:7  box=[737,231,815,639]
#   → chair 0.53 ID:8  box=[508,250,671,540]
#
# 0: 640x192 1 person, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:5  box=[423,137,498,387]
#   → chair 0.32 ID:13  box=[789,154,870,270]
#
# 0: 640x384 (no detections), 54.5ms
# Speed: 1.8ms preprocess, 54.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[530,92,599,216]
#
# 0: 640x288 1 person, 42.4ms
# Speed: 3.0ms preprocess, 42.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.21 ID:19  box=[93,496,203,741]
#   → chair 0.26 ID:1  box=[836,340,985,718]
#
# 0: 640x416 (no detections), 48.9ms
# Speed: 3.4ms preprocess, 48.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.44 ID:9  box=[534,143,645,318]
# video 1/1 (frame 39/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 50.2ms
# Frame 38:
#   → chair 0.69 ID:2  box=[393,316,496,488]
#
# 0: 640x224 (no detections), 31.0ms
# Speed: 1.4ms preprocess, 31.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.45 ID:3  box=[192,342,289,640]
#   → chair 0.34 ID:4  box=[947,216,1015,373]
#   → chair 0.30 ID:7  box=[738,231,817,639]
#   → chair 0.64 ID:8  box=[510,250,674,539]
#
# 0: 640x224 1 person, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[422,137,498,387]
#   → chair 0.19 ID:13  box=[788,154,868,270]
#
# 0: 640x384 (no detections), 47.8ms
# Speed: 5.0ms preprocess, 47.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.44 ID:15  box=[529,93,601,221]
#
# 0: 640x288 1 person, 39.8ms
# Speed: 2.9ms preprocess, 39.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.21 ID:19  box=[94,496,203,741]
#   → chair 0.29 ID:1  box=[839,340,986,718]
#
# 0: 640x416 (no detections), 49.2ms
# Speed: 1.7ms preprocess, 49.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.44 ID:9  box=[535,145,645,319]
# video 1/1 (frame 40/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 51.8ms
# Frame 39:
#   → chair 0.69 ID:2  box=[394,316,495,483]
#
# 0: 640x224 1 person, 30.3ms
# Speed: 3.0ms preprocess, 30.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.40 ID:3  box=[192,341,289,639]
#   → chair 0.33 ID:4  box=[951,215,1017,373]
#   → chair 0.31 ID:7  box=[739,237,816,642]
#   → chair 0.56 ID:8  box=[509,251,673,540]
#
# 0: 640x224 1 person, 33.5ms
# Speed: 4.1ms preprocess, 33.5ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:5  box=[422,137,498,387]
#   → chair 0.24 ID:13  box=[787,154,867,271]
#
# 0: 640x384 (no detections), 47.3ms
# Speed: 4.0ms preprocess, 47.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.53 ID:15  box=[529,94,602,223]
#
# 0: 640x288 1 person, 41.6ms
# Speed: 2.1ms preprocess, 41.6ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.15 ID:19  box=[94,496,203,740]
#
# 0: 640x416 1 person, 48.4ms
# Speed: 2.3ms preprocess, 48.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.22 ID:9  box=[537,157,642,319]
# video 1/1 (frame 41/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 50.2ms
# Frame 40:
#   → chair 0.69 ID:2  box=[395,316,495,480]
#
# 0: 640x224 1 person, 31.1ms
# Speed: 1.8ms preprocess, 31.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.44 ID:3  box=[192,342,288,637]
#   → chair 0.35 ID:4  box=[953,216,1017,373]
#   → chair 0.39 ID:7  box=[738,233,815,639]
#   → chair 0.57 ID:8  box=[509,251,673,539]
#
# 0: 640x224 1 person, 28.6ms
# Speed: 1.3ms preprocess, 28.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[422,137,498,387]
#   → chair 0.42 ID:13  box=[787,154,865,271]
#
# 0: 640x384 (no detections), 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:15  box=[529,93,601,222]
#
# 0: 640x288 1 person, 40.5ms
# Speed: 3.3ms preprocess, 40.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.16 ID:19  box=[94,496,203,739]
#
# 0: 640x416 1 person, 51.4ms
# Speed: 1.6ms preprocess, 51.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.42 ID:9  box=[536,153,642,318]
# video 1/1 (frame 42/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 52.8ms
# Frame 41:
#   → chair 0.71 ID:2  box=[395,317,494,478]
#
# 0: 640x224 1 person, 30.2ms
# Speed: 2.5ms preprocess, 30.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.44 ID:3  box=[192,341,288,638]
#   → chair 0.32 ID:4  box=[953,216,1016,373]
#   → chair 0.41 ID:7  box=[738,231,815,639]
#   → chair 0.46 ID:8  box=[505,250,669,540]
#
# 0: 640x224 1 person, 28.1ms
# Speed: 1.9ms preprocess, 28.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:5  box=[422,137,498,387]
#   → chair 0.48 ID:13  box=[788,154,865,270]
#
# 0: 640x384 (no detections), 43.1ms
# Speed: 3.9ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.39 ID:15  box=[529,94,602,222]
#
# 0: 640x288 1 person, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.20 ID:19  box=[94,496,203,740]
#
# 0: 640x416 1 person, 48.8ms
# Speed: 3.6ms preprocess, 48.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.48 ID:9  box=[536,151,643,317]
# video 1/1 (frame 43/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 48.1ms
# Frame 42:
#   → chair 0.70 ID:2  box=[395,317,493,477]
#
# 0: 640x224 1 person, 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.37 ID:3  box=[192,341,288,637]
#   → chair 0.41 ID:4  box=[951,216,1013,373]
#   → chair 0.43 ID:7  box=[737,231,815,639]
#   → chair 0.45 ID:8  box=[506,250,670,540]
#
# 0: 640x224 1 person, 28.3ms
# Speed: 1.2ms preprocess, 28.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[422,137,498,388]
#   → chair 0.49 ID:13  box=[789,154,865,271]
#
# 0: 640x384 (no detections), 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[529,94,602,222]
#
# 0: 640x288 1 person, 41.0ms
# Speed: 2.0ms preprocess, 41.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.19 ID:19  box=[94,496,203,741]
#
# 0: 640x416 (no detections), 49.9ms
# Speed: 1.7ms preprocess, 49.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.46 ID:9  box=[537,154,642,316]
#   → chair 0.27 ID:1  box=[842,340,988,719]
# video 1/1 (frame 44/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 51.2ms
# Frame 43:
#   → chair 0.68 ID:2  box=[396,317,493,476]
#
# 0: 640x224 1 person, 29.9ms
# Speed: 1.6ms preprocess, 29.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.39 ID:3  box=[192,341,288,638]
#   → chair 0.39 ID:4  box=[951,216,1013,373]
#   → chair 0.42 ID:7  box=[737,231,815,639]
#   → chair 0.40 ID:8  box=[508,251,672,540]
#
# 0: 640x224 (no detections), 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.64 ID:5  box=[422,137,498,388]
#   → chair 0.46 ID:13  box=[789,154,864,270]
#
# 0: 640x384 (no detections), 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.38 ID:15  box=[529,93,603,224]
#
# 0: 640x288 1 person, 40.8ms
# Speed: 1.1ms preprocess, 40.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.13 ID:19  box=[94,496,203,740]
#
# 0: 640x448 (no detections), 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.35 ID:9  box=[537,152,644,316]
#   → chair 0.34 ID:1  box=[845,339,988,718]
# video 1/1 (frame 45/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 48.7ms
# Frame 44:
#   → chair 0.69 ID:2  box=[396,318,493,475]
#
# 0: 640x224 (no detections), 29.2ms
# Speed: 2.2ms preprocess, 29.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.33 ID:3  box=[192,341,288,637]
#   → chair 0.42 ID:4  box=[954,216,1015,373]
#   → chair 0.45 ID:7  box=[737,232,814,638]
#   → chair 0.59 ID:8  box=[509,250,674,540]
#
# 0: 640x224 1 person, 28.9ms
# Speed: 1.4ms preprocess, 28.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:5  box=[422,137,498,388]
#   → chair 0.46 ID:13  box=[790,154,864,270]
#
# 0: 640x384 (no detections), 43.4ms
# Speed: 4.8ms preprocess, 43.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[529,95,603,224]
#
# 0: 640x288 1 person, 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.19 ID:19  box=[94,496,203,740]
#
# 0: 640x416 1 person, 49.8ms
# Speed: 1.8ms preprocess, 49.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.44 ID:9  box=[537,153,643,316]
#   → chair 0.38 ID:1  box=[845,340,987,719]
# video 1/1 (frame 46/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 49.3ms
# Frame 45:
#   → chair 0.62 ID:2  box=[393,318,494,483]
#
# 0: 640x224 1 person, 28.8ms
# Speed: 1.1ms preprocess, 28.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[192,341,288,637]
#   → chair 0.30 ID:4  box=[948,218,1010,375]
#   → chair 0.30 ID:8  box=[510,252,674,540]
#
# 0: 640x192 (no detections), 29.6ms
# Speed: 0.9ms preprocess, 29.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.68 ID:5  box=[423,138,498,388]
#   → chair 0.14 ID:13  box=[790,154,864,270]
#
# 0: 640x384 (no detections), 45.4ms
# Speed: 2.3ms preprocess, 45.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[528,95,600,220]
#
# 0: 640x288 (no detections), 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.15 ID:19  box=[95,496,203,741]
#
# 0: 640x448 (no detections), 50.2ms
# Speed: 2.6ms preprocess, 50.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.39 ID:9  box=[539,168,639,318]
#   → chair 0.30 ID:1  box=[839,335,982,722]
# video 1/1 (frame 47/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 50.0ms
# Frame 46:
#   → chair 0.62 ID:2  box=[390,319,496,493]
#
# 0: 640x224 1 person, 31.3ms
# Speed: 1.3ms preprocess, 31.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[192,341,288,636]
#   → chair 0.35 ID:4  box=[952,218,1012,374]
#   → chair 0.30 ID:8  box=[508,252,671,541]
#
# 0: 640x192 (no detections), 28.9ms
# Speed: 1.1ms preprocess, 28.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.67 ID:5  box=[423,138,498,388]
#   → chair 0.22 ID:13  box=[791,154,864,270]
#
# 0: 640x384 (no detections), 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:15  box=[528,95,599,220]
#
# 0: 640x288 1 person, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.24 ID:19  box=[95,496,203,741]
#
# 0: 640x448 (no detections), 49.5ms
# Speed: 2.2ms preprocess, 49.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.34 ID:9  box=[541,179,634,316]
#   → chair 0.39 ID:1  box=[839,338,980,720]
# video 1/1 (frame 48/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 50.6ms
# Frame 47:
#   → chair 0.59 ID:2  box=[390,319,496,494]
#
# 0: 640x224 2 persons, 29.7ms
# ...
#   → unknown 0.57 ID:5  box=[425,137,523,391]
#   → chair 0.31 ID:1  box=[824,336,976,718]
#   → chair 0.18 ID:84  box=[955,215,1021,372]
#   → chair 0.29 ID:65  box=[550,249,648,610]
#
# 0: 640x384 (no detections), 44.5ms
# Speed: 3.4ms preprocess, 44.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.31 ID:89  box=[533,144,632,314]
#   → chair 0.11 ID:91  box=[655,140,718,438]
# video 1/1 (frame 227/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 6 chairs, 50.0ms
# Frame 226:
#   → chair 0.42 ID:2  box=[394,316,500,505]
#
# 0: 640x256 1 person, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.43 ID:5  box=[423,138,521,391]
#   → chair 0.36 ID:1  box=[824,336,976,718]
#   → chair 0.11 ID:84  box=[958,215,1021,372]
#   → chair 0.23 ID:65  box=[550,250,648,610]
#   → chair 0.11 ID:91  box=[656,146,718,439]
#   → chair 0.39 ID:92  box=[890,339,974,718]
# video 1/1 (frame 228/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 6 chairs, 49.8ms
# Frame 227:
#   → chair 0.47 ID:2  box=[398,315,505,503]
#
# 0: 640x256 1 person, 29.7ms
# Speed: 1.7ms preprocess, 29.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.68 ID:5  box=[422,137,521,392]
#   → chair 0.60 ID:1  box=[823,337,975,718]
#   → chair 0.13 ID:84  box=[959,215,1021,371]
#   → chair 0.26 ID:65  box=[550,249,648,611]
#   → chair 0.20 ID:91  box=[656,142,719,438]
#   → chair 0.21 ID:92  box=[888,340,973,718]
# video 1/1 (frame 229/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 6 chairs, 48.2ms
# Frame 228:
#   → chair 0.48 ID:2  box=[397,315,504,502]
#
# 0: 640x256 1 person, 29.4ms
# Speed: 4.0ms preprocess, 29.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.65 ID:5  box=[422,137,520,392]
#   → chair 0.26 ID:1  box=[823,337,975,719]
#   → chair 0.13 ID:84  box=[960,215,1020,371]
#   → chair 0.24 ID:65  box=[550,249,648,611]
#   → chair 0.19 ID:91  box=[655,137,719,438]
#   → chair 0.42 ID:92  box=[889,340,973,718]
#
# 0: 640x384 (no detections), 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.28 ID:89  box=[533,141,634,313]
# video 1/1 (frame 230/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 51.3ms
# Frame 229:
#   → chair 0.46 ID:2  box=[398,315,506,502]
#
# 0: 640x256 (no detections), 31.5ms
# Speed: 1.4ms preprocess, 31.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.50 ID:5  box=[420,137,518,392]
#   → chair 0.42 ID:1  box=[822,338,975,720]
#   → chair 0.18 ID:84  box=[960,216,1019,371]
#   → chair 0.27 ID:65  box=[550,249,648,611]
#   → chair 0.19 ID:91  box=[656,139,718,436]
#   → chair 0.26 ID:92  box=[890,339,975,723]
#
# 0: 640x384 (no detections), 45.1ms
# Speed: 1.5ms preprocess, 45.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.38 ID:89  box=[533,140,634,313]
#
# 0: 640x288 (no detections), 44.9ms
# Speed: 1.8ms preprocess, 44.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.34 ID:69  box=[195,363,306,632]
# video 1/1 (frame 231/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 6 chairs, 48.5ms
# Frame 230:
#   → chair 0.48 ID:2  box=[400,315,510,503]
#
# 0: 640x256 (no detections), 32.1ms
# Speed: 2.9ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.36 ID:5  box=[422,138,519,391]
#   → chair 0.35 ID:1  box=[827,339,978,720]
#   → chair 0.14 ID:84  box=[961,216,1019,371]
#   → chair 0.28 ID:65  box=[550,248,648,611]
#   → chair 0.11 ID:91  box=[655,126,720,438]
#   → chair 0.26 ID:92  box=[890,339,975,721]
#
# 0: 640x288 (no detections), 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.15 ID:69  box=[197,363,303,624]
# video 1/1 (frame 232/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 51.1ms
# Frame 231:
#   → chair 0.45 ID:2  box=[400,316,512,504]
#
# 0: 640x256 (no detections), 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.41 ID:5  box=[418,138,514,391]
#   → chair 0.18 ID:1  box=[831,335,981,719]
#   → chair 0.13 ID:84  box=[961,217,1017,371]
#   → chair 0.17 ID:65  box=[551,249,648,611]
#   → chair 0.21 ID:92  box=[887,339,972,719]
#
# 0: 640x288 1 person, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.13 ID:69  box=[198,362,302,621]
# video 1/1 (frame 233/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 4 chairs, 47.9ms
# Frame 232:
#   → chair 0.47 ID:2  box=[399,316,511,503]
#
# 0: 640x256 (no detections), 31.9ms
# Speed: 1.6ms preprocess, 31.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.41 ID:5  box=[416,138,510,388]
#   → chair 0.26 ID:1  box=[837,338,985,719]
#   → chair 0.17 ID:84  box=[961,216,1017,371]
#   → chair 0.19 ID:65  box=[551,249,649,611]
# video 1/1 (frame 234/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 47.3ms
# Frame 233:
#   → chair 0.44 ID:2  box=[398,316,512,504]
#
# 0: 640x256 (no detections), 30.4ms
# Speed: 2.4ms preprocess, 30.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.41 ID:5  box=[419,138,512,388]
#   → chair 0.31 ID:1  box=[841,339,986,719]
#   → chair 0.15 ID:84  box=[960,217,1015,372]
#   → chair 0.18 ID:65  box=[551,248,648,611]
#   → chair 0.33 ID:13  box=[792,153,862,270]
#
# 0: 640x288 (no detections), 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.32 ID:69  box=[199,363,301,616]
# video 1/1 (frame 235/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 47.6ms
# Frame 234:
#   → chair 0.45 ID:2  box=[397,316,513,505]
#
# 0: 640x256 (no detections), 33.6ms
# Speed: 2.6ms preprocess, 33.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.11 ID:5  box=[419,138,511,387]
#   → chair 0.29 ID:1  box=[841,339,985,719]
#   → chair 0.12 ID:84  box=[962,217,1016,371]
#   → chair 0.16 ID:65  box=[552,248,649,610]
#   → chair 0.34 ID:13  box=[792,153,862,270]
#
# 0: 640x256 1 person, 32.3ms
# Speed: 3.3ms preprocess, 32.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.61 ID:69  box=[199,363,301,621]
# video 1/1 (frame 236/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 5 chairs, 49.3ms
# Frame 235:
#   → chair 0.44 ID:2  box=[395,317,511,506]
#   → chair 0.39 ID:1  box=[840,339,983,719]
#   → chair 0.22 ID:84  box=[963,216,1016,371]
#   → chair 0.19 ID:65  box=[551,249,648,611]
#   → chair 0.34 ID:13  box=[792,153,862,270]
#
# 0: 640x256 1 person, 29.5ms
# Speed: 1.5ms preprocess, 29.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.66 ID:69  box=[200,363,301,620]
# video 1/1 (frame 237/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 6 chairs, 48.4ms
# Frame 236:
#   → chair 0.44 ID:2  box=[392,317,507,506]
#   → chair 0.51 ID:1  box=[833,338,977,719]
#   → chair 0.22 ID:84  box=[963,215,1016,371]
#   → chair 0.17 ID:65  box=[551,249,648,610]
#   → chair 0.15 ID:13  box=[792,153,862,271]
#
# 0: 640x256 1 person, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.35 ID:69  box=[201,363,299,616]
#   → chair 0.28 ID:7  box=[738,232,818,642]
# video 1/1 (frame 238/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 6 chairs, 48.6ms
# Frame 237:
#   → chair 0.43 ID:2  box=[390,317,503,505]
#   → chair 0.36 ID:1  box=[834,339,977,719]
#   → chair 0.24 ID:84  box=[963,214,1016,371]
#   → chair 0.19 ID:65  box=[550,249,647,610]
#   → chair 0.19 ID:13  box=[792,153,862,270]
#
# 0: 640x256 1 person, 29.4ms
# Speed: 2.3ms preprocess, 29.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.11 ID:69  box=[200,363,298,615]
#   → chair 0.19 ID:7  box=[738,232,818,641]
# video 1/1 (frame 239/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 48.2ms
# Frame 238:
#   → chair 0.44 ID:2  box=[389,317,503,506]
#   → chair 0.30 ID:1  box=[836,339,979,718]
#   → chair 0.19 ID:84  box=[963,214,1015,371]
#   → chair 0.23 ID:65  box=[549,249,646,610]
#   → chair 0.24 ID:13  box=[793,153,862,270]
#
# 0: 640x256 1 person, 29.4ms
# Speed: 1.7ms preprocess, 29.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.23 ID:69  box=[199,363,299,621]
#   → chair 0.24 ID:7  box=[738,231,817,640]
#
# 0: 640x384 (no detections), 45.1ms
# Speed: 4.1ms preprocess, 45.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.55 ID:89  box=[535,142,635,314]
#
# 0: 640x256 1 person, 32.9ms
# Speed: 1.3ms preprocess, 32.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.43 ID:5  box=[418,140,507,385]
# video 1/1 (frame 240/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 48.7ms
# Frame 239:
#   → chair 0.52 ID:2  box=[390,317,501,504]
#   → chair 0.37 ID:1  box=[837,339,981,718]
#   → chair 0.19 ID:84  box=[963,213,1015,371]
#   → chair 0.32 ID:13  box=[793,153,862,269]
#
# 0: 640x256 1 person, 28.5ms
# Speed: 1.6ms preprocess, 28.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.58 ID:69  box=[200,363,300,621]
#   → chair 0.34 ID:7  box=[738,231,817,640]
#
# 0: 640x384 (no detections), 47.5ms
# Speed: 1.4ms preprocess, 47.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.60 ID:89  box=[535,142,635,314]
#
# 0: 640x256 (no detections), 32.2ms
# Speed: 3.8ms preprocess, 32.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.61 ID:5  box=[418,140,506,386]
#   → chair 0.33 ID:8  box=[520,257,675,536]
# video 1/1 (frame 241/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 45.0ms
# Frame 240:
#   → chair 0.56 ID:2  box=[391,318,496,493]
#   → chair 0.64 ID:1  box=[835,338,979,719]
#   → chair 0.33 ID:84  box=[954,216,1007,372]
#   → chair 0.22 ID:13  box=[791,154,860,270]
#
# 0: 640x256 1 person, 29.1ms
# Speed: 1.4ms preprocess, 29.1ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.32 ID:69  box=[200,363,301,625]
#   → chair 0.33 ID:7  box=[739,235,817,639]
#
# 0: 640x384 (no detections), 44.7ms
# Speed: 1.4ms preprocess, 44.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.37 ID:89  box=[535,144,634,314]
#
# 0: 640x256 (no detections), 34.9ms
# Speed: 2.0ms preprocess, 34.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.65 ID:5  box=[422,141,512,391]
#   → chair 0.16 ID:8  box=[512,255,667,541]
#
# 0: 640x288 (no detections), 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.30 ID:19  box=[98,499,202,741]
# video 1/1 (frame 242/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 7 chairs, 50.6ms
# Frame 241:
#   → chair 0.55 ID:2  box=[391,318,496,494]
#   → chair 0.62 ID:1  box=[836,338,979,720]
#   → chair 0.47 ID:84  box=[950,216,1004,372]
#   → chair 0.36 ID:13  box=[790,155,860,271]
#
# 0: 640x256 2 persons, 31.1ms
# Speed: 1.4ms preprocess, 31.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.36 ID:69  box=[202,363,300,620]
#   → chair 0.43 ID:7  box=[740,233,819,640]
#
# 0: 640x384 (no detections), 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.29 ID:89  box=[536,147,633,314]
#
# 0: 640x256 1 person, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.65 ID:5  box=[423,141,514,393]
#   → chair 0.20 ID:8  box=[511,253,665,541]
#
# 0: 640x288 (no detections), 39.0ms
# Speed: 1.2ms preprocess, 39.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.25 ID:19  box=[98,499,202,741]
#   → chair 0.29 ID:65  box=[552,250,648,610]
# video 1/1 (frame 243/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 7 chairs, 50.5ms
# Frame 242:
#   → chair 0.55 ID:2  box=[391,318,495,492]
#   → chair 0.57 ID:1  box=[836,338,979,720]
#   → chair 0.49 ID:84  box=[947,216,1004,373]
#   → chair 0.41 ID:13  box=[790,155,860,271]
#
# 0: 640x256 2 persons, 31.3ms
# Speed: 2.0ms preprocess, 31.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.30 ID:69  box=[202,363,299,614]
#   → chair 0.32 ID:7  box=[739,250,815,641]
#
# 0: 640x384 (no detections), 44.2ms
# Speed: 1.6ms preprocess, 44.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.41 ID:89  box=[541,168,628,313]
#
# 0: 640x256 (no detections), 34.0ms
# Speed: 1.6ms preprocess, 34.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.65 ID:5  box=[423,141,514,393]
#   → chair 0.26 ID:8  box=[511,255,663,539]
#
# 0: 640x288 (no detections), 39.6ms
# Speed: 1.2ms preprocess, 39.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.26 ID:19  box=[97,498,202,741]
#   → chair 0.20 ID:65  box=[551,250,648,609]
# video 1/1 (frame 244/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 7 chairs, 48.6ms
# Frame 243:
#   → chair 0.55 ID:2  box=[392,318,494,489]
#   → chair 0.56 ID:1  box=[836,338,978,720]
#   → chair 0.43 ID:84  box=[947,216,1005,373]
#   → chair 0.37 ID:13  box=[790,155,860,271]
#
# 0: 640x256 2 persons, 31.2ms
# Speed: 1.6ms preprocess, 31.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.26 ID:69  box=[203,362,298,611]
#   → chair 0.26 ID:7  box=[739,241,817,639]
#
# 0: 640x416 (no detections), 50.0ms
# Speed: 1.9ms preprocess, 50.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.39 ID:89  box=[543,176,627,313]
#
# 0: 640x256 (no detections), 32.9ms
# Speed: 3.2ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 256)
#   → unknown 0.62 ID:5  box=[423,142,515,393]
#   → chair 0.21 ID:8  box=[510,255,662,539]
#
# 0: 640x288 (no detections), 39.0ms
# Speed: 1.2ms preprocess, 39.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.24 ID:19  box=[96,497,201,741]
#   → chair 0.17 ID:65  box=[551,250,648,609]
# video 1/1 (frame 245/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 7 chairs, 49.3ms
# Frame 244:
#   → chair 0.52 ID:2  box=[392,318,493,488]
#   → chair 0.62 ID:1  box=[834,338,976,720]
#   → chair 0.51 ID:84  box=[946,216,1005,373]
#   → chair 0.39 ID:13  box=[790,155,860,271]
#
# 0: 640x256 1 person, 30.9ms
# Speed: 1.9ms preprocess, 30.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.36 ID:69  box=[201,362,300,623]
#   → chair 0.37 ID:7  box=[739,237,818,638]
#
# 0: 640x416 (no detections), 49.3ms
# Speed: 2.1ms preprocess, 49.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.39 ID:89  box=[543,180,627,313]
#
# 0: 640x256 1 person, 33.2ms
# Speed: 1.2ms preprocess, 33.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.59 ID:5  box=[423,142,516,396]
#   → chair 0.24 ID:8  box=[511,255,663,539]
#
# 0: 640x288 (no detections), 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.22 ID:19  box=[97,499,201,740]
#   → chair 0.18 ID:65  box=[551,250,648,609]
