# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (8.3.133)
# Requirement already satisfied: opencv-python in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: pillow>=7.1.2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.7.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.22.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\self study\0 - fyp\seatify\myenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import time

# %%
# Load the YOLOv8 model
model = YOLO('yolov8x.pt').to('cuda:0')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs

# %%
# --------Human & Object detection in video - correctly working--------

'''

# Initialize video capture
cap = cv2.VideoCapture(r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4')

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    while cap.isOpened():
        print("Reading frame...")
        ret, frame = cap.read()

        # Perform detection on the current frame
        results = model(frame)  # Detect objects in the frame

        # Filter detections for 'person' and 'chair' classes
        # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

        # Process the results
        for result in results:

            boxes = result.boxes  # Get bounding boxes

            for box in boxes:
                class_id = box.cls[0].item()  # Get the class id of the detected object
                if class_id in person_and_chair:  # Check if it is a person or a chair
                    # Get the bounding box coordinates
                    x1, y1, x2, y2 = map(int, box.xyxy[0])

                    # Get the class ID and confidence score
                    class_id = box.cls[0].item()
                    confidence = box.conf[0].item()

                    # Get the class name
                    label = model.names[class_id]

                    # Print out the detected object details
                    print(
                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                    )
                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                    # Draw a bounding box around the object

                    # Define different colors for different objects
                    if label == "person":
                        color = (255, 0, 0)  # Blue color for human (person)
                    elif label == "chair":
                        color = (0, 0, 255)  # Red color for chair
                    else:
                        color = (0, 255, 0)  # Default green for other objects

                    # Draw a bounding box around the object with the selected color
                    cv2.rectangle(
                        frame, (x1, y1), (x2, y2), color, 2
                    )  # Bounding box with the chosen color

                    cv2.putText(
                        frame,
                        label,
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        (0, 255, 0),
                        2,
                    )

        if frame is not None and frame.size > 0:
            cv2.imshow("Video", frame)
        else:
            print("Warning: Empty frame encountered!")
            break

        # Press 'q' to quit the video window
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\1471836195.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo6.mp4\')\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    while cap.isOpened():\n        print("Reading frame...")\n        ret, frame = cap.read()\n\n        # Perform detection on the current frame\n        results = model(frame)  # Detect objects in the frame\n\n        # Filter detections for \'person\' and \'chair\' classes\n        # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n        # Process the results\n        for result in results:\n\n            boxes = result.boxes  # Get bounding boxes\n\n            for box in boxes:\n                class_id = box.cls[0].item()  # Get the class id of the detected object\n                if class_id in person_and_chair:  # Check if it is a person or a chair\n                    # Get the bounding box coordinates\n                    x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                    # Get the class ID and confidence score\n                    class_id = box.cls[0].item()\n                    confidence = box.conf[0].item()\n\n                    # Get the class name\n                    label = model.names[class_id]\n\n                    # Print out the detected object details\n                    print(\n                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                    )\n                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                    # Draw a bounding box around the object\n\n                    # Define different colors for different objects\n                    if label == "person":\n                        color = (255, 0, 0)  # Blue color for human (person)\n                    elif label == "chair":\n                        color = (0, 0, 255)  # Red color for chair\n                    else:\n                        color = (0, 255, 0)  # Default green for other objects\n\n                    # Draw a bounding box around the object with the selected color\n                    cv2.rectangle(\n                        frame, (x1, y1), (x2, y2), color, 2\n                    )  # Bounding box with the chosen color\n\n                    cv2.putText(\n                        frame,\n                        label,\n                        (x1, y1 - 10),\n                        cv2.FONT_HERSHEY_SIMPLEX,\n                        0.9,\n                        (0, 255, 0),\n                        2,\n                    )\n\n        if frame is not None and frame.size > 0:\n            cv2.imshow("Video", frame)\n        else:\n            print("Warning: Empty frame encountered!")\n            break\n\n        # Press \'q\' to quit the video window\n        if cv2.waitKey(1) & 0xFF == ord("q"):\n            break\n\n    # Release the video capture object and close all windows\n    cap.release()\n    cv2.destroyAllWindows()\n\n'

# %%
# -----Tried to skip frames and process frames after every 10 seconds. Did not worked-----


'''

# Initialize video capture
cap = cv2.VideoCapture(
    r"D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4"
)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    # Get the frame rate (fps) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video Frame Rate (FPS): {fps}")

    # Time between frames we want to process (10 seconds)
    interval = 2  # Process every 10 seconds

    # Calculate the frame number corresponding to the desired times
    frame_number = 0
    prev_time = 0  # Start at time 0

    while cap.isOpened():
        # Calculate the time for the current frame (in seconds)
        current_time = frame_number / fps

        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)
        if current_time >= prev_time:

            print("Reading frame...")
            # Read a frame from the video
            ret, frame = cap.read()

            # Check if the frame was read properly
            if not ret:
                print("Error: Couldn't read the frame.")
                break

            # Perform detection on the current frame
            results = model(frame)  # Detect objects in the frame

            # Filter detections for 'person' and 'chair' classes
            # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

            # Process the results
            for result in results:
                # Extract bounding boxes, confidence, and class IDs
                boxes = result.boxes  # Get bounding boxes

                for box in boxes:
                    class_id = box.cls[0].item()  # Get the class id of the detected object

                    if (class_id in person_and_chair):  # Check if it is a person or a chair
                        # Get the bounding box coordinates
                        x1, y1, x2, y2 = map(int, box.xyxy[0])

                        # Get the class ID and confidence score
                        class_id = box.cls[0].item()
                        confidence = box.conf[0].item()

                        # Get the class name
                        label = model.names[class_id]

                        # Print out the detected object details
                        print(
                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                        )
                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                        # Draw a bounding box around the object

                        # Define different colors for different objects
                        if label == "person":
                            color = (255, 0, 0)  # Blue color for human (person)
                        elif label == "chair":
                            color = (0, 0, 255)  # Red color for chair
                        else:
                            color = (0, 255, 0)  # Default green for other objects

                        # Draw a bounding box around the object with the selected color
                        cv2.rectangle(
                            frame, (x1, y1), (x2, y2), color, 2
                        )  # Bounding box with the chosen color

                        cv2.putText(
                            frame,
                            label,
                            (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.9,
                            (0, 255, 0),
                            2,
                        )

                if frame is not None and frame.size > 0:
                    cv2.imshow("Video", frame)
                else:
                    print("Warning: Empty frame encountered!")
                    break

                # Press 'q' to quit the video window
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break

                # Update prev_time to the next desired frame time (e.g., t = 10s, 20s)
                prev_time += interval  # Move to the next interval (10 seconds)

            # Skip frames until we reach the desired frame time
            frame_number += 1
        
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\3711239310.py:4: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(\n    r"D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4"\n)\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    # Get the frame rate (fps) of the video\n    fps = cap.get(cv2.CAP_PROP_FPS)\n    print(f"Video Frame Rate (FPS): {fps}")\n\n    # Time between frames we want to process (10 seconds)\n    interval = 2  # Process every 10 seconds\n\n    # Calculate the frame number corresponding to the desired times\n    frame_number = 0\n    prev_time = 0  # Start at time 0\n\n    while cap.isOpened():\n        # Calculate the time for the current frame (in seconds)\n        current_time = frame_number / fps\n\n        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)\n        if current_time >= prev_time:\n\n            print("Reading frame...")\n            # Read a frame from the video\n            ret, frame = cap.read()\n\n            # Check if the frame was read properly\n            if not ret:\n                print("Error: Couldn\'t read the frame.")\n                break\n\n            # Perform detection on the current frame\n            results = model(frame)  # Detect objects in the frame\n\n            # Filter detections for \'person\' and \'chair\' classes\n            # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n            # Process the results\n            for result in results:\n                # Extract bounding boxes, confidence, and class IDs\n                boxes = result.boxes  # Get bounding boxes\n\n                for box in boxes:\n                    class_id = box.cls[0].item()  # Get the class id of the detected object\n\n                    if (class_id in person_and_chair):  # Check if it is a person or a chair\n                        # Get the bounding box coordinates\n                        x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                        # Get the class ID and confidence score\n                        class_id = box.cls[0].item()\n                        confidence = box.conf[0].item()\n\n                        # Get the class name\n                        label = model.names[class_id]\n\n                        # Print out the detected object details\n                        print(\n                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                        )\n                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                        # Draw a bounding box around the object\n\n                        # Define different colors for different objects\n                        if label == "person":\n                            color = (255, 0, 0)  # Blue color for human (person)\n                        elif label == "chair":\n                            color = (0, 0, 255)  # Red color for chair\n                        else:\n                            color = (0, 255, 0)  # Default green for other objects\n\n                        # Draw a bounding box around the object with the selected color\n                        cv2.rectangle(\n                            frame, (x1, y1), (x2, y2), color, 2\n                        )  # Bounding box with the chosen color\n\n                        cv2.putText(\n                            frame,\n                            label,\n                            (x1, y1 - 10),\n                            cv2.FONT_HERSHEY_SIMPLEX,\n                            0.9,\n                            (0, 255, 0),\n                            2,\n                        )\n\n                if frame is not None and frame.size > 0:\n                    cv2.imshow("Video", frame)\n                else:\n          ...

# %%
import torch
print("CUDA available? ", torch.cuda.is_available())
print("GPU count:    ", torch.cuda.device_count())
print("Current dev:  ", torch.cuda.current_device())
print("Dev name:     ", torch.cuda.get_device_name(0))
# Out:
# CUDA available?  True
# GPU count:     1
# Current dev:   0
# Dev name:      NVIDIA GeForce GTX 1660 Ti

# %%
# ----- Human & Chair detection and tracking - correctly working -----

'''
# 3. Run detection + ByteTrack on your video
#    – source: your file path
#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)
#    – classes: [0,56] → only person (0) & chair (56)
#    – persist: keep track IDs alive across frames
#    – show: pop up each frame (set False if headless)
#    – save: write out an annotated video to runs/track/exp*
stream = model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4',
    tracker='bytetrack.yaml',
    classes=[0, 56],
    persist=True,
    show=False,    # we’ll show manually
    save=True,    # disable automatic save
    save_dir='my_outputs/',
    stream=True,   # <— Enable streaming!
    device='cuda:0'
)

for frame_idx, res in enumerate(stream):
    print(f"Frame {frame_idx}:")
    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id
    for xyxy, conf, cls_id, track_id in zip(
        res.boxes.xyxy, 
        res.boxes.conf, 
        res.boxes.cls, 
        res.boxes.id
    ):
        x1, y1, x2, y2 = map(int, xyxy.tolist())
        conf = float(conf)
        cls_id = int(cls_id)
        track_id = int(track_id)
        label = res.names[cls_id]  # e.g. "person" or "chair"
        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")

    # Optional: display the annotated frame and quit on 'q'
    frame = res.plot()
    cv2.imshow("Track (press q to quit)", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\1808955419.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n# 3. Run detection + ByteTrack on your video\n#    – source: your file path\n#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)\n#    – classes: [0,56] → only person (0) & chair (56)\n#    – persist: keep track IDs alive across frames\n#    – show: pop up each frame (set False if headless)\n#    – save: write out an annotated video to runs/track/exp*\nstream = model.track(\n    source=r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4\',\n    tracker=\'bytetrack.yaml\',\n    classes=[0, 56],\n    persist=True,\n    show=False,    # we’ll show manually\n    save=True,    # disable automatic save\n    save_dir=\'my_outputs/\',\n    stream=True,   # <— Enable streaming!\n    device=\'cuda:0\'\n)\n\nfor frame_idx, res in enumerate(stream):\n    print(f"Frame {frame_idx}:")\n    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id\n    for xyxy, conf, cls_id, track_id in zip(\n        res.boxes.xyxy, \n        res.boxes.conf, \n        res.boxes.cls, \n        res.boxes.id\n    ):\n        x1, y1, x2, y2 = map(int, xyxy.tolist())\n        conf = float(conf)\n        cls_id = int(cls_id)\n        track_id = int(track_id)\n        label = res.names[cls_id]  # e.g. "person" or "chair"\n        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")\n\n    # Optional: display the annotated frame and quit on \'q\'\n    frame = res.plot()\n    cv2.imshow("Track (press q to quit)", frame)\n    if cv2.waitKey(1) & 0xFF == ord(\'q\'):\n        break\n\ncv2.destroyAllWindows()\n\n'

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load models onto GPU
det_model  = YOLO('yolov8x.pt').to('cuda:0')
pose_model = YOLO('yolov8x-pose.pt').to('cuda:0')

def calculate_angle(a, b, c):
    #Builds vectors ba and bc around joint b.
    ba = a - b
    bc = c - b
    
    #Uses the dot-product formula to get the cosine of angle abc
    cosang = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-6)

    #clip to valid range and convert from radians to degrees
    return np.degrees(np.arccos(np.clip(cosang, -1.0, 1.0)))

# compute knee angle
def kneeAngleCondition(kpts):
    try:
        # compute left & right knee angles
        l_ang = calculate_angle(kpts[11,:2], kpts[13,:2], kpts[15,:2]) #computes left knee angles
        r_ang = calculate_angle(kpts[12,:2], kpts[14,:2], kpts[16,:2]) #computes right knee angles
        # compute average angle
        knee_angle = (l_ang + r_ang) / 2

        # Threshold to decide sitting vs standing
        if knee_angle < 110:
            return True
        else:
            return False
    except:
        pass  

#Compute torso lean: angle at the hip by shoulder→hip→knee
def torsoAngleCondition(kpts):
    try:
        left_torso  = calculate_angle(kpts[5,:2],  kpts[11,:2], kpts[13,:2])  # L-shoulder, L-hip, L-knee
        right_torso = calculate_angle(kpts[6,:2],  kpts[12,:2], kpts[14,:2])  # R-shoulder, R-hip, R-knee
        torso_angle = (left_torso + right_torso) / 2

        # Threshold to decide sitting vs standing
        if torso_angle < 120:
            return True
        else:
            return False

    except:
        pass  

# Start the detection + track stream
stream = det_model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4',
    tracker='bytetrack.yaml',
    classes=[0],
    persist=True,
    show=False,
    save=True,
    save_dir='my_outputs/',
    stream=True,
    device='cuda:0'
)

#process frames
for frame_idx, res in enumerate(stream): #enumerate(stream) gives (frame_idx, res) as soon as each frame is done
    frame = res.orig_img.copy() # copy of raw frame we annotate
    print(f"Frame {frame_idx}:")

    # Pull detections
    # Unpack the tracked detections in parallel arrays
    xyxys     = res.boxes.xyxy.cpu().numpy() # bounding boxes (n×4)
    confs     = res.boxes.conf.cpu().numpy() # confidence scores (n) 
    cls_ids   = res.boxes.cls.cpu().numpy().astype(int) # class IDs (n)
    track_ids = res.boxes.id.cpu().numpy().astype(int) # track IDs (n)

    #Iterate through each detection in this frame
    for (x1, y1, x2, y2), conf, cls_id, track_id in zip(xyxys, confs, cls_ids, track_ids): #Zips the four arrays so you handle each detection in lockstep.
        
        #Converts the box coords to integers
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))

        #looks up the human-readable class name
        label = res.names[cls_id] # e.g. "person" or "chair"

        # Person branch
        if label == 'person':

            # Defaults the posture to “unknown” with a yellow box
            posture, color = 'unknown', (0,255,255)

            # Crops the detected person region and runs pose_model on that ROI
            roi = frame[y1:y2, x1:x2]
            p = pose_model(roi, device='cuda:0')[0]


            # If keypoints were found, extracts the raw (n,17,3) array from p.keypoints.data.
            # In the shape tuple (n, 17, 3), that leading n is simply the number of person instances (i.e. detections) 
            # that the pose model found in your cropped image
            # Since you’re cropping around a single detected box, in most cases n will be 1
            if p.keypoints is not None:
                # Extract the raw (n,17,3) tensor of keypoints
                kpts_np = p.keypoints.data.cpu().numpy()  # shape (n,17,3)

                # Ensure we have at least 17 keypoints
                if kpts_np.ndim == 3 and kpts_np.shape[1] >= 17:
                    kpts = kpts_np[0]  # first person
                    # shape (17,3): [x,y,conf] per joint

                    # Compute the knee angle
                    kneeAngleResult = kneeAngleCondition(kpts)

                    # Compute the torso angle
                    torsoAngleResult = torsoAngleCondition(kpts)
                    
                    if torsoAngleResult or kneeAngleResult:
                        posture, color = 'sitting',  (0,255,0)
                    else:
                        posture, color = 'standing', (0,0,255)
                    
            text = f"{posture} {conf:.2f} ID:{track_id}"

        else:
            # chair
            color = (255,0,0)
            text  = f"chair {conf:.2f} ID:{track_id}"

        # Draw & print
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
        cv2.putText(frame, text, (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        print(f"  → {text}  box=[{x1},{y1},{x2},{y2}]")

    cv2.imshow("Pose+Track", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# video 1/1 (frame 1/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 65.7ms
# Frame 0:
#
# 0: 640x352 2 persons, 49.2ms
# Speed: 2.5ms preprocess, 49.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.85 ID:1  box=[200,145,430,564]
#
# 0: 640x288 1 person, 44.1ms
# Speed: 2.3ms preprocess, 44.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.83 ID:2  box=[452,149,623,532]
#
# 0: 640x576 2 persons, 69.2ms
# Speed: 5.1ms preprocess, 69.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[830,107,971,267]
#
# 0: 640x224 2 persons, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.76 ID:4  box=[100,73,258,535]
#
# 0: 640x224 2 persons, 30.9ms
# Speed: 2.7ms preprocess, 30.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.74 ID:5  box=[0,15,99,320]
#
# 0: 640x448 3 persons, 53.0ms
# Speed: 1.8ms preprocess, 53.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1085,388]
#
# 0: 640x608 (no detections), 75.3ms
# Speed: 5.3ms preprocess, 75.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.59 ID:7  box=[1149,192,1221,268]
#
# 0: 640x416 3 persons, 58.4ms
# Speed: 3.5ms preprocess, 58.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.58 ID:8  box=[926,124,1014,260]
#
# 0: 640x416 1 person, 52.1ms
# Speed: 1.8ms preprocess, 52.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.47 ID:9  box=[1209,177,1295,311]
#
# 0: 640x384 (no detections), 50.8ms
# Speed: 1.7ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.40 ID:10  box=[1235,260,1324,420]
# video 1/1 (frame 2/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 44.4ms
# Frame 1:
#
# 0: 640x352 2 persons, 47.8ms
# Speed: 3.9ms preprocess, 47.8ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.85 ID:1  box=[200,145,429,563]
#
# 0: 640x288 1 person, 48.2ms
# Speed: 2.3ms preprocess, 48.2ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[452,149,623,531]
#
# 0: 640x576 2 persons, 68.3ms
# Speed: 3.6ms preprocess, 68.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[831,107,972,267]
#
# 0: 640x224 2 persons, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.75 ID:4  box=[100,73,258,536]
#
# 0: 640x224 2 persons, 29.4ms
# Speed: 2.2ms preprocess, 29.4ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.73 ID:5  box=[0,14,100,321]
#
# 0: 640x448 2 persons, 55.2ms
# Speed: 3.5ms preprocess, 55.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.67 ID:6  box=[953,192,1085,388]
#
# 0: 640x608 (no detections), 68.7ms
# Speed: 5.4ms preprocess, 68.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.60 ID:7  box=[1149,192,1222,269]
#
# 0: 640x448 2 persons, 55.0ms
# Speed: 1.8ms preprocess, 55.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.58 ID:8  box=[925,124,1014,260]
#
# 0: 640x416 1 person, 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.60 ID:9  box=[1210,177,1296,311]
#
# 0: 640x384 (no detections), 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.41 ID:10  box=[1236,260,1324,419]
# video 1/1 (frame 3/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 43.6ms
# Frame 2:
#
# 0: 640x352 2 persons, 45.6ms
# Speed: 1.9ms preprocess, 45.6ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.85 ID:1  box=[200,145,429,563]
#
# 0: 640x288 1 person, 45.3ms
# Speed: 3.0ms preprocess, 45.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[452,149,623,531]
#
# 0: 640x576 2 persons, 66.4ms
# Speed: 2.7ms preprocess, 66.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[831,107,972,267]
#
# 0: 640x224 2 persons, 33.2ms
# Speed: 1.2ms preprocess, 33.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.74 ID:4  box=[99,74,258,536]
#
# 0: 640x224 1 person, 30.5ms
# Speed: 1.2ms preprocess, 30.5ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.72 ID:5  box=[0,14,101,325]
#
# 0: 640x448 3 persons, 52.8ms
# Speed: 4.2ms preprocess, 52.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.67 ID:6  box=[953,192,1085,388]
#
# 0: 640x608 (no detections), 67.1ms
# Speed: 4.7ms preprocess, 67.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.60 ID:7  box=[1149,192,1221,269]
#
# 0: 640x448 2 persons, 54.2ms
# Speed: 1.8ms preprocess, 54.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.58 ID:8  box=[925,124,1014,260]
#
# 0: 640x416 2 persons, 53.3ms
# Speed: 2.5ms preprocess, 53.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1210,177,1296,310]
#
# 0: 640x384 1 person, 48.5ms
# Speed: 2.1ms preprocess, 48.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.48 ID:10  box=[1234,260,1324,422]
# video 1/1 (frame 4/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 42.8ms
# Frame 3:
#
# 0: 640x352 2 persons, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.85 ID:1  box=[199,145,429,563]
#
# 0: 640x288 1 person, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.83 ID:2  box=[452,149,623,531]
#
# 0: 640x576 2 persons, 63.8ms
# Speed: 3.3ms preprocess, 63.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[831,107,971,267]
#
# 0: 640x224 2 persons, 32.4ms
# Speed: 1.4ms preprocess, 32.4ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.71 ID:4  box=[100,75,257,534]
#
# 0: 640x224 1 person, 30.9ms
# Speed: 1.7ms preprocess, 30.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.72 ID:5  box=[0,13,102,329]
#
# 0: 640x448 3 persons, 51.7ms
# Speed: 1.8ms preprocess, 51.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.67 ID:6  box=[954,192,1085,388]
#
# 0: 640x608 (no detections), 68.3ms
# Speed: 3.6ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.59 ID:7  box=[1149,192,1221,269]
#
# 0: 640x416 1 person, 51.7ms
# Speed: 1.6ms preprocess, 51.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.58 ID:8  box=[926,124,1014,260]
#
# 0: 640x416 2 persons, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.56 ID:9  box=[1210,177,1296,310]
#
# 0: 640x384 1 person, 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.49 ID:10  box=[1234,261,1324,423]
# video 1/1 (frame 5/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 43.7ms
# Frame 4:
#
# 0: 640x352 2 persons, 42.1ms
# Speed: 1.6ms preprocess, 42.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.85 ID:1  box=[199,145,429,563]
#
# 0: 640x288 1 person, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.83 ID:2  box=[452,149,623,532]
#
# 0: 640x576 2 persons, 64.0ms
# Speed: 2.8ms preprocess, 64.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[830,107,971,267]
#
# 0: 640x224 2 persons, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:4  box=[99,75,256,533]
#
# 0: 640x224 1 person, 28.4ms
# Speed: 1.4ms preprocess, 28.4ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.73 ID:5  box=[0,13,102,333]
#
# 0: 640x448 3 persons, 54.8ms
# Speed: 1.6ms preprocess, 54.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1085,388]
#
# 0: 640x608 (no detections), 66.3ms
# Speed: 3.1ms preprocess, 66.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.57 ID:7  box=[1149,192,1222,269]
#
# 0: 640x416 2 persons, 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.62 ID:8  box=[926,124,1014,260]
#
# 0: 640x416 2 persons, 49.8ms
# Speed: 1.4ms preprocess, 49.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.55 ID:9  box=[1210,177,1296,310]
#
# 0: 640x384 1 person, 47.5ms
# Speed: 2.2ms preprocess, 47.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.52 ID:10  box=[1234,261,1324,424]
# video 1/1 (frame 6/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 43.2ms
# Frame 5:
#
# 0: 640x352 2 persons, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[200,145,430,564]
#
# 0: 640x288 1 person, 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.83 ID:2  box=[452,149,623,531]
#
# 0: 640x576 2 persons, 64.8ms
# Speed: 2.9ms preprocess, 64.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[830,107,971,267]
#
# 0: 640x224 2 persons, 34.1ms
# Speed: 1.1ms preprocess, 34.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.70 ID:4  box=[98,75,256,533]
#
# 0: 640x192 1 person, 27.9ms
# Speed: 0.9ms preprocess, 27.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.52 ID:5  box=[0,14,108,375]
#
# 0: 640x448 3 persons, 51.9ms
# Speed: 1.6ms preprocess, 51.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 (no detections), 68.5ms
# Speed: 2.6ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.57 ID:7  box=[1149,193,1222,269]
#
# 0: 640x448 1 person, 52.9ms
# Speed: 1.7ms preprocess, 52.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.61 ID:8  box=[926,124,1015,260]
#
# 0: 640x416 2 persons, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.55 ID:9  box=[1210,177,1296,310]
#
# 0: 640x384 (no detections), 47.5ms
# Speed: 1.2ms preprocess, 47.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.52 ID:10  box=[1234,260,1324,423]
# video 1/1 (frame 7/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 43.0ms
# Frame 6:
#
# 0: 640x352 2 persons, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,144,429,564]
#
# 0: 640x288 1 person, 43.1ms
# Speed: 2.7ms preprocess, 43.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,531]
#
# 0: 640x576 2 persons, 64.1ms
# Speed: 2.3ms preprocess, 64.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[831,107,971,267]
#
# 0: 640x224 2 persons, 31.0ms
# Speed: 1.2ms preprocess, 31.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:4  box=[99,75,255,530]
#
# 0: 640x192 1 person, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.55 ID:5  box=[0,14,110,392]
#
# 0: 640x448 3 persons, 51.4ms
# Speed: 1.5ms preprocess, 51.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.67 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 (no detections), 68.6ms
# Speed: 2.8ms preprocess, 68.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.57 ID:7  box=[1149,193,1222,269]
#
# 0: 640x448 2 persons, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.63 ID:8  box=[925,124,1014,260]
#
# 0: 640x416 2 persons, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.58 ID:9  box=[1210,177,1296,310]
#
# 0: 640x384 (no detections), 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.48 ID:10  box=[1234,260,1324,423]
# video 1/1 (frame 8/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 44.9ms
# Frame 7:
#
# 0: 640x352 2 persons, 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,144,429,564]
#
# 0: 640x288 1 person, 39.4ms
# Speed: 1.4ms preprocess, 39.4ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.83 ID:2  box=[451,149,623,532]
#
# 0: 640x576 2 persons, 65.0ms
# Speed: 2.4ms preprocess, 65.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[828,106,969,267]
#
# 0: 640x224 2 persons, 32.4ms
# Speed: 1.0ms preprocess, 32.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.61 ID:4  box=[98,75,255,531]
#
# 0: 640x192 1 person, 28.0ms
# Speed: 0.9ms preprocess, 28.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.61 ID:5  box=[0,14,111,402]
#
# 0: 640x448 2 persons, 55.0ms
# Speed: 3.1ms preprocess, 55.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.67 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 (no detections), 68.9ms
# Speed: 3.2ms preprocess, 68.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.58 ID:7  box=[1149,193,1222,269]
#
# 0: 640x416 1 person, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.61 ID:8  box=[925,123,1014,260]
#
# 0: 640x416 1 person, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1210,177,1295,309]
#
# 0: 640x384 (no detections), 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.54 ID:10  box=[1234,260,1324,423]
# video 1/1 (frame 9/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 45.5ms
# Frame 8:
#
# 0: 640x352 2 persons, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,143,430,564]
#
# 0: 640x288 1 person, 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,622,532]
#
# 0: 640x576 2 persons, 63.5ms
# Speed: 2.4ms preprocess, 63.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[827,106,968,267]
#
# 0: 640x224 2 persons, 32.3ms
# Speed: 1.0ms preprocess, 32.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:4  box=[97,76,255,534]
#
# 0: 640x192 1 person, 27.3ms
# Speed: 1.4ms preprocess, 27.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.65 ID:5  box=[0,14,110,403]
#
# 0: 640x448 2 persons, 54.1ms
# Speed: 1.7ms preprocess, 54.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.64 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 (no detections), 68.7ms
# Speed: 3.2ms preprocess, 68.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.58 ID:7  box=[1149,193,1222,269]
#
# 0: 640x416 1 person, 52.5ms
# Speed: 1.3ms preprocess, 52.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.58 ID:8  box=[925,123,1014,260]
#
# 0: 640x416 1 person, 49.8ms
# Speed: 1.2ms preprocess, 49.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1210,177,1295,309]
#
# 0: 640x384 1 person, 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.53 ID:10  box=[1234,260,1324,423]
# video 1/1 (frame 10/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 45.6ms
# Frame 9:
#
# 0: 640x352 2 persons, 44.2ms
# Speed: 2.1ms preprocess, 44.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,143,430,565]
#
# 0: 640x288 1 person, 39.5ms
# Speed: 1.1ms preprocess, 39.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,622,532]
#
# 0: 640x576 2 persons, 65.4ms
# Speed: 3.3ms preprocess, 65.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[826,106,967,267]
#
# 0: 640x224 2 persons, 30.8ms
# Speed: 1.1ms preprocess, 30.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:4  box=[96,76,254,536]
#
# 0: 640x192 1 person, 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.79 ID:5  box=[0,14,109,404]
#
# 0: 640x448 3 persons, 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 1 person, 68.5ms
# Speed: 2.7ms preprocess, 68.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.59 ID:7  box=[1149,193,1222,269]
#
# 0: 640x416 2 persons, 51.9ms
# Speed: 1.4ms preprocess, 51.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.59 ID:8  box=[925,124,1013,260]
#
# 0: 640x416 1 person, 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.58 ID:9  box=[1210,177,1295,309]
#
# 0: 640x352 1 person, 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 25.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.46 ID:10  box=[1235,260,1324,422]
# video 1/1 (frame 11/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 52.2ms
# Frame 10:
#
# 0: 640x352 2 persons, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,143,430,564]
#
# 0: 640x288 1 person, 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,622,532]
#
# 0: 640x576 2 persons, 63.6ms
# Speed: 2.7ms preprocess, 63.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[826,106,967,266]
#
# 0: 640x224 2 persons, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:4  box=[96,76,253,531]
#
# 0: 640x192 1 person, 27.8ms
# Speed: 1.1ms preprocess, 27.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.73 ID:5  box=[0,14,109,403]
#
# 0: 640x448 4 persons, 51.5ms
# Speed: 2.3ms preprocess, 51.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 1 person, 68.3ms
# Speed: 3.0ms preprocess, 68.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.59 ID:7  box=[1149,193,1222,269]
#
# 0: 640x448 3 persons, 51.9ms
# Speed: 1.6ms preprocess, 51.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.60 ID:8  box=[925,124,1013,259]
#
# 0: 640x416 1 person, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.58 ID:9  box=[1210,177,1295,309]
#
# 0: 640x352 1 person, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.44 ID:10  box=[1235,260,1324,422]
# video 1/1 (frame 12/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 10 persons, 42.6ms
# Frame 11:
#
# 0: 640x352 2 persons, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[199,144,429,564]
#
# 0: 640x288 1 person, 40.6ms
# Speed: 1.2ms preprocess, 40.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,622,531]
#
# 0: 640x576 3 persons, 64.5ms
# Speed: 2.3ms preprocess, 64.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[825,106,967,266]
#
# 0: 640x224 2 persons, 33.1ms
# Speed: 1.1ms preprocess, 33.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:4  box=[95,76,253,531]
#
# 0: 640x192 1 person, 27.4ms
# Speed: 0.9ms preprocess, 27.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.43 ID:5  box=[0,15,109,409]
#
# 0: 640x448 4 persons, 54.7ms
# Speed: 1.9ms preprocess, 54.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 (no detections), 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.59 ID:7  box=[1149,193,1222,269]
#
# 0: 640x416 3 persons, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.63 ID:8  box=[925,124,1013,260]
#
# 0: 640x416 1 person, 49.2ms
# Speed: 1.3ms preprocess, 49.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1210,177,1295,309]
#
# 0: 640x384 (no detections), 46.5ms
# Speed: 1.1ms preprocess, 46.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:10  box=[1235,260,1324,421]
# video 1/1 (frame 13/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 45.0ms
# Frame 12:
#
# 0: 640x352 2 persons, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[200,145,429,564]
#
# 0: 640x288 1 person, 39.5ms
# Speed: 1.1ms preprocess, 39.5ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,531]
#
# 0: 640x576 2 persons, 63.9ms
# Speed: 2.4ms preprocess, 63.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[825,106,967,266]
#
# 0: 640x224 2 persons, 30.0ms
# Speed: 1.2ms preprocess, 30.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:4  box=[96,77,254,534]
#
# 0: 640x192 1 person, 27.4ms
# Speed: 1.3ms preprocess, 27.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.36 ID:5  box=[0,15,111,415]
#
# 0: 640x448 2 persons, 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1085,388]
#
# 0: 640x640 1 person, 67.9ms
# Speed: 2.9ms preprocess, 67.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.59 ID:7  box=[1149,193,1222,269]
#
# 0: 640x416 2 persons, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.62 ID:8  box=[925,124,1013,260]
#
# 0: 640x416 1 person, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.59 ID:9  box=[1210,177,1295,309]
#
# 0: 640x384 (no detections), 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:10  box=[1236,260,1324,418]
#
# 0: 640x192 1 person, 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.45 ID:13  box=[0,14,135,540]
# video 1/1 (frame 14/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 43.2ms
# Frame 13:
#
# 0: 640x352 2 persons, 47.3ms
# Speed: 3.3ms preprocess, 47.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[200,145,429,564]
#
# 0: 640x288 1 person, 40.5ms
# Speed: 1.7ms preprocess, 40.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,531]
#
# 0: 640x576 3 persons, 64.5ms
# Speed: 2.9ms preprocess, 64.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[824,106,967,267]
#
# 0: 640x224 2 persons, 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:4  box=[95,77,254,536]
#
# 0: 640x192 1 person, 31.0ms
# Speed: 1.7ms preprocess, 31.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.40 ID:5  box=[0,16,110,417]
#
# 0: 640x448 1 person, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.63 ID:6  box=[953,192,1085,388]
#
# 0: 640x608 (no detections), 66.1ms
# Speed: 2.4ms preprocess, 66.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.57 ID:7  box=[1150,193,1222,269]
#
# 0: 640x416 2 persons, 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.61 ID:8  box=[925,124,1012,259]
#
# 0: 640x416 1 person, 49.0ms
# Speed: 1.8ms preprocess, 49.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.54 ID:9  box=[1210,177,1295,308]
#
# 0: 640x384 (no detections), 47.7ms
# Speed: 1.4ms preprocess, 47.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.50 ID:10  box=[1235,260,1324,421]
#
# 0: 640x192 1 person, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.41 ID:13  box=[0,15,133,538]
# video 1/1 (frame 15/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 43.9ms
# Frame 14:
#
# 0: 640x352 2 persons, 46.9ms
# Speed: 3.1ms preprocess, 46.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[200,145,429,564]
#
# 0: 640x288 1 person, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,532]
#
# 0: 640x576 2 persons, 64.7ms
# Speed: 3.1ms preprocess, 64.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[824,106,967,266]
#
# 0: 640x224 2 persons, 30.3ms
# Speed: 0.9ms preprocess, 30.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.50 ID:4  box=[96,77,254,533]
#
# 0: 640x192 1 person, 29.5ms
# Speed: 1.6ms preprocess, 29.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.46 ID:5  box=[0,25,108,418]
#
# 0: 640x448 2 persons, 53.7ms
# Speed: 1.5ms preprocess, 53.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.63 ID:6  box=[953,192,1085,388]
#
# 0: 640x608 1 person, 65.0ms
# Speed: 2.5ms preprocess, 65.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 608)
#   → sitting 0.58 ID:7  box=[1150,193,1222,269]
#
# 0: 640x416 3 persons, 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.63 ID:8  box=[925,124,1013,260]
#
# 0: 640x416 1 person, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.51 ID:9  box=[1210,177,1295,308]
#
# 0: 640x384 (no detections), 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.53 ID:10  box=[1234,260,1324,422]
#
# 0: 640x192 1 person, 30.3ms
# Speed: 1.4ms preprocess, 30.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.29 ID:13  box=[1,24,135,542]
# video 1/1 (frame 16/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 42.2ms
# Frame 15:
#
# 0: 640x352 2 persons, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[200,143,430,563]
#
# 0: 640x288 1 person, 40.6ms
# Speed: 1.2ms preprocess, 40.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.83 ID:2  box=[451,149,623,532]
#
# 0: 640x576 3 persons, 64.4ms
# Speed: 2.7ms preprocess, 64.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[823,106,967,267]
#
# 0: 640x224 2 persons, 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.38 ID:4  box=[100,77,253,519]
#
# 0: 640x192 1 person, 28.3ms
# Speed: 1.1ms preprocess, 28.3ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.47 ID:5  box=[0,30,107,411]
#
# 0: 640x448 2 persons, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.68 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.6ms
# Speed: 2.6ms preprocess, 67.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.55 ID:7  box=[1149,193,1222,269]
#
# 0: 640x416 2 persons, 51.2ms
# Speed: 1.7ms preprocess, 51.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.70 ID:8  box=[925,124,1013,260]
#
# 0: 640x416 2 persons, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.56 ID:9  box=[1210,177,1294,307]
#
# 0: 640x384 1 person, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.62 ID:10  box=[1233,260,1325,426]
#
# 0: 640x192 1 person, 28.1ms
# Speed: 0.9ms preprocess, 28.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.26 ID:13  box=[4,28,137,542]
#
# 0: 640x448 1 person, 50.0ms
# Speed: 2.7ms preprocess, 50.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.36 ID:15  box=[108,77,255,290]
# video 1/1 (frame 17/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 42.3ms
# Frame 16:
#
# 0: 640x352 2 persons, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[200,143,430,563]
#
# 0: 640x288 1 person, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,532]
#
# 0: 640x576 2 persons, 64.2ms
# Speed: 2.5ms preprocess, 64.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.81 ID:3  box=[823,106,967,267]
#
# 0: 640x224 2 persons, 33.1ms
# Speed: 1.0ms preprocess, 33.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.39 ID:4  box=[100,77,253,518]
#
# 0: 640x192 1 person, 28.4ms
# Speed: 1.1ms preprocess, 28.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.44 ID:5  box=[0,34,107,413]
#
# 0: 640x448 2 persons, 51.7ms
# Speed: 1.9ms preprocess, 51.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.69 ID:6  box=[954,192,1086,388]
#
# 0: 640x640 1 person, 67.3ms
# Speed: 2.7ms preprocess, 67.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.55 ID:7  box=[1148,192,1222,269]
#
# 0: 640x416 3 persons, 52.5ms
# Speed: 1.3ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.70 ID:8  box=[925,124,1013,260]
#
# 0: 640x416 2 persons, 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1210,177,1294,307]
#
# 0: 640x384 1 person, 47.5ms
# Speed: 1.2ms preprocess, 47.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.61 ID:10  box=[1233,260,1325,425]
#
# 0: 640x192 1 person, 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.30 ID:13  box=[4,30,135,536]
#
# 0: 640x448 1 person, 50.9ms
# Speed: 1.6ms preprocess, 50.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.35 ID:15  box=[107,77,255,291]
# video 1/1 (frame 18/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 43.0ms
# Frame 17:
#
# 0: 640x352 2 persons, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[200,143,429,562]
#
# 0: 640x288 1 person, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,532]
#
# 0: 640x576 3 persons, 65.9ms
# Speed: 2.6ms preprocess, 65.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.79 ID:3  box=[823,106,967,267]
#
# 0: 640x224 2 persons, 31.6ms
# Speed: 1.3ms preprocess, 31.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.32 ID:4  box=[102,77,253,514]
#
# 0: 640x192 1 person, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.44 ID:5  box=[0,38,107,417]
#
# 0: 640x448 1 person, 50.0ms
# Speed: 1.4ms preprocess, 50.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[954,192,1086,388]
#
# 0: 640x640 1 person, 67.7ms
# Speed: 2.8ms preprocess, 67.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.56 ID:7  box=[1148,192,1222,269]
#
# 0: 640x416 3 persons, 52.3ms
# Speed: 1.3ms preprocess, 52.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.68 ID:8  box=[925,124,1013,261]
#
# 0: 640x416 2 persons, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1210,177,1294,307]
#
# 0: 640x384 1 person, 47.2ms
# Speed: 1.2ms preprocess, 47.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.60 ID:10  box=[1233,260,1324,424]
#
# 0: 640x192 1 person, 30.9ms
# Speed: 0.9ms preprocess, 30.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.31 ID:13  box=[3,31,134,533]
#
# 0: 640x448 1 person, 50.9ms
# Speed: 1.4ms preprocess, 50.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.45 ID:15  box=[107,77,255,291]
# video 1/1 (frame 19/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 45.2ms
# Frame 18:
#
# 0: 640x352 2 persons, 47.2ms
# Speed: 2.9ms preprocess, 47.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,143,429,562]
#
# 0: 640x288 1 person, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,532]
#
# 0: 640x576 3 persons, 64.2ms
# Speed: 3.3ms preprocess, 64.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.79 ID:3  box=[824,106,968,267]
#
# 0: 640x224 2 persons, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.39 ID:4  box=[101,77,253,517]
#
# 0: 640x192 1 person, 30.5ms
# Speed: 0.9ms preprocess, 30.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.43 ID:5  box=[0,40,109,420]
#
# 0: 640x448 3 persons, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.4ms
# Speed: 2.6ms preprocess, 67.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.55 ID:7  box=[1148,192,1222,269]
#
# 0: 640x416 2 persons, 51.5ms
# Speed: 1.3ms preprocess, 51.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.69 ID:8  box=[925,124,1014,261]
#
# 0: 640x416 2 persons, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.60 ID:9  box=[1210,177,1294,307]
#
# 0: 640x384 1 person, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.66 ID:10  box=[1233,260,1325,427]
#
# 0: 640x192 1 person, 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.38 ID:13  box=[3,34,134,536]
#
# 0: 640x448 1 person, 50.6ms
# Speed: 1.9ms preprocess, 50.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.37 ID:15  box=[108,77,255,291]
# video 1/1 (frame 20/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 45.4ms
# Frame 19:
#
# 0: 640x352 2 persons, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[199,143,429,562]
#
# 0: 640x288 1 person, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,149,623,532]
#
# 0: 640x576 2 persons, 64.1ms
# Speed: 2.5ms preprocess, 64.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[824,106,968,268]
#
# 0: 640x224 2 persons, 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.42 ID:4  box=[100,77,253,521]
#
# 0: 640x192 1 person, 31.0ms
# Speed: 1.8ms preprocess, 31.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.42 ID:5  box=[0,38,109,420]
#
# 0: 640x448 2 persons, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.6ms
# Speed: 2.6ms preprocess, 67.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.55 ID:7  box=[1148,192,1222,269]
#
# 0: 640x416 2 persons, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.69 ID:8  box=[925,124,1014,261]
#
# 0: 640x416 2 persons, 49.4ms
# Speed: 1.2ms preprocess, 49.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.59 ID:9  box=[1209,177,1294,308]
#
# 0: 640x384 1 person, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.67 ID:10  box=[1232,260,1325,428]
#
# 0: 640x192 1 person, 30.6ms
# Speed: 0.9ms preprocess, 30.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.38 ID:13  box=[2,32,134,535]
#
# 0: 640x448 1 person, 49.7ms
# Speed: 1.4ms preprocess, 49.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.36 ID:15  box=[108,77,255,290]
# video 1/1 (frame 21/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 45.5ms
# Frame 20:
#
# 0: 640x352 2 persons, 43.2ms
# Speed: 2.0ms preprocess, 43.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[199,144,429,562]
#
# 0: 640x288 1 person, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,150,622,531]
#
# 0: 640x576 2 persons, 63.6ms
# Speed: 2.5ms preprocess, 63.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[824,106,968,268]
#
# 0: 640x224 2 persons, 32.2ms
# Speed: 1.1ms preprocess, 32.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.52 ID:4  box=[98,78,253,527]
#
# 0: 640x192 1 person, 27.6ms
# Speed: 0.9ms preprocess, 27.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.64 ID:5  box=[5,61,111,424]
#
# 0: 640x448 3 persons, 55.4ms
# Speed: 3.2ms preprocess, 55.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.6ms
# Speed: 2.6ms preprocess, 67.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.55 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 3 persons, 52.0ms
# Speed: 1.7ms preprocess, 52.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.69 ID:8  box=[924,124,1014,261]
#
# 0: 640x416 2 persons, 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.60 ID:9  box=[1209,177,1294,308]
#
# 0: 640x384 (no detections), 46.5ms
# Speed: 1.3ms preprocess, 46.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.68 ID:10  box=[1232,260,1325,428]
#
# 0: 640x192 1 person, 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.23 ID:13  box=[3,59,129,539]
#
# 0: 640x448 1 person, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.30 ID:15  box=[108,78,256,293]
# video 1/1 (frame 22/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 46.5ms
# Frame 21:
#
# 0: 640x352 2 persons, 47.5ms
# Speed: 2.3ms preprocess, 47.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,144,429,562]
#
# 0: 640x288 1 person, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.82 ID:2  box=[451,150,622,530]
#
# 0: 640x576 2 persons, 65.1ms
# Speed: 2.4ms preprocess, 65.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.79 ID:3  box=[824,106,967,267]
#
# 0: 640x224 2 persons, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.46 ID:4  box=[99,78,254,528]
#
# 0: 640x192 1 person, 27.7ms
# Speed: 1.1ms preprocess, 27.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.51 ID:5  box=[7,73,111,422]
#
# 0: 640x448 3 persons, 51.6ms
# Speed: 2.7ms preprocess, 51.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.5ms
# Speed: 3.5ms preprocess, 67.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.54 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 2 persons, 52.4ms
# Speed: 1.3ms preprocess, 52.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.70 ID:8  box=[924,124,1014,261]
#
# 0: 640x416 2 persons, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.60 ID:9  box=[1209,177,1294,308]
#
# 0: 640x352 1 person, 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.67 ID:10  box=[1232,260,1325,429]
#
# 0: 640x192 1 person, 28.8ms
# Speed: 1.0ms preprocess, 28.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.37 ID:13  box=[4,72,128,538]
#
# 0: 640x448 1 person, 50.9ms
# Speed: 2.1ms preprocess, 50.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.33 ID:15  box=[108,78,256,293]
# video 1/1 (frame 23/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 46.5ms
# Frame 22:
#
# 0: 640x352 2 persons, 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[200,143,429,563]
#
# 0: 640x320 1 person, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.83 ID:2  box=[450,150,621,528]
#
# 0: 640x576 2 persons, 64.1ms
# Speed: 2.5ms preprocess, 64.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.79 ID:3  box=[824,106,967,267]
#
# 0: 640x224 2 persons, 33.1ms
# Speed: 1.2ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.47 ID:4  box=[98,78,254,529]
#
# 0: 640x224 1 person, 28.0ms
# Speed: 1.4ms preprocess, 28.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:5  box=[8,78,114,427]
#
# 0: 640x448 3 persons, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.8ms
# Speed: 2.6ms preprocess, 67.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.55 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 3 persons, 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.69 ID:8  box=[924,124,1014,261]
#
# 0: 640x416 2 persons, 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1210,177,1294,307]
#
# 0: 640x352 1 person, 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.67 ID:10  box=[1232,260,1325,429]
#
# 0: 640x192 1 person, 28.4ms
# Speed: 0.8ms preprocess, 28.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.33 ID:13  box=[4,77,128,541]
#
# 0: 640x448 1 person, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.34 ID:15  box=[109,78,255,291]
# video 1/1 (frame 24/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 12 persons, 45.9ms
# Frame 23:
#
# 0: 640x352 2 persons, 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[200,144,429,563]
#
# 0: 640x320 2 persons, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.83 ID:2  box=[450,150,621,528]
#
# 0: 640x576 2 persons, 63.1ms
# Speed: 3.1ms preprocess, 63.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.79 ID:3  box=[823,106,967,267]
#
# 0: 640x224 2 persons, 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.48 ID:4  box=[97,78,254,532]
#
# 0: 640x224 1 person, 27.4ms
# Speed: 1.8ms preprocess, 27.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:5  box=[5,81,104,406]
#
# 0: 640x448 3 persons, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 66.7ms
# Speed: 3.0ms preprocess, 66.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.54 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 2 persons, 52.3ms
# Speed: 1.4ms preprocess, 52.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.70 ID:8  box=[924,124,1014,261]
#
# 0: 640x416 2 persons, 51.8ms
# Speed: 1.2ms preprocess, 51.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.59 ID:9  box=[1210,177,1294,307]
#
# 0: 640x352 1 person, 43.5ms
# ...
# Speed: 1.4ms preprocess, 44.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.83 ID:2  box=[450,150,622,530]
#
# 0: 640x576 2 persons, 64.1ms
# Speed: 2.5ms preprocess, 64.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.78 ID:3  box=[826,106,968,267]
#
# 0: 640x224 2 persons, 31.5ms
# Speed: 1.2ms preprocess, 31.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.43 ID:4  box=[94,79,253,535]
#
# 0: 640x224 1 person, 27.7ms
# Speed: 1.2ms preprocess, 27.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.78 ID:5  box=[5,82,115,435]
#
# 0: 640x448 2 persons, 53.5ms
# Speed: 1.6ms preprocess, 53.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 68.1ms
# Speed: 3.4ms preprocess, 68.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.54 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 3 persons, 52.4ms
# Speed: 1.9ms preprocess, 52.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.68 ID:8  box=[923,124,1014,261]
#
# 0: 640x416 2 persons, 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.52 ID:9  box=[1210,177,1293,305]
#
# 0: 640x352 1 person, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.65 ID:10  box=[1233,260,1325,428]
#
# 0: 640x448 1 person, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.40 ID:15  box=[110,79,254,289]
# video 1/1 (frame 27/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 45.1ms
# Frame 26:
#
# 0: 640x352 2 persons, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[200,144,429,562]
#
# 0: 640x320 1 person, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.83 ID:2  box=[450,150,622,530]
#
# 0: 640x576 2 persons, 63.8ms
# Speed: 2.6ms preprocess, 63.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.79 ID:3  box=[825,106,967,267]
#
# 0: 640x224 2 persons, 32.9ms
# Speed: 1.3ms preprocess, 32.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:4  box=[94,78,254,537]
#
# 0: 640x224 1 person, 28.0ms
# Speed: 1.6ms preprocess, 28.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:5  box=[16,82,126,419]
#
# 0: 640x448 2 persons, 54.7ms
# Speed: 2.4ms preprocess, 54.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 68.2ms
# Speed: 3.0ms preprocess, 68.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.54 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 3 persons, 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.68 ID:8  box=[923,124,1014,261]
#
# 0: 640x416 2 persons, 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.55 ID:9  box=[1210,177,1293,306]
#
# 0: 640x384 1 person, 46.5ms
# Speed: 1.2ms preprocess, 46.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.65 ID:10  box=[1233,260,1325,427]
#
# 0: 640x448 1 person, 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.27 ID:15  box=[111,79,254,288]
# video 1/1 (frame 28/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 43.1ms
# Frame 27:
#
# 0: 640x352 2 persons, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,144,429,564]
#
# 0: 640x320 1 person, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.84 ID:2  box=[450,149,623,532]
#
# 0: 640x576 2 persons, 64.7ms
# Speed: 2.6ms preprocess, 64.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[826,106,968,267]
#
# 0: 640x224 2 persons, 31.8ms
# Speed: 0.9ms preprocess, 31.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:4  box=[94,79,253,537]
#
# 0: 640x224 1 person, 27.5ms
# Speed: 1.2ms preprocess, 27.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.76 ID:5  box=[10,83,119,414]
#
# 0: 640x448 2 persons, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.0ms
# Speed: 2.7ms preprocess, 67.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.55 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 3 persons, 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.69 ID:8  box=[923,124,1015,261]
#
# 0: 640x416 2 persons, 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.56 ID:9  box=[1210,177,1293,307]
#
# 0: 640x384 1 person, 46.6ms
# Speed: 1.4ms preprocess, 46.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.65 ID:10  box=[1233,260,1325,427]
#
# 0: 640x448 1 person, 51.1ms
# Speed: 1.4ms preprocess, 51.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.25 ID:15  box=[111,79,254,288]
# video 1/1 (frame 29/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 44.2ms
# Frame 28:
#
# 0: 640x352 2 persons, 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,144,429,563]
#
# 0: 640x288 1 person, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.83 ID:2  box=[450,149,623,533]
#
# 0: 640x576 2 persons, 64.0ms
# Speed: 2.6ms preprocess, 64.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[826,106,968,267]
#
# 0: 640x224 2 persons, 33.7ms
# Speed: 1.1ms preprocess, 33.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:4  box=[92,79,253,539]
#
# 0: 640x224 1 person, 27.5ms
# Speed: 1.2ms preprocess, 27.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.85 ID:5  box=[6,82,121,430]
#
# 0: 640x448 2 persons, 51.7ms
# Speed: 2.4ms preprocess, 51.7ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.1ms
# Speed: 3.2ms preprocess, 67.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.54 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 3 persons, 50.7ms
# Speed: 1.4ms preprocess, 50.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.68 ID:8  box=[923,124,1015,261]
#
# 0: 640x416 2 persons, 51.1ms
# Speed: 1.3ms preprocess, 51.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.57 ID:9  box=[1209,177,1293,307]
#
# 0: 640x384 1 person, 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.65 ID:10  box=[1233,260,1325,427]
#
# 0: 640x448 1 person, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.29 ID:15  box=[111,79,254,289]
# video 1/1 (frame 30/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 42.7ms
# Frame 29:
#
# 0: 640x352 2 persons, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[200,144,429,563]
#
# 0: 640x320 1 person, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.83 ID:2  box=[450,150,622,530]
#
# 0: 640x576 2 persons, 64.0ms
# Speed: 2.6ms preprocess, 64.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[825,106,967,267]
#
# 0: 640x224 4 persons, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:4  box=[93,79,254,538]
#
# 0: 640x224 1 person, 28.3ms
# Speed: 0.9ms preprocess, 28.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.79 ID:5  box=[8,82,124,432]
#
# 0: 640x448 2 persons, 54.4ms
# Speed: 1.6ms preprocess, 54.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.65 ID:6  box=[953,192,1086,388]
#
# 0: 640x640 1 person, 67.2ms
# Speed: 2.8ms preprocess, 67.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#   → sitting 0.54 ID:7  box=[1148,192,1222,269]
#
# 0: 640x448 3 persons, 51.9ms
# Speed: 1.4ms preprocess, 51.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.67 ID:8  box=[923,124,1014,261]
#
# 0: 640x416 2 persons, 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.56 ID:9  box=[1209,177,1293,307]
#
# 0: 640x352 1 person, 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.63 ID:10  box=[1233,260,1324,427]
#
# 0: 640x448 1 person, 50.1ms
# Speed: 1.3ms preprocess, 50.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.28 ID:15  box=[111,79,254,287]
# video 1/1 (frame 31/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 42.2ms
# Frame 30:
#
# 0: 640x352 2 persons, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[200,144,430,564]
#
# 0: 640x320 1 person, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.85 ID:2  box=[450,150,622,531]
#
# 0: 640x576 2 persons, 63.7ms
# Speed: 2.6ms preprocess, 63.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[825,106,967,267]
#
# 0: 640x224 3 persons, 31.3ms
# Speed: 1.0ms preprocess, 31.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.50 ID:4  box=[92,79,253,538]
#
# 0: 640x224 1 person, 30.3ms
# Speed: 1.7ms preprocess, 30.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.88 ID:5  box=[12,82,127,428]
#
# 0: 640x448 2 persons, 51.2ms
# Speed: 1.4ms preprocess, 51.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.51 ID:6  box=[952,192,1085,388]
#
# 0: 640x640 (no detections), 68.7ms
# Speed: 2.6ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.57 ID:7  box=[1147,193,1222,270]
#
# 0: 640x448 3 persons, 51.9ms
# Speed: 1.4ms preprocess, 51.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:8  box=[924,124,1015,261]
#
# 0: 640x416 3 persons, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.49 ID:9  box=[1210,177,1293,305]
#
# 0: 640x352 1 person, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.42 ID:10  box=[1236,261,1322,418]
#
# 0: 640x448 1 person, 51.1ms
# Speed: 1.4ms preprocess, 51.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.47 ID:15  box=[111,79,253,285]
# video 1/1 (frame 32/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 45.8ms
# Frame 31:
#
# 0: 640x352 2 persons, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.87 ID:1  box=[200,144,430,564]
#
# 0: 640x320 1 person, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.84 ID:2  box=[450,150,622,531]
#
# 0: 640x576 3 persons, 63.1ms
# Speed: 2.5ms preprocess, 63.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[824,106,967,267]
#
# 0: 640x256 2 persons, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.32 ID:4  box=[91,78,253,537]
#
# 0: 640x224 2 persons, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.88 ID:5  box=[14,82,128,426]
#
# 0: 640x448 2 persons, 50.6ms
# Speed: 1.4ms preprocess, 50.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.56 ID:6  box=[951,192,1085,388]
#
# 0: 640x640 (no detections), 67.6ms
# Speed: 3.1ms preprocess, 67.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.56 ID:7  box=[1147,193,1221,270]
#
# 0: 640x448 3 persons, 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.68 ID:8  box=[924,124,1015,261]
#
# 0: 640x448 1 person, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.48 ID:9  box=[1211,177,1293,303]
#
# 0: 640x384 (no detections), 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:10  box=[1236,261,1322,415]
#
# 0: 640x448 1 person, 52.4ms
# Speed: 1.6ms preprocess, 52.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.66 ID:15  box=[110,79,252,283]
# video 1/1 (frame 33/60780) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam2 - 2.mp4: 384x640 11 persons, 44.5ms
# Frame 32:
#
# 0: 640x352 2 persons, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.86 ID:1  box=[199,143,430,564]
#
# 0: 640x320 1 person, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 320)
#   → sitting 0.84 ID:2  box=[450,150,623,532]
#
# 0: 640x576 3 persons, 63.6ms
# Speed: 2.6ms preprocess, 63.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#   → sitting 0.80 ID:3  box=[824,106,967,267]
#
# 0: 640x256 1 person, 34.1ms
# Speed: 1.3ms preprocess, 34.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 256)
#   → sitting 0.26 ID:4  box=[91,79,253,535]
#
# 0: 640x224 2 persons, 30.5ms
# Speed: 1.0ms preprocess, 30.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.89 ID:5  box=[17,81,131,425]
#
# 0: 640x448 2 persons, 50.0ms
# Speed: 1.4ms preprocess, 50.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.59 ID:6  box=[951,192,1085,388]
#
# 0: 640x640 (no detections), 66.9ms
# Speed: 2.7ms preprocess, 66.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.56 ID:7  box=[1147,193,1221,270]
#
# 0: 640x448 2 persons, 52.4ms
# Speed: 1.3ms preprocess, 52.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.67 ID:8  box=[924,124,1015,261]
#
# 0: 640x448 1 person, 49.9ms
# Speed: 1.4ms preprocess, 49.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.49 ID:9  box=[1211,177,1293,303]
#
# 0: 640x384 (no detections), 46.4ms
# Speed: 1.3ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:10  box=[1236,261,1322,416]
#
# 0: 640x448 2 persons, 51.3ms
# Speed: 1.3ms preprocess, 51.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.72 ID:15  box=[111,79,251,281]
