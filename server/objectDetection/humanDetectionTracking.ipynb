# %%
# !pip install ultralytics opencv-python

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import time

# %%
# Load the YOLOv8 model
model = YOLO('yolov8x.pt').to('cuda:0')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs

# %%
# --------Human & Object detection in video - correctly working--------

'''

# Initialize video capture
cap = cv2.VideoCapture(r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4')

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    while cap.isOpened():
        print("Reading frame...")
        ret, frame = cap.read()

        # Perform detection on the current frame
        results = model(frame)  # Detect objects in the frame

        # Filter detections for 'person' and 'chair' classes
        # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

        # Process the results
        for result in results:

            boxes = result.boxes  # Get bounding boxes

            for box in boxes:
                class_id = box.cls[0].item()  # Get the class id of the detected object
                if class_id in person_and_chair:  # Check if it is a person or a chair
                    # Get the bounding box coordinates
                    x1, y1, x2, y2 = map(int, box.xyxy[0])

                    # Get the class ID and confidence score
                    class_id = box.cls[0].item()
                    confidence = box.conf[0].item()

                    # Get the class name
                    label = model.names[class_id]

                    # Print out the detected object details
                    print(
                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                    )
                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                    # Draw a bounding box around the object

                    # Define different colors for different objects
                    if label == "person":
                        color = (255, 0, 0)  # Blue color for human (person)
                    elif label == "chair":
                        color = (0, 0, 255)  # Red color for chair
                    else:
                        color = (0, 255, 0)  # Default green for other objects

                    # Draw a bounding box around the object with the selected color
                    cv2.rectangle(
                        frame, (x1, y1), (x2, y2), color, 2
                    )  # Bounding box with the chosen color

                    cv2.putText(
                        frame,
                        label,
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        (0, 255, 0),
                        2,
                    )

        if frame is not None and frame.size > 0:
            cv2.imshow("Video", frame)
        else:
            print("Warning: Empty frame encountered!")
            break

        # Press 'q' to quit the video window
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\1471836195.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo6.mp4\')\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    while cap.isOpened():\n        print("Reading frame...")\n        ret, frame = cap.read()\n\n        # Perform detection on the current frame\n        results = model(frame)  # Detect objects in the frame\n\n        # Filter detections for \'person\' and \'chair\' classes\n        # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n        # Process the results\n        for result in results:\n\n            boxes = result.boxes  # Get bounding boxes\n\n            for box in boxes:\n                class_id = box.cls[0].item()  # Get the class id of the detected object\n                if class_id in person_and_chair:  # Check if it is a person or a chair\n                    # Get the bounding box coordinates\n                    x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                    # Get the class ID and confidence score\n                    class_id = box.cls[0].item()\n                    confidence = box.conf[0].item()\n\n                    # Get the class name\n                    label = model.names[class_id]\n\n                    # Print out the detected object details\n                    print(\n                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                    )\n                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                    # Draw a bounding box around the object\n\n                    # Define different colors for different objects\n                    if label == "person":\n                        color = (255, 0, 0)  # Blue color for human (person)\n                    elif label == "chair":\n                        color = (0, 0, 255)  # Red color for chair\n                    else:\n                        color = (0, 255, 0)  # Default green for other objects\n\n                    # Draw a bounding box around the object with the selected color\n                    cv2.rectangle(\n                        frame, (x1, y1), (x2, y2), color, 2\n                    )  # Bounding box with the chosen color\n\n                    cv2.putText(\n                        frame,\n                        label,\n                        (x1, y1 - 10),\n                        cv2.FONT_HERSHEY_SIMPLEX,\n                        0.9,\n                        (0, 255, 0),\n                        2,\n                    )\n\n        if frame is not None and frame.size > 0:\n            cv2.imshow("Video", frame)\n        else:\n            print("Warning: Empty frame encountered!")\n            break\n\n        # Press \'q\' to quit the video window\n        if cv2.waitKey(1) & 0xFF == ord("q"):\n            break\n\n    # Release the video capture object and close all windows\n    cap.release()\n    cv2.destroyAllWindows()\n\n'

# %%
# -----Tried to skip frames and process frames after every 10 seconds. Did not worked-----


'''

# Initialize video capture
cap = cv2.VideoCapture(
    r"D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4"
)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    # Get the frame rate (fps) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video Frame Rate (FPS): {fps}")

    # Time between frames we want to process (10 seconds)
    interval = 2  # Process every 10 seconds

    # Calculate the frame number corresponding to the desired times
    frame_number = 0
    prev_time = 0  # Start at time 0

    while cap.isOpened():
        # Calculate the time for the current frame (in seconds)
        current_time = frame_number / fps

        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)
        if current_time >= prev_time:

            print("Reading frame...")
            # Read a frame from the video
            ret, frame = cap.read()

            # Check if the frame was read properly
            if not ret:
                print("Error: Couldn't read the frame.")
                break

            # Perform detection on the current frame
            results = model(frame)  # Detect objects in the frame

            # Filter detections for 'person' and 'chair' classes
            # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

            # Process the results
            for result in results:
                # Extract bounding boxes, confidence, and class IDs
                boxes = result.boxes  # Get bounding boxes

                for box in boxes:
                    class_id = box.cls[0].item()  # Get the class id of the detected object

                    if (class_id in person_and_chair):  # Check if it is a person or a chair
                        # Get the bounding box coordinates
                        x1, y1, x2, y2 = map(int, box.xyxy[0])

                        # Get the class ID and confidence score
                        class_id = box.cls[0].item()
                        confidence = box.conf[0].item()

                        # Get the class name
                        label = model.names[class_id]

                        # Print out the detected object details
                        print(
                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                        )
                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                        # Draw a bounding box around the object

                        # Define different colors for different objects
                        if label == "person":
                            color = (255, 0, 0)  # Blue color for human (person)
                        elif label == "chair":
                            color = (0, 0, 255)  # Red color for chair
                        else:
                            color = (0, 255, 0)  # Default green for other objects

                        # Draw a bounding box around the object with the selected color
                        cv2.rectangle(
                            frame, (x1, y1), (x2, y2), color, 2
                        )  # Bounding box with the chosen color

                        cv2.putText(
                            frame,
                            label,
                            (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.9,
                            (0, 255, 0),
                            2,
                        )

                if frame is not None and frame.size > 0:
                    cv2.imshow("Video", frame)
                else:
                    print("Warning: Empty frame encountered!")
                    break

                # Press 'q' to quit the video window
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break

                # Update prev_time to the next desired frame time (e.g., t = 10s, 20s)
                prev_time += interval  # Move to the next interval (10 seconds)

            # Skip frames until we reach the desired frame time
            frame_number += 1
        
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\3711239310.py:4: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n\n# Initialize video capture\ncap = cv2.VideoCapture(\n    r"D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4"\n)\n\n# Check if video opened successfully\nif not cap.isOpened():\n    print("Error: Couldn\'t open the video file.")\nelse:\n    print("Video file opened successfully.")\n\n    # Get the frame rate (fps) of the video\n    fps = cap.get(cv2.CAP_PROP_FPS)\n    print(f"Video Frame Rate (FPS): {fps}")\n\n    # Time between frames we want to process (10 seconds)\n    interval = 2  # Process every 10 seconds\n\n    # Calculate the frame number corresponding to the desired times\n    frame_number = 0\n    prev_time = 0  # Start at time 0\n\n    while cap.isOpened():\n        # Calculate the time for the current frame (in seconds)\n        current_time = frame_number / fps\n\n        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)\n        if current_time >= prev_time:\n\n            print("Reading frame...")\n            # Read a frame from the video\n            ret, frame = cap.read()\n\n            # Check if the frame was read properly\n            if not ret:\n                print("Error: Couldn\'t read the frame.")\n                break\n\n            # Perform detection on the current frame\n            results = model(frame)  # Detect objects in the frame\n\n            # Filter detections for \'person\' and \'chair\' classes\n            # \'person\' has class ID 0 and \'chair\' has class ID 56 in the COCO dataset\n            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs\n\n            # Process the results\n            for result in results:\n                # Extract bounding boxes, confidence, and class IDs\n                boxes = result.boxes  # Get bounding boxes\n\n                for box in boxes:\n                    class_id = box.cls[0].item()  # Get the class id of the detected object\n\n                    if (class_id in person_and_chair):  # Check if it is a person or a chair\n                        # Get the bounding box coordinates\n                        x1, y1, x2, y2 = map(int, box.xyxy[0])\n\n                        # Get the class ID and confidence score\n                        class_id = box.cls[0].item()\n                        confidence = box.conf[0].item()\n\n                        # Get the class name\n                        label = model.names[class_id]\n\n                        # Print out the detected object details\n                        print(\n                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"\n                        )\n                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")\n\n                        # Draw a bounding box around the object\n\n                        # Define different colors for different objects\n                        if label == "person":\n                            color = (255, 0, 0)  # Blue color for human (person)\n                        elif label == "chair":\n                            color = (0, 0, 255)  # Red color for chair\n                        else:\n                            color = (0, 255, 0)  # Default green for other objects\n\n                        # Draw a bounding box around the object with the selected color\n                        cv2.rectangle(\n                            frame, (x1, y1), (x2, y2), color, 2\n                        )  # Bounding box with the chosen color\n\n                        cv2.putText(\n                            frame,\n                            label,\n                            (x1, y1 - 10),\n                            cv2.FONT_HERSHEY_SIMPLEX,\n                            0.9,\n                            (0, 255, 0),\n                            2,\n                        )\n\n                if frame is not None and frame.size > 0:\n                    cv2.imshow("Video", frame)\n                else:\n          ...

# %%
import torch
print("CUDA available? ", torch.cuda.is_available())
print("GPU count:    ", torch.cuda.device_count())
print("Current dev:  ", torch.cuda.current_device())
print("Dev name:     ", torch.cuda.get_device_name(0))
# Out:
# CUDA available?  True
# GPU count:     1
# Current dev:   0
# Dev name:      NVIDIA GeForce GTX 1660 Ti

# %%
# ----- Human & Chair detection and tracking - correctly working -----

'''
# 3. Run detection + ByteTrack on your video
#    – source: your file path
#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)
#    – classes: [0,56] → only person (0) & chair (56)
#    – persist: keep track IDs alive across frames
#    – show: pop up each frame (set False if headless)
#    – save: write out an annotated video to runs/track/exp*
stream = model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4',
    tracker='bytetrack.yaml',
    classes=[0, 56],
    persist=True,
    show=False,    # we’ll show manually
    save=True,    # disable automatic save
    save_dir='my_outputs/',
    stream=True,   # <— Enable streaming!
    device='cuda:0'
)

for frame_idx, res in enumerate(stream):
    print(f"Frame {frame_idx}:")
    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id
    for xyxy, conf, cls_id, track_id in zip(
        res.boxes.xyxy, 
        res.boxes.conf, 
        res.boxes.cls, 
        res.boxes.id
    ):
        x1, y1, x2, y2 = map(int, xyxy.tolist())
        conf = float(conf)
        cls_id = int(cls_id)
        track_id = int(track_id)
        label = res.names[cls_id]  # e.g. "person" or "chair"
        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")

    # Optional: display the annotated frame and quit on 'q'
    frame = res.plot()
    cv2.imshow("Track (press q to quit)", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_22524\1808955419.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\n# 3. Run detection + ByteTrack on your video\n#    – source: your file path\n#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)\n#    – classes: [0,56] → only person (0) & chair (56)\n#    – persist: keep track IDs alive across frames\n#    – show: pop up each frame (set False if headless)\n#    – save: write out an annotated video to runs/track/exp*\nstream = model.track(\n    source=r\'D:\\self study\x00 - FYP\\Seatify\\server\\objectDetection\x07ssets\x0bideo5.mp4\',\n    tracker=\'bytetrack.yaml\',\n    classes=[0, 56],\n    persist=True,\n    show=False,    # we’ll show manually\n    save=True,    # disable automatic save\n    save_dir=\'my_outputs/\',\n    stream=True,   # <— Enable streaming!\n    device=\'cuda:0\'\n)\n\nfor frame_idx, res in enumerate(stream):\n    print(f"Frame {frame_idx}:")\n    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id\n    for xyxy, conf, cls_id, track_id in zip(\n        res.boxes.xyxy, \n        res.boxes.conf, \n        res.boxes.cls, \n        res.boxes.id\n    ):\n        x1, y1, x2, y2 = map(int, xyxy.tolist())\n        conf = float(conf)\n        cls_id = int(cls_id)\n        track_id = int(track_id)\n        label = res.names[cls_id]  # e.g. "person" or "chair"\n        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")\n\n    # Optional: display the annotated frame and quit on \'q\'\n    frame = res.plot()\n    cv2.imshow("Track (press q to quit)", frame)\n    if cv2.waitKey(1) & 0xFF == ord(\'q\'):\n        break\n\ncv2.destroyAllWindows()\n\n'

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load models onto GPU
det_model  = YOLO('yolov8x.pt').to('cuda:0')
pose_model = YOLO('yolov8x-pose.pt').to('cuda:0')

def calculate_angle(a, b, c):
    #Builds vectors ba and bc around joint b.
    ba = a - b
    bc = c - b
    
    #Uses the dot-product formula to get the cosine of angle abc
    cosang = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-6)

    #clip to valid range and convert from radians to degrees
    return np.degrees(np.arccos(np.clip(cosang, -1.0, 1.0)))

# Start the detection + track stream
stream = det_model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4',
    tracker='bytetrack.yaml',
    classes=[0,56],
    persist=True,
    show=False,
    save=True,
    save_dir='my_outputs/',
    stream=True,
    device='cuda:0'
)

#process frames
for frame_idx, res in enumerate(stream): #enumerate(stream) gives (frame_idx, res) as soon as each frame is done
    frame = res.orig_img.copy() # copy of raw frame we annotate
    print(f"Frame {frame_idx}:")

    # Pull detections
    # Unpack the tracked detections in parallel arrays
    xyxys     = res.boxes.xyxy.cpu().numpy() # bounding boxes (n×4)
    confs     = res.boxes.conf.cpu().numpy() # confidence scores (n) 
    cls_ids   = res.boxes.cls.cpu().numpy().astype(int) # class IDs (n)
    track_ids = res.boxes.id.cpu().numpy().astype(int) # track IDs (n)

    #Iterate through each detection in this frame
    for (x1, y1, x2, y2), conf, cls_id, track_id in zip(xyxys, confs, cls_ids, track_ids): #Zips the four arrays so you handle each detection in lockstep.
        
        #Converts the box coords to integers
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))

        #looks up the human-readable class name
        label = res.names[cls_id] # e.g. "person" or "chair"

        # Person branch
        if label == 'person':

            # Defaults the posture to “unknown” with a yellow box
            posture, color = 'unknown', (0,255,255)

            # Crops the detected person region and runs pose_model on that ROI
            roi = frame[y1:y2, x1:x2]
            p = pose_model(roi, device='cuda:0')[0]

            # If keypoints are found, extracts the raw (n,17,3) array from p.keypoints.data.
            # In the shape tuple (n, 17, 3), that leading n is simply the number of person instances (i.e. detections) 
            # that the pose model found in your cropped image
            # Since you’re cropping around a single detected box, in most cases n will be 1
            if p.keypoints is not None:
                # Extract the raw (n,17,3) tensor of keypoints
                kpts_np = p.keypoints.data.cpu().numpy()  # shape (n,17,3)

                # Ensure we have at least 17 keypoints
                if kpts_np.ndim == 3 and kpts_np.shape[1] >= 17:
                    kpts = kpts_np[0]  # first person
                    # shape (17,3): [x,y,conf] per joint

                    # compute knee angle
                    try:
                        # compute left & right knee angles
                        l_ang = calculate_angle(kpts[11,:2], kpts[13,:2], kpts[15,:2]) #computes left knee angles
                        r_ang = calculate_angle(kpts[12,:2], kpts[14,:2], kpts[16,:2]) #computes right knee angles
                        # compute average angle
                        avg_ang = (l_ang + r_ang) / 2

                        # Threshold to decide sitting vs standing
                        
                        if avg_ang < 110:
                            posture, color = 'sitting',  (0,255,0)
                        else:
                            posture, color = 'standing', (0,0,255)
                    except:
                        pass
                    
            text = f"{posture} {conf:.2f} ID:{track_id}"

        else:
            # chair
            color = (255,0,0)
            text  = f"chair {conf:.2f} ID:{track_id}"

        # Draw & print
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
        cv2.putText(frame, text, (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        print(f"  → {text}  box=[{x1},{y1},{x2},{y2}]")

    cv2.imshow("Pose+Track", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# video 1/1 (frame 1/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 3 chairs, 73.1ms
# Frame 0:
#   → chair 0.63 ID:1  box=[822,337,974,719]
#   → chair 0.52 ID:2  box=[393,317,494,497]
#
# 0: 640x224 (no detections), 47.3ms
# Speed: 1.8ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.47 ID:3  box=[192,339,290,632]
#   → chair 0.47 ID:4  box=[941,220,1010,370]
#
# 0: 640x224 (no detections), 33.4ms
# Speed: 2.6ms preprocess, 33.4ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.38 ID:5  box=[425,142,501,385]
# video 1/1 (frame 2/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 1 person, 3 chairs, 50.7ms
# Frame 1:
#   → chair 0.69 ID:1  box=[823,337,975,719]
#   → chair 0.55 ID:2  box=[393,317,494,498]
#
# 0: 640x224 (no detections), 36.4ms
# Speed: 3.5ms preprocess, 36.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.42 ID:3  box=[192,339,290,634]
#   → chair 0.46 ID:4  box=[941,219,1011,369]
# video 1/1 (frame 3/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 3 chairs, 58.8ms
# Frame 2:
#   → chair 0.57 ID:1  box=[824,338,976,719]
#   → chair 0.56 ID:2  box=[394,317,493,494]
#
# 0: 640x224 2 persons, 32.0ms
# Speed: 1.6ms preprocess, 32.0ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.32 ID:3  box=[193,339,289,629]
#   → chair 0.47 ID:4  box=[941,218,1011,370]
#
# 0: 640x224 1 person, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.37 ID:5  box=[422,141,499,385]
# video 1/1 (frame 4/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 52.4ms
# Frame 3:
#   → chair 0.53 ID:1  box=[825,339,976,719]
#   → chair 0.61 ID:2  box=[396,317,493,490]
#
# 0: 640x224 1 person, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.35 ID:3  box=[193,339,290,631]
#   → chair 0.56 ID:4  box=[940,217,1011,371]
#   → chair 0.33 ID:7  box=[739,233,816,639]
#   → chair 0.34 ID:8  box=[511,252,663,535]
#
# 0: 640x224 1 person, 32.4ms
# Speed: 1.3ms preprocess, 32.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.32 ID:5  box=[422,140,499,386]
# video 1/1 (frame 5/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 50.2ms
# Frame 4:
#   → chair 0.43 ID:1  box=[825,336,977,719]
#   → chair 0.63 ID:2  box=[396,318,492,489]
#
# 0: 640x224 (no detections), 31.4ms
# Speed: 1.2ms preprocess, 31.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.32 ID:3  box=[192,339,289,632]
#   → chair 0.58 ID:4  box=[940,217,1011,371]
#   → chair 0.28 ID:7  box=[739,232,815,640]
#   → chair 0.43 ID:8  box=[512,251,665,535]
#
# 0: 640x224 1 person, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.38 ID:5  box=[423,140,499,386]
# video 1/1 (frame 6/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 48.9ms
# Frame 5:
#   → chair 0.32 ID:1  box=[825,339,976,719]
#   → chair 0.66 ID:2  box=[396,318,492,488]
#
# 0: 640x224 2 persons, 32.6ms
# Speed: 1.1ms preprocess, 32.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.31 ID:3  box=[192,339,289,632]
#   → chair 0.51 ID:4  box=[940,218,1010,371]
#   → chair 0.26 ID:7  box=[738,232,815,640]
#   → chair 0.52 ID:8  box=[513,251,667,537]
#
# 0: 640x224 1 person, 31.7ms
# Speed: 1.1ms preprocess, 31.7ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.43 ID:5  box=[423,140,499,386]
# video 1/1 (frame 7/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 54.7ms
# Frame 6:
#   → chair 0.35 ID:1  box=[825,339,976,719]
#   → chair 0.66 ID:2  box=[395,317,493,490]
#
# 0: 640x224 (no detections), 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.49 ID:3  box=[191,339,288,633]
#   → chair 0.52 ID:4  box=[940,218,1010,372]
#   → chair 0.36 ID:7  box=[738,232,815,640]
#   → chair 0.47 ID:8  box=[514,252,668,536]
#
# 0: 640x224 1 person, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.46 ID:5  box=[424,140,499,386]
# video 1/1 (frame 8/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 5 chairs, 52.6ms
# Frame 7:
#   → chair 0.31 ID:1  box=[827,339,977,719]
#   → chair 0.64 ID:2  box=[396,318,493,489]
#
# 0: 640x224 2 persons, 32.7ms
# Speed: 1.4ms preprocess, 32.7ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.33 ID:3  box=[192,339,288,631]
#   → chair 0.47 ID:4  box=[940,219,1010,371]
#   → chair 0.27 ID:7  box=[738,233,814,639]
#   → chair 0.49 ID:8  box=[513,251,668,538]
#
# 0: 640x224 1 person, 31.2ms
# Speed: 1.0ms preprocess, 31.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.51 ID:5  box=[424,140,500,386]
# video 1/1 (frame 9/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 53.2ms
# Frame 8:
#   → chair 0.50 ID:1  box=[825,336,977,719]
#   → chair 0.66 ID:2  box=[396,318,493,489]
#
# 0: 640x224 1 person, 31.2ms
# Speed: 1.7ms preprocess, 31.2ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.38 ID:3  box=[193,339,288,629]
#   → chair 0.46 ID:4  box=[940,219,1010,371]
#   → chair 0.31 ID:7  box=[738,233,814,639]
#   → chair 0.56 ID:8  box=[512,251,669,539]
#
# 0: 640x224 1 person, 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:5  box=[424,140,499,385]
#
# 0: 640x448 (no detections), 52.9ms
# Speed: 2.8ms preprocess, 52.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.39 ID:9  box=[532,152,643,322]
# video 1/1 (frame 10/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 54.8ms
# Frame 9:
#   → chair 0.53 ID:1  box=[824,338,976,719]
#   → chair 0.67 ID:2  box=[396,318,493,487]
#
# 0: 640x224 1 person, 33.5ms
# Speed: 1.1ms preprocess, 33.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.41 ID:3  box=[193,339,289,631]
#   → chair 0.42 ID:4  box=[940,219,1010,371]
#   → chair 0.29 ID:7  box=[739,234,815,639]
#   → chair 0.71 ID:8  box=[513,251,670,539]
#
# 0: 640x224 1 person, 35.8ms
# Speed: 1.9ms preprocess, 35.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:5  box=[424,139,499,386]
#
# 0: 640x448 (no detections), 55.6ms
# Speed: 3.5ms preprocess, 55.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.30 ID:9  box=[533,156,642,321]
# video 1/1 (frame 11/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 55.9ms
# Frame 10:
#   → chair 0.64 ID:1  box=[823,338,975,718]
#   → chair 0.65 ID:2  box=[396,318,493,487]
#
# 0: 640x224 1 person, 39.0ms
# Speed: 4.6ms preprocess, 39.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.51 ID:3  box=[193,339,290,633]
#   → chair 0.35 ID:4  box=[940,218,1011,371]
#   → chair 0.28 ID:7  box=[739,234,815,639]
#   → chair 0.67 ID:8  box=[513,251,671,539]
#
# 0: 640x224 1 person, 32.1ms
# Speed: 1.5ms preprocess, 32.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:5  box=[424,140,499,385]
#
# 0: 640x448 1 person, 57.6ms
# Speed: 1.3ms preprocess, 57.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.26 ID:9  box=[538,167,639,320]
# video 1/1 (frame 12/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 50.3ms
# Frame 11:
#   → chair 0.57 ID:1  box=[825,339,976,718]
#   → chair 0.65 ID:2  box=[396,318,493,486]
#
# 0: 640x224 (no detections), 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.33 ID:3  box=[193,339,290,633]
#   → chair 0.32 ID:4  box=[941,218,1011,371]
#   → chair 0.23 ID:7  box=[739,233,815,639]
#   → chair 0.68 ID:8  box=[512,250,671,540]
#
# 0: 640x224 1 person, 32.0ms
# Speed: 1.6ms preprocess, 32.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.57 ID:5  box=[424,140,498,385]
#
# 0: 640x448 (no detections), 57.4ms
# Speed: 2.5ms preprocess, 57.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.19 ID:9  box=[541,174,636,317]
# video 1/1 (frame 13/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 5 chairs, 53.7ms
# Frame 12:
#   → chair 0.50 ID:1  box=[827,339,978,718]
#   → chair 0.70 ID:2  box=[396,318,493,485]
#
# 0: 640x224 1 person, 37.5ms
# Speed: 2.8ms preprocess, 37.5ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.42 ID:3  box=[193,339,289,631]
#   → chair 0.29 ID:4  box=[941,217,1011,372]
#   → chair 0.21 ID:7  box=[741,234,817,639]
#   → chair 0.64 ID:8  box=[512,251,672,540]
#
# 0: 640x224 1 person, 31.9ms
# Speed: 3.3ms preprocess, 31.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:5  box=[424,140,498,385]
#
# 0: 640x448 (no detections), 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.35 ID:9  box=[539,170,637,317]
# video 1/1 (frame 14/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 58.1ms
# Frame 13:
#   → chair 0.48 ID:1  box=[829,340,979,718]
#   → chair 0.70 ID:2  box=[395,318,493,487]
#
# 0: 640x224 1 person, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.44 ID:3  box=[194,339,289,628]
#   → chair 0.32 ID:4  box=[941,217,1011,373]
#   → chair 0.20 ID:7  box=[741,235,817,640]
#   → chair 0.52 ID:8  box=[510,251,670,541]
#
# 0: 640x224 1 person, 33.5ms
# Speed: 4.5ms preprocess, 33.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:5  box=[424,140,498,385]
#
# 0: 640x448 (no detections), 58.1ms
# Speed: 2.3ms preprocess, 58.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.36 ID:9  box=[539,168,638,317]
#   → chair 0.33 ID:13  box=[795,153,864,270]
# video 1/1 (frame 15/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 53.9ms
# Frame 14:
#   → chair 0.54 ID:1  box=[828,340,979,718]
#   → chair 0.69 ID:2  box=[395,318,493,488]
#
# 0: 640x224 1 person, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.42 ID:3  box=[192,339,289,634]
#   → chair 0.42 ID:4  box=[940,218,1011,373]
#   → chair 0.19 ID:7  box=[743,260,814,641]
#   → chair 0.57 ID:8  box=[510,251,671,541]
#
# 0: 640x224 1 person, 33.4ms
# Speed: 3.3ms preprocess, 33.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:5  box=[423,139,498,387]
#
# 0: 640x448 1 person, 59.4ms
# Speed: 2.4ms preprocess, 59.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.28 ID:9  box=[538,169,638,317]
#   → chair 0.36 ID:13  box=[795,153,864,269]
# video 1/1 (frame 16/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 2 persons, 6 chairs, 55.3ms
# Frame 15:
#   → chair 0.25 ID:1  box=[838,342,988,718]
#   → chair 0.69 ID:2  box=[396,317,494,484]
#
# 0: 640x224 1 person, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.47 ID:3  box=[192,339,291,640]
#   → chair 0.41 ID:4  box=[940,218,1011,373]
#   → chair 0.22 ID:7  box=[740,243,815,639]
#   → chair 0.23 ID:8  box=[510,251,671,542]
#
# 0: 640x224 1 person, 32.9ms
# Speed: 1.1ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:5  box=[423,139,498,387]
#   → chair 0.21 ID:13  box=[794,153,863,270]
# video 1/1 (frame 17/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 54.6ms
# Frame 16:
#   → chair 0.30 ID:1  box=[840,342,990,719]
#   → chair 0.69 ID:2  box=[397,317,494,483]
#
# 0: 640x224 1 person, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:3  box=[193,339,290,636]
#   → chair 0.45 ID:4  box=[940,218,1011,373]
#   → chair 0.25 ID:7  box=[740,236,816,638]
#   → chair 0.32 ID:8  box=[512,251,674,542]
#
# 0: 640x224 1 person, 36.4ms
# Speed: 1.2ms preprocess, 36.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:5  box=[424,139,499,387]
#   → chair 0.28 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.38 ID:15  box=[529,96,599,227]
# video 1/1 (frame 18/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 53.8ms
# Frame 17:
#   → chair 0.22 ID:1  box=[840,342,991,719]
#   → chair 0.66 ID:2  box=[397,317,495,482]
#
# 0: 640x224 (no detections), 33.6ms
# Speed: 4.3ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.64 ID:3  box=[193,339,289,633]
#   → chair 0.33 ID:4  box=[940,218,1010,373]
#   → chair 0.19 ID:7  box=[740,234,817,640]
#   → chair 0.37 ID:8  box=[514,252,675,540]
#
# 0: 640x192 (no detections), 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.60 ID:5  box=[423,138,498,388]
#   → chair 0.19 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.25 ID:15  box=[530,94,600,227]
# video 1/1 (frame 19/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 3 persons, 6 chairs, 54.2ms
# Frame 18:
#   → chair 0.12 ID:1  box=[843,351,990,716]
#   → chair 0.70 ID:2  box=[397,316,496,482]
#
# 0: 640x224 1 person, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.61 ID:3  box=[193,339,288,632]
#   → chair 0.50 ID:4  box=[940,217,1011,374]
#   → chair 0.20 ID:7  box=[739,233,817,641]
#   → chair 0.49 ID:8  box=[514,251,676,540]
#
# 0: 640x224 (no detections), 30.9ms
# Speed: 2.4ms preprocess, 30.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.64 ID:5  box=[423,138,498,387]
#   → chair 0.28 ID:13  box=[794,154,863,270]
#
# 0: 640x352 1 person, 46.7ms
# Speed: 4.8ms preprocess, 46.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.40 ID:15  box=[531,93,601,226]
# video 1/1 (frame 20/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 53.3ms
# Frame 19:
#   → chair 0.27 ID:1  box=[833,343,983,717]
#   → chair 0.68 ID:2  box=[397,316,496,483]
#
# 0: 640x224 (no detections), 33.2ms
# Speed: 1.2ms preprocess, 33.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.56 ID:3  box=[193,339,288,631]
#   → chair 0.48 ID:4  box=[940,217,1011,374]
#   → chair 0.17 ID:7  box=[738,233,816,640]
#   → chair 0.61 ID:8  box=[513,250,677,541]
#
# 0: 640x192 (no detections), 32.4ms
# Speed: 4.0ms preprocess, 32.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.65 ID:5  box=[423,137,498,387]
#   → chair 0.30 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.36 ID:15  box=[530,93,601,225]
#
# 0: 640x448 (no detections), 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.39 ID:9  box=[533,157,640,318]
# video 1/1 (frame 21/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 49.9ms
# Frame 20:
#   → chair 0.30 ID:1  box=[830,340,981,718]
#   → chair 0.67 ID:2  box=[396,316,496,483]
#
# 0: 640x224 1 person, 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:3  box=[194,339,288,631]
#   → chair 0.39 ID:4  box=[941,217,1011,374]
#   → chair 0.23 ID:7  box=[737,232,815,639]
#   → chair 0.56 ID:8  box=[513,250,677,541]
#
# 0: 640x192 (no detections), 31.2ms
# Speed: 1.6ms preprocess, 31.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.65 ID:5  box=[423,137,498,387]
#   → chair 0.27 ID:13  box=[794,154,863,270]
#
# 0: 640x352 1 person, 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#   → sitting 0.27 ID:15  box=[530,93,601,227]
#
# 0: 640x288 1 person, 50.1ms
# Speed: 2.3ms preprocess, 50.1ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.32 ID:19  box=[94,496,203,739]
#
# 0: 640x448 (no detections), 58.3ms
# Speed: 4.8ms preprocess, 58.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.18 ID:9  box=[531,154,640,318]
# video 1/1 (frame 22/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 53.9ms
# Frame 21:
#   → chair 0.20 ID:1  box=[838,344,988,717]
#   → chair 0.67 ID:2  box=[396,316,496,483]
#
# 0: 640x224 1 person, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.52 ID:3  box=[193,340,288,631]
#   → chair 0.53 ID:4  box=[941,217,1011,375]
#   → chair 0.20 ID:7  box=[736,232,814,638]
#   → chair 0.52 ID:8  box=[513,249,678,541]
#
# 0: 640x192 2 persons, 33.1ms
# Speed: 2.3ms preprocess, 33.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.66 ID:5  box=[423,137,498,387]
#   → chair 0.27 ID:13  box=[794,154,863,270]
#
# 0: 640x352 (no detections), 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.42 ID:15  box=[530,92,602,229]
#
# 0: 640x288 1 person, 50.2ms
# Speed: 3.1ms preprocess, 50.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.31 ID:19  box=[94,496,203,740]
# video 1/1 (frame 23/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 56.9ms
# Frame 22:
#   → chair 0.26 ID:1  box=[840,344,990,718]
#   → chair 0.64 ID:2  box=[395,317,496,483]
#
# 0: 640x224 2 persons, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[193,340,287,632]
#   → chair 0.55 ID:4  box=[941,218,1011,375]
#   → chair 0.31 ID:7  box=[736,232,814,639]
#   → chair 0.44 ID:8  box=[513,250,678,541]
#
# 0: 640x192 1 person, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.61 ID:5  box=[423,137,498,387]
#   → chair 0.26 ID:13  box=[794,154,864,270]
#
# 0: 640x352 (no detections), 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.41 ID:15  box=[530,93,602,230]
#
# 0: 640x288 1 person, 47.1ms
# Speed: 1.8ms preprocess, 47.1ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.38 ID:19  box=[94,496,203,741]
# video 1/1 (frame 24/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 52.7ms
# Frame 23:
#   → chair 0.34 ID:1  box=[836,342,988,718]
#   → chair 0.64 ID:2  box=[395,317,497,484]
#
# 0: 640x224 1 person, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.45 ID:3  box=[194,340,287,629]
#   → chair 0.50 ID:4  box=[941,219,1010,375]
#   → chair 0.35 ID:7  box=[736,231,815,639]
#   → chair 0.48 ID:8  box=[513,251,678,541]
#
# 0: 640x192 1 person, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.64 ID:5  box=[423,137,498,388]
#   → chair 0.25 ID:13  box=[794,154,864,270]
#
# 0: 640x352 (no detections), 54.9ms
# Speed: 2.5ms preprocess, 54.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.26 ID:15  box=[530,93,602,229]
#
# 0: 640x288 1 person, 45.3ms
# Speed: 2.5ms preprocess, 45.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.35 ID:19  box=[94,496,204,741]
# video 1/1 (frame 25/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 56.8ms
# Frame 24:
#   → chair 0.27 ID:1  box=[838,343,990,718]
#   → chair 0.64 ID:2  box=[396,318,496,482]
#
# 0: 640x224 1 person, 32.8ms
# Speed: 1.3ms preprocess, 32.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:3  box=[193,340,288,631]
#   → chair 0.43 ID:4  box=[941,218,1011,374]
#   → chair 0.39 ID:7  box=[737,232,815,638]
#   → chair 0.44 ID:8  box=[512,251,678,541]
#
# 0: 640x192 1 person, 32.1ms
# Speed: 1.0ms preprocess, 32.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.60 ID:5  box=[423,137,498,387]
#   → chair 0.27 ID:13  box=[794,154,863,269]
#
# 0: 640x352 (no detections), 49.0ms
# Speed: 1.8ms preprocess, 49.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.32 ID:15  box=[530,93,602,230]
#
# 0: 640x288 1 person, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.42 ID:19  box=[94,496,204,742]
# video 1/1 (frame 26/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 54.6ms
# Frame 25:
#   → chair 0.35 ID:1  box=[830,340,983,718]
#   → chair 0.67 ID:2  box=[396,318,496,481]
#
# 0: 640x224 1 person, 32.0ms
# Speed: 3.1ms preprocess, 32.0ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[194,340,288,632]
#   → chair 0.40 ID:4  box=[942,219,1011,374]
#   → chair 0.49 ID:7  box=[736,232,815,638]
#   → chair 0.48 ID:8  box=[511,249,678,541]
#
# 0: 640x192 (no detections), 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.62 ID:5  box=[423,137,498,388]
#   → chair 0.29 ID:13  box=[793,154,863,269]
#
# 0: 640x352 (no detections), 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.32 ID:15  box=[530,93,602,229]
#
# 0: 640x288 1 person, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.42 ID:19  box=[94,496,204,742]
# video 1/1 (frame 27/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 55.0ms
# Frame 26:
#   → chair 0.40 ID:1  box=[827,339,980,718]
#   → chair 0.66 ID:2  box=[396,318,496,482]
#
# 0: 640x224 2 persons, 42.4ms
# Speed: 6.1ms preprocess, 42.4ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:3  box=[194,341,289,633]
#   → chair 0.44 ID:4  box=[942,218,1011,374]
#   → chair 0.44 ID:7  box=[736,232,814,637]
#   → chair 0.51 ID:8  box=[511,249,679,541]
#
# 0: 640x192 1 person, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.59 ID:5  box=[423,137,498,388]
#   → chair 0.36 ID:13  box=[793,154,863,270]
#
# 0: 640x352 (no detections), 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.23 ID:15  box=[529,93,601,229]
#
# 0: 640x288 1 person, 47.5ms
# Speed: 1.1ms preprocess, 47.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.38 ID:19  box=[94,496,204,741]
# video 1/1 (frame 28/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 53.3ms
# Frame 27:
#   → chair 0.43 ID:1  box=[826,340,978,718]
#   → chair 0.65 ID:2  box=[395,318,497,482]
#
# 0: 640x224 1 person, 37.3ms
# Speed: 1.3ms preprocess, 37.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[194,341,288,630]
#   → chair 0.33 ID:4  box=[943,218,1012,373]
#   → chair 0.48 ID:7  box=[736,232,814,637]
#   → chair 0.52 ID:8  box=[511,250,679,542]
#
# 0: 640x192 1 person, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.60 ID:5  box=[423,137,498,389]
#   → chair 0.35 ID:13  box=[793,154,862,270]
#
# 0: 640x352 (no detections), 50.1ms
# Speed: 2.7ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.14 ID:15  box=[530,93,598,221]
#
# 0: 640x288 1 person, 45.6ms
# Speed: 2.3ms preprocess, 45.6ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.42 ID:19  box=[95,496,204,741]
#
# 0: 640x416 (no detections), 58.5ms
# Speed: 1.2ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.40 ID:9  box=[530,151,639,319]
# video 1/1 (frame 29/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 54.5ms
# Frame 28:
#   → chair 0.46 ID:1  box=[827,340,978,718]
#   → chair 0.59 ID:2  box=[394,318,499,488]
#
# 0: 640x224 2 persons, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:3  box=[194,341,288,630]
#   → chair 0.35 ID:4  box=[943,219,1011,373]
#   → chair 0.45 ID:7  box=[736,232,815,638]
#   → chair 0.40 ID:8  box=[511,251,679,543]
#
# 0: 640x224 1 person, 34.1ms
# Speed: 2.6ms preprocess, 34.1ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:5  box=[423,137,499,388]
#   → chair 0.31 ID:13  box=[793,154,862,270]
#
# 0: 640x352 (no detections), 46.6ms
# Speed: 3.7ms preprocess, 46.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.16 ID:15  box=[530,93,596,219]
#
# 0: 640x288 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.44 ID:19  box=[95,496,204,741]
#
# 0: 640x416 1 person, 56.2ms
# Speed: 1.3ms preprocess, 56.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.39 ID:9  box=[530,151,637,318]
# video 1/1 (frame 30/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 54.2ms
# Frame 29:
#   → chair 0.48 ID:1  box=[826,340,978,718]
#   → chair 0.61 ID:2  box=[393,317,499,489]
#
# 0: 640x224 1 person, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[194,341,288,629]
#   → chair 0.38 ID:4  box=[943,218,1011,373]
#   → chair 0.47 ID:7  box=[736,232,816,639]
#   → chair 0.52 ID:8  box=[511,250,679,543]
#
# 0: 640x192 1 person, 33.9ms
# Speed: 1.9ms preprocess, 33.9ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.65 ID:5  box=[423,137,498,388]
#   → chair 0.41 ID:13  box=[792,154,862,270]
#
# 0: 640x352 (no detections), 52.0ms
# Speed: 2.4ms preprocess, 52.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.36 ID:15  box=[531,94,601,225]
#
# 0: 640x288 1 person, 48.7ms
# Speed: 2.8ms preprocess, 48.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.34 ID:19  box=[95,496,204,741]
# video 1/1 (frame 31/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 5 chairs, 57.8ms
# Frame 30:
#   → chair 0.66 ID:2  box=[394,318,495,482]
#
# 0: 640x224 (no detections), 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.40 ID:3  box=[194,341,287,628]
#   → chair 0.26 ID:4  box=[942,222,1010,374]
#   → chair 0.12 ID:7  box=[736,235,813,627]
#   → chair 0.30 ID:8  box=[507,250,674,542]
#
# 0: 640x192 1 person, 31.7ms
# Speed: 0.8ms preprocess, 31.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.66 ID:5  box=[423,137,498,387]
#   → chair 0.12 ID:13  box=[805,154,877,269]
#
# 0: 640x352 (no detections), 48.8ms
# Speed: 2.9ms preprocess, 48.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.51 ID:15  box=[531,98,600,226]
#
# 0: 640x288 1 person, 49.4ms
# Speed: 3.2ms preprocess, 49.4ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.13 ID:19  box=[95,496,204,741]
# video 1/1 (frame 32/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 5 chairs, 60.4ms
# Frame 31:
#   → chair 0.67 ID:2  box=[395,318,494,479]
#
# 0: 640x224 (no detections), 36.9ms
# Speed: 0.9ms preprocess, 36.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.49 ID:3  box=[194,342,288,629]
#   → chair 0.31 ID:4  box=[942,222,1009,375]
#   → chair 0.22 ID:7  box=[736,234,814,633]
#   → chair 0.29 ID:8  box=[504,250,669,542]
#
# 0: 640x224 2 persons, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[423,137,498,386]
#   → chair 0.16 ID:13  box=[808,154,884,270]
#
# 0: 640x352 (no detections), 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.57 ID:15  box=[531,99,599,225]
#
# 0: 640x288 (no detections), 50.1ms
# Speed: 1.1ms preprocess, 50.1ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.11 ID:19  box=[94,496,204,742]
# video 1/1 (frame 33/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 5 chairs, 49.3ms
# Frame 32:
#   → chair 0.66 ID:2  box=[395,318,494,478]
#
# 0: 640x224 1 person, 33.9ms
# Speed: 1.0ms preprocess, 33.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.46 ID:3  box=[193,342,288,630]
#   → chair 0.23 ID:4  box=[941,224,1008,375]
#   → chair 0.25 ID:7  box=[736,233,814,636]
#   → chair 0.33 ID:8  box=[503,250,667,541]
#
# 0: 640x224 2 persons, 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:5  box=[423,138,498,387]
#   → chair 0.20 ID:13  box=[809,154,887,270]
#
# 0: 640x352 (no detections), 45.1ms
# Speed: 2.3ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.57 ID:15  box=[532,97,599,221]
#
# 0: 640x288 1 person, 44.7ms
# Speed: 2.6ms preprocess, 44.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.14 ID:19  box=[95,496,204,741]
# video 1/1 (frame 34/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 50.9ms
# Frame 33:
#   → chair 0.65 ID:2  box=[395,318,494,478]
#
# 0: 640x224 (no detections), 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.46 ID:3  box=[194,342,288,632]
#   → chair 0.22 ID:4  box=[941,225,1008,375]
#   → chair 0.26 ID:7  box=[737,232,815,638]
#   → chair 0.37 ID:8  box=[504,250,667,541]
#
# 0: 640x224 1 person, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:5  box=[423,138,498,386]
#   → chair 0.11 ID:13  box=[808,154,889,271]
#
# 0: 640x352 (no detections), 49.1ms
# Speed: 1.4ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.57 ID:15  box=[531,96,599,220]
#
# 0: 640x320 (no detections), 53.3ms
# Speed: 2.4ms preprocess, 53.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 320)
#   → unknown 0.20 ID:19  box=[94,496,204,740]
#   → chair 0.31 ID:1  box=[825,337,977,718]
# video 1/1 (frame 35/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 54.3ms
# Frame 34:
#   → chair 0.61 ID:2  box=[393,317,496,484]
#
# 0: 640x224 1 person, 31.1ms
# Speed: 1.6ms preprocess, 31.1ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.30 ID:3  box=[193,342,288,635]
#   → chair 0.33 ID:4  box=[942,227,1008,375]
#   → chair 0.39 ID:7  box=[738,231,816,639]
#   → chair 0.41 ID:8  box=[505,250,668,542]
#
# 0: 640x224 1 person, 34.1ms
# Speed: 3.3ms preprocess, 34.1ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:5  box=[422,137,498,387]
#   → chair 0.18 ID:13  box=[807,154,890,270]
#
# 0: 640x352 (no detections), 45.1ms
# Speed: 2.8ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#   → unknown 0.47 ID:15  box=[531,94,601,223]
#
# 0: 640x288 1 person, 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.13 ID:19  box=[94,496,203,739]
#   → chair 0.39 ID:1  box=[827,337,979,718]
# video 1/1 (frame 36/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 53.8ms
# Frame 35:
#   → chair 0.63 ID:2  box=[391,317,497,490]
#
# 0: 640x224 1 person, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.32 ID:3  box=[192,342,289,639]
#   → chair 0.29 ID:4  box=[942,227,1008,374]
#   → chair 0.37 ID:7  box=[737,231,815,639]
#   → chair 0.49 ID:8  box=[507,250,669,541]
#
# 0: 640x192 1 person, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:5  box=[423,137,498,387]
#   → chair 0.13 ID:13  box=[805,154,891,271]
#
# 0: 640x384 (no detections), 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.46 ID:15  box=[530,93,601,220]
#
# 0: 640x288 1 person, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.12 ID:19  box=[94,496,204,742]
#   → chair 0.33 ID:1  box=[828,337,979,718]
# video 1/1 (frame 37/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 6 chairs, 57.4ms
# Frame 36:
#   → chair 0.66 ID:2  box=[390,316,498,494]
#
# 0: 640x224 (no detections), 37.6ms
# Speed: 2.0ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.40 ID:3  box=[193,342,289,637]
#   → chair 0.30 ID:4  box=[944,220,1013,374]
#   → chair 0.41 ID:7  box=[737,231,815,639]
#   → chair 0.53 ID:8  box=[508,250,670,540]
#
# 0: 640x192 1 person, 31.5ms
# Speed: 1.3ms preprocess, 31.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.67 ID:5  box=[423,137,498,387]
#   → chair 0.24 ID:13  box=[793,154,876,271]
#
# 0: 640x384 (no detections), 51.7ms
# Speed: 2.6ms preprocess, 51.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:15  box=[530,93,601,220]
#
# 0: 640x288 1 person, 45.5ms
# Speed: 1.7ms preprocess, 45.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.15 ID:19  box=[93,496,203,742]
#   → chair 0.32 ID:1  box=[830,337,980,719]
# video 1/1 (frame 38/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 54.3ms
# Frame 37:
#   → chair 0.67 ID:2  box=[391,316,498,494]
#
# 0: 640x224 1 person, 33.2ms
# Speed: 1.1ms preprocess, 33.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.39 ID:3  box=[193,342,288,637]
#   → chair 0.32 ID:4  box=[945,217,1014,373]
#   → chair 0.36 ID:7  box=[737,231,815,639]
#   → chair 0.53 ID:8  box=[508,250,671,540]
#
# 0: 640x192 1 person, 30.0ms
# Speed: 1.6ms preprocess, 30.0ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.68 ID:5  box=[423,137,498,387]
#   → chair 0.32 ID:13  box=[789,154,870,270]
#
# 0: 640x384 (no detections), 51.3ms
# Speed: 1.3ms preprocess, 51.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[530,92,599,216]
#
# 0: 640x288 1 person, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.21 ID:19  box=[93,496,203,741]
#   → chair 0.26 ID:1  box=[836,340,985,718]
#
# 0: 640x416 (no detections), 55.3ms
# Speed: 1.2ms preprocess, 55.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.44 ID:9  box=[534,143,645,318]
# video 1/1 (frame 39/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 58.9ms
# Frame 38:
#   → chair 0.69 ID:2  box=[393,316,496,488]
#
# 0: 640x224 (no detections), 31.9ms
# Speed: 2.6ms preprocess, 31.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.45 ID:3  box=[192,342,289,640]
#   → chair 0.34 ID:4  box=[947,216,1015,373]
#   → chair 0.30 ID:7  box=[738,231,817,639]
#   → chair 0.64 ID:8  box=[510,250,674,539]
#
# 0: 640x224 1 person, 32.8ms
# Speed: 1.1ms preprocess, 32.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[422,137,498,387]
#   → chair 0.19 ID:13  box=[788,154,868,270]
#
# 0: 640x384 (no detections), 51.6ms
# Speed: 2.2ms preprocess, 51.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.44 ID:15  box=[529,93,601,221]
#
# 0: 640x288 1 person, 46.0ms
# Speed: 2.1ms preprocess, 46.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.21 ID:19  box=[94,496,203,741]
#   → chair 0.29 ID:1  box=[839,340,986,718]
#
# 0: 640x416 (no detections), 59.5ms
# Speed: 2.9ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.44 ID:9  box=[535,145,645,319]
# video 1/1 (frame 40/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 59.7ms
# Frame 39:
#   → chair 0.69 ID:2  box=[394,316,495,483]
#
# 0: 640x224 1 person, 33.8ms
# Speed: 0.9ms preprocess, 33.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.40 ID:3  box=[192,341,289,639]
#   → chair 0.33 ID:4  box=[951,215,1017,373]
#   → chair 0.31 ID:7  box=[739,237,816,642]
#   → chair 0.56 ID:8  box=[509,251,673,540]
#
# 0: 640x224 1 person, 36.7ms
# Speed: 1.6ms preprocess, 36.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:5  box=[422,137,498,387]
#   → chair 0.24 ID:13  box=[787,154,867,271]
#
# 0: 640x384 (no detections), 57.5ms
# Speed: 1.8ms preprocess, 57.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.53 ID:15  box=[529,94,602,223]
#
# 0: 640x288 1 person, 45.5ms
# Speed: 3.2ms preprocess, 45.5ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.15 ID:19  box=[94,496,203,740]
#
# 0: 640x416 1 person, 59.3ms
# Speed: 2.7ms preprocess, 59.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.22 ID:9  box=[537,157,642,319]
# video 1/1 (frame 41/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 53.7ms
# Frame 40:
#   → chair 0.69 ID:2  box=[395,316,495,480]
#
# 0: 640x224 1 person, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.44 ID:3  box=[192,342,288,637]
#   → chair 0.35 ID:4  box=[953,216,1017,373]
#   → chair 0.39 ID:7  box=[738,233,815,639]
#   → chair 0.57 ID:8  box=[509,251,673,539]
#
# 0: 640x224 1 person, 31.3ms
# Speed: 1.7ms preprocess, 31.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[422,137,498,387]
#   → chair 0.42 ID:13  box=[787,154,865,271]
#
# 0: 640x384 (no detections), 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:15  box=[529,93,601,222]
#
# 0: 640x288 1 person, 46.2ms
# Speed: 2.2ms preprocess, 46.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.16 ID:19  box=[94,496,203,739]
#
# 0: 640x416 1 person, 60.8ms
# Speed: 1.4ms preprocess, 60.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.42 ID:9  box=[536,153,642,318]
# video 1/1 (frame 42/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 48.5ms
# Frame 41:
#   → chair 0.71 ID:2  box=[395,317,494,478]
#
# 0: 640x224 1 person, 34.2ms
# Speed: 2.3ms preprocess, 34.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.44 ID:3  box=[192,341,288,638]
#   → chair 0.32 ID:4  box=[953,216,1016,373]
#   → chair 0.41 ID:7  box=[738,231,815,639]
#   → chair 0.46 ID:8  box=[505,250,669,540]
#
# 0: 640x224 1 person, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:5  box=[422,137,498,387]
#   → chair 0.48 ID:13  box=[788,154,865,270]
#
# 0: 640x384 (no detections), 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.39 ID:15  box=[529,94,602,222]
#
# 0: 640x288 1 person, 46.1ms
# Speed: 1.6ms preprocess, 46.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.20 ID:19  box=[94,496,203,740]
#
# 0: 640x416 1 person, 57.3ms
# Speed: 1.8ms preprocess, 57.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.48 ID:9  box=[536,151,643,317]
# video 1/1 (frame 43/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 55.4ms
# Frame 42:
#   → chair 0.70 ID:2  box=[395,317,493,477]
#
# 0: 640x224 1 person, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.37 ID:3  box=[192,341,288,637]
#   → chair 0.41 ID:4  box=[951,216,1013,373]
#   → chair 0.43 ID:7  box=[737,231,815,639]
#   → chair 0.45 ID:8  box=[506,250,670,540]
#
# 0: 640x224 1 person, 31.8ms
# Speed: 1.0ms preprocess, 31.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.68 ID:5  box=[422,137,498,388]
#   → chair 0.49 ID:13  box=[789,154,865,271]
#
# 0: 640x384 (no detections), 48.3ms
# Speed: 3.6ms preprocess, 48.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[529,94,602,222]
#
# 0: 640x288 1 person, 45.2ms
# Speed: 2.4ms preprocess, 45.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.19 ID:19  box=[94,496,203,741]
#
# 0: 640x416 (no detections), 57.4ms
# Speed: 2.5ms preprocess, 57.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 416)
#   → unknown 0.46 ID:9  box=[537,154,642,316]
#   → chair 0.27 ID:1  box=[842,340,988,719]
# video 1/1 (frame 44/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 54.9ms
# Frame 43:
#   → chair 0.68 ID:2  box=[396,317,493,476]
#
# 0: 640x224 1 person, 34.6ms
# Speed: 2.8ms preprocess, 34.6ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.39 ID:3  box=[192,341,288,638]
#   → chair 0.39 ID:4  box=[951,216,1013,373]
#   → chair 0.42 ID:7  box=[737,231,815,639]
#   → chair 0.40 ID:8  box=[508,251,672,540]
#
# 0: 640x224 (no detections), 32.3ms
# Speed: 1.2ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.64 ID:5  box=[422,137,498,388]
#   → chair 0.46 ID:13  box=[789,154,864,270]
#
# 0: 640x384 (no detections), 47.2ms
# Speed: 1.8ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.38 ID:15  box=[529,93,603,224]
#
# 0: 640x288 1 person, 49.9ms
# Speed: 3.0ms preprocess, 49.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.13 ID:19  box=[94,496,203,740]
#
# 0: 640x448 (no detections), 57.3ms
# Speed: 2.8ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.35 ID:9  box=[537,152,644,316]
#   → chair 0.34 ID:1  box=[845,339,988,718]
# video 1/1 (frame 45/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 6 chairs, 59.4ms
# Frame 44:
#   → chair 0.69 ID:2  box=[396,318,493,475]
#
# 0: 640x224 (no detections), 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.33 ID:3  box=[192,341,288,637]
#   → chair 0.42 ID:4  box=[954,216,1015,373]
#   → chair 0.45 ID:7  box=[737,232,814,638]
#   → chair 0.59 ID:8  box=[509,250,674,540]
#
# 0: 640x224 1 person, 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:5  box=[422,137,498,388]
#   → chair 0.46 ID:13  box=[790,154,864,270]
#
# 0: 640x384 (no detections), 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[529,95,603,224]
#
# 0: 640x288 1 person, 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.19 ID:19  box=[94,496,203,740]
#
# 0: 640x416 1 person, 55.6ms
# Speed: 2.7ms preprocess, 55.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 416)
#   → sitting 0.44 ID:9  box=[537,153,643,316]
#   → chair 0.38 ID:1  box=[845,340,987,719]
# video 1/1 (frame 46/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 54.9ms
# Frame 45:
#   → chair 0.62 ID:2  box=[393,318,494,483]
#
# 0: 640x224 1 person, 34.4ms
# Speed: 1.3ms preprocess, 34.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.54 ID:3  box=[192,341,288,637]
#   → chair 0.30 ID:4  box=[948,218,1010,375]
#   → chair 0.30 ID:8  box=[510,252,674,540]
#
# 0: 640x192 (no detections), 31.5ms
# Speed: 0.9ms preprocess, 31.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.68 ID:5  box=[423,138,498,388]
#   → chair 0.14 ID:13  box=[790,154,864,270]
#
# 0: 640x384 (no detections), 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.42 ID:15  box=[528,95,600,220]
#
# 0: 640x288 (no detections), 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.15 ID:19  box=[95,496,203,741]
#
# 0: 640x448 (no detections), 58.0ms
# Speed: 1.3ms preprocess, 58.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.39 ID:9  box=[539,168,639,318]
#   → chair 0.30 ID:1  box=[839,335,982,722]
# video 1/1 (frame 47/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 53.5ms
# Frame 46:
#   → chair 0.62 ID:2  box=[390,319,496,493]
#
# 0: 640x224 1 person, 37.6ms
# Speed: 2.4ms preprocess, 37.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[192,341,288,636]
#   → chair 0.35 ID:4  box=[952,218,1012,374]
#   → chair 0.30 ID:8  box=[508,252,671,541]
#
# 0: 640x192 (no detections), 32.1ms
# Speed: 0.7ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.67 ID:5  box=[423,138,498,388]
#   → chair 0.22 ID:13  box=[791,154,864,270]
#
# 0: 640x384 (no detections), 47.9ms
# Speed: 2.5ms preprocess, 47.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.43 ID:15  box=[528,95,599,220]
#
# 0: 640x288 1 person, 45.6ms
# Speed: 2.8ms preprocess, 45.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.24 ID:19  box=[95,496,203,741]
#
# 0: 640x448 (no detections), 57.3ms
# Speed: 2.3ms preprocess, 57.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.34 ID:9  box=[541,179,634,316]
#   → chair 0.39 ID:1  box=[839,338,980,720]
# video 1/1 (frame 48/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 50.1ms
# Frame 47:
#   → chair 0.59 ID:2  box=[390,319,496,494]
#
# 0: 640x224 2 persons, 33.5ms
# ...
#   → unknown 0.65 ID:3  box=[192,347,286,637]
#   → chair 0.35 ID:8  box=[492,254,674,590]
#
# 0: 640x192 (no detections), 31.3ms
# Speed: 0.9ms preprocess, 31.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.63 ID:5  box=[425,138,499,388]
#
# 0: 640x288 1 person, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.31 ID:19  box=[96,497,203,742]
#
# 0: 640x448 1 person, 60.3ms
# Speed: 3.0ms preprocess, 60.3ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.48 ID:9  box=[533,150,646,318]
#   → chair 0.54 ID:1  box=[836,338,974,720]
#   → chair 0.54 ID:7  box=[740,234,820,645]
# video 1/1 (frame 63/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 4 persons, 5 chairs, 56.3ms
# Frame 62:
#   → chair 0.59 ID:2  box=[394,317,500,499]
#
# 0: 640x224 1 person, 37.5ms
# Speed: 1.9ms preprocess, 37.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:3  box=[192,349,285,631]
#   → chair 0.24 ID:8  box=[497,251,679,604]
#
# 0: 640x192 (no detections), 31.1ms
# Speed: 0.8ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.63 ID:5  box=[425,138,499,388]
#
# 0: 640x288 1 person, 47.7ms
# Speed: 1.0ms preprocess, 47.7ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.31 ID:19  box=[95,497,202,742]
#
# 0: 640x448 (no detections), 57.0ms
# Speed: 1.3ms preprocess, 57.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.45 ID:9  box=[534,152,645,317]
#   → chair 0.58 ID:1  box=[837,338,975,719]
#   → chair 0.51 ID:7  box=[740,234,820,646]
#   → chair 0.27 ID:13  box=[792,154,864,270]
# video 1/1 (frame 64/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 55.4ms
# Frame 63:
#   → chair 0.59 ID:2  box=[394,317,500,499]
#
# 0: 640x224 1 person, 38.4ms
# Speed: 2.0ms preprocess, 38.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:3  box=[193,351,284,624]
#   → chair 0.18 ID:8  box=[495,252,676,609]
#
# 0: 640x192 (no detections), 31.4ms
# Speed: 2.1ms preprocess, 31.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.62 ID:5  box=[424,138,499,389]
#
# 0: 640x288 (no detections), 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.37 ID:19  box=[95,496,202,743]
#
# 0: 640x448 1 person, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.51 ID:9  box=[535,153,645,317]
#   → chair 0.47 ID:1  box=[837,338,975,719]
#   → chair 0.52 ID:7  box=[739,234,820,644]
#   → chair 0.28 ID:13  box=[792,154,864,270]
#
# 0: 640x384 1 person, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.27 ID:15  box=[526,92,603,228]
# video 1/1 (frame 65/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 54.1ms
# Frame 64:
#   → chair 0.62 ID:2  box=[394,316,499,498]
#
# 0: 640x224 1 person, 33.4ms
# Speed: 1.1ms preprocess, 33.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[193,352,284,621]
#   → chair 0.23 ID:8  box=[496,251,673,611]
#
# 0: 640x192 (no detections), 33.8ms
# Speed: 1.1ms preprocess, 33.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.67 ID:5  box=[424,138,499,389]
#
# 0: 640x288 1 person, 46.3ms
# Speed: 2.7ms preprocess, 46.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.31 ID:19  box=[94,496,202,743]
#
# 0: 640x448 1 person, 61.9ms
# Speed: 2.3ms preprocess, 61.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.37 ID:9  box=[534,152,645,318]
#   → chair 0.47 ID:1  box=[837,338,975,720]
#   → chair 0.50 ID:7  box=[739,234,820,644]
#   → chair 0.30 ID:13  box=[791,154,863,271]
#
# 0: 640x384 (no detections), 48.9ms
# Speed: 2.7ms preprocess, 48.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.36 ID:15  box=[527,94,603,228]
# video 1/1 (frame 66/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 6 persons, 5 chairs, 53.7ms
# Frame 65:
#   → chair 0.63 ID:2  box=[394,316,499,496]
#
# 0: 640x224 1 person, 30.7ms
# Speed: 1.7ms preprocess, 30.7ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[193,353,285,624]
#   → chair 0.22 ID:8  box=[499,251,671,612]
#
# 0: 640x224 (no detections), 31.9ms
# Speed: 0.9ms preprocess, 31.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.68 ID:5  box=[423,137,499,389]
#
# 0: 640x288 (no detections), 43.6ms
# Speed: 3.1ms preprocess, 43.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.31 ID:19  box=[94,496,202,743]
#
# 0: 640x448 (no detections), 56.9ms
# Speed: 1.5ms preprocess, 56.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.10 ID:9  box=[533,147,646,317]
#   → chair 0.41 ID:1  box=[836,338,975,720]
#   → chair 0.50 ID:7  box=[739,234,820,643]
#   → chair 0.25 ID:13  box=[792,155,863,270]
#
# 0: 640x384 (no detections), 56.0ms
# Speed: 2.4ms preprocess, 56.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.44 ID:15  box=[529,97,603,228]
#
# 0: 640x640 (no detections), 82.0ms
# Speed: 5.6ms preprocess, 82.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.32 ID:28  box=[538,205,642,314]
# video 1/1 (frame 67/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 6 persons, 5 chairs, 60.1ms
# Frame 66:
#   → chair 0.64 ID:2  box=[394,316,499,495]
#
# 0: 640x224 1 person, 33.9ms
# Speed: 1.3ms preprocess, 33.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[193,353,286,626]
#   → chair 0.20 ID:8  box=[503,251,671,612]
#
# 0: 640x224 (no detections), 27.6ms
# Speed: 1.5ms preprocess, 27.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.69 ID:5  box=[423,137,499,389]
#
# 0: 640x288 (no detections), 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.29 ID:19  box=[94,495,202,743]
#
# 0: 640x448 1 person, 61.7ms
# Speed: 1.8ms preprocess, 61.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
#   → sitting 0.23 ID:9  box=[534,148,646,316]
#   → chair 0.51 ID:1  box=[834,338,973,720]
#   → chair 0.55 ID:7  box=[739,233,820,642]
#   → chair 0.27 ID:13  box=[792,156,862,269]
#
# 0: 640x384 (no detections), 55.1ms
# Speed: 2.8ms preprocess, 55.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.45 ID:15  box=[529,99,603,227]
#
# 0: 640x608 (no detections), 79.2ms
# Speed: 5.8ms preprocess, 79.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.30 ID:28  box=[537,202,644,315]
# video 1/1 (frame 68/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 6 persons, 5 chairs, 54.5ms
# Frame 67:
#   → chair 0.62 ID:2  box=[394,316,499,495]
#
# 0: 640x224 1 person, 36.4ms
# Speed: 1.7ms preprocess, 36.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.34 ID:3  box=[193,354,287,630]
#   → chair 0.13 ID:8  box=[503,250,667,606]
#
# 0: 640x192 (no detections), 35.0ms
# Speed: 1.6ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.69 ID:5  box=[423,137,498,389]
#
# 0: 640x288 (no detections), 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.26 ID:19  box=[94,496,202,743]
#
# 0: 640x448 (no detections), 56.8ms
# Speed: 4.9ms preprocess, 56.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.15 ID:9  box=[534,147,647,316]
#   → chair 0.49 ID:1  box=[835,338,974,720]
#   → chair 0.45 ID:7  box=[738,233,820,641]
#   → chair 0.29 ID:13  box=[792,156,862,269]
#
# 0: 640x384 (no detections), 52.8ms
# Speed: 2.5ms preprocess, 52.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.41 ID:15  box=[528,97,603,227]
#
# 0: 640x608 (no detections), 69.5ms
# Speed: 3.9ms preprocess, 69.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 608)
#   → unknown 0.24 ID:28  box=[538,204,643,315]
# video 1/1 (frame 69/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 55.1ms
# Frame 68:
#   → chair 0.61 ID:2  box=[394,316,499,496]
#
# 0: 640x224 1 person, 33.6ms
# Speed: 1.1ms preprocess, 33.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.48 ID:3  box=[193,354,288,633]
#   → chair 0.15 ID:8  box=[505,251,661,590]
#
# 0: 640x192 (no detections), 37.0ms
# Speed: 3.6ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.62 ID:5  box=[424,138,498,389]
#
# 0: 640x288 1 person, 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.20 ID:19  box=[94,496,202,743]
#   → chair 0.38 ID:1  box=[841,339,979,719]
#   → chair 0.39 ID:7  box=[738,232,819,641]
#   → chair 0.32 ID:13  box=[790,155,861,270]
#
# 0: 640x384 (no detections), 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.22 ID:15  box=[528,94,603,228]
#
# 0: 640x640 (no detections), 78.8ms
# Speed: 3.0ms preprocess, 78.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.16 ID:28  box=[532,195,649,317]
# video 1/1 (frame 70/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 57.9ms
# Frame 69:
#   → chair 0.60 ID:2  box=[394,317,498,494]
#
# 0: 640x224 1 person, 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:3  box=[194,355,289,633]
#   → chair 0.24 ID:8  box=[509,251,666,604]
#
# 0: 640x192 1 person, 33.3ms
# Speed: 0.8ms preprocess, 33.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.65 ID:5  box=[423,137,499,390]
#
# 0: 640x288 (no detections), 42.3ms
# Speed: 1.9ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.25 ID:19  box=[94,496,202,743]
#   → chair 0.53 ID:1  box=[836,339,975,720]
#   → chair 0.47 ID:7  box=[738,232,819,641]
#   → chair 0.36 ID:13  box=[788,154,860,270]
#
# 0: 640x384 (no detections), 53.6ms
# Speed: 2.7ms preprocess, 53.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.29 ID:15  box=[528,93,604,228]
#
# 0: 640x640 (no detections), 79.1ms
# Speed: 4.4ms preprocess, 79.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.16 ID:28  box=[535,201,645,316]
# video 1/1 (frame 71/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 59.8ms
# Frame 70:
#   → chair 0.60 ID:2  box=[394,316,498,494]
#
# 0: 640x224 1 person, 34.2ms
# Speed: 1.9ms preprocess, 34.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:3  box=[193,354,289,633]
#   → chair 0.19 ID:8  box=[508,250,660,591]
#
# 0: 640x192 (no detections), 27.9ms
# Speed: 1.2ms preprocess, 27.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.65 ID:5  box=[424,138,498,389]
#
# 0: 640x288 (no detections), 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.23 ID:19  box=[94,495,202,743]
#   → chair 0.48 ID:1  box=[835,339,974,720]
#   → chair 0.47 ID:7  box=[736,231,816,641]
#   → chair 0.52 ID:13  box=[789,154,860,270]
#
# 0: 640x384 1 person, 53.9ms
# Speed: 2.4ms preprocess, 53.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#   → sitting 0.37 ID:15  box=[528,93,604,228]
#
# 0: 640x640 (no detections), 74.7ms
# Speed: 2.7ms preprocess, 74.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.18 ID:28  box=[539,208,642,315]
# video 1/1 (frame 72/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 53.6ms
# Frame 71:
#   → chair 0.62 ID:2  box=[395,316,497,489]
#
# 0: 640x224 1 person, 35.8ms
# Speed: 3.3ms preprocess, 35.8ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:3  box=[194,354,290,634]
#   → chair 0.27 ID:8  box=[507,250,657,587]
#
# 0: 640x192 1 person, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 192)
#   → sitting 0.66 ID:5  box=[424,138,498,388]
#
# 0: 640x288 (no detections), 42.7ms
# Speed: 2.1ms preprocess, 42.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.25 ID:19  box=[94,495,202,743]
#   → chair 0.47 ID:1  box=[833,339,973,720]
#   → chair 0.58 ID:7  box=[735,232,815,640]
#   → chair 0.41 ID:13  box=[790,154,861,270]
#
# 0: 640x384 (no detections), 54.1ms
# Speed: 3.4ms preprocess, 54.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.45 ID:15  box=[528,93,604,228]
#
# 0: 640x640 (no detections), 77.9ms
# Speed: 3.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#   → unknown 0.11 ID:28  box=[541,212,640,314]
# video 1/1 (frame 73/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 54.1ms
# Frame 72:
#   → chair 0.59 ID:2  box=[395,316,497,488]
#
# 0: 640x224 1 person, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.48 ID:3  box=[193,354,290,636]
#   → chair 0.31 ID:8  box=[507,250,655,582]
#
# 0: 640x192 (no detections), 31.7ms
# Speed: 2.2ms preprocess, 31.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.62 ID:5  box=[423,138,498,389]
#
# 0: 640x288 (no detections), 44.3ms
# Speed: 2.2ms preprocess, 44.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 288)
#   → unknown 0.19 ID:19  box=[94,495,202,743]
#   → chair 0.38 ID:1  box=[835,339,974,720]
#   → chair 0.55 ID:7  box=[735,232,814,640]
#   → chair 0.34 ID:13  box=[778,154,852,271]
#
# 0: 640x384 (no detections), 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.20 ID:15  box=[528,92,603,225]
#
# 0: 640x448 (no detections), 58.3ms
# Speed: 2.4ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.34 ID:9  box=[535,151,646,317]
# video 1/1 (frame 74/16425) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video1.mp4: 640x448 5 persons, 5 chairs, 53.0ms
# Frame 73:
#   → chair 0.61 ID:2  box=[395,316,496,486]
#
# 0: 640x224 1 person, 29.1ms
# Speed: 1.9ms preprocess, 29.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.43 ID:3  box=[193,355,290,636]
#   → chair 0.35 ID:8  box=[514,252,651,556]
#
# 0: 640x192 (no detections), 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 192)
#   → unknown 0.65 ID:5  box=[423,137,498,389]
#
# 0: 640x288 1 person, 45.4ms
# Speed: 2.5ms preprocess, 45.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 288)
#   → sitting 0.27 ID:19  box=[94,496,202,743]
#   → chair 0.41 ID:1  box=[833,339,974,720]
#   → chair 0.52 ID:7  box=[735,232,813,639]
#   → chair 0.37 ID:13  box=[773,153,850,271]
#
# 0: 640x384 (no detections), 56.6ms
# Speed: 2.3ms preprocess, 56.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#   → unknown 0.22 ID:15  box=[529,94,602,222]
#
# 0: 640x448 (no detections), 57.4ms
# Speed: 3.4ms preprocess, 57.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
#   → unknown 0.51 ID:9  box=[534,151,645,318]
