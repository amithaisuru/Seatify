# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (8.3.168)
# Requirement already satisfied: opencv-python in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (4.12.0.88)
# Requirement already satisfied: numpy>=1.23.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: pillow>=7.1.2 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (0.22.1)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: filelock in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.13.1)
# Requirement already satisfied: setuptools in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sadeepa/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import time

# %%
# Load the YOLOv8 model
model = YOLO('yolov8x.pt').to('cuda:0')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x.pt to 'yolov8x.pt'...
# WARNING ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x.pt...
# ######################################################################## 100.0%
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load the YOLOv8 model
# ----> 2 model = YOLO('yolov8x.pt').to('cuda:0')  # You can choose different versions (e.g., yolov8s.pt, yolov8m.pt) depending on your needs
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1355, in Module.to(self, *args, **kwargs)
#    1352         else:
#    1353             raise
# -> 1355 return self._apply(convert)
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/ultralytics/engine/model.py:879, in Model._apply(self, fn)
#     857 """
#     858 Apply a function to model tensors that are not parameters or registered buffers.
#     859
#    (...)    876     >>> model = model._apply(lambda t: t.cuda())  # Move model to GPU
#     877 """
#     878 self._check_is_pytorch_model()
# --> 879 self = super()._apply(fn)  # noqa
#     880 self.predictor = None  # reset predictor as device may have changed
#     881 self.overrides["device"] = self.device  # was str(self.device) i.e. device(type='cuda', index=0) -> 'cuda:0'
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/ultralytics/nn/tasks.py:292, in BaseModel._apply(self, fn)
#     282 def _apply(self, fn):
#     283     """
#     284     Apply a function to all tensors in the model that are not parameters or registered buffers.
#     285
#    (...)    290         (BaseModel): An updated BaseModel object.
#     291     """
# --> 292     self = super()._apply(fn)
#     293     m = self.model[-1]  # Detect()
#     294     if isinstance(
#     295         m, Detect
#     296     ):  # includes all Detect subclasses like Segment, Pose, OBB, WorldDetect, YOLOEDetect, YOLOESegment
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:915, in Module._apply(self, fn, recurse)
#     913 if recurse:
#     914     for module in self.children():
# --> 915         module._apply(fn)
#     917 def compute_should_use_set_data(tensor, tensor_applied):
#     918     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     919         # If the new tensor has compatible tensor type as the existing tensor,
#     920         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)    925         # global flag to let the user control whether they want the future
#     926         # behavior of overwriting the existing tensor or not.
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:942, in Module._apply(self, fn, recurse)
#     938 # Tensors stored in modules are graph leaves, and we don't want to
#     939 # track autograd history of `param_applied`, so we have to use
#     940 # `with torch.no_grad():`
#     941 with torch.no_grad():
# --> 942     param_applied = fn(param)
#     943 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     945 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1341, in Module.to.<locals>.convert(t)
#    1334     if convert_to_format is not None and t.dim() in (4, 5):
#    1335         return t.to(
#    1336             device,
#    1337             dtype if t.is_floating_point() or t.is_complex() else None,
#    1338             non_blocking,
#    1339             memory_format=convert_to_format,
#    1340         )
# -> 1341     return t.to(
#    1342         device,
#    1343         dtype if t.is_floating_point() or t.is_complex() else None,
#    1344         non_blocking,
#    1345     )
#    1346 except NotImplementedError as e:
#    1347     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File ~/Desktop/Self Study/Seatify/venv/lib/python3.13/site-packages/torch/cuda/__init__.py:363, in _lazy_init()
#     358     raise RuntimeError(
#     359         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     360         "multiprocessing, you must use the 'spawn' start method"
#     361     )
#     362 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 363     raise AssertionError("Torch not compiled with CUDA enabled")
#     364 if _cudart is None:
#     365     raise AssertionError(
#     366         "libcudart functions unavailable. It looks like you have a broken build?"
#     367     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
# --------Human & Object detection in video - correctly working--------

'''

# Initialize video capture
cap = cv2.VideoCapture(r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video6.mp4')

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    while cap.isOpened():
        print("Reading frame...")
        ret, frame = cap.read()

        # Perform detection on the current frame
        results = model(frame)  # Detect objects in the frame

        # Filter detections for 'person' and 'chair' classes
        # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
        person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

        # Process the results
        for result in results:

            boxes = result.boxes  # Get bounding boxes

            for box in boxes:
                class_id = box.cls[0].item()  # Get the class id of the detected object
                if class_id in person_and_chair:  # Check if it is a person or a chair
                    # Get the bounding box coordinates
                    x1, y1, x2, y2 = map(int, box.xyxy[0])

                    # Get the class ID and confidence score
                    class_id = box.cls[0].item()
                    confidence = box.conf[0].item()

                    # Get the class name
                    label = model.names[class_id]

                    # Print out the detected object details
                    print(
                        f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                    )
                    print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                    # Draw a bounding box around the object

                    # Define different colors for different objects
                    if label == "person":
                        color = (255, 0, 0)  # Blue color for human (person)
                    elif label == "chair":
                        color = (0, 0, 255)  # Red color for chair
                    else:
                        color = (0, 255, 0)  # Default green for other objects

                    # Draw a bounding box around the object with the selected color
                    cv2.rectangle(
                        frame, (x1, y1), (x2, y2), color, 2
                    )  # Bounding box with the chosen color

                    cv2.putText(
                        frame,
                        label,
                        (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX,
                        0.9,
                        (0, 255, 0),
                        2,
                    )

        if frame is not None and frame.size > 0:
            cv2.imshow("Video", frame)
        else:
            print("Warning: Empty frame encountered!")
            break

        # Press 'q' to quit the video window
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''

# %%
# -----Tried to skip frames and process frames after every 10 seconds. Did not worked-----


'''

# Initialize video capture
cap = cv2.VideoCapture(
    r"D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4"
)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Couldn't open the video file.")
else:
    print("Video file opened successfully.")

    # Get the frame rate (fps) of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Video Frame Rate (FPS): {fps}")

    # Time between frames we want to process (10 seconds)
    interval = 2  # Process every 10 seconds

    # Calculate the frame number corresponding to the desired times
    frame_number = 0
    prev_time = 0  # Start at time 0

    while cap.isOpened():
        # Calculate the time for the current frame (in seconds)
        current_time = frame_number / fps

        # If the current frame time is at the desired interval (0s, 10s, 20s, ...)
        if current_time >= prev_time:

            print("Reading frame...")
            # Read a frame from the video
            ret, frame = cap.read()

            # Check if the frame was read properly
            if not ret:
                print("Error: Couldn't read the frame.")
                break

            # Perform detection on the current frame
            results = model(frame)  # Detect objects in the frame

            # Filter detections for 'person' and 'chair' classes
            # 'person' has class ID 0 and 'chair' has class ID 56 in the COCO dataset
            person_and_chair = [0, 56]  # person (0) and chair (56) class IDs

            # Process the results
            for result in results:
                # Extract bounding boxes, confidence, and class IDs
                boxes = result.boxes  # Get bounding boxes

                for box in boxes:
                    class_id = box.cls[0].item()  # Get the class id of the detected object

                    if (class_id in person_and_chair):  # Check if it is a person or a chair
                        # Get the bounding box coordinates
                        x1, y1, x2, y2 = map(int, box.xyxy[0])

                        # Get the class ID and confidence score
                        class_id = box.cls[0].item()
                        confidence = box.conf[0].item()

                        # Get the class name
                        label = model.names[class_id]

                        # Print out the detected object details
                        print(
                            f"\nDetected {label} (Class ID: {class_id}) with confidence {confidence:.2f}"
                        )
                        print(f"Bounding box coordinates: [{x1}, {y1}, {x2}, {y2}]")

                        # Draw a bounding box around the object

                        # Define different colors for different objects
                        if label == "person":
                            color = (255, 0, 0)  # Blue color for human (person)
                        elif label == "chair":
                            color = (0, 0, 255)  # Red color for chair
                        else:
                            color = (0, 255, 0)  # Default green for other objects

                        # Draw a bounding box around the object with the selected color
                        cv2.rectangle(
                            frame, (x1, y1), (x2, y2), color, 2
                        )  # Bounding box with the chosen color

                        cv2.putText(
                            frame,
                            label,
                            (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            0.9,
                            (0, 255, 0),
                            2,
                        )

                if frame is not None and frame.size > 0:
                    cv2.imshow("Video", frame)
                else:
                    print("Warning: Empty frame encountered!")
                    break

                # Press 'q' to quit the video window
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break

                # Update prev_time to the next desired frame time (e.g., t = 10s, 20s)
                prev_time += interval  # Move to the next interval (10 seconds)

            # Skip frames until we reach the desired frame time
            frame_number += 1
        
    
    # Release the video capture object and close all windows
    cap.release()
    cv2.destroyAllWindows()

'''

# %%
import torch
print("CUDA available? ", torch.cuda.is_available())
print("GPU count:    ", torch.cuda.device_count())
print("Current dev:  ", torch.cuda.current_device())
print("Dev name:     ", torch.cuda.get_device_name(0))
# Out:
# CUDA available?  True
# GPU count:     1
# Current dev:   0
# Dev name:      NVIDIA GeForce GTX 1660 Ti

# %%
# ----- Human & Chair detection and tracking - correctly working -----

'''
# 3. Run detection + ByteTrack on your video
#    – source: your file path
#    – tracker: "bytetrack.yaml" (config shipped with ultralytics)
#    – classes: [0,56] → only person (0) & chair (56)
#    – persist: keep track IDs alive across frames
#    – show: pop up each frame (set False if headless)
#    – save: write out an annotated video to runs/track/exp*
stream = model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\video5.mp4',
    tracker='bytetrack.yaml',
    classes=[0, 56],
    persist=True,
    show=False,    # we’ll show manually
    save=True,    # disable automatic save
    save_dir='my_outputs/',
    stream=True,   # <— Enable streaming!
    device='cuda:0'
)

for frame_idx, res in enumerate(stream):
    print(f"Frame {frame_idx}:")
    # res.boxes is a Boxes object, with attributes .xyxy, .conf, .cls, .id
    for xyxy, conf, cls_id, track_id in zip(
        res.boxes.xyxy, 
        res.boxes.conf, 
        res.boxes.cls, 
        res.boxes.id
    ):
        x1, y1, x2, y2 = map(int, xyxy.tolist())
        conf = float(conf)
        cls_id = int(cls_id)
        track_id = int(track_id)
        label = res.names[cls_id]  # e.g. "person" or "chair"
        print(f"  → {label:6s}  conf={conf:.2f}  box=[{x1},{y1},{x2},{y2}]  track_id={track_id}")

    # Optional: display the annotated frame and quit on 'q'
    frame = res.plot()
    cv2.imshow("Track (press q to quit)", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

'''

# %%
import cv2
import numpy as np
import os

# Create an output folder for annotated frames
# output_dir = 'annotated_frames/HOTWOK-1-A'
# os.makedirs(output_dir, exist_ok=True)

from ultralytics import YOLO

# Load models onto GPU
det_model  = YOLO('yolov8x.pt').to('cuda:0')
pose_model = YOLO('yolov8x-pose.pt').to('cuda:0')

def calculate_angle(a, b, c):
    #Builds vectors ba and bc around joint b.
    ba = a - b
    bc = c - b
    
    #Uses the dot-product formula to get the cosine of angle abc
    cosang = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-6)

    #clip to valid range and convert from radians to degrees
    return np.degrees(np.arccos(np.clip(cosang, -1.0, 1.0)))

# compute knee angle
def kneeAngleCondition(kpts):
    try:
        # compute left & right knee angles
        l_ang = calculate_angle(kpts[11,:2], kpts[13,:2], kpts[15,:2]) #computes left knee angles
        r_ang = calculate_angle(kpts[12,:2], kpts[14,:2], kpts[16,:2]) #computes right knee angles
        # compute average angle
        knee_angle = (l_ang + r_ang) / 2

        # Threshold to decide sitting vs standing
        if knee_angle < 110:
            return True
        else:
            return False
    except:
        pass  

#Compute torso lean: angle at the hip by shoulder→hip→knee
def torsoAngleCondition(kpts):
    try:
        left_torso  = calculate_angle(kpts[5,:2],  kpts[11,:2], kpts[13,:2])  # L-shoulder, L-hip, L-knee
        right_torso = calculate_angle(kpts[6,:2],  kpts[12,:2], kpts[14,:2])  # R-shoulder, R-hip, R-knee
        torso_angle = (left_torso + right_torso) / 2

        # Threshold to decide sitting vs standing
        if torso_angle < 110:
            return True
        else:
            return False

    except:
        pass  

#Hip‐knee level test: True if avg vertical distance between hip & knee is < 15% of crop height
def hipKneeLevelCondition(kpts, crop_height):
    try:
        dy_left  = abs(kpts[11,1] - kpts[13,1])
        dy_right = abs(kpts[12,1] - kpts[14,1])
        avg_dy   = (dy_left + dy_right) / 2

        return (avg_dy / crop_height) < 0.15
    except:
        return False

# IoU helper
def bbox_iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1b, y1b, x2b, y2b = box2
    xi1, yi1 = max(x1, x1b), max(y1, y1b)
    xi2, yi2 = min(x2, x2b), min(y2, y2b)
    inter_w = max(0, xi2 - xi1)
    inter_h = max(0, yi2 - yi1)
    inter = inter_w * inter_h
    area1 = (x2 - x1) * (y2 - y1)
    area2 = (x2b - x1b) * (y2b - y1b)
    union = area1 + area2 - inter
    return inter / union if union > 0 else 0

IOU_THRESHOLD = 0.2

## ------------------Save Annotated Video------------------

# 5) Prepare VideoWriter
'''
input_path = r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-Cam1 - 1.mp4'
cap = cv2.VideoCapture(input_path)
fps    = cap.get(cv2.CAP_PROP_FPS)
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
output_path = 'outputs/annotated_HOTWOK_Cam1_OR.mp4'
os.makedirs(os.path.dirname(output_path), exist_ok=True)
writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

'''
# ---end of save annotated video code---

# Start the detection + track stream
stream = det_model.track(
    source=r'D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4',
    tracker='bytetrack.yaml',
    classes=[0,56],
    persist=True,
    show=False,
    save=True,
    save_dir='outputs/',
    stream=True,
    device='cuda:0'
)

#process frames
for frameIndex, singleFrame in enumerate(stream): #enumerate(stream) gives (frame_idx, res) as soon as each frame is done
    frame = singleFrame.orig_img.copy() # copy of raw frame we annotate
    print(f"Frame {frameIndex}:")

    # Pull detections
    # Unpack the tracked detections in parallel arrays
    boxesXYXYs = singleFrame.boxes.xyxy.cpu().numpy() # bounding boxes (n×4)
    confs     = singleFrame.boxes.conf.cpu().numpy() # confidence scores (n) 
    cls_ids   = singleFrame.boxes.cls.cpu().numpy().astype(int) # class IDs (n)
    track_ids = singleFrame.boxes.id.cpu().numpy().astype(int) # track IDs (n)

    # Build a list of chairs this frame
    chair_boxes = []
    for (x1,y1,x2,y2), cls_id in zip(boxesXYXYs, cls_ids):
        if singleFrame.names[cls_id] == 'chair':
            chairBoundingBox = list(map(int, (x1,y1,x2,y2)))
            chair_boxes.append(chairBoundingBox)
        
    # print(f"  → Found {len(chair_boxes)} chairs in this frame")
    # print(f"  → Found {len(boxesXYXYs)} total detections in this frame")

    #Iterate through each detection in this frame
    for (x1, y1, x2, y2), conf, cls_id, track_id in zip(boxesXYXYs, confs, cls_ids, track_ids): #Zips the four arrays so you handle each detection in lockstep.
        
        #Converts the box coords to integers
        x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))

        #looks up the human-readable class name
        label = singleFrame.names[cls_id] # e.g. "person" or "chair"

        # Person branch
        if label == 'person':

            # Defaults the posture to “unknown” with a yellow box
            posture, color = 'unknown', (0,255,255)

            # Crops the detected person region and runs pose_model on that ROI
            roi = frame[y1:y2, x1:x2]
            p = pose_model(roi, device='cuda:0')[0]


            # If keypoints were found, extracts the raw (n,17,3) array from p.keypoints.data.
            # In the shape tuple (n, 17, 3), that leading n is simply the number of person instances (i.e. detections) 
            # that the pose model found in your cropped image
            # Since you’re cropping around a single detected box, in most cases n will be 1
            if p.keypoints is not None:
                # Extract the raw (n,17,3) tensor of keypoints
                kpts_np = p.keypoints.data.cpu().numpy()  # shape (n,17,3)

                # Ensure we have at least 17 keypoints
                if kpts_np.ndim == 3 and kpts_np.shape[1] >= 17:
                    kpts = kpts_np[0]  # first person
                    # shape (17,3): [x,y,conf] per joint

                    # Compute the knee angle
                    kneeAngleResult = kneeAngleCondition(kpts)

                    # Compute the torso angle
                    torsoAngleResult = torsoAngleCondition(kpts)

                    # Compute the hip-knee level condition
                    hipKneeLevelResult = hipKneeLevelCondition(kpts, crop_height=(y2-y1))
                    
                    # 4th test: does this person overlap any chair?
                    iouSittingResult = any(
                        bbox_iou([x1,y1,x2,y2], cb) > IOU_THRESHOLD
                        for cb in chair_boxes
                    )
                    
                    if kneeAngleResult or torsoAngleResult:
                        posture, color = 'sitting',  (0,255,0)
                    else:
                        posture, color = 'standing', (0,0,255)
                    
            text = f"{posture} {conf:.2f} ID:{track_id}"

        else:
            # chair
            color = (255,0,0)
            text  = f"chair {conf:.2f} ID:{track_id}"

        # Draw & print
        cv2.rectangle(frame, (x1,y1), (x2,y2), color, 2)
        cv2.putText(frame, text, (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        print(f"  → {text}  box=[{x1},{y1},{x2},{y2}]")

    # write and optionally display
    #writer.write(frame)

    # save annotated frames
    # out_path = os.path.join(output_dir, f"frame_{frameIndex:06d}.jpg")
    # cv2.imwrite(out_path, frame)

    cv2.imshow("Pose+Track", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# <>:89: SyntaxWarning: invalid escape sequence '\s'
# <>:89: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Sadeepa Ranasinghe\AppData\Local\Temp\ipykernel_18480\3435064810.py:89: SyntaxWarning: invalid escape sequence '\s'
#   '''
# video 1/1 (frame 1/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 72.2ms
# Frame 0:
#   → chair 0.66 ID:1  box=[393,321,498,492]
#
# 0: 640x224 1 person, 43.7ms
# Speed: 2.7ms preprocess, 43.7ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:2  box=[422,143,500,389]
#
# 0: 640x224 (no detections), 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.54 ID:3  box=[195,343,291,633]
#   → chair 0.40 ID:4  box=[967,217,1011,378]
#   → chair 0.28 ID:5  box=[944,222,1012,378]
# video 1/1 (frame 2/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 49.0ms
# Frame 1:
#   → chair 0.65 ID:1  box=[393,321,498,493]
#
# 0: 640x224 1 person, 30.3ms
# Speed: 1.3ms preprocess, 30.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.69 ID:2  box=[423,143,501,389]
#
# 0: 640x224 (no detections), 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.59 ID:3  box=[194,343,292,638]
#   → chair 0.44 ID:4  box=[967,217,1011,376]
#   → chair 0.27 ID:5  box=[946,221,1014,378]
# video 1/1 (frame 3/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 59.1ms
# Frame 2:
#   → chair 0.61 ID:1  box=[392,321,498,494]
#
# 0: 640x224 1 person, 31.1ms
# Speed: 1.5ms preprocess, 31.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.62 ID:2  box=[423,143,501,389]
#
# 0: 640x224 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.57 ID:3  box=[193,343,293,645]
#   → chair 0.39 ID:4  box=[967,216,1011,375]
#   → chair 0.22 ID:5  box=[946,221,1013,378]
# video 1/1 (frame 4/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 52.7ms
# Frame 3:
#   → chair 0.62 ID:1  box=[392,321,498,494]
#
# 0: 640x224 1 person, 30.9ms
# Speed: 1.1ms preprocess, 30.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[423,143,501,389]
#
# 0: 640x224 (no detections), 31.9ms
# Speed: 1.5ms preprocess, 31.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.54 ID:3  box=[191,343,292,648]
#   → chair 0.37 ID:4  box=[967,217,1011,376]
#   → chair 0.17 ID:5  box=[946,223,1013,377]
# video 1/1 (frame 5/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 51.3ms
# Frame 4:
#   → chair 0.61 ID:1  box=[392,321,498,495]
#
# 0: 640x224 1 person, 31.1ms
# Speed: 3.7ms preprocess, 31.1ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.60 ID:2  box=[422,143,500,389]
#
# 0: 640x224 1 person, 31.7ms
# Speed: 1.2ms preprocess, 31.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.50 ID:3  box=[191,342,292,649]
#   → chair 0.36 ID:4  box=[967,217,1011,376]
#   → chair 0.15 ID:5  box=[946,223,1012,377]
# video 1/1 (frame 6/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 3 chairs, 53.4ms
# Frame 5:
#   → chair 0.65 ID:1  box=[392,321,498,494]
#
# 0: 640x224 1 person, 28.2ms
# Speed: 1.1ms preprocess, 28.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[422,143,500,390]
#
# 0: 640x224 1 person, 28.2ms
# Speed: 1.5ms preprocess, 28.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.59 ID:3  box=[190,342,292,653]
#   → chair 0.34 ID:4  box=[967,217,1011,375]
#   → chair 0.14 ID:5  box=[946,224,1012,377]
# video 1/1 (frame 7/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 44.7ms
# Frame 6:
#   → chair 0.64 ID:1  box=[392,321,499,495]
#
# 0: 640x224 1 person, 27.7ms
# Speed: 1.0ms preprocess, 27.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[422,143,500,390]
#
# 0: 640x224 1 person, 28.3ms
# Speed: 1.0ms preprocess, 28.3ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.58 ID:3  box=[191,342,292,654]
#   → chair 0.29 ID:4  box=[967,217,1011,375]
#   → chair 0.12 ID:5  box=[944,224,1010,375]
#   → chair 0.33 ID:7  box=[511,261,662,543]
# video 1/1 (frame 8/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 46.2ms
# Frame 7:
#   → chair 0.66 ID:1  box=[392,321,499,496]
#
# 0: 640x224 1 person, 27.7ms
# Speed: 1.6ms preprocess, 27.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.67 ID:2  box=[422,142,500,390]
#
# 0: 640x224 (no detections), 27.4ms
# Speed: 1.2ms preprocess, 27.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.61 ID:3  box=[191,342,293,656]
#   → chair 0.31 ID:4  box=[967,217,1011,375]
#   → chair 0.11 ID:5  box=[944,224,1009,374]
#   → chair 0.46 ID:7  box=[510,256,664,545]
# video 1/1 (frame 9/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 44.2ms
# Frame 8:
#   → chair 0.67 ID:1  box=[392,321,499,495]
#
# 0: 640x224 1 person, 30.4ms
# Speed: 2.4ms preprocess, 30.4ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.66 ID:2  box=[422,142,500,389]
#
# 0: 640x224 (no detections), 30.1ms
# Speed: 1.8ms preprocess, 30.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.58 ID:3  box=[192,342,293,655]
#   → chair 0.30 ID:4  box=[967,217,1011,375]
#   → chair 0.10 ID:5  box=[944,224,1009,373]
#   → chair 0.55 ID:7  box=[512,255,667,545]
# video 1/1 (frame 10/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 2 persons, 4 chairs, 49.9ms
# Frame 9:
#   → chair 0.67 ID:1  box=[392,321,498,495]
#
# 0: 640x224 1 person, 27.4ms
# Speed: 1.2ms preprocess, 27.4ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:2  box=[422,142,500,389]
#
# 0: 640x224 (no detections), 28.1ms
# Speed: 1.3ms preprocess, 28.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 224)
#   → unknown 0.59 ID:3  box=[192,342,293,655]
#   → chair 0.32 ID:4  box=[967,217,1011,375]
#   → chair 0.12 ID:5  box=[945,223,1011,375]
#   → chair 0.58 ID:7  box=[513,256,667,545]
# video 1/1 (frame 11/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 44.0ms
# Frame 10:
#   → chair 0.68 ID:1  box=[392,321,499,495]
#
# 0: 640x224 1 person, 28.4ms
# Speed: 2.1ms preprocess, 28.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,142,500,390]
#
# 0: 640x224 1 person, 28.9ms
# Speed: 2.1ms preprocess, 28.9ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.53 ID:3  box=[194,342,292,650]
#   → chair 0.30 ID:4  box=[966,217,1011,374]
#   → chair 0.55 ID:7  box=[513,256,667,544]
#
# 0: 640x480 1 person, 58.5ms
# Speed: 2.4ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.42 ID:9  box=[537,174,641,319]
#   → chair 0.45 ID:10  box=[822,342,977,723]
# video 1/1 (frame 12/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 44.6ms
# Frame 11:
#   → chair 0.67 ID:1  box=[392,321,499,496]
#
# 0: 640x224 1 person, 29.6ms
# Speed: 1.1ms preprocess, 29.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.64 ID:2  box=[422,142,500,390]
#
# 0: 640x224 1 person, 28.3ms
# Speed: 1.1ms preprocess, 28.3ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.53 ID:3  box=[194,342,292,649]
#   → chair 0.36 ID:4  box=[966,217,1011,375]
#   → chair 0.60 ID:7  box=[514,256,668,544]
#
# 0: 640x480 1 person, 52.1ms
# Speed: 2.3ms preprocess, 52.1ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.38 ID:9  box=[539,179,638,319]
#   → chair 0.47 ID:10  box=[822,342,977,723]
# video 1/1 (frame 13/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 51.6ms
# Frame 12:
#   → chair 0.68 ID:1  box=[392,321,499,497]
#
# 0: 640x224 1 person, 33.4ms
# Speed: 1.7ms preprocess, 33.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[422,142,500,390]
#
# 0: 640x224 1 person, 30.7ms
# Speed: 1.4ms preprocess, 30.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.55 ID:3  box=[195,343,292,648]
#   → chair 0.35 ID:4  box=[966,217,1011,375]
#   → chair 0.58 ID:7  box=[513,255,669,543]
#
# 0: 640x480 1 person, 61.1ms
# Speed: 2.2ms preprocess, 61.1ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.35 ID:9  box=[541,189,635,319]
#   → chair 0.48 ID:10  box=[823,342,978,723]
# video 1/1 (frame 14/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 50.8ms
# Frame 13:
#   → chair 0.65 ID:1  box=[392,321,499,497]
#
# 0: 640x224 1 person, 29.7ms
# Speed: 3.3ms preprocess, 29.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[423,142,501,389]
#
# 0: 640x224 1 person, 28.5ms
# Speed: 1.2ms preprocess, 28.5ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.49 ID:3  box=[195,342,292,648]
#   → chair 0.28 ID:4  box=[966,217,1011,375]
#   → chair 0.53 ID:7  box=[514,255,670,543]
#
# 0: 640x480 1 person, 49.7ms
# Speed: 1.6ms preprocess, 49.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.25 ID:9  box=[539,181,639,320]
#   → chair 0.44 ID:10  box=[822,342,978,723]
# video 1/1 (frame 15/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 48.5ms
# Frame 14:
#   → chair 0.70 ID:1  box=[393,321,497,493]
#
# 0: 640x224 2 persons, 29.9ms
# Speed: 1.2ms preprocess, 29.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.65 ID:2  box=[423,142,501,389]
#
# 0: 640x224 1 person, 28.3ms
# Speed: 1.6ms preprocess, 28.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.56 ID:3  box=[196,342,291,642]
#   → chair 0.39 ID:4  box=[965,218,1010,375]
#   → chair 0.42 ID:7  box=[513,257,670,543]
#
# 0: 640x480 1 person, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#   → sitting 0.28 ID:9  box=[537,181,638,321]
#   → chair 0.28 ID:10  box=[823,342,977,722]
# video 1/1 (frame 16/3608) D:\self study\0 - FYP\Seatify\server\objectDetection\assets\HOTWOK-1-A.mp4: 640x448 3 persons, 4 chairs, 47.8ms
# Frame 15:
#   → chair 0.70 ID:1  box=[393,321,497,491]
#
# 0: 640x224 2 persons, 29.3ms
# Speed: 1.3ms preprocess, 29.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.63 ID:2  box=[423,142,501,389]
#
# 0: 640x224 1 person, 28.3ms
# Speed: 1.8ms preprocess, 28.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 224)
#   → sitting 0.51 ID:3  box=[195,342,290,642]
#   → chair 0.39 ID:4  box=[965,219,1010,375]
#   → chair 0.43 ID:7  box=[513,258,670,543]
#
# 0: 640x480 (no detections), 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#   → unknown 0.25 ID:9  box=[536,177,639,321]
#   → chair 0.26 ID:10  box=[822,342,977,722]
